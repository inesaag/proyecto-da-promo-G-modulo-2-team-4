# %%
import pandas as pd

import requests

pd.set_option('display.max_columns', None)

# %%
#creamos una funcion para sacar una url dinámica con todas la páginas

def url_dinamica (genero, anio, tipo, clave):

    lista_json = []
    
    for pag in range (1,51):

        url = "https://moviesdatabase.p.rapidapi.com/titles"
        querystring = {"genre":genero,"titleType":tipo,"year":anio,"page":pag}
        headers = {
        "X-RapidAPI-Key": clave,
        "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"}

        response = requests.get(url, headers=headers, params=querystring)

        response_json = response.json()

        lista_json.append (response_json)
       

    return lista_json

# %% [markdown]
# MOVIE

# %%
#HECHO 9:55
#creamos un bucle para sacar jsons de varios años llamando a la función anterior, como hay límite sacaremos en esta ronda del 2010 al 2023
lista_json_anios = []

for anio in range(2010,2024):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Drama", anio, "movie","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios.append(url2)

# %%
#HECHO 11:29

#repetimos lo que hemos hecho en la celda anterior para sacar los datos del 2000 al 2009
lista_json_anios1 = []

for anio in range(2000,2010):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Drama", anio, "movie","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios1.append(url2)

# %% [markdown]
# SHORT

# %%
#HECHO 12:30

#creamos un bucle para sacar jsons de varios años llamando a la función anterior, como hay límite sacaremos en esta ronda del 2010 al 2023
lista_json_anios2 = []

for anio in range(2010,2024):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Drama", anio, "short","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios2.append(url2)

# %%
#HECHO 13:48

#repetimos lo que hemos hecho en la celda anterior para sacar los datos del 2000 al 2009
lista_json_anios3 = []

for anio in range(2000,2010):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Drama", anio, "short","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios3.append(url2)

# %%
#comprobamos que las últimas páginas tienen datos
lista_json_anios[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=movie&page=2&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58cf595801a78bc4406db',
#     'id': 'tt10298848',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bambi', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bambi', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e58d3f78c012aa34441653',
#     'id': 'tt10351180',
#     'primaryImage': {'id': 'rm2857219841',
#      'width': 960,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjcyMDE3YTgtZDQ3Ni00NWRiLWE2NTctZDU4MjE2MzU5YTgyXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Amrin Qureshi and Namashi Chakraborthy in Bad Boy (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bad Boy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bad Boy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58db495801a78bc4436ed',
#     'id': 'tt10425998',
#     'primaryImage': {'id': 'rm223189249',
#      'width': 1728,
#      'height': 2304,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTBlYzE4MTgtZGVmNy00NjUyLWFmYWItZTJlMzA2ODBiNjJhXkEyXkFqcGdeQXVyNDgwNjAyMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Valerie Michelson in The Place in Between (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Place in Between', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Place in Between',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58e6b8a5a6a599f4461c3',
#     'id': 'tt10545296',
#     'primaryImage': {'id': 'rm770462209',
#      'width': 1728,
#      'height': 2664,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTZmMmY2MzctMjU2Yy00YjJlLTk1NjAtY2U4MmMxOWZkZWY4XkEyXkFqcGdeQXVyMjM4NTM5NDY@._V1_.jpg',
#      'caption': {'plainText': 'Jason Schwartzman, Viola Davis, Peter Dinklage, Rachel Zegler, Josh Andrés Rivera, Tom Blyth, and Hunter Schafer in The Hunger Games: The Ballad of Songbirds & Snakes (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Hunger Games: The Ballad of Songbirds & Snakes',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Hunger Games: The Ballad of Songbirds & Snakes',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58e71d8f3c0931e44615b',
#     'id': 'tt10548482',
#     'primaryImage': {'id': 'rm1798413825',
#      'width': 1920,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGE4OGY1OTEtMzM2Yi00MjM5LTg2YmItZGM5YWQ4Y2ZiOTIwXkEyXkFqcGdeQXVyMTA0NzgxOTU4._V1_.jpg',
#      'caption': {'plainText': 'Raw Power (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Raw Power', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Raw Power', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fbf95801a78bc44b441',
#     'id': 'tt10767052',
#     'primaryImage': {'id': 'rm245586945',
#      'width': 1334,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDIwNWQwYTktZGQwYS00NzNjLThhNDMtODBlYmI5N2E0NjM0XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Next Goal Wins (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Next Goal Wins', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Next Goal Wins', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2024,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59039d735dff3f944d0ef',
#     'id': 'tt10849046',
#     'primaryImage': {'id': 'rm843485441',
#      'width': 2400,
#      'height': 3600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzkwNDdhYWEtMWZjOC00MWQ0LThkMWYtNjZjMDRlNWExMGE3XkEyXkFqcGdeQXVyNjA2NjMxNDg@._V1_.jpg',
#      'caption': {'plainText': 'Cloud by Night (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cloud by Night', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cloud by Night', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590b48a5a6a599f44f0a1',
#     'id': 'tt10929648',
#     'primaryImage': {'id': 'rm2233112321',
#      'width': 642,
#      'height': 859,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDExYzQ5ZDItMTc5Ni00MWFlLTg5Y2QtOTgzN2U0OWQ4YjA4XkEyXkFqcGdeQXVyMzU4ODc0MDA@._V1_.jpg',
#      'caption': {'plainText': 'Minamoto Monogatari (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Minamoto Monogatari', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Minamoto Monogatari',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590ebe1a8ddbd9644fcc9',
#     'id': 'tt10965102',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mujeres Silenciosas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mujeres Silenciosas',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5911495801a78bc450823',
#     'id': 'tt1099209',
#     'primaryImage': {'id': 'rm1741636352',
#      'width': 1200,
#      'height': 1800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTBhOWM5MGEtOWYxNC00MDZkLWJkOGUtMTcxZTJmNzI4MDQ5XkEyXkFqcGdeQXVyMTkwNjcyOTk@._V1_.jpg',
#      'caption': {'plainText': 'Terry Moore and Vladislav Alex Kozlov in Silent Life: The Story of the Lady in Black (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Silent Life: The Story of the Lady in Black',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Silent Life: The Story of the Lady in Black',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 2,
#      'year': 2024,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=movie&page=3&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e591b9e1a8ddbd96452ff3',
#     'id': 'tt11100698',
#     'primaryImage': {'id': 'rm2677836545',
#      'width': 2536,
#      'height': 3646,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTg1YWE0MzctNzlhMS00OTk2LThhYzUtMjExNjMxY2ZmNTNjXkEyXkFqcGdeQXVyNjMyNDEzMjU@._V1_.jpg',
#      'caption': {'plainText': 'The Silent Prayer (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Silent Prayer', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Silent Prayer',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e591f78a5a6a599f45409d',
#     'id': 'tt11143850',
#     'primaryImage': {'id': 'rm1681392897',
#      'width': 1722,
#      'height': 2560,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjUxNmYxMzItMDZiMS00OGUxLWIxZDEtMTg3N2YzZGQ0YzkyXkEyXkFqcGdeQXVyNjg1NTY4MA@@._V1_.jpg',
#      'caption': {'plainText': 'Rafael Morais and Ana Lopes in Amadeo (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Amadeo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Amadeo', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e591fc909c2ca781453eb1',
#     'id': 'tt11145118',
#     'primaryImage': {'id': 'rm1102520577',
#      'width': 1944,
#      'height': 2880,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzIxOTk1NDQtMzJlOC00ODZlLWE1YTAtNTA5ODZlZmZmMDBhXkEyXkFqcGdeQXVyMjkwOTAyMDU@._V1_.jpg',
#      'caption': {'plainText': 'Creed III (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Creed III', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Creed III', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59216cffb8f2faa454607',
#     'id': 'tt11165686',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Go Go', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Go Go', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5924695801a78bc4553a9',
#     'id': 'tt11196176',
#     'primaryImage': {'id': 'rm3911909377',
#      'width': 1587,
#      'height': 2245,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMWI3YjM2NmQtN2Y2Mi00NmQzLWE4NDktZWU5YzY3YWE3NjY5XkEyXkFqcGdeQXVyMTEyMDI3NjIz._V1_.jpg',
#      'caption': {'plainText': 'Dark Room (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dark Room', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dark Room', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5924ad735dff3f94553a9',
#     'id': 'tt11197400',
#     'primaryImage': {'id': 'rm3292824065',
#      'width': 970,
#      'height': 1345,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTNlMjg2YWQtOWVjOC00ODU2LWI4ZGEtZWFhYzJhYmY0NzEwXkEyXkFqcGdeQXVyNDU1ODIzMjA@._V1_.jpg',
#      'caption': {'plainText': 'Elsi Eng in Ai Lun (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ai Lun', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ai Lun', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59266971a4a15d6455abf',
#     'id': 'tt11218958',
#     'primaryImage': {'id': 'rm2211679745',
#      'width': 1728,
#      'height': 2304,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmNlZTlhZjctNmVkMS00ZTQ0LTllYWMtYTA4ZGZmMGFjNTkxXkEyXkFqcGdeQXVyODU3Nzc1NzQ@._V1_.jpg',
#      'caption': {'plainText': 'Kyle Helsper and Natasha Thompson in Divine Flames (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Divine Flames', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Divine Flames', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59275e1a8ddbd96455eab',
#     'id': 'tt11226102',
#     'primaryImage': {'id': 'rm1972604417',
#      'width': 1728,
#      'height': 2304,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODEyYTllYzAtMzM0YS00ZGI4LWJkYjMtZWU2MDdiZmM5ODg2XkEyXkFqcGdeQXVyODU3Nzc1NzQ@._V1_.jpg',
#      'caption': {'plainText': 'Divine Flames (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Divine Flames', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Divine Flames', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59299cffb8f2faa456623',
#     'id': 'tt11253182',
#     'primaryImage': {'id': 'rm2893948417',
#      'width': 1284,
#      'height': 1818,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDAwNzkyMGItMGUyNC00NjEwLWI1ZGEtNDU2NWMyNmFmZjcxXkEyXkFqcGdeQXVyMjQ3ODk1Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Herman Knop in Vincent (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Vincent', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Vincent', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e592f0cffb8f2faa457a75',
#     'id': 'tt11306970',
#     'primaryImage': {'id': 'rm4192240641',
#      'width': 2601,
#      'height': 3840,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU0ZTFlNGMtMDcyMy00OWE1LTg0YjQtYmEzMmRiNjY1YmRmXkEyXkFqcGdeQXVyNTg2MDM1Mjk@._V1_.jpg',
#      'caption': {'plainText': 'Black Nightmares (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Black Nightmares', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Black Nightmares',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=movie&page=4&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5935d8a5a6a599f45973f',
#     'id': 'tt11379234',
#     'primaryImage': {'id': 'rm55046401',
#      'width': 518,
#      'height': 691,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZmQ3NWI4ZDUtMzgwNS00OTVmLWJjY2UtOTY2NzM1ZTgxNmUzXkEyXkFqcGdeQXVyNDU1ODIzMjA@._V1_.jpg',
#      'caption': {'plainText': 'Aleksandra Abaunza Shen, Yukina Takase, Tomoko Karina, and Hector Abaunza in Yuna (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Yuna', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Yuna', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 12,
#      'year': 2024,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5944dd735dff3f945d097',
#     'id': 'tt11541438',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'CultureshockED', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'CultureshockED', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e594a9ef99b1c54345e65f',
#     'id': 'tt11601444',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Extraordinary Sacrifice',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Extraordinary Sacrifice',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59514b597b91eb945ffcb',
#     'id': 'tt11668514',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Oliver Outloud', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Oliver Outloud', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5959a78c012aa34462023',
#     'id': 'tt11760408',
#     'primaryImage': {'id': 'rm1922673409',
#      'width': 7192,
#      'height': 9598,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGEwZTQ1OTAtZWJlNi00NDlkLWEyYzItYTM0ZGJjZjk3MDEwXkEyXkFqcGdeQXVyMjMxNjQ4MDI@._V1_.jpg',
#      'caption': {'plainText': 'Cookster (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cookster', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cookster', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e595b6ef99b1c543462867',
#     'id': 'tt11779282',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ladies Are Pimps Too', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ladies Are Pimps Too',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e596bcb597b91eb94668b9',
#     'id': 'tt11950404',
#     'primaryImage': {'id': 'rm597186817',
#      'width': 1575,
#      'height': 2100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzQyYzIxNmEtMjYzNC00OTU5LTgwMjQtNWMxMWE0ZDZiNTdjXkEyXkFqcGdeQXVyMTE5NTI1Ng@@._V1_.jpg',
#      'caption': {'plainText': "Saraphina Joachim, Phil Trasolini, Lumen Beltran, Keerthi Paikera, Maritza Brikisak, Dan Zachary, and Marcio Moreno in Sophie's Rules (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Sophie's Rules", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Sophie's Rules", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e596d8d8f3c0931e4670f1',
#     'id': 'tt11972054',
#     'primaryImage': {'id': 'rm2629551873',
#      'width': 2550,
#      'height': 3300,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjA5YTY3NDgtNzMwZC00NjE3LWEwNWMtMTFiODE2NTBhZjFkXkEyXkFqcGdeQXVyNTY5NzczNTE@._V1_.jpg',
#      'caption': {'plainText': 'Bugsy the Becoming (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bugsy the Becoming', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bugsy the Becoming',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 8,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e596fe78c012aa34467859',
#     'id': 'tt11998558',
#     'primaryImage': {'id': 'rm2636535297',
#      'width': 1366,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjE1MTcwOGEtZGM2Ny00ZDNlLWJhNWEtNDNiN2M4NjEzN2NiXkEyXkFqcGdeQXVyMTY4MjU0NDY3._V1_.jpg',
#      'caption': {'plainText': 'Joseph Vijay in Varisu (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Varisu', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Varisu', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59708cffb8f2faa467c79',
#     'id': 'tt1200263',
#     'primaryImage': {'id': 'rm11882497',
#      'width': 2764,
#      'height': 4096,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjBkNGE0NGYtYmU5Ny00NjRiLTk5MmYtMWU4NzYxMDE4YWY4XkEyXkFqcGdeQXVyMTUzMTg2ODkz._V1_.jpg',
#      'caption': {'plainText': 'Taraji P. Henson, Fantasia Barrino, and Danielle Brooks in The Color Purple (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Color Purple', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Color Purple',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=movie&page=5&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e59785971a4a15d6469bb9',
#     'id': 'tt12087678',
#     'primaryImage': {'id': 'rm723866369',
#      'width': 1414,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDE3ZTVkODEtZTc0Yy00ZDg4LWEyYWUtNjExYTFlMTcwYjEyXkEyXkFqcGdeQXVyNTg0NjQwMDM@._V1_.jpg',
#      'caption': {'plainText': 'Aksel Yakup Bektas, Hazal Uzunoglu, Osman Cavci, and Bessy Adut in Karanliktaki Kadin (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Karanliktaki Kadin', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Karanliktaki Kadin',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5978ce1a8ddbd96469d97',
#     'id': 'tt12092594',
#     'primaryImage': {'id': 'rm2649141761',
#      'width': 763,
#      'height': 1201,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2UxMTZiZWItZTQwNi00MTdhLTk1NjgtMzQ4NTE5OGU0NDNiXkEyXkFqcGdeQXVyNzMzNjY2MDA@._V1_.jpg',
#      'caption': {'plainText': 'Dominic Giannetti in Romeo Is Dead (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Romeo Is Dead', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Romeo Is Dead', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e597a4cffb8f2faa46a2b5',
#     'id': 'tt12109690',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Piedade', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Piedade', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59850a66e59642346ce81',
#     'id': 'tt12226632',
#     'primaryImage': {'id': 'rm1997746945',
#      'width': 972,
#      'height': 1440,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNWNlZTUxOTUtMzhmMi00MDg4LThmMTYtNjZhNmM2NDcxYjk1XkEyXkFqcGdeQXVyMTQzNTA5MzYz._V1_.jpg',
#      'caption': {'plainText': 'Khris Davis in Big George Foreman (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Big George Foreman', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Big George Foreman',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5988695801a78bc46de2d',
#     'id': 'tt12261776',
#     'primaryImage': {'id': 'rm166147329',
#      'width': 500,
#      'height': 741,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDgwNzc4MGYtOWMwMi00YjExLWIzMGEtMGQxMzA2NmExNzAxXkEyXkFqcGdeQXVyMTA3MDk2NDg2._V1_.jpg',
#      'caption': {'plainText': 'Adam Driver in 65 (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '65', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '65', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5997478c012aa3447141d',
#     'id': 'tt12422694',
#     'primaryImage': {'id': 'rm1241856257',
#      'width': 2070,
#      'height': 2945,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDhjMTA0NGItMjFjNy00NWQwLWE2ZTAtZmM0ZGVlOGEyNzcyXkEyXkFqcGdeQXVyNDQyNDAzMTk@._V1_.jpg',
#      'caption': {'plainText': 'Deshawn Long, Tuckeya Robinson, and Jasmine Alysha in Getting to the Plug (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Getting to the Plug', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Getting to the Plug',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a23909c2ca78147417b',
#     'id': 'tt12543840',
#     'primaryImage': {'id': 'rm4077594881',
#      'width': 1420,
#      'height': 2129,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODg5NzdmYzctMjc3MS00MGQwLWFiMzItZTczOGRhMTA5MjQ0XkEyXkFqcGdeQXVyMTU4NDA4NTc@._V1_.jpg',
#      'caption': {'plainText': 'Travis Andre Ross, Xavi Avina, Gabrielle Walsh, and Joseph David-Jones in Central Valley (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Central Valley', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Central Valley', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a548a5a6a599f4751a9',
#     'id': 'tt12573454',
#     'primaryImage': {'id': 'rm781729025',
#      'width': 1000,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2JlN2Q2ZmYtYmU4OS00ZjNlLWE2OTEtOTc2ZDY5NjEwMTM4XkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_.jpg',
#      'caption': {'plainText': 'Julianne Moore, John Lithgow, Sebastian Stan, Justice Smith, and Briana Middleton in Sharper (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sharper', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sharper', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a7e78c012aa3447567f',
#     'id': 'tt12601334',
#     'primaryImage': {'id': 'rm4102831617',
#      'width': 1448,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODA5NTU0ZmMtZDc3MC00M2Y4LTkzMTUtNzg4MGFhOTJjNmNlXkEyXkFqcGdeQXVyMTUwMjg2Nzg0._V1_.jpg',
#      'caption': {'plainText': 'The Nothingness Club - Não Sou Nada (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Nothingness Club - Não Sou Nada',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Nothingness Club - Não Sou Nada',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59bc1d735dff3f947aaa3',
#     'id': 'tt12821606',
#     'primaryImage': {'id': 'rm36809729',
#      'width': 640,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODY3YTVjYTctNDM2NS00MGFhLTg4ZjAtODNmMTliZTAxM2IxXkEyXkFqcGdeQXVyNjkyOTYwNDA@._V1_.jpg',
#      'caption': {'plainText': 'Matthew Laird in The Internationalist (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Internationalist', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Internationalist',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=movie&page=6&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e59c4d971a4a15d647cd87',
#     'id': 'tt12915716',
#     'primaryImage': {'id': 'rm3437243649',
#      'width': 1080,
#      'height': 1350,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTIwZWI0Y2YtZGJhZC00MjU4LTliZTUtODVjZjk4Y2FlYzI1XkEyXkFqcGdeQXVyMTE0MTY2Mzk2._V1_.jpg',
#      'caption': {'plainText': 'Prabhas in Adipurush (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Adipurush', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Adipurush', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59c7def99b1c54347d987',
#     'id': 'tt12948086',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rhythm in Blues', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rhythm in Blues',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59d8b8a5a6a599f481f3d',
#     'id': 'tt13130948',
#     'primaryImage': {'id': 'rm4283248897',
#      'width': 1638,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjQzYjE0NGEtZjBkOS00NjUzLWIwOWQtOWYyYjZjNjI1MzQyXkEyXkFqcGdeQXVyMTA1OTk1MjY3._V1_.jpg',
#      'caption': {'plainText': 'Sachin Khedekar, Manisha Koirala, Paresh Rawal, Ronit Roy, Rajpal Naurang Yadav, and Kartik Aaryan in Shehzada (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shehzada', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shehzada', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59d91971a4a15d6481e0f',
#     'id': 'tt13131232',
#     'primaryImage': {'id': 'rm992819457',
#      'width': 3276,
#      'height': 4096,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTYwYmI0NGItYmFkYi00NzViLWIwMGEtNGNjYjQwYjY1NTQ1XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Sidharth Malhotra in Mission Majnu (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mission Majnu', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mission Majnu', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59d91a66e596423481db1',
#     'id': 'tt13131610',
#     'primaryImage': {'id': 'rm1111448065',
#      'width': 2160,
#      'height': 2700,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjBiMTA4ZTctMzRmMC00YjIxLWFlN2YtMjA4NjYwYzZjMGUxXkEyXkFqcGdeQXVyMTUyNjIwMDEw._V1_.jpg',
#      'caption': {'plainText': 'Chiranjeevi in Bholaa Shankar (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
# ...
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '5 Billion Reasons', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '5 Billion Reasons',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bb103baabb586b7cbfa13b',
#     'id': 'tt25809252',
#     'primaryImage': {'id': 'rm3982375937',
#      'width': 853,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTk3ZmRlODMtZGZlYi00ZTgzLWEyOWYtMGVmZTJlYzNmZDE1XkEyXkFqcGdeQXVyMTk3MTE2NQ@@._V1_.jpg',
#      'caption': {'plainText': 'Mask (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mask', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mask', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bc60c9df660ac735461b8b',
#     'id': 'tt25785622',
#     'primaryImage': {'id': 'rm1901476865',
#      'width': 1728,
#      'height': 2304,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGM2NDU4MmMtOWJiNy00ZWU1LWExNjItYzJjOWQ3OTM2YzA1XkEyXkFqcGdeQXVyMTMwNTEzOTUy._V1_.jpg',
#      'caption': {'plainText': 'Streets (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Streets', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Streets', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bc60ccdf660ac735461b99',
#     'id': 'tt25786480',
#     'primaryImage': {'id': 'rm424098817',
#      'width': 960,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2NiMzZlOWMtMmM2NC00N2E5LWIyOWMtY2FmY2ZmNzgwMGZkXkEyXkFqcGdeQXVyMTA4MzQ4NzMw._V1_.jpg',
#      'caption': {'plainText': 'Do Over (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Do Over', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Do Over', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bc60dddf660ac735461bf9',
#     'id': 'tt25810546',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fate Whisper', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fate Whisper', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=movie&page=63c055420064c7b364a9bdce&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '63bc61954eb0103786462171',
#     'id': 'tt25814516',
#     'primaryImage': {'id': 'rm841432065',
#      'width': 1072,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTU3NGY1YTktM2U4Ni00MTVkLWEyYzMtOWNiMTIzMzFjNWY1XkEyXkFqcGdeQXVyNjY0OTkzMjk@._V1_.jpg',
#      'caption': {'plainText': 'Mareyade Kshamisu (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mareyade Kshamisu', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mareyade Kshamisu',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bc61f54eb010378646243b',
#     'id': 'tt25816706',
#     'primaryImage': {'id': 'rm3360963585',
#      'width': 1242,
#      'height': 2208,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmM1ZDljMGEtNzY3OC00NDZhLWJkYjgtNjI2OGZmYWI5NWZiXkEyXkFqcGdeQXVyMTUxNTUwOTM0._V1_.jpg',
#      'caption': {'plainText': "The Producer's Chronicles (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "The Producer's Chronicles",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "The Producer's Chronicles",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb23fcad0c15b86fd0b07',
#     'id': 'tt25815968',
#     'primaryImage': {'id': 'rm220216321',
#      'width': 731,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDAyMjBhMmEtMDIwNC00ZTY5LWJhODMtZGUxZTNiNTcwYzlmXkEyXkFqcGdeQXVyMTYwODk5OTIz._V1_.jpg',
#      'caption': {'plainText': 'Shivaramakrishna and Nandini Nataraj in Smarami (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Smarami', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Smarami', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb2596c4e239139fd0cb7',
#     'id': 'tt25830282',
#     'primaryImage': {'id': 'rm2579902977',
#      'width': 636,
#      'height': 979,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmYyMTU3YjEtMjBjYi00MzU2LTliYzgtN2NkNGQwNzYzMGRmXkEyXkFqcGdeQXVyMTAyNjY5NTY@._V1_.jpg',
#      'caption': {'plainText': 'Tai tou jian xi (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tai tou jian xi', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tai tou jian xi',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb26b6c4e239139fd0de9',
#     'id': 'tt25846662',
#     'primaryImage': {'id': 'rm2749185281',
#      'width': 1984,
#      'height': 1191,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDYzYjg4NzItMjE0NC00NjExLTlhYTUtYjk2NzQ3YzA3OGQzXkEyXkFqcGdeQXVyMTQwNDk0MzYy._V1_.jpg',
#      'caption': {'plainText': 'Ararat (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ararat', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ararat', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb28ccad0c15b86fd100f',
#     'id': 'tt25874946',
#     'primaryImage': {'id': 'rm85605377',
#      'width': 1887,
#      'height': 2700,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGVlZDliNjctZjYxNC00YmI5LWJkODctMmVhNDFhZjM5NmMwXkEyXkFqcGdeQXVyNzY4NDQzNTg@._V1_.jpg',
#      'caption': {'plainText': 'The Day Before the Wedding (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Day Before the Wedding',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Day Before the Wedding',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb28e6c4e239139fd102f',
#     'id': 'tt25875858',
#     'primaryImage': {'id': 'rm219823105',
#      'width': 1798,
#      'height': 2700,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzZjNGVmYWUtZDU4ZC00ZDVmLTlmNjgtN2U3MDdmOWZiZTdjXkEyXkFqcGdeQXVyNzY4NDQzNTg@._V1_.jpg',
#      'caption': {'plainText': 'Layar (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Layar', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Layar', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb2b46c4e239139fd12c1',
#     'id': 'tt25919640',
#     'primaryImage': {'id': 'rm3272096769',
#      'width': 1148,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2UxOWJkOTItMTYzMi00ODAzLTg3YjktZjMxOTgzMWE0ZGQ1XkEyXkFqcGdeQXVyNzE4MjQ2MA@@._V1_.jpg',
#      'caption': {'plainText': 'Paul Marquis in The Man of D.C. (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Man of D.C.', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Man of D.C.',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63bdb2c0cad0c15b86fd1397',
#     'id': 'tt25940670',
#     'primaryImage': {'id': 'rm2100444161',
#      'width': 850,
#      'height': 1513,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMmVlYzQyYzctNmQzYy00MjY0LWExMWUtNWRkYTY2MGE4NmFlXkEyXkFqcGdeQXVyMTc2NzgzODM@._V1_.jpg',
#      'caption': {'plainText': 'Valentina (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Valentina', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Valentina', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63c055420064c7b364a9bdce',
#     'id': 'tt25828590',
#     'primaryImage': {'id': 'rm2097560577',
#      'width': 2000,
#      'height': 2998,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjFiZmFjMTctMmEyMS00YzBkLWI1ODYtYjRmNzBmZDg4Y2VhXkEyXkFqcGdeQXVyMTU3MDMxMTMw._V1_.jpg',
#      'caption': {'plainText': 'Fulbari (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fulbari', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fulbari', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]}]

# %%
#comprobamos que las últimas páginas tienen datos
lista_json_anios1[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=movie&page=2&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e581d978c012aa3441796f',
#     'id': 'tt0143558',
#     'primaryImage': {'id': 'rm134947328',
#      'width': 450,
#      'height': 643,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjA5Y2M3ZDAtNjg4OC00ZDQ5LWI4MzgtM2E0NTdjZmUwZjE1XkEyXkFqcGdeQXVyNDYzMDMxOTc@._V1_.jpg',
#      'caption': {'plainText': 'Apaföld (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Apaföld', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Apaföld', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e581f5cffb8f2faa41808d',
#     'id': 'tt0153140',
#     'primaryImage': {'id': 'rm3937200640',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE2NDAxNDE0Nl5BMl5BanBnXkFtZTgwMTU1MjQwNjE@._V1_.jpg',
#      'caption': {'plainText': 'Rózsaszín sajt (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rózsaszín sajt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rózsaszín sajt', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58287a66e59642341a0cf',
#     'id': 'tt0205380',
#     'primaryImage': {'id': 'rm1364663808',
#      'width': 650,
#      'height': 472,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjc3MGNhMmItMjljOS00NjY5LThlMmQtYWM1NWZiOGJlY2EyXkEyXkFqcGdeQXVyMjU4NDY1ODA@._V1_.jpg',
#      'caption': {'plainText': 'Pooja Bhatt and Saif Ali Khan in Sanam Teri Kasam (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sanam Teri Kasam', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sanam Teri Kasam',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5830dcffb8f2faa41bed5',
#     'id': 'tt0254832',
#     'primaryImage': {'id': 'rm546868736',
#      'width': 4500,
#      'height': 6250,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI2NjA5NDkyMl5BMl5BanBnXkFtZTcwNjAxNTEwMw@@._V1_.jpg',
#      'caption': {'plainText': 'Twice as Dead (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Twice as Dead', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Twice as Dead', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e583a9b597b91eb941e329',
#     'id': 'tt0311698',
#     'primaryImage': {'id': 'rm3357524224',
#      'width': 800,
#      'height': 1185,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTkyMzIzNjUwOF5BMl5BanBnXkFtZTgwMzgwNzE1MjE@._V1_.jpg',
#      'caption': {'plainText': 'Railed (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Railed', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Railed', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e583d2b597b91eb941ec81',
#     'id': 'tt0327597',
#     'primaryImage': {'id': 'rm1274647808',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzQxNjM5NzkxNV5BMl5BanBnXkFtZTcwMzg5NDMwMg@@._V1_.jpg',
#      'caption': {'plainText': 'Keith David and Dakota Fanning in Coraline (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Coraline', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Coraline', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e583ff909c2ca78141f5a5',
#     'id': 'tt0344074',
#     'primaryImage': {'id': 'rm2549912064',
#      'width': 450,
#      'height': 310,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTgwNTgxNzM5MV5BMl5BanBnXkFtZTcwODk1MDIzMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Namrata Singh Gujral playing "Vidi" in "Mitsein"',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mitsein', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mitsein', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58402d735dff3f941f787',
#     'id': 'tt0346631',
#     'primaryImage': {'id': 'rm2558036224',
#      'width': 434,
#      'height': 641,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjE0MDc4ODY4Ml5BMl5BanBnXkFtZTcwNDI2NjM4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Michael Jai White in Blood and Bone (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Blood and Bone', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Blood and Bone', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584308a5a6a599f420255',
#     'id': 'tt0361748',
#     'primaryImage': {'id': 'rm3163035648',
#      'width': 2025,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTJiNDEzOWYtMTVjOC00ZjlmLWE0NGMtZmE1OWVmZDQ2OWJhXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_.jpg',
#      'caption': {'plainText': 'Brad Pitt, Til Schweiger, Mélanie Laurent, Eli Roth, Christoph Waltz, and Diane Kruger in Inglourious Basterds (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Inglourious Basterds', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Inglourious Basterds',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58431909c2ca78142012f',
#     'id': 'tt0362478',
#     'primaryImage': {'id': 'rm710904576',
#      'width': 509,
#      'height': 755,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI4MDA5NjIwM15BMl5BanBnXkFtZTcwNTA2MjY0Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Cameron Diaz in The Box (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Box', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Box', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=movie&page=3&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58442e1a8ddbd964205a1',
#     'id': 'tt0368563',
#     'primaryImage': {'id': 'rm649763072',
#      'width': 450,
#      'height': 669,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTk3MzQwNDA2Ml5BMl5BanBnXkFtZTcwNTQwMDg1MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Possession (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Possession', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Possession', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584548a5a6a599f420a4d',
#     'id': 'tt0374853',
#     'primaryImage': {'id': 'rm671517696',
#      'width': 1449,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTM5ODQ0NDUyMV5BMl5BanBnXkFtZTcwMzg5OTEzMw@@._V1_.jpg',
#      'caption': {'plainText': 'Maggie Grace in Malice in Wonderland (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Malice in Wonderland', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Malice in Wonderland',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 12,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58456e1a8ddbd96420a25',
#     'id': 'tt0375568',
#     'primaryImage': {'id': 'rm3129051392',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI5NTEwNTcxMl5BMl5BanBnXkFtZTcwMDEyMTE4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Nicolas Cage, Donald Sutherland, Newell Alexander, Kristen Bell, Freddie Highmore, Eugene Levy, Bob Logan, and Ryan Stiles in Astro Boy (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Astro Boy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Astro Boy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58464e1a8ddbd96420d67',
#     'id': 'tt0380510',
#     'primaryImage': {'id': 'rm2236976640',
#      'width': 1200,
#      'height': 1777,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAwNDA1MTM2MF5BMl5BanBnXkFtZTcwMzg3NDcwMw@@._V1_.jpg',
#      'caption': {'plainText': 'The Lovely Bones (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Lovely Bones', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Lovely Bones',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5846aef99b1c543420eb9',
#     'id': 'tt0382579',
#     'primaryImage': {'id': 'rm3580940800',
#      'width': 343,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTQyOTExOTcyOV5BMl5BanBnXkFtZTgwMTMxMDA2MDE@._V1_.jpg',
#      'caption': {'plainText': "Boppin' at the Glue Factory (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Boppin' at the Glue Factory",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Boppin' at the Glue Factory",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58471971a4a15d64210cb',
#     'id': 'tt0386117',
#     'primaryImage': {'id': 'rm2173864192',
#      'width': 800,
#      'height': 1183,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzQ1NzAwODEwM15BMl5BanBnXkFtZTcwNTE4MjI4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'James Gandolfini and Max Records in Where the Wild Things Are (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Max en de maximonsters', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Where the Wild Things Are',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 1,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584a6d735dff3f9421d23',
#     'id': 'tt0405022',
#     'primaryImage': {'id': 'rm59168000',
#      'width': 1362,
#      'height': 1737,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc3MjIwMTI1M15BMl5BanBnXkFtZTgwMDEyNTQyMTE@._V1_.jpg',
#      'caption': {'plainText': 'House of Boys (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'House of Boys', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'House of Boys', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584a8b597b91eb9421dc5',
#     'id': 'tt0403702',
#     'primaryImage': {'id': 'rm1877642752',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE3NTkxODUwOV5BMl5BanBnXkFtZTcwMjE4NjI5Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Michael Cera and Portia Doubleday in Youth in Revolt (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Youth in Revolt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Youth in Revolt',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 1,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584aecffb8f2faa421de3',
#     'id': 'tt0407852',
#     'primaryImage': {'id': 'rm2895002368',
#      'width': 450,
#      'height': 661,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZmYyZGMzMzctMDYyNy00YmIxLWEyZmUtZDUxYjk5MzViMDliL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjIzMDAwOTc@._V1_.jpg',
#      'caption': {'plainText': 'Utolsó jelentés Annáról (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Utolsó jelentés Annáról',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Utolsó jelentés Annáról',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584b18a5a6a599f421f89',
#     'id': 'tt0409459',
#     'primaryImage': {'id': 'rm2931438848',
#      'width': 2000,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2IzNGNiODgtOWYzOS00OTI0LTgxZTUtOTA5OTQ5YmI3NGUzXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#      'caption': {'plainText': 'Billy Crudup, Malin Akerman, Matthew Goode, Jackie Earle Haley, Jeffrey Dean Morgan, and Patrick Wilson in Watchmen (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Watchmen', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Watchmen', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=movie&page=4&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e584b995801a78bc42215f',
#     'id': 'tt0411670',
#     'primaryImage': {'id': 'rm710909184',
#      'width': 300,
#      'height': 480,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTE5OTMzMjc2OV5BMl5BanBnXkFtZTcwMDMzOTkyMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Mixing Karma (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mixing Karma', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mixing Karma', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584e38a5a6a599f422ae3',
#     'id': 'tt0425080',
#     'primaryImage': {'id': 'rm2788526080',
#      'width': 1135,
#      'height': 1608,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTkxMTYxNTYyMl5BMl5BanBnXkFtZTcwMDgwNzE3Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Tuncel Kurtiz, Avni Yalçin, Okan Yalabik, Kenan Bal, Ilker Aksum, Hüseyin Avni Danyal, Murat Yildirim, Beren Saat, Belçim Bilgin, and Umut Kurt in Güz Sancisi (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Güz Sancisi', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Güz Sancisi', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584eecffb8f2faa422c75',
#     'id': 'tt0429664',
#     'primaryImage': {'id': 'rm2000028416',
#      'width': 288,
#      'height': 396,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMmNhNTUzYjMtYWUxMC00YWQwLWJiYTgtM2YxNzMyZDBjNzRiXkEyXkFqcGdeQXVyNjkzMzk0Mjk@._V1_.jpg',
#      'caption': {'plainText': 'Stephen Hawking in Beyond the Horizon (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Beyond the Horizon', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Beyond the Horizon',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584f28a5a6a599f422e3b',
#     'id': 'tt0432283',
#     'primaryImage': {'id': 'rm329928960',
#      'width': 2359,
#      'height': 3495,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGUwYTU4NGEtNDM4MS00NDRjLTkwNmQtOTkwMWMyMjhmMjdlXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg',
#      'caption': {'plainText': 'George Clooney, Bill Murray, Meryl Streep, Jason Schwartzman, Owen Wilson, Eric Chase Anderson, and Wallace Wolodarsky in Fantastic Mr. Fox (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fantastic Mr. Fox', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fantastic Mr. Fox',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584f2e1a8ddbd96422d5b',
#     'id': 'tt0432314',
#     'primaryImage': {'id': 'rm3446640384',
#      'width': 352,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjEzNzQwMjYwOV5BMl5BanBnXkFtZTcwMDQ4MzgxMw@@._V1_.jpg',
#      'caption': {'plainText': 'Leningrad (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Attack on Leningrad', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Leningrad', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 3,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584fca66e59642342304f',
#     'id': 'tt0435711',
#     'primaryImage': {'id': 'rm4202543104',
#      'width': 4224,
#      'height': 5988,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTQ1NDE2NjU5Ml5BMl5BanBnXkFtZTcwNzM0NTY5NA@@._V1_.jpg',
#      'caption': {'plainText': 'American Primitive (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'American Primitive', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'American Primitive',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2014,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584fe909c2ca781423023',
#     'id': 'tt0435716',
#     'primaryImage': {'id': 'rm2074839040',
#      'width': 354,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTQyMDk5NTA2MF5BMl5BanBnXkFtZTcwNTEyMjk1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'The Perfect Sleep (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Perfect Sleep', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Perfect Sleep',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584ffd735dff3f942313b',
#     'id': 'tt0437065',
#     'primaryImage': {'id': 'rm554999040',
#      'width': 450,
#      'height': 563,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTgwMjIxMDg1NV5BMl5BanBnXkFtZTcwMjQyOTczMQ@@._V1_.jpg',
#      'caption': {'plainText': 'AmerAsian (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'AmerAsian', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'AmerAsian', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5850195801a78bc4231cd',
#     'id': 'tt0437405',
#     'primaryImage': {'id': 'rm2024049920',
#      'width': 1383,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTExODM1MDI4MDVeQTJeQWpwZ15BbWU3MDQzMjc1MzM@._V1_.jpg',
#      'caption': {'plainText': 'Jeff Daniels and Ryan Reynolds in Paper Man (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Paper Man', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Paper Man', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 5,
#      'year': 2014,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58503cffb8f2faa423127',
#     'id': 'tt0437550',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Why George?', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Why George?', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=movie&page=5&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58503e1a8ddbd96423125',
#     'id': 'tt0438894',
#     'primaryImage': {'id': 'rm2995410176',
#      'width': 1090,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODU3NGRjYjEtZTViNS00NmE0LWFlOGUtYmJkODhhYmJiNzRjXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Kisse Pyaar Karoon? (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Kisse Pyaar Karoon?', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Kisse Pyaar Karoon?',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58506b597b91eb94232c1',
#     'id': 'tt0438154',
#     'primaryImage': {'id': 'rm4170128640',
#      'width': 2550,
#      'height': 3300,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAxZjM5NzktMTRkMy00ZGZmLWI1OWEtNmNlMjIyYTk2MGI1XkEyXkFqcGdeQXVyMTM4NTU4NQ@@._V1_.jpg',
#      'caption': {'plainText': 'The Zero Sum (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Zero Sum', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Zero Sum', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58509d735dff3f9423387',
#     'id': 'tt0441328',
#     'primaryImage': {'id': 'rm3860719360',
#      'width': 3385,
#      'height': 4705,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjcxZDNkMGUtMWJjMi00YzFiLTlmYTAtODMwYWIzZjJjMzhjXkEyXkFqcGdeQXVyMjIxMzMyMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Ocas jesterky (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ocas jesterky', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ocas jesterky', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5851b971a4a15d6423759',
#     'id': 'tt0445968',
#     'primaryImage': {'id': 'rm3009121792',
#      'width': 8100,
#      'height': 12000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTk1MDA2MzUwN15BMl5BanBnXkFtZTcwMjcxNjYwMw@@._V1_.jpg',
#      'caption': {'plainText': 'For Real (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'For Real', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'For Real', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5851e971a4a15d6423841',
#     'id': 'tt0448093',
#     'primaryImage': {'id': 'rm3769310464',
#      'width': 854,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzZmZjEwNGMtMjBhYi00Y2MxLWI0YTUtMzc4MDg0MWE2YWIxXkEyXkFqcGdeQXVyMjM0NTc3OTY@._V1_.jpg',
#      'caption': {'plainText': "Punctured Hope: A Story About Trokosi and the Young Girls' Slavery in Today's West Africa (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Punctured Hope: A Story About Trokosi and the Young Girls' Slavery in Today's West Africa",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Punctured Hope: A Story About Trokosi and the Young Girls' Slavery in Today's West Africa",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5851ea66e5964234237e7',
#     'id': 'tt0447692',
#     'primaryImage': {'id': 'rm13824512',
#      'width': 333,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjE5NTM1MjcwMF5BMl5BanBnXkFtZTgwODkxOTM0NDE@._V1_.jpg',
#      'caption': {'plainText': 'Réfractaire (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Réfractaire', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Réfractaire', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5851f78c012aa3442375f',
#     'id': 'tt0446564',
#     'primaryImage': {'id': 'rm406985216',
#      'width': 301,
#      'height': 450,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTA4ZmNjYjktOWM1Zi00MmE0LWIwZWUtODE2ZTkxMGNlYjc2XkEyXkFqcGdeQXVyMTU2ODc4ODQ@._V1_.jpg',
#      'caption': {'plainText': 'Bela Noite Para Voar (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bela Noite Para Voar', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bela Noite Para Voar',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58520909c2ca7814237eb',
#     'id': 'tt0448182',
#     'primaryImage': {'id': 'rm1521454592',
#      'width': 447,
#      'height': 647,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTA2MTk1MTU2MTFeQTJeQWpwZ15BbWU3MDcwODA5OTI@._V1_.jpg',
#      'caption': {'plainText': 'Yesterday Was a Lie (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Yesterday Was a Lie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Yesterday Was a Lie',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e585228a5a6a599f42392b',
#     'id': 'tt0448011',
#     'primaryImage': {'id': 'rm3804006912',
#      'width': 510,
#      'height': 755,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTMyMjgyMDIyM15BMl5BanBnXkFtZTcwNjg3MjAyMg@@._V1_.jpg',
#      'caption': {'plainText': 'Knowing (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Knowing', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Knowing', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5852bcffb8f2faa423a33',
#     'id': 'tt0453501',
#     'primaryImage': {'id': 'rm4199998976',
#      'width': 290,
#      'height': 431,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGIwM2M5ZGEtNzAyOS00MmNiLTkxYTktNzUzYmQwMjA0MjYwXkEyXkFqcGdeQXVyNTIwODMzNjc@._V1_.jpg',
#      'caption': {'plainText': "It's a Mismatch (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "It's a Mismatch", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "It's a Mismatch",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=movie&page=6&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58530cffb8f2faa423b5d',
#     'id': 'tt0452694',
#     'primaryImage': {'id': 'rm3885367808',
#      'width': 1000,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWNlN2RmZDktNzllNC00NDVlLTllMzgtZGQ1YmRmZThmZjZmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#      'caption': {'plainText': "The Time Traveler's Wife (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "The Time Traveler's Wife",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "The Time Traveler's Wife",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5853295801a78bc423d29',
#     'id': 'tt0456407',
#     'primaryImage': {'id': 'rm3953095680',
#      'width': 1411,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2E2OGFkMmYtY2Q5NC00ZjZiLTk0ZmYtZmQzZGU0MjQzNWUyXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_.jpg',
#      'caption': {'plainText': 'The Fakir of Venice (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Fakir of Venice', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Fakir of Venice',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 2,
#      'year': 2019,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58535b597b91eb9423d99',
#     'id': 'tt0454918',
#     'primaryImage': {'id': 'rm3775664640',
#      'width': 1176,
#      'height': 1407,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjRlYzZkOTMtMjAyOC00MTIxLWI4ZDYtYTdhZDI2NzIyNmQyXkEyXkFqcGdeQXVyMTg2NTIzMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Prima Primavera (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Prima Primavera', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Prima Primavera',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e585368a5a6a599f423dd3',
#     'id': 'tt0454777',
#     'primaryImage': {'id': 'rm4285129728',
#      'width': 1280,
#      'height': 857,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY5MjkwNTY5N15BMl5BanBnXkFtZTgwNjA0NzQ4NzE@._V1_.jpg',
#      'caption': {'plainText': 'Yekaterina Golubeva in American Widow (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'American Widow', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'American Widow', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 5,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58538909c2ca781423d55',
#     'id': 'tt0457355',
#     'primaryImage': {'id': 'rm1043564800',
#      'width': 1100,
#      'height': 1530,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTMyMzUyNzMwNF5BMl5BanBnXkFtZTcwMTgzMDk4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'From Mexico with Love (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'From Mexico with Love', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'From Mexico with Love',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5853be1a8ddbd96423e03',
#     'id': 'tt0458455',
#     'primaryImage': {'id': 'rm2422670336',
#      'width': 1000,
#      'height': 1416,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY4NzdkNjYtNWJiYS00MDlmLWExN2UtZmM5ZjNiODdmYjVjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMzA3Njg4MzY@._V1_.jpg',
#      'caption': {'plainText': 'Die Päpstin (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pope Joan', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Die Päpstin', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5853c971a4a15d6423eef',
#     'id': 'tt0458515',
#     'primaryImage': {'id': 'rm1949206784',
#      'width': 1944,
#      'height': 2880,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTM2NTYxNTM1OV5BMl5BanBnXkFtZTcwMzAyNDc4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Io, Don Giovanni (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Io, Don Giovanni', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Io, Don Giovanni',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58543909c2ca781423fb9',
#     'id': 'tt0460943',
#     'primaryImage': {'id': 'rm1984083968',
#      'width': 1539,
#      'height': 2179,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY1OTQwNjA0MF5BMl5BanBnXkFtZTcwNDI4NTk5NA@@._V1_.jpg',
#      'caption': {'plainText': 'The Ritual (Theatrical/DVD Poster)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Ritual', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Ritual', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58547b597b91eb942418d',
#     'id': 'tt0462232',
#     'primaryImage': {'id': 'rm241603072',
#      'width': 450,
#      'height': 655,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTMyOTQ5NjI0Ml5BMl5BanBnXkFtZTcwNDUxMDczMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Cold Storage (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cold Storage', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cold Storage', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 5,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58550e1a8ddbd964242e3',
#     'id': 'tt0464077',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Labor Day', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Labor Day', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None}]},
#  {'page': '6',
#   'next': '/titles?titleType=movie&page=7&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58558cffb8f2faa424491',
#     'id': 'tt0468529',
#     'primaryImage': {'id': 'rm1864072960',
#      'width': 1082,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTkxNmViZGItYzAzZS00MWIyLThjOGYtNzVjNDRhYWJmMDI4XkEyXkFqcGdeQXVyNjU0NTI0Nw@@._V1_.jpg',
#      'caption': {'plainText': 'Kate Walsh, Kim Dickens, and Gabriel Macht in One Way to Valhalla (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'One Way to Valhalla', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'One Way to Valhalla',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58559d8f3c0931e42459d',
#     'id': 'tt0470846',
#     'primaryImage': {'id': 'rm2570238208',
#      'width': 711,
#      'height': 1000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTMyODY5ODAxMl5BMl5BanBnXkFtZTcwOTAzNjkzNQ@@._V1_.jpg',
#      'caption': {'plainText': 'A Line in the Sand (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Line in the Sand', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Line in the Sand',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5855f909c2ca781424629',
#     'id': 'tt0473102',
#     'primaryImage': {'id': 'rm1782224640',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI1MTgzMTk1OF5BMl5BanBnXkFtZTcwNDY3Nzk3MQ@@._V1_.jpg',
#      'caption': {'plainText': 'The Perfect Game (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Perfect Game', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Perfect Game',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5856278c012aa3442467b',
#     'id': 'tt0472033',
#     'primaryImage': {'id': 'rm1133545472',
#      'width': 575,
#      'height': 851,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY2ODE1MTgxMV5BMl5BanBnXkFtZTcwNTM1NTM2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Elijah Wood in 9 (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '9', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '9', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58563d8f3c0931e4247e3',
#     'id': 'tt0472198',
#     'primaryImage': {'id': 'rm3403257088',
#      'width': 400,
#      'height': 592,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjA3ODUwOTg2NF5BMl5BanBnXkFtZTcwNjgwOTUwMg@@._V1_.jpg',
#      'caption': {'plainText': 'Jamal Woolard in Notorious (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Notorious', '__typename': 'TitleText'},
# ...
#    {'_id': '61e593fe95801a78bc45be55',
#     'id': 'tt1148779',
#     'primaryImage': {'id': 'rm249136128',
#      'width': 1500,
#      'height': 1124,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc4MTk0MTk0MF5BMl5BanBnXkFtZTcwNjYxMTUxNA@@._V1_.jpg',
#      'caption': {'plainText': 'Cuckoo (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cuckoo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cuckoo', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 12,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5940878c012aa3445bd1b',
#     'id': 'tt1149362',
#     'primaryImage': {'id': 'rm2267230464',
#      'width': 1748,
#      'height': 2480,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTJhN2UzMzYtODcyMS00YThiLTgxOTktNzgzYmQ2YzU0NTA3XkEyXkFqcGdeQXVyNDkzNTM2ODg@._V1_.jpg',
#      'caption': {'plainText': 'Leonard Proxauf in Das weiße Band - Eine deutsche Kindergeschichte (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Das weiße Band - Eine deutsche Kindergeschichte',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Das weiße Band - Eine deutsche Kindergeschichte',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59409909c2ca78145bee5',
#     'id': 'tt1149363',
#     'primaryImage': {'id': 'rm1531499008',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTExMjk4NzQ4MzFeQTJeQWpwZ15BbWU4MDA2MjIwNjAx._V1_.jpg',
#      'caption': {'plainText': 'Yuki & Nina (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Yuki & Nina', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Yuki & Nina', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5940b909c2ca78145bf95',
#     'id': 'tt11496490',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Yuan Long Ping', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Yuan Long Ping', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5940c971a4a15d645c0d5',
#     'id': 'tt1149592',
#     'primaryImage': {'id': 'rm3597256704',
#      'width': 510,
#      'height': 680,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAyNTM4OTc1OF5BMl5BanBnXkFtZTgwMTA0MzU1MTE@._V1_.jpg',
#      'caption': {'plainText': 'Espion(s) (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Espion(s)', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Espion(s)', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5940ca66e59642345bffd',
#     'id': 'tt1149604',
#     'primaryImage': {'id': 'rm363954432',
#      'width': 356,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc2NDI0OTE5M15BMl5BanBnXkFtZTcwMzg4MjQ4Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Rabioso sol, rabioso cielo (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rabioso sol, rabioso cielo',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rabioso sol, rabioso cielo',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5940ecffb8f2faa45c067',
#     'id': 'tt11496534',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Seeking Naadam', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Seeking Naadam', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59426b597b91eb945c523',
#     'id': 'tt1151410',
#     'primaryImage': {'id': 'rm4175674368',
#      'width': 1442,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDY5OTYwNDMzNF5BMl5BanBnXkFtZTcwODU2MTQyNg@@._V1_.jpg',
#      'caption': {'plainText': 'Tanner Hall (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tanner Hall', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tanner Hall', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2015,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59427d8f3c0931e45c6b5',
#     'id': 'tt1151359',
#     'primaryImage': {'id': 'rm2505740032',
#      'width': 434,
#      'height': 640,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjI1MzE2ODI1NV5BMl5BanBnXkFtZTcwNDkwNzAyMw@@._V1_.jpg',
#      'caption': {'plainText': 'Leaves of Grass (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Double Trouble', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Leaves of Grass',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 9,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=movie&page=61e59470d8f3c0931e45d8af&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e594308a5a6a599f45cbd7',
#     'id': 'tt1151921',
#     'primaryImage': {'id': 'rm2825948672',
#      'width': 354,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU4NDk1NjI2NV5BMl5BanBnXkFtZTcwMjMwNzQwMw@@._V1_.jpg',
#      'caption': {'plainText': 'The Path of the Wind (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Path of the Wind', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Path of the Wind',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59430ef99b1c54345c873',
#     'id': 'tt1151924',
#     'primaryImage': {'id': 'rm1447531520',
#      'width': 1000,
#      'height': 1481,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjIxMTAzNzc5Nl5BMl5BanBnXkFtZTcwOTIyNzc5MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Rockabilly Baby (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rockabilly Baby', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rockabilly Baby',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5943c8a5a6a599f45cf0d',
#     'id': 'tt1152836',
#     'primaryImage': {'id': 'rm1424044800',
#      'width': 800,
#      'height': 1185,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGI4YTIxMDQtNDlmNC00ZDJhLWIyZGItM2QyODRiMTEzN2ViXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_.jpg',
#      'caption': {'plainText': 'Johnny Depp in Public Enemies (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Public Enemies', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Public Enemies', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59440a66e59642345cccd',
#     'id': 'tt1153043',
#     'primaryImage': {'id': 'rm2702489856',
#      'width': 4200,
#      'height': 6225,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTk4ODMyMDUyOV5BMl5BanBnXkFtZTcwNjA1ODQ0NQ@@._V1_.jpg',
#      'caption': {'plainText': 'Lauren Holly, William Devane, Louis Gossett Jr., and Cedric Sanders in The Least Among You (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Least Among You', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Least Among You',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59440d735dff3f945cd5b',
#     'id': 'tt1153040',
#     'primaryImage': {'id': 'rm1127858176',
#      'width': 2000,
#      'height': 2851,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODA1MTE2OTIyM15BMl5BanBnXkFtZTgwMTA1MTE0MjE@._V1_.jpg',
#      'caption': {'plainText': 'Ha Ji-Won, Joong-Hoon Park, Sol Kyung-gu, and Uhm Junghwa in Haeundae (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Haeundae', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Haeundae', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59442d8f3c0931e45cd57',
#     'id': 'tt1153105',
#     'primaryImage': {'id': 'rm2966763520',
#      'width': 450,
#      'height': 660,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTQ0MmYxMmMtZjVlNy00Y2UwLWExY2YtMGYzMWRmNTRhNzFmL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjIzMDAwOTc@._V1_.jpg',
#      'caption': {'plainText': 'A hetedik kör (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A hetedik kör', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A hetedik kör', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 1,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59462cffb8f2faa45d547',
#     'id': 'tt11554762',
#     'primaryImage': {'id': 'rm1493270785',
#      'width': 2667,
#      'height': 3429,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTQxYTI4YTItMjg0MC00NmU4LWI3ODEtMmNiOTBiM2Q5OWI5XkEyXkFqcGdeQXVyNTcwNDU1NTI@._V1_.jpg',
#      'caption': {'plainText': 'Kavita Joshi and Uttar Kumar in Natkhat (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Natkhat', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Natkhat', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59466971a4a15d645d71d',
#     'id': 'tt1155587',
#     'primaryImage': {'id': 'rm3723597056',
#      'width': 1200,
#      'height': 1800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTQxNzM0OTMxNV5BMl5BanBnXkFtZTcwNTY4OTMwMg@@._V1_.jpg',
#      'caption': {'plainText': 'Callous (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Callous', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Callous', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5947078c012aa3445d6d5',
#     'id': 'tt1156173',
#     'primaryImage': {'id': 'rm43288576',
#      'width': 420,
#      'height': 600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjIyOTAwMjAzOF5BMl5BanBnXkFtZTcwODc1ODM2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Vincere (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Vincere', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Vincere', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59470d8f3c0931e45d8af',
#     'id': 'tt1156143',
#     'primaryImage': {'id': 'rm1389526272',
#      'width': 600,
#      'height': 800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNWVlOTYwMDgtYzQ0Zi00NmY0LWJlZDctZDA1ZTAwMTg0YmFhXkEyXkFqcGdeQXVyMzIwNDY4NDI@._V1_.jpg',
#      'caption': {'plainText': 'Les herbes folles (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Les herbes folles', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Les herbes folles',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]}]

# %%
lista_json_anios2[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=short&page=2&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58c9b909c2ca78143ef47',
#     'id': 'tt10242552',
#     'primaryImage': {'id': 'rm574711552',
#      'width': 1002,
#      'height': 749,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODhjMTMzNzgtYTgxYS00NWY2LTk0ZjAtNjVhYjg4YjcxYTk3XkEyXkFqcGdeQXVyNzQ1NjEyMTg@._V1_.jpg',
#      'caption': {'plainText': 'Astray (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Astray', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Astray', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59c7295801a78bc47d969',
#     'id': 'tt12941822',
#     'primaryImage': {'id': 'rm2576868353',
#      'width': 4160,
#      'height': 2340,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTQ3NDYxODEtYTdjZi00MmMzLTgxN2MtZjgzMGM4ZTc5MGZlXkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg',
#      'caption': {'plainText': 'Bedroom (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bedroom', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bedroom', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59c77e1a8ddbd9647d845',
#     'id': 'tt12942176',
#     'primaryImage': {'id': 'rm90170881',
#      'width': 1600,
#      'height': 1200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzdjY2RlOWItNWYwMy00Y2I5LWExYjktNGU3ZmQ5MmFkOWQxXkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg',
#      'caption': {'plainText': 'Gouge (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Gouge', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Gouge', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a472a66e59642349d7ad',
#     'id': 'tt14329118',
#     'primaryImage': {'id': 'rm3104558849',
#      'width': 346,
#      'height': 534,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGI1MGE4YzQtYjI3MS00NzYxLWE5MTktY2ZiNjhmNDkwMjY0XkEyXkFqcGdeQXVyNjA2MzY4NTg@._V1_.jpg',
#      'caption': {'plainText': "Zha'kym Coakley in In Control of Me (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'In Control of Me', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'In Control of Me',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a4ec971a4a15d649f715',
#     'id': 'tt14412048',
#     'primaryImage': {'id': 'rm4173486593',
#      'width': 4050,
#      'height': 5998,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjdmYjM1MjgtODE2OS00OTdjLWI1ZmEtYWZkZjNlMThmMjdhXkEyXkFqcGdeQXVyMTMxMzkxNjM0._V1_.jpg',
#      'caption': {'plainText': 'Bury a Dream (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bury a Dream', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bury a Dream', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a698e1a8ddbd964a64a7',
#     'id': 'tt14700656',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pieces of My Husband & His Friends',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pieces of My Husband & His Friends',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a8b1ef99b1c5434ae731',
#     'id': 'tt15061326',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'O Fim do Verão', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'O Fim do Verão', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5ab0cd735dff3f94b7f9b',
#     'id': 'tt15462438',
#     'primaryImage': {'id': 'rm2469392641',
#      'width': 1536,
#      'height': 2276,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGIzMTI4OTctZmU3NS00YWVjLWFlNGQtNThiY2JmNGU2NzVjXkEyXkFqcGdeQXVyNTgxMzg5MDQ@._V1_.jpg',
#      'caption': {'plainText': '2030 (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '2030', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '2030', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5c6dfcffb8f2faa521f59',
#     'id': 'tt6325374',
#     'primaryImage': {'id': 'rm3233277441',
#      'width': 587,
#      'height': 879,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjhjNjkzMGYtOTczZi00NzNiLTk0M2EtNjY3YTRmMzZhNTljXkEyXkFqcGdeQXVyNTE3Mjg2OTQ@._V1_.jpg',
#      'caption': {'plainText': 'Xmas (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Xmas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Xmas', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5d067b597b91eb9546299',
#     'id': 'tt16769782',
#     'primaryImage': {'id': 'rm566824961',
#      'width': 1026,
#      'height': 1283,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODYzMjVjZjAtNDdiNS00NzcwLWI2YTUtN2EzMTc2MWE1NDJhXkEyXkFqcGdeQXVyMTQ3ODA1ODA0._V1_.jpg',
#      'caption': {'plainText': 'R.A.T (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'R.A.T', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'R.A.T', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=short&page=3&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5d156d735dff3f9549fdd',
#     'id': 'tt16030316',
#     'primaryImage': {'id': 'rm313733121',
#      'width': 2122,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmMwMmQyNjMtYmI4ZC00ODE4LTgxMmYtYjYxZmUxOWZiMTA0XkEyXkFqcGdeQXVyMTQwNTg2ODI5._V1_.jpg',
#      'caption': {'plainText': 'First Mission (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'First Mission', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'First Mission', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5d9f978c012aa3456bb35',
#     'id': 'tt16382922',
#     'primaryImage': {'id': 'rm3013928449',
#      'width': 1536,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmQ3ZDYzZjYtMTgzMS00YjhkLWFlMzAtNjE0NGM0NmYxNGI0XkEyXkFqcGdeQXVyODIxMDcyMjk@._V1_.jpg',
#      'caption': {'plainText': 'Silent Proclivities (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Silent Proclivities', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Silent Proclivities',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5dbbdcffb8f2faa572987',
#     'id': 'tt15770114',
#     'primaryImage': {'id': 'rm1632367873',
#      'width': 779,
#      'height': 1008,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzlmZjQ0ZWMtZDFlNy00ODQ4LWE2MWUtMmMzMWY0NGMzMjZkXkEyXkFqcGdeQXVyMzQ5MjE5Nzc@._V1_.jpg',
#      'caption': {'plainText': 'Kumud Pant in Facebook (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Facebook', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Facebook', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f012bf399aff92263d53a8',
#     'id': 'tt16996540',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Pendant of Persia', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Pendant of Persia',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f01adac3d4b9c602873168',
#     'id': 'tt17003510',
#     'primaryImage': {'id': 'rm1194451713',
#      'width': 1224,
#      'height': 1730,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjQ4MjgxMzItZTc3OS00ZDY2LTlkZTItY2NiNmZmNWJlZmVhXkEyXkFqcGdeQXVyOTI1NzA1OTU@._V1_.jpg',
#      'caption': {'plainText': 'Brother (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Brother', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Brother', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f16ea2c5509aeb5071ca47',
#     'id': 'tt17350036',
#     'primaryImage': {'id': 'rm4116898049',
#      'width': 750,
#      'height': 738,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2MxNmZlZjYtMDZlNy00ZTYyLWFiNDUtN2NmM2RiNDUxMjdjXkEyXkFqcGdeQXVyODE4MjczNDE@._V1_.jpg',
#      'caption': {'plainText': 'Sweetheart (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sweetheart', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sweetheart', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f16ebac5509aeb5071cb67',
#     'id': 'tt17351942',
#     'primaryImage': {'id': 'rm3977401345',
#      'width': 2121,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTNkYzhjNjEtOGMzYS00MDUzLThmMDUtNDBmMWVlNDY4ZmM3XkEyXkFqcGdeQXVyMzM0MzI2ODg@._V1_.jpg',
#      'caption': {'plainText': 'Zidane Roulette (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Zidane Roulette', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Zidane Roulette',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61fe84ea0c84e2d670804a2d',
#     'id': 'tt17677510',
#     'primaryImage': {'id': 'rm964042497',
#      'width': 2500,
#      'height': 3300,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjg4YTI2NDktZDE0Ni00MzljLThlMmYtODk2MzdmODA1NWI0XkEyXkFqcGdeQXVyNDg3NjAyNDg@._V1_.jpg',
#      'caption': {'plainText': 'Annie Unk and T.J. May in Incidental (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Incidental', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Incidental', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6207c52691410969a3dfb34a',
#     'id': 'tt18160884',
#     'primaryImage': {'id': 'rm1631512321',
#      'width': 2400,
#      'height': 3600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDRlMDliNGEtZjk1ZS00YTE4LTkzMWMtNDkzNDVkNjRlOGIwXkEyXkFqcGdeQXVyMTA3NjE4ODMy._V1_.jpg',
#      'caption': {'plainText': 'Wake up with me (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Wake up with me', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Wake up with me',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6209618ebec57314a888e8fb',
#     'id': 'tt18226288',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shadows Fall Behind You',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shadows Fall Behind You',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=short&page=4&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '62160a29bd5dd4960a7cf3ef',
#     'id': 'tt18284310',
#     'primaryImage': {'id': 'rm189871361',
#      'width': 2700,
#      'height': 4050,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDYxMTI0NTQtMmMzNS00MTVlLTgyYzctNDUxNjk2ZjU5MzM3XkEyXkFqcGdeQXVyNDA1NDQ3MjI@._V1_.jpg',
#      'caption': {'plainText': 'Danae Balladares, Jesse Vega, and Gian Raffaele DiCostanzo in Tell Me(Lies) (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tell Me(Lies)', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tell Me(Lies)', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62160abd86141f87b77cf8d9',
#     'id': 'tt18293510',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Heroic', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Heroic', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6218a2f79dee539dea022034',
#     'id': 'tt18303312',
#     'primaryImage': {'id': 'rm1907431937',
#      'width': 4000,
#      'height': 6000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDMwZDkxYWUtMzc2Ni00MDk3LWE3ODMtN2JlNGI3M2YwMGNmXkEyXkFqcGdeQXVyMTE2NjU3MzA0._V1_.jpg',
#      'caption': {'plainText': 'Restitution (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Restitution', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Restitution', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6218a305c6a4b1ad860220a4',
#     'id': 'tt18304360',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'This End', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'This End', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '622d00f7556e3fdece1904a8',
#     'id': 'tt18567588',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Roll with It', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Roll with It', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6233a869609bef0c2c3317a0',
#     'id': 'tt18766098',
#     'primaryImage': {'id': 'rm3289721089',
#      'width': 1000,
#      'height': 1333,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmRiYzgxZjUtN2JkMy00N2RmLWI1NDAtMzBjNWE1MDY5NDhhXkEyXkFqcGdeQXVyMTI2MzQwNTM5._V1_.jpg',
#      'caption': {'plainText': 'Ask the Mask (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ask the Mask', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ask the Mask', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6238379e3f141533e4509586',
#     'id': 'tt18930628',
#     'primaryImage': {'id': 'rm1688687361',
#      'width': 2666,
#      'height': 3999,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjJlN2U5MzEtN2MxMi00ZGIzLWIxZTYtNzI0OGUxZjdjOGJhXkEyXkFqcGdeQXVyOTYzMjk1MTU@._V1_.jpg',
#      'caption': {'plainText': 'Erica Colson, Adwoa Duncan Williams, James Battisti, and Jeff Briggs in Inimicus (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Inimicus', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Inimicus', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '623c2bc202cf2ad0953dade9',
#     'id': 'tt18950928',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Love We Knew', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Love We Knew',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '624020335166e96bc8f789b8',
#     'id': 'tt19045634',
#     'primaryImage': {'id': 'rm3289322497',
#      'width': 7200,
#      'height': 10800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWIzNTdhMjgtMmZiMi00NmY1LWE1MjQtNGY0MzFmNWNkY2FlXkEyXkFqcGdeQXVyMTQ2NzQ0ODIw._V1_.jpg',
#      'caption': {'plainText': 'Choose the Right (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Choose the Right', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Choose the Right',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6245668262f161ebb656fc6c',
#     'id': 'tt19226682',
#     'primaryImage': {'id': 'rm1355824897',
#      'width': 2400,
#      'height': 3600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODZjNGI2ZjgtNGUyZS00Y2VkLWFmM2YtY2U1ZTRlY2FiNWM0XkEyXkFqcGdeQXVyMjgyOTQ3NzE@._V1_.jpg',
#      'caption': {'plainText': 'Emiah Reilly and Elijah Washington in Pending... (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pending...', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pending...', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=short&page=5&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '624aac3cf9b454d08db2e107',
#     'id': 'tt19317000',
#     'primaryImage': {'id': 'rm4255923969',
#      'width': 960,
#      'height': 1387,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjVjMmE5MzItMWQ2Ny00NmI2LThiODEtODRkYzQ1N2RkYTdkXkEyXkFqcGdeQXVyMjE1NTg5OTY@._V1_.jpg',
#      'caption': {'plainText': '11:53 (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '11:53', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '11:53', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '624d4ffdb1ca6fd239765db7',
#     'id': 'tt19381050',
#     'primaryImage': {'id': 'rm1106255617',
#      'width': 4096,
#      'height': 2160,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWQ5ZTUwOTAtOWY3Zi00MTc5LTg4OTAtOTY4ODljODU4NmJjXkEyXkFqcGdeQXVyMTE4Nzg0MzE2._V1_.jpg',
#      'caption': {'plainText': 'As Night Falls (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'As Night Falls', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'As Night Falls', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '624ea1533ad58cc10d81a391',
#     'id': 'tt19387342',
#     'primaryImage': {'id': 'rm1659969281',
#      'width': 3600,
#      'height': 5400,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2QxN2EwYWYtZjFhOC00MjQ3LTlhNGYtYzQ2NmJiZDJlNmMyXkEyXkFqcGdeQXVyODY0MDk4ODc@._V1_.jpg',
#      'caption': {'plainText': 'Lifeline (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Lifeline', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Lifeline', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '624ff235e1237de6d239054f',
#     'id': 'tt19384066',
#     'primaryImage': {'id': 'rm1248332289',
#      'width': 3500,
#      'height': 5250,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMWIwZjgzMTctYTNkYy00MDY4LTk4ZjYtZTY1YjU5NmEyMmRjXkEyXkFqcGdeQXVyMTI4MzQyMTY0._V1_.jpg',
#      'caption': {'plainText': 'ALUS (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'ALUS', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'ALUS', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '624ff28bc59c04e0e33907ad',
#     'id': 'tt19395042',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Machane', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Machane', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '625143d4340144166822e772',
#     'id': 'tt19396900',
#     'primaryImage': {'id': 'rm3569965057',
#      'width': 1116,
#      'height': 918,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODkwMTM5MzktYTc5Mi00YzNkLWIzOGUtZTk0NjEwN2I3MjViXkEyXkFqcGdeQXVyMTUxNTg4OTkz._V1_.jpg',
#      'caption': {'plainText': 'Katy Held and Rick Wiltshire in Here We Are (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Here We Are', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Here We Are', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62592ce3186ee232cd6986fb',
#     'id': 'tt19539550',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Prelude to War', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Prelude to War',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '626a50a1b409a79ccd76546c',
#     'id': 'tt19849708',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'For the Sake of the Kids',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'For the Sake of the Kids',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6274dc97a3f6a0265087f038',
#     'id': 'tt19896034',
#     'primaryImage': {'id': 'rm3846659585',
#      'width': 2588,
#      'height': 1598,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDA5ZDE1NmMtN2RiNC00ZTE2LWIzMTItYmZmYmQ5NzU0YTJkXkEyXkFqcGdeQXVyNDMyNTgyNDQ@._V1_.jpg',
#      'caption': {'plainText': 'Julia Rabello in Her Body, Her Choice! (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Her Body, Her Choice!', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Her Body, Her Choice!',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62777f57714c971eae4ec010',
#     'id': 'tt20101536',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Her', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Her', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=short&page=6&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '62777f57714c971eae4ec012',
#     'id': 'tt20101402',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Trip Through the Multiverse',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Trip Through the Multiverse',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6280ba2ffdc79ced9f956d06',
#     'id': 'tt20229364',
#     'primaryImage': {'id': 'rm1512582913',
#      'width': 1179,
#      'height': 1668,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZThiOGM5MjMtYmI1NS00NjNmLWE3NTUtOWY5NDAxN2QxMDNhXkEyXkFqcGdeQXVyMTUxMjA5ODQy._V1_.jpg',
#      'caption': {'plainText': 'Paige Hudson and El Anthony in Doglike (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Doglike', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Doglike', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '628b46497718ff7a6935d9d3',
#     'id': 'tt20425192',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Alguien Me Dijo Una Vez',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Alguien Me Dijo Una Vez',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '628f3aa1c3d0301a382a9fed',
#     'id': 'tt20508366',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'How He Lived', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'How He Lived', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '629480a0d0e7176f3f384a4c',
#     'id': 'tt20674446',
#     'primaryImage': {'id': 'rm2086556673',
#      'width': 1587,
#      'height': 2245,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDFmZjZkOTYtYTg0NC00ZjFhLTlmZjctNTRiYmQyMjdmYzgxXkEyXkFqcGdeQXVyODk2ODU5MzM@._V1_.jpg',
#      'caption': {'plainText': 'Fortissimo (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fortissimo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fortissimo', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6295d25812a68ca70e24824a',
#     'id': 'tt20751774',
#     'primaryImage': {'id': 'rm381366785',
#      'width': 1385,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjU3NGZmNTQtNmMxOC00YzNkLTliNDItOTBjYzY3ZGVmN2FhXkEyXkFqcGdeQXVyMjMwNDQwNA@@._V1_.jpg',
#      'caption': {'plainText': 'Pátio do Carrasco (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pátio do Carrasco', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pátio do Carrasco',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '629c6ab23d9c40f6e8a41d09',
#     'id': 'tt20854118',
#     'primaryImage': {'id': 'rm2159283969',
#      'width': 1080,
#      'height': 1920,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTI0ZjlhMGEtMWNjMy00YzA3LTk3MmMtMWYyMDA2NTE2ZDFiXkEyXkFqcGdeQXVyODE4NjU3MDg@._V1_.jpg',
#      'caption': {'plainText': "Dexter's Heart (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Dexter's Heart", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Dexter's Heart", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62a1b02627aab2c569190ce3',
#     'id': 'tt20861130',
#     'primaryImage': {'id': 'rm3601939713',
#      'width': 1072,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjg2ZmZlZmQtZjc1NC00YjZlLWE3YzktYTRjNDMwMTQ3MTNhXkEyXkFqcGdeQXVyMTUzNDcxMzEy._V1_.jpg',
#      'caption': {'plainText': 'Érinyes (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
# ...
#      'height': 7200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGNmMTAzYjYtN2QyZS00YmUwLWI3NTMtNjIxNTJhYjZjZmI2XkEyXkFqcGdeQXVyMjIxMDg1NTQ@._V1_.jpg',
#      'caption': {'plainText': 'Guilherme Daniel in Applause (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Applause', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Applause', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63d962b78c929ebea26beaa6',
#     'id': 'tt26475350',
#     'primaryImage': {'id': 'rm2842309377',
#      'width': 5400,
#      'height': 8000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjY5Mzk4ZjMtYTY4YS00YTMwLWEyNjctNWE2NTRjNWEzNzk5XkEyXkFqcGdeQXVyMTEyMDQ2OTUw._V1_.jpg',
#      'caption': {'plainText': 'Jenna Has to Live (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Jenna Has to Live', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Jenna Has to Live',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63d962c74c5e74a0576beb6e',
#     'id': 'tt26475689',
#     'primaryImage': {'id': 'rm3597349633',
#      'width': 2880,
#      'height': 1146,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzYyMDYwMjItNjc2My00MTdhLWIyNTQtODRkNTkzYjUyZDZhXkEyXkFqcGdeQXVyMTU1MjgxNzUx._V1_.jpg',
#      'caption': {'plainText': 'Lily Hutchins in Partners Forever? (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Partners Forever?', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Partners Forever?',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63d962ca8c929ebea26beba2',
#     'id': 'tt26475774',
#     'primaryImage': {'id': 'rm2892837633',
#      'width': 1414,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTY1N2EwNTYtZjg4Ni00Njg4LThlY2EtYThlOWMyMWQ3OTlmXkEyXkFqcGdeQXVyMTIyODY5Mjk1._V1_.jpg',
#      'caption': {'plainText': 'Milite (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Milite', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Milite', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=short&page=63dc04f7d70186dfb0e118d4&year=2023&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '63d962dd4c5e74a0576bec7c',
#     'id': 'tt26485446',
#     'primaryImage': {'id': 'rm65744897',
#      'width': 2000,
#      'height': 2667,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTRiMWIzYmUtNDQwOS00NDc2LTg3MDctNmU3OTIxNGY1NTlmXkEyXkFqcGdeQXVyMTQxOTg0MDU4._V1_.jpg',
#      'caption': {'plainText': 'Contrapuesto (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Contrapuesto', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Contrapuesto', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63d963324c5e74a0576bf066',
#     'id': 'tt26491529',
#     'primaryImage': {'id': 'rm4120326145',
#      'width': 2500,
#      'height': 3333,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjdjY2Y2NDgtMTNjYy00YjNhLWFjN2YtMDhiNjAyZmFhMTE1XkEyXkFqcGdeQXVyMzgyMDI4Njk@._V1_.jpg',
#      'caption': {'plainText': 'Cody Slice, Trenton Shirk, Nick Rodriguez, and Frederick Ramirez in Face the music (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Face the music', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Face the music', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63d963518c929ebea26bf1fe',
#     'id': 'tt26492355',
#     'primaryImage': {'id': 'rm460468993',
#      'width': 967,
#      'height': 1611,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjQ0YmU1MGUtNGQ5ZS00MDQxLWI1MDItOGIyNGE0YTgwZWZiXkEyXkFqcGdeQXVyMTA0NTMxMDk3._V1_.jpg',
#      'caption': {'plainText': 'Debbie Marr in Jackie (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Jackie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Jackie', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63dc04ce92b87e828fe116d8',
#     'id': 'tt26492049',
#     'primaryImage': {'id': 'rm3029020673',
#      'width': 4294,
#      'height': 5978,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjdlN2VjMjItNmJiMy00Y2IwLTk3MjItMjMyNjQ4MDNiZDA1XkEyXkFqcGdeQXVyNjk3MjcyMTg@._V1_.jpg',
#      'caption': {'plainText': 'Ashish Khondker and Asma Akhter in Khowab: Castle in The Air (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Khowab: Castle in The Air',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Khowab: Castle in The Air',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '63dc04ced70186dfb0e116d8',
#     'id': 'tt26491587',
#     'primaryImage': {'id': 'rm2452763393',
#      'width': 7205,
#      'height': 10748,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2I4NGQ5YmQtZGJjNS00MWRjLTk2NzAtZmViYTM3OTVjNzZkXkEyXkFqcGdeQXVyMTUwMTY5MTk0._V1_.jpg',
#      'caption': {'plainText': 'Amy Newton in Cecile Park Rd. (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cecile Park Rd.', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cecile Park Rd.',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '63dc04cfd70186dfb0e116da',
#     'id': 'tt26490796',
#     'primaryImage': {'id': 'rm1629762305',
#      'width': 2400,
#      'height': 3600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGI4MDI0OTEtOWRjZS00ODZhLTg4YzUtZmNmOTc5MWU5ODY3XkEyXkFqcGdeQXVyMTI2ODc3NDAw._V1_.jpg',
#      'caption': {'plainText': 'Shit Happens (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shit Happens', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shit Happens', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63dc04d0d70186dfb0e116e4',
#     'id': 'tt26492279',
#     'primaryImage': {'id': 'rm1906323457',
#      'width': 2896,
#      'height': 4096,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTE5YmQ5YTgtZWZjOC00MThkLWIzNmItZTM5ZTliYjBjZTgwXkEyXkFqcGdeQXVyNTg5ODA2MTk@._V1_.jpg',
#      'caption': {'plainText': 'Bella Duve, Kartiya Ilardo, Ethan Hall, Michael Lake, and Ella Muscroft in Just Us Two (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Just Us Two', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Just Us Two', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63dc04d192b87e828fe116f2',
#     'id': 'tt26491972',
#     'primaryImage': {'id': 'rm2958177025',
#      'width': 2912,
#      'height': 4119,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDg3ODZiYzktZTQzZC00ZDJiLWFjNjQtNzZhMDcwOWI3NmJlXkEyXkFqcGdeQXVyMTM5MTI0MTQ1._V1_.jpg',
#      'caption': {'plainText': "D'amgo (2023)", '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "D'amgo", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "D'amgo", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63dc04e192b87e828fe117b2',
#     'id': 'tt26493003',
#     'primaryImage': {'id': 'rm688075521',
#      'width': 4050,
#      'height': 6000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzA4ZTNhYTItZDgzZS00MjY5LWEzNmMtN2M5OGI1NTRlMTMwXkEyXkFqcGdeQXVyNjc1Mzg5MzU@._V1_.jpg',
#      'caption': {'plainText': 'Red, Green and All Things in Between (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Red, Green and All Things in Between',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Red, Green and All Things in Between',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63dc04f7d70186dfb0e118d4',
#     'id': 'tt26493843',
#     'primaryImage': {'id': 'rm2370188033',
#      'width': 949,
#      'height': 1080,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNWYzNmI3Y2EtNDRkZi00MzEyLTgzMDgtZmNiNjlkYWY5MTFhXkEyXkFqcGdeQXVyMTExOTk2ODI4._V1_.jpg',
#      'caption': {'plainText': 'A Cousin and a Hood Complex (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Cousin and a Hood Complex',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Cousin and a Hood Complex',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]}]

# %%
lista_json_anios3[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=short&page=2&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5846095801a78bc420d3f',
#     'id': 'tt0381701',
#     'primaryImage': {'id': 'rm2070718208',
#      'width': 473,
#      'height': 712,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAwNDQzNzE3MF5BMl5BanBnXkFtZTcwMDcwOTU1OQ@@._V1_.jpg',
#      'caption': {'plainText': 'The Watch (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Watch', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Watch', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58545ef99b1c5434240a9',
#     'id': 'tt0462225',
#     'primaryImage': {'id': 'rm1261434113',
#      'width': 1013,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGNiYTE4MjctNDY4Yy00MjM4LWE5YjctZmFmZDU5MmQ1ZDgwXkEyXkFqcGdeQXVyODA0NDUyODA@._V1_.jpg',
#      'caption': {'plainText': 'Changeling (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Changeling', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Changeling', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5898d78c012aa344334ff',
#     'id': 'tt0847208',
#     'primaryImage': {'id': 'rm228953088',
#      'width': 600,
#      'height': 896,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU4NDY1ODUyMl5BMl5BanBnXkFtZTcwOTk4NjcyMw@@._V1_.jpg',
#      'caption': {'plainText': 'The Crooked Eye (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Crooked Eye', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Crooked Eye',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e589a68a5a6a599f433d01',
#     'id': 'tt0855849',
#     'primaryImage': {'id': 'rm2813581568',
#      'width': 2592,
#      'height': 1944,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU2NTk1NzUxNF5BMl5BanBnXkFtZTgwMzE1NDAxMDE@._V1_.jpg',
#      'caption': {'plainText': 'Ahichel Valle in Julieta (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Julieta', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Julieta', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e589faa66e596423434e37',
#     'id': 'tt0886528',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rougge the Vampyre', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rougge the Vampyre',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58a4f95801a78bc436319',
#     'id': 'tt0918541',
#     'primaryImage': {'id': 'rm3718246912',
#      'width': 350,
#      'height': 494,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTA4MTIyODgwMjheQTJeQWpwZ15BbWU4MDUwMDg3NDQx._V1_.jpg',
#      'caption': {'plainText': 'Laundry (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Laundry', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Laundry', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58a57ef99b1c543436411',
#     'id': 'tt0918631',
#     'primaryImage': {'id': 'rm712430080',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjI0NTM5MjU3OV5BMl5BanBnXkFtZTgwNTk1MTA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'The Summer House (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Summer House', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Summer House',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58a89a66e596423436f4f',
#     'id': 'tt0939641',
#     'primaryImage': {'id': 'rm246124032',
#      'width': 511,
#      'height': 768,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjg3ODg5NDk5OV5BMl5BanBnXkFtZTcwMjkxODg5Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Poster for the 2009 Short Film "Murder by Appointment"',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Murder by Appointment', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Murder by Appointment',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58a94e1a8ddbd964371cf',
#     'id': 'tt0942381',
#     'primaryImage': {'id': 'rm747114496',
#      'width': 7200,
#      'height': 10800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTVkZDZkY2YtOTJkMS00NGFkLWI0ZjYtYmI5NmI4NzFkMzU1XkEyXkFqcGdeQXVyMTk1OTQ3Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Hassan Said, Dan Higgins, Jesse Mueller, and Vanessa Donley in Mute (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mute', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mute', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58acb909c2ca781437e5b',
#     'id': 'tt0963160',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Birthday Party', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Birthday Party',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=short&page=3&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58aeb95801a78bc4387a7',
#     'id': 'tt0974610',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Offer', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Offer', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e58b1078c012aa34438e1f',
#     'id': 'tt0989088',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Today', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Today', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e58b72ef99b1c54343a653',
#     'id': 'tt10042034',
#     'primaryImage': {'id': 'rm3104989696',
#      'width': 458,
#      'height': 258,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjA4ZDc1Y2QtNTcwMi00NWQ2LThmNmMtNWVjZDY5MGVlZDU0XkEyXkFqcGdeQXVyODM0MjU0NzQ@._V1_.jpg',
#      'caption': {'plainText': 'Giovanni Morassutti in Diavoli nella polvere (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Diavoli nella polvere', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Diavoli nella polvere',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58b7def99b1c54343a939',
#     'id': 'tt10049918',
#     'primaryImage': {'id': 'rm3954270976',
#      'width': 1920,
#      'height': 1080,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOWRhZWFkNDgtNDcwOC00NmM2LWJlZTktNGM1ZWRhNTcwNjExXkEyXkFqcGdeQXVyMzY0MTY2MDA@._V1_.jpg',
#      'caption': {'plainText': 'Colchones (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Colchones', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Colchones', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 2,
#      'year': 2014,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58b9e971a4a15d643b1dd',
#     'id': 'tt10073900',
#     'primaryImage': {'id': 'rm274359040',
#      'width': 3043,
#      'height': 1699,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTAxMGE2ZGEtMDc5Yy00Y2YwLWE0OGUtZjhiYmMzNGRjMDcxXkEyXkFqcGdeQXVyODMzMDIzNjI@._V1_.jpg',
#      'caption': {'plainText': 'Bandoneón (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bandoneón', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bandoneón', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58bb48a5a6a599f43b8bf',
#     'id': 'tt10089486',
#     'primaryImage': {'id': 'rm3740164096',
#      'width': 632,
#      'height': 893,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTQ4NmVmOWMtODFlNS00ZmViLThmYjItODg5ODMzMmFjMTcxXkEyXkFqcGdeQXVyOTIxNDQ1MTQ@._V1_.jpg',
#      'caption': {'plainText': 'Chú Bé Dánh Giày (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Chú Bé Dánh Giày', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Chú Bé Dánh Giày',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58bd478c012aa3443bdbb',
#     'id': 'tt10111260',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Twisted Summer', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Twisted Summer',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58bfad8f3c0931e43c88b',
#     'id': 'tt10136042',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Perdóname', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Perdóname', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58c23e1a8ddbd9643d259',
#     'id': 'tt10164194',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'O Homem do Realejo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'O Homem do Realejo',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58c47971a4a15d643dc0b',
#     'id': 'tt1018822',
#     'primaryImage': {'id': 'rm2138656256',
#      'width': 4972,
#      'height': 2682,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTNmYjk0ODctNmM2NC00MjAxLWEwYmYtNTVhYzJmZjdiMjI1XkEyXkFqcGdeQXVyMTg4MTAxMDM@._V1_.jpg',
#      'caption': {'plainText': 'Stray (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Stray', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Stray', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=short&page=4&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58c6ad735dff3f943e53f',
#     'id': 'tt10209132',
#     'primaryImage': {'id': 'rm722429440',
#      'width': 363,
#      'height': 393,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTEwYzc2OTItNDY3OC00ZjcyLWE3MjEtMGU3ZjFmZjgxZTFjXkEyXkFqcGdeQXVyNzI4MDMyMTU@._V1_.jpg',
#      'caption': {'plainText': 'Be with Me (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Be with Me', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Be with Me', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cf7d735dff3f944071d',
#     'id': 'tt10300058',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tango du poulailler', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tango du poulailler',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d1cef99b1c543440e57',
#     'id': 'tt10326996',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'La Nada Absoluta', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'La Nada Absoluta',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d6395801a78bc442295',
#     'id': 'tt10374158',
#     'primaryImage': {'id': 'rm690854401',
#      'width': 1260,
#      'height': 900,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmFmNjBmMmYtYzFjOS00YWFkLWEwMzItYjM4ODFkNDc3NDVlXkEyXkFqcGdeQXVyNjI5MDU4OTE@._V1_.jpg',
#      'caption': {'plainText': 'Hódomb (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Hódomb', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Hódomb', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58db0a66e5964234433b3',
#     'id': 'tt10428636',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '16mm Films', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '16mm Films', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58dde8a5a6a599f444081',
#     'id': 'tt10456884',
#     'primaryImage': {'id': 'rm1498454273',
#      'width': 941,
#      'height': 1408,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzQwNTIxMmEtN2M1MS00Yzg3LThiMWUtN2I3NzhmMWIwMGM2XkEyXkFqcGdeQXVyMDc2NTM3Nw@@._V1_.jpg',
#      'caption': {'plainText': 'Surrogate Dad (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Surrogate Dad', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Surrogate Dad', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58de0971a4a15d6443fbb',
#     'id': 'tt10457270',
#     'primaryImage': {'id': 'rm2639960321',
#      'width': 896,
#      'height': 1408,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjJjYjViZDctN2QwNC00OWExLTlhMDQtODZiNzc1Y2NiZWE0XkEyXkFqcGdeQXVyMDc2NTM3Nw@@._V1_.jpg',
#      'caption': {'plainText': 'Carrie (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Carrie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Carrie', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ea5b597b91eb9446e5d',
#     'id': 'tt10585010',
#     'primaryImage': {'id': 'rm2526911489',
#      'width': 2880,
#      'height': 1800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzIzMmY4YmEtMGUzOC00ODQ5LWI0YmQtM2RlNDE1MWIzMmUwXkEyXkFqcGdeQXVyNDYyOTUwMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Vonne Patiag in Aftermath (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Aftermath', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Aftermath', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ebfd8f3c0931e447471',
#     'id': 'tt1059949',
#     'primaryImage': {'id': 'rm55005696',
#      'width': 1024,
#      'height': 776,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjQ0NTgzMTItNTA1Mi00NDFkLTlmOTUtZTk3ZTNjYWEyMTZlXkEyXkFqcGdeQXVyMDM1MzIyMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Nous (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nous', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nous', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ec1d8f3c0931e4474e5',
#     'id': 'tt10603028',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Thorns', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Thorns', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=short&page=5&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e58eefd8f3c0931e448007',
#     'id': 'tt10631596',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'El color de la mandarina',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'El color de la mandarina',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58f118a5a6a599f44899b',
#     'id': 'tt10654678',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Superkrefter', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Superkrefter', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58f3ad8f3c0931e4491f5',
#     'id': 'tt10678520',
#     'primaryImage': {'id': 'rm1983880449',
#      'width': 641,
#      'height': 967,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGM3YzY5NjYtNTI1MS00ZjI5LWFhNDYtMmU4MzI1ZThkNWJkXkEyXkFqcGdeQXVyMTE3MjgyODQ@._V1_.jpg',
#      'caption': {'plainText': 'The Powerhouse (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Powerhouse', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Powerhouse', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fda909c2ca78144b853',
#     'id': 'tt10784390',
#     'primaryImage': {'id': 'rm3603795969',
#      'width': 1680,
#      'height': 1050,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAwN2E4MWUtN2E0MS00MTVhLTg3MGEtNzYwNGRhY2ZmYmNkXkEyXkFqcGdeQXVyODQ1Mzk1NDI@._V1_.jpg',
#      'caption': {'plainText': 'Trozos de lluvia (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Trozos de lluvia', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Trozos de lluvia',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fe595801a78bc44bddd',
#     'id': 'tt10793810',
#     'primaryImage': {'id': 'rm3634794497',
#      'width': 2556,
#      'height': 1404,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZGZkYmEyYTQtY2FmNS00MTA5LTlhMjQtNzRlZWQzNTg5YjRmXkEyXkFqcGdeQXVyMTAwNDU2NjE4._V1_.jpg',
#      'caption': {'plainText': 'Conrad Sundqvist-Olmos in Vit som Snö (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Vit som Snö', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Vit som Snö', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58feeb597b91eb944bdc5',
#     'id': 'tt10798590',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ne sluchilos', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ne sluchilos', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fef8a5a6a599f44c00b',
#     'id': 'tt10800016',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Soul Happiness', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Soul Happiness', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fefe1a8ddbd9644bee9',
#     'id': 'tt10801372',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Den Utvalgte', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Den Utvalgte', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59075d8f3c0931e44df15',
#     'id': 'tt10888940',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dieu est loin', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dieu est loin', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5907e95801a78bc44e337',
#     'id': 'tt10893594',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dia de sol', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dia de sol', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=short&page=6&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e590b2a66e59642344ee6f',
#     'id': 'tt10927096',
#     'primaryImage': {'id': 'rm1940297473',
#      'width': 1240,
#      'height': 1754,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOThmNThlOGUtZmRhZi00MDA2LTk2MjEtZjc5MzJkNTBkYTAwXkEyXkFqcGdeQXVyMTA3NDMyNjM2._V1_.jpg',
#      'caption': {'plainText': '7 Dias Após 8 Semanas (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '7 Dias Após 8 Semanas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '7 Dias Após 8 Semanas',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590bda66e59642344f123',
#     'id': 'tt10933254',
#     'primaryImage': {'id': 'rm2602403841',
#      'width': 3300,
#      'height': 5100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjFjMDk4NTQtOTk1OC00ZWFjLWI0MGMtMDk1NTA5YjkwMDFiXkEyXkFqcGdeQXVyMTg5NjczNzI@._V1_.jpg',
#      'caption': {'plainText': 'Ken Robbins, Marco Leone, Stuart Starr, and Alina Pryanishnikova in Shylock (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shylock', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shylock', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59124971a4a15d6450ad7',
#     'id': 'tt11001120',
#     'primaryImage': {'id': 'rm1549764865',
#      'width': 3300,
#      'height': 5100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjcxYTkxZGUtMjczZi00OWM1LWI3YjktMThkMmVmODY2YTI2XkEyXkFqcGdeQXVyMDU5NzQzNA@@._V1_.jpg',
#      'caption': {'plainText': 'Jackie Williams and Deserae Williams in Beyond the Forest (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Beyond the Forest', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Beyond the Forest',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59139cffb8f2faa450f3d',
#     'id': 'tt11016412',
#     'primaryImage': {'id': 'rm1045072897',
#      'width': 586,
#      'height': 780,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWY5NWY4ZmItODUwYy00ZDkwLThlM2MtMzFhODg0Njg2ZWMwXkEyXkFqcGdeQXVyMjAwMTQ0NDM@._V1_.jpg',
#      'caption': {'plainText': 'Vit Fic in Silver Rainbow (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Silver Rainbow', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Silver Rainbow', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5917278c012aa34451ba7',
#     'id': 'tt11055948',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Timelord Warning', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Timelord Warning',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5917a909c2ca781451ecd',
#     'id': 'tt11061068',
#     'primaryImage': {'id': 'rm2773912065',
#      'width': 800,
#      'height': 1160,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzYwMzRmNTEtZmUzOC00Yjc4LTlkNTctY2Q1ZWFhMjllN2U4XkEyXkFqcGdeQXVyNDQxNTgzMzM@._V1_.jpg',
#      'caption': {'plainText': 'Ascenso (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ascenso', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ascenso', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e591b178c012aa34452b2b',
#     'id': 'tt1109617',
#     'primaryImage': {'id': 'rm969104128',
#      'width': 1440,
#      'height': 1080,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTFmYzFmMzctZTNiNi00MzIzLWFmN2UtZjkzZDM3MWMwYjMwXkEyXkFqcGdeQXVyMjY2OTQ2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Meshuggeneh (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Meshuggeneh', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Meshuggeneh', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e591ead8f3c0931e453aed',
#     'id': 'tt11132832',
#     'primaryImage': {'id': 'rm3316484097',
#      'width': 652,
#      'height': 732,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2MxMmU3NDQtYTY2Ni00ODgwLWExYzctOWM2MzA2OTZmMjY4XkEyXkFqcGdeQXVyMjI3MDczMjI@._V1_.jpg',
#      'caption': {'plainText': 'Dance of the Last Shaker (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dance of the Last Shaker',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dance of the Last Shaker',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59242909c2ca781455013',
#     'id': 'tt11192326',
#     'primaryImage': {'id': 'rm3023735041',
#      'width': 881,
#      'height': 1250,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjIyOWE2YmItNGM3Ny00OTdkLWJlYmQtYjZlN2QzMmYzY2Y1XkEyXkFqcGdeQXVyNDMxMTMxOTk@._V1_.jpg',
#      'caption': {'plainText': 'Deux (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Deux', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Deux', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5928fd735dff3f9456427',
#     'id': 'tt11244380',
#     'primaryImage': {'id': 'rm3354117889',
#      'width': 1718,
#      'height': 2571,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDk5YTViMjctMDBjNi00ZmEzLTljYjAtYzAyY2FjMGFlZGYyXkEyXkFqcGdeQXVyNjQ1OTk0MDY@._V1_.jpg',
#      'caption': {'plainText': 'What happened to Ellie (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'What happened to Ellie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'What happened to Ellie',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '6',
#   'next': '/titles?titleType=short&page=7&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5930b78c012aa34457f2f',
#     'id': 'tt11323780',
#     'primaryImage': {'id': 'rm3695807489',
#      'width': 750,
#      'height': 1282,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGYwNDc5NDgtZmE3OS00NGRhLTlmMDAtMzc3MjQ5NWZiZWRjXkEyXkFqcGdeQXVyNDEyMzAyNQ@@._V1_.jpg',
#      'caption': {'plainText': 'El Centro (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'El Centro', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'El Centro', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5930ccffb8f2faa45815f',
#     'id': 'tt11327134',
#     'primaryImage': {'id': 'rm3398141185',
#      'width': 331,
#      'height': 488,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzZlZDJkMzItNTQ3Zi00ZDZlLTk3YzctZTg5OTM5NWJmYWUzXkEyXkFqcGdeQXVyMjAyOTcwMjA@._V1_.jpg',
#      'caption': {'plainText': 'Dias de Greve (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dias de Greve', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dias de Greve', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5936478c012aa344594b9',
#     'id': 'tt11383680',
#     'primaryImage': {'id': 'rm3879581185',
#      'width': 1542,
#      'height': 2172,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjYxOTkxMDgtZWI2Ni00MWM5LWIyOTUtMjRlYzJlYjI2ZGExXkEyXkFqcGdeQXVyMzUyODYwOTA@._V1_.jpg',
#      'caption': {'plainText': 'Coser e cantar (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Coser e cantar', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Coser e cantar', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59395cffb8f2faa45a289',
#     'id': 'tt11417124',
#     'primaryImage': {'id': 'rm2017952257',
#      'width': 1366,
#      'height': 768,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzM1YjI0YmYtYzM4Yi00NmQ4LTljMTQtNzk5MDU1MzFhODdiXkEyXkFqcGdeQXVyMTAxMzQ0MTYy._V1_.jpg',
#      'caption': {'plainText': 'Karta al Padre (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Karta al Padre', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Karta al Padre', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593afcffb8f2faa45a901',
#     'id': 'tt11432772',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Boxer', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Boxer', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593ba8a5a6a599f45aebb',
#     'id': 'tt11439500',
#     'primaryImage': {'id': 'rm2556657665',
#      'width': 873,
#      'height': 480,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjBjNzBiNWMtYzAyNi00MzAxLThlYzktN2VjYjE4MzE0YTFkXkEyXkFqcGdeQXVyMTcwMTE1NjU@._V1_.jpg',
#      'caption': {'plainText': 'Graham K. Furness and Mark Theodossiou in Before the sun sets (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Before the sun sets', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Before the sun sets',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593c18a5a6a599f45b0ab',
#     'id': 'tt11446004',
#     'primaryImage': {'id': 'rm3149366017',
#      'width': 420,
#      'height': 600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzdlMmRjOTYtMjU5Zi00NDk4LTk0ODYtMmVlMWZmNTNhMDhiXkEyXkFqcGdeQXVyNjgzMjQ0MTA@._V1_.jpg',
#      'caption': {'plainText': 'Boutellisse (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Boutellisse', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Boutellisse', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593dad735dff3f945b441',
#     'id': 'tt11460056',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Prestige', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Prestige', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e593f98a5a6a599f45be67',
#     'id': 'tt11483260',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nimiedades', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nimiedades', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5942378c012aa3445c3c1',
#     'id': 'tt11511942',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Redención', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Redención', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '7',
#   'next': '/titles?titleType=short&page=8&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5943c78c012aa3445c9f1',
#     'id': 'tt1152837',
#     'primaryImage': {'id': 'rm240817920',
#      'width': 3590,
#      'height': 5375,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTMyODY1OTc1M15BMl5BanBnXkFtZTcwNzYwODc3MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Purge (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Purge', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Purge', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59462d735dff3f945d5dd',
#     'id': 'tt11553258',
#     'primaryImage': {'id': 'rm2037940481',
#      'width': 509,
#      'height': 720,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjk3YjdmODUtODg3ZS00YzliLTk3MDQtNjFkYWU1NDMzNjYyXkEyXkFqcGdeQXVyMjA3ODA3ODc@._V1_.jpg',
#      'caption': {'plainText': 'Conception (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Conception', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Conception', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5946c95801a78bc45d99f',
#     'id': 'tt11559408',
#     'primaryImage': {'id': 'rm1117437953',
#      'width': 2667,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODBlYTA1YzMtYThlOC00YTYyLTg2OTQtODczNzM5MDdkYWZlXkEyXkFqcGdeQXVyMDU2ODU4MQ@@._V1_.jpg',
#      'caption': {'plainText': 'The Night (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Night', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Night', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
# ...
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Reunion of Amilia Marbleberry and Marcy Stills',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a058a66e59642348d089',
#     'id': 'tt1361849',
#     'primaryImage': {'id': 'rm2417920512',
#      'width': 500,
#      'height': 773,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODA2MzQwMzI3MF5BMl5BanBnXkFtZTcwMzkyMDEzMg@@._V1_.jpg',
#      'caption': {'plainText': 'A Bakery Story (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Bakery Story', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Bakery Story', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a058b597b91eb948ce2b',
#     'id': 'tt1361854',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Committed', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Committed', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a0598a5a6a599f48d427',
#     'id': 'tt1361884',
#     'primaryImage': {'id': 'rm189583872',
#      'width': 343,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjQ0Nzg0NjQzNF5BMl5BanBnXkFtZTgwNjQyMzA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'Satisfaction (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Satisfaction', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Satisfaction', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a059971a4a15d648d155',
#     'id': 'tt1362085',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Homeland Security: A Cinépoem',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Homeland Security: A Cinépoem',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '49',
#   'next': '/titles?titleType=short&page=50&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5a059e1a8ddbd9648d39f',
#     'id': 'tt1362091',
#     'primaryImage': {'id': 'rm272173056',
#      'width': 1467,
#      'height': 2160,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjQyMjQwZjQtNzU5Ni00MGEwLWI4NTQtNDE1NDI5ZjM1ODkyXkEyXkFqcGdeQXVyMjA0NjcxNzk@._V1_.jpg',
#      'caption': {'plainText': 'Jeannette (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Jeannette', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Jeannette', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a05a78c012aa3448ce33',
#     'id': 'tt1362199',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cross Currents', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cross Currents', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a05ad8f3c0931e48d3a9',
#     'id': 'tt1362162',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'American Soil', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'American Soil', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05b78c012aa3448cea7',
#     'id': 'tt1362214',
#     'primaryImage': {'id': 'rm617187328',
#      'width': 1575,
#      'height': 2399,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAzMTQ5MzIyOF5BMl5BanBnXkFtZTcwNTU5NjU1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Empathy (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Empathy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Empathy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05b95801a78bc48d4ef',
#     'id': 'tt1362129',
#     'primaryImage': {'id': 'rm241317120',
#      'width': 2816,
#      'height': 2112,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDgzNzA5OTctYTM0OS00Y2NmLWE2YzktOGY3MjQ0MjgzZGFhXkEyXkFqcGdeQXVyMjA0MjQ5MzY@._V1_.jpg',
#      'caption': {'plainText': "Emmanuel Delcour in Sunday at the Sinners' (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Sunday at the Sinners'", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Sunday at the Sinners'",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a05b971a4a15d648d1bb',
#     'id': 'tt1362236',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Indigo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Indigo', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05b971a4a15d648d1eb',
#     'id': 'tt1362459',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The One-Wayz', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The One-Wayz', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a05ba66e59642348d155',
#     'id': 'tt1362142',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Visitation', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Visitation', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05bb597b91eb948cf01',
#     'id': 'tt1362145',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Where Do the Balloons Go?',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Where Do the Balloons Go?',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05bb597b91eb948cf05',
#     'id': 'tt1362155',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '1956', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '1956', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=short&page=61e5a05cd8f3c0931e48d441&year=2009&genre=Drama',
#   'entries': 10,
#   'results': [{'_id': '61e5a05bcffb8f2faa48d247',
#     'id': 'tt1362346',
#     'primaryImage': {'id': 'rm2767785216',
#      'width': 563,
#      'height': 756,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzJiYjk0ZTMtMWFmZi00ZmVjLTljOTYtZTg2ZmYyNGFiZmE3XkEyXkFqcGdeQXVyNjg5NTYyNTg@._V1_.jpg',
#      'caption': {'plainText': '5 Then 4 (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '5 Then 4', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '5 Then 4', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05bd735dff3f948d25f',
#     'id': 'tt1362108',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Panic Attack', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Panic Attack', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05bd735dff3f948d273',
#     'id': 'tt1362166',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Andheri', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Andheri', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05bd8f3c0931e48d409',
#     'id': 'tt13621736',
#     'primaryImage': {'id': 'rm1833426177',
#      'width': 438,
#      'height': 606,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDQxOGU3ZTAtNDNhNS00ZDliLTllN2EtMDg4MmU0N2Y3ZTU0XkEyXkFqcGdeQXVyODgxMDAxMjY@._V1_.jpg',
#      'caption': {'plainText': 'São (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'São', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'São', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05be1a8ddbd9648d3f7',
#     'id': 'tt1362382',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Closet', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Closet', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05c8a5a6a599f48d4d9',
#     'id': 'tt1362332',
#     'primaryImage': {'id': 'rm672107776',
#      'width': 3500,
#      'height': 5250,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTg4NTkxNTA2NV5BMl5BanBnXkFtZTcwNDEyNjQ0Mw@@._V1_.jpg',
#      'caption': {'plainText': 'When in Rome (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'When in Rome', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'When in Rome', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05cb597b91eb948cf2d',
#     'id': 'tt1362288',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Perspective', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Perspective', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a05cb597b91eb948cf3b',
#     'id': 'tt1362385',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Communion', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Communion', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05ccffb8f2faa48d271',
#     'id': 'tt1362383',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Closure', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Closure', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a05cd8f3c0931e48d441',
#     'id': 'tt1362306',
#     'primaryImage': {'id': 'rm3057433344',
#      'width': 2550,
#      'height': 4200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTk3NDA0Nzc1MF5BMl5BanBnXkFtZTcwNjE2ODk3NA@@._V1_.jpg',
#      'caption': {'plainText': 'A Second Chance (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Second Chance', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Second Chance',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]}]

# %%
#unificamos ambas listas con lo sacado de la API
lista_json_anios = lista_json_anios + lista_json_anios1 + lista_json_anios2 + lista_json_anios3

# %%
#creamos una función para sacar los datos que queremos de los json

def busqueda_info (lista):
    datos = []
    #un primer bucle para iterar por cada año
    for num in range (0,len(lista)):
        #iteramos por cada película
        for pelicula in lista[num]["results"]:
            lista_para_tupla = []
            lista_para_tupla.append(pelicula["titleType"]["text"])
            lista_para_tupla.append(pelicula['originalTitleText']['text'])
            
            try: #si el valor de año es nulo cogemos el otro dato de año que tiene el json
                lista_para_tupla.append(pelicula["releaseDate"]["year"])
            except:
                lista_para_tupla.append(pelicula["releaseYear"]["year"])

            try:#si el valor de mes es nulo, appendeamos 0
                lista_para_tupla.append(pelicula['releaseDate']['month'])
            except:
                lista_para_tupla.append(0)

            lista_para_tupla.append(pelicula['id'])

            #convertimos en tupla
            tupla = tuple(lista_para_tupla)
            
            #añadimos la tupla a la lista 
            datos.append(tupla)
            
                
    return datos

# %%
#llamamos a la funcion anterior

datos_final = []

fin =len(lista_json_anios)

for num in range(0,fin):
    lista3 = busqueda_info(lista_json_anios[num])
    datos_final = datos_final + lista3

datos_final
# Out:
# [('Movie', 'Pál Adrienn', 2011, 6, 'tt0146592'),
#  ('Movie', 'Oda az igazság', 2010, 2, 'tt0154039'),
#  ('Movie', 'A zöld sárkány gyermekei', 2011, 4, 'tt0162942'),
#  ('Movie', 'The Final Journey', 2010, 9, 'tt0230212'),
#  ('Movie', 'In My Sleep', 2010, 4, 'tt0326965'),
#  ('Movie', 'This Wretched Life', 2010, 7, 'tt0331312'),
#  ('Movie', 'Blind Sided', 2010, 0, 'tt0337882'),
#  ('Movie', "Anderson's Cross", 2010, 5, 'tt0393049'),
#  ('Movie', 'Den milde smerte', 2014, 5, 'tt0396123'),
#  ('Movie', 'Capture the Flag', 2010, 0, 'tt0402887'),
#  ('Movie', 'Utomlennye solntsem 2', 2010, 4, 'tt0403645'),
#  ('Movie', 'Tekken', 2010, 3, 'tt0411951'),
#  ('Movie', 'Disconnect', 2010, 8, 'tt0419692'),
#  ('Movie', 'Milenge Milenge', 2010, 7, 'tt0443331'),
#  ('Movie', 'Les 7 jours du talion', 2010, 11, 'tt0445054'),
#  ('Movie', 'Vidas pequeñas', 2011, 3, 'tt0444531'),
#  ('Movie', 'Dream Street', 2010, 1, 'tt0446686'),
#  ('Movie', 'Mad World', 2010, 8, 'tt0451108'),
#  ('Movie', 'El hada buena - Una fábula peronista', 2010, 4, 'tt0454155'),
#  ('Movie', 'Memorias del desarrollo', 2011, 11, 'tt0457591'),
#  ('Movie', 'Drunkboat', 2013, 6, 'tt0460778'),
#  ('Movie', 'Federal', 2010, 10, 'tt0463311'),
#  ('Movie', 'Taken by Force', 2010, None, 'tt0465637'),
#  ('Movie', 'Sensual', 2010, None, 'tt0465760'),
#  ('Movie', 'Harlem Hostel', 2010, 2, 'tt0469094'),
#  ('Movie', 'Cielito lindo', 2010, 6, 'tt0473343'),
#  ('Movie',
#   'The Deafening Silence of a Very Bright Light',
#   2010,
#   0,
#   'tt0475983'),
#  ('Movie', 'The Greater Meaning of Water', 2010, None, 'tt0479051'),
#  ('Movie', 'Barry Munday', 2010, 3, 'tt0482461'),
#  ('Movie', 'Bandeiji', 2010, 1, 'tt0482459'),
#  ('Movie', 'A Woman Is a Woman', 2010, None, 'tt0483839'),
#  ('Movie', 'PrimeMates', 2010, 1, 'tt0490199'),
#  ('Movie', 'Ramona and Beezus', 2010, 7, 'tt0493949'),
#  ('Movie', 'Good Sharma', 2017, None, 'tt0494229'),
#  ('Movie', 'O Inimigo Sem Rosto', 2010, 8, 'tt0495037'),
#  ('Movie', 'Tranced', 2010, None, 'tt0499608'),
#  ('Movie', 'Love & Other Drugs', 2011, 1, 'tt0758752'),
#  ('Movie', 'King of the Avenue', 2010, 9, 'tt0770778'),
#  ('Movie', 'Night Catches Us', 2010, 12, 'tt0775543'),
#  ('Movie', "L'illusionniste", 2010, 7, 'tt0775489'),
#  ('Movie', 'El cielo elegido', 2012, 9, 'tt0774519'),
#  ('Movie', 'The Wolfman', 2010, 2, 'tt0780653'),
#  ('Movie', 'The First Grader', 2011, 8, 'tt0790663'),
#  ('Movie', '13', 2011, 6, 'tt0798817'),
#  ('Movie', 'Ironmen', 2010, None, 'tt0800092'),
#  ('Movie', 'Nemesis', 2010, 10, 'tt0800353'),
#  ('Movie', "It's Kind of a Funny Story", 2010, 10, 'tt0804497'),
#  ('Movie', 'Ashes', 2010, 9, 'tt0815101'),
#  ('Movie', 'Flipped', 2010, 9, 'tt0817177'),
#  ('Movie', 'Soupernatural', 2010, None, 'tt0818172'),
#  ('Movie', 'Waking Madison', 2010, None, 'tt0831280'),
#  ('Movie', 'The Kids Are All Right', 2010, 12, 'tt0842926'),
#  ('Movie', 'The Town', 2010, 10, 'tt0840361'),
#  ('Movie', 'Killer by Nature', 2010, None, 'tt0844866'),
#  ('Movie', 'Risen', 2011, 5, 'tt0850709'),
#  ('Movie', 'Bloudím', 2010, 10, 'tt0852939'),
#  ('Movie', 'A Summer Song', 2012, None, 'tt0853002'),
#  ('Movie', 'Kolorádó Kid', 2010, 10, 'tt0856796'),
#  ('Movie', 'Wide Blue Yonder', 2012, 5, 'tt0858500'),
#  ('Movie', 'Surprise, Surprise', 2010, 8, 'tt0871893'),
#  ('Movie', 'Please Give', 2010, 7, 'tt0878835'),
#  ('Movie', 'Eat Pray Love', 2010, 10, 'tt0879870'),
#  ('Movie', 'Repo', 2010, None, 'tt0887161'),
#  ('Movie', 'Kavod', 2010, 5, 'tt0887751'),
#  ('Movie', 'The Switch', 2010, 10, 'tt0889573'),
#  ('Movie', 'Letters to Juliet', 2010, 6, 'tt0892318'),
#  ('Movie', 'The Whistleblower', 2011, 11, 'tt0896872'),
#  ('Movie', "Don't Fade Away", 2011, None, 'tt0899145'),
#  ('Movie', 'Acts of Violence', 2010, 5, 'tt0902247'),
#  ('Movie', 'Eager to Die', 2010, 7, 'tt0907731'),
#  ('Movie', 'Proie', 2011, 7, 'tt0907305'),
#  ('Movie', 'Unthinkable', 2010, 7, 'tt0914863'),
#  ('Movie', 'De gelukkige huisvrouw', 2010, 4, 'tt0920459'),
#  ('Movie', 'Truth About Kerry', 2012, 3, 'tt0923954'),
#  ('Movie', 'Glenn, the Flying Robot', 2011, 7, 'tt0934446'),
#  ('Movie', 'The Waiter', 2010, 3, 'tt0934981'),
#  ('Movie', 'Rabbit Hole', 2011, 4, 'tt0935075'),
#  ('Movie', 'White Knuckles', 2010, None, 'tt0942906'),
#  ('Movie', 'Green Zone', 2010, 4, 'tt0947810'),
#  ('Movie', 'Black Swan', 2011, 2, 'tt0947798'),
#  ('Movie', 'The Killer Inside Me', 2010, 10, 'tt0954947'),
#  ('Movie', 'Robin Hood', 2010, 5, 'tt0955308'),
#  ('Movie', 'Heart of Now', 2010, 6, 'tt0960067'),
#  ('Movie', 'Dom Solntsa', 2010, 4, 'tt0962764'),
#  ('Movie', 'The Fighter', 2011, 3, 'tt0964517'),
#  ('Movie', 'The Conspirator', 2011, 8, 'tt0968264'),
#  ('Movie', 'The Chosen One', 2010, 9, 'tt0970926'),
#  ('Movie', 'La razón', 2011, 4, 'tt0970955'),
#  ('Movie', 'The Land of the Astronauts', 2010, 10, 'tt0974584'),
#  ('Movie', 'Sinatra Club', 2010, 9, 'tt0975738'),
#  ('Movie', 'Fair Game', 2010, 11, 'tt0977855'),
#  ('Movie', 'A Dance for Grace', 2010, 0, 'tt0984113'),
#  ('Movie', 'Multiple Sarcasms', 2010, 4, 'tt0984210'),
#  ('Movie', 'A Flat', 2010, 11, 'tt0988655'),
#  ('Movie', 'Dear John', 2010, 3, 'tt0989757'),
#  ('Movie', 'The Experiment', 2010, 8, 'tt0997152'),
#  ('Movie', 'Bibliothèque Pascal', 2010, 3, 'tt0997035'),
#  ('Movie', 'Rosso autunno', 2010, 0, 'tt10010654'),
#  ('Movie', 'Opal', 2010, 10, 'tt1008015'),
#  ('Movie', 'The Steamroom', 2010, None, 'tt1008046'),
#  ('Movie', 'Love Sick Diaries', 2012, 9, 'tt1010270'),
#  ('Movie', 'Prime of Your Life', 2010, None, 'tt1016226'),
#  ('Movie', 'The Runaways', 2010, 11, 'tt1017451'),
#  ('Movie', 'Woyzeck 2010', 2010, 6, 'tt10195742'),
#  ('Movie', 'Deal', 2010, None, 'tt1020011'),
#  ('Movie', 'Patagonia', 2011, 3, 'tt1020559'),
#  ('Movie', 'Centurion', 2010, 5, 'tt1020558'),
#  ('Movie', 'Copie conforme', 2010, 8, 'tt1020773'),
#  ('Movie', 'Rising Star', 2010, None, 'tt1022884'),
#  ('Movie', 'The Way Back', 2011, 1, 'tt1023114'),
#  ('Movie', 'What About Cuba?', 2010, 11, 'tt10240942'),
#  ('Movie', 'Wall Street: Money Never Sleeps', 2010, 9, 'tt1027718'),
#  ('Movie', 'Secretariat', 2010, 10, 'tt1028576'),
#  ('Movie', 'Sawariya lai de ho rangni chudi', 2010, None, 'tt10309458'),
#  ('Movie', 'Jai Balaji Mehndipur Wale', 2010, 1, 'tt10323662'),
#  ('Movie', 'The Book of Eli', 2010, 3, 'tt1037705'),
#  ('Movie', 'Let the Game Begin', 2010, 1, 'tt1041778'),
#  ('Movie', 'O: love, beauty, pain, struggle', 2010, 2, 'tt10417654'),
#  ('Movie', 'Tamassu', 2010, 6, 'tt10428942'),
#  ('Movie', 'Just Inès', 2010, 11, 'tt1042974'),
#  ('Movie', 'El mal ajeno', 2010, 11, 'tt1043800'),
#  ('Movie', 'Camp Hell', 2011, 12, 'tt1047449'),
#  ('Movie', 'Howl', 2011, 5, 'tt1049402'),
#  ('Movie', 'The Singularity Is Near', 2012, 7, 'tt1049412'),
#  ('Movie', 'Between The Lines', 2010, 6, 'tt10500904'),
#  ('Movie', 'Asa Mi Kay Gunha Kela', 2010, None, 'tt10510724'),
#  ('Movie', 'The Black Bay Sequence', 2010, None, 'tt10510738'),
#  ('Movie', 'Ivory', 2010, None, 'tt1051340'),
#  ('Movie', 'Lost Everything', 2013, 11, 'tt1051715'),
#  ('Movie', 'Hearts of Three', 2010, 5, 'tt10529804'),
#  ('Movie', 'Chike Naija', 2010, None, 'tt10533316'),
#  ('Movie', 'As Melhores Coisas do Mundo', 2010, 4, 'tt1054677'),
#  ('Movie', 'Life as We Know It', 2010, 10, 'tt1055292'),
#  ('Movie', 'Spud', 2010, 12, 'tt1059969'),
#  ('Movie', 'Al Nebras', 2010, 0, 'tt10624618'),
#  ('Movie', 'Small Town Saturday Night', 2010, 6, 'tt1063111'),
#  ('Movie', 'Bare Knuckles', 2010, None, 'tt1063327'),
#  ('Movie', "Punk's Dead", 2010, 9, 'tt10637610'),
#  ('Movie', 'Je ne vous oublierai jamais', 2010, 4, 'tt1064960'),
#  ('Movie', "Quincas Berro d'Água", 2010, 5, 'tt1068962'),
#  ('Movie', 'From the Midst of Pain', 2010, 10, 'tt1071927'),
#  ('Movie', 'The Dead Sleep', 2010, 2, 'tt1071783'),
#  ('Movie', 'Troubadours', 2010, None, 'tt1073519'),
#  ('Movie', 'Jonah Hex', 2010, 9, 'tt1075747'),
#  ('Movie', 'Psychosomatika', 2011, 12, 'tt1078591'),
#  ('Movie', 'Krews', 2010, 3, 'tt1078583'),
#  ('Movie', '10 Years Later', 2010, 3, 'tt1079974'),
#  ('Movie', 'Happiness Runs', 2010, 5, 'tt1079964'),
#  ('Movie', 'Pusher', 2010, 10, 'tt1082075'),
#  ('Movie', 'Lights Out', 2015, 6, 'tt1085448'),
#  ('Movie', 'The Last Musketeer', 2010, 6, 'tt1087459'),
#  ('Movie', 'Consent', 2013, 2, 'tt1090749'),
#  ('Movie', 'Çiglik Çigliga Bir Sevda', 2010, None, 'tt10912916'),
#  ('Movie', 'Shanghai', 2010, 9, 'tt1092634'),
#  ('Movie', 'Orsova Noua 5: Epilog', 2010, None, 'tt10931336'),
#  ('Movie', 'Louis', 2010, 8, 'tt1093902'),
#  ('Movie', 'Hamill', 2011, 10, 'tt1094666'),
#  ('Movie', 'The Quiet Ones', 2012, 5, 'tt1094597'),
#  ('Movie', 'Forgotten Pills', 2010, 6, 'tt1095180'),
#  ('Movie', 'Morning', 2010, 6, 'tt1095417'),
#  ('Movie', 'Do Elephants Pray?', 2013, 2, 'tt1098326'),
#  ('Movie', 'Frenchy', 2022, 1, 'tt1286146'),
#  ('Movie', 'Broken Sun', 2010, 11, 'tt1101031'),
#  ('Movie', 'Peep World', 2011, 3, 'tt1103273'),
#  ('Movie', 'Red Dirt Rising', 2014, 10, 'tt1103274'),
#  ('Movie', 'Eva', 2010, 10, 'tt1105740'),
#  ('Movie', 'Dirty Girl', 2011, 7, 'tt1107319'),
#  ('Movie', 'You Have the Right to Remain Violent', 2010, 5, 'tt1107855'),
#  ('Movie', 'Nirahua Rickshawwala', 2010, 2, 'tt11091790'),
#  ('Movie', 'Nirahua No. 1', 2010, 1, 'tt11091794'),
#  ('Movie', 'Kalamity', 2010, 10, 'tt1109594'),
#  ('Movie', 'Ae Bhaujee Ke Sister', 2010, None, 'tt11114760'),
#  ('Movie', 'Code Blue', 2010, 9, 'tt1111884'),
#  ('Movie', "Carmen's Kiss", 2017, 11, 'tt1116183'),
#  ('Movie',
#   'O Sonho de Inacim - O Aprendiz do Padre Rolim',
#   2010,
#   6,
#   'tt11176246'),
#  ('Movie', 'Pravosudie volkov', 2010, 10, 'tt1119192'),
#  ('Movie', 'Sajal Ehtidhar', 2010, 10, 'tt11198656'),
#  ('Movie', 'Blue Valentine', 2011, 3, 'tt1120985'),
#  ('Movie', 'Di renjie: Tong tian di guo', 2010, 9, 'tt1123373'),
#  ('Movie', 'Pankh', 2010, 4, 'tt1124386'),
#  ('Movie', 'Love Ranch', 2011, 1, 'tt1125929'),
#  ('Movie', 'Burlesque', 2010, 12, 'tt1126591'),
#  ('Movie', 'Morning Glory', 2011, 1, 'tt1126618'),
#  ('Movie', 'The Beautiful Outsiders', 2010, None, 'tt11274532'),
#  ('Movie', 'Another Harvest Moon', 2010, 10, 'tt1129404'),
#  ('Movie', 'Sisanje', 2010, 10, 'tt1129437'),
#  ('Movie', 'Radio Free Albemuth', 2014, 6, 'tt1129396'),
#  ('Movie', 'The 5th Quarter', 2011, 3, 'tt1130964'),
#  ('Movie', 'Redlight Greenlight', 2010, 9, 'tt1130968'),
#  ('Movie', 'Maharaja: the story of ranjit singh', 2010, None, 'tt11317462'),
#  ('Movie', 'Aaj Ke Karan Arjun', 2010, 7, 'tt11317936'),
#  ('Movie', 'Donkeys', 2010, 10, 'tt1134846'),
#  ('Movie', 'Krach', 2010, 9, 'tt1135083'),
#  ('Movie', 'Io non ti assolvo', 2010, 1, 'tt11374176'),
#  ('Movie', 'Moo-jeok-ja', 2010, 9, 'tt1138442'),
#  ('Movie', 'The Ghost Writer', 2010, 5, 'tt1139328'),
#  ('Movie', 'Due vite per caso', 2010, 5, 'tt1141306'),
#  ('Movie', 'Dreams ahead', 2010, 6, 'tt11423890'),
#  ('Movie', 'Holy Rollers', 2010, 12, 'tt1143896'),
#  ('Movie', 'Between the Raindrops', 2010, 1, 'tt11440314'),
#  ('Movie', 'Dar Joued', 2010, 10, 'tt11439792'),
#  ('Movie', 'De día y de noche', 2011, 10, 'tt1145430'),
#  ('Movie', 'Laat Sahab', 2010, None, 'tt11483028'),
#  ('Movie', 'Rudolfa mantojums', 2010, 1, 'tt1149607'),
#  ('Movie', 'Kong Ming Deng', 2010, None, 'tt11496418'),
#  ('Movie', 'Adelaide', 2010, None, 'tt11512458'),
#  ('Movie', 'NY Export: Opus Jazz', 2010, 3, 'tt1152278'),
#  ('Movie', 'The Karate Kid', 2010, 7, 'tt1155076'),
#  ('Movie', 'Na putu', 2011, 3, 'tt1156531'),
#  ('Movie', 'Agua fria de mar', 2011, 3, 'tt1156527'),
#  ('Movie', 'Odio Los Lunes', 2010, 0, 'tt11574510'),
#  ('Movie', 'Gor Bapa No Gotalo', 2010, None, 'tt11646432'),
#  ('Movie', 'Ame Prem Deewana', 2010, 7, 'tt11646390'),
#  ('Movie', 'Radha Chudlo Perje Mara Naam No', 2010, 4, 'tt11646454'),
#  ('Movie', 'Sahabuddin Rather Na Hasya Na', 2010, 10, 'tt11646642'),
#  ('Movie', 'Biutiful', 2011, 2, 'tt1164999'),
#  ('Movie', "L'immortel", 2010, 5, 'tt1167638'),
#  ('Movie', 'The Company Men', 2012, 4, 'tt1172991'),
#  ('Movie', 'The Bang Bang Club', 2011, 7, 'tt1173687'),
#  ('Movie', 'The Myth of the American Sleepover', 2011, 4, 'tt1174042'),
#  ('Movie', 'The Four-Faced Liar', 2010, 1, 'tt1174693'),
#  ('Movie', 'All Good Things', 2010, 12, 'tt1175709'),
#  ('Movie', 'Las buenas hierbas', 2010, 8, 'tt1176931'),
#  ('Movie', 'A Nightmare on Elm Street', 2010, 5, 'tt1179056'),
#  ('Movie', 'Tunha Chalawan', 2010, None, 'tt11814006'),
#  ('Movie', 'Black Death', 2010, 6, 'tt1181791'),
#  ('Movie', 'Bunraku', 2011, 11, 'tt1181795'),
#  ('Movie', 'You Will Meet a Tall Dark Stranger', 2010, 12, 'tt1182350'),
#  ('Movie', 'Dulha Mil Gaya', 2010, 1, 'tt1182884'),
#  ('Movie', 'Palyaço Recep', 2010, None, 'tt11835344'),
#  ('Movie', 'Mr. Nice', 2011, 9, 'tt1183911'),
#  ('Movie', 'Sadiyaan: Boundaries Divide... Love Unites', 2010, 4, 'tt1183944'),
#  ('Movie', 'Welcome to the Rileys', 2011, 4, 'tt1183923'),
#  ('Movie', 'Teen Patti', 2010, 2, 'tt1183917'),
#  ('Movie', 'Veer', 2010, 1, 'tt1185412'),
#  ('Movie', 'Lope', 2010, 9, 'tt1186357'),
#  ('Movie', 'Peacock', 2010, 5, 'tt1188113'),
#  ('Movie', 'My Name Is Khan', 2010, 2, 'tt1188996'),
#  ('Movie', 'Anaphylaxis', 2010, 11, 'tt1189021'),
#  ('Movie', 'Woodshop', 2010, 9, 'tt1189267'),
#  ('Movie', 'Small Town Hero', 2010, None, 'tt1189904'),
#  ('Movie', 'Shekarchi', 2011, 12, 'tt1190072'),
#  ('Movie', 'Tingala sa pugad', 2010, None, 'tt1191135'),
#  ('Movie', 'Right Yaaa Wrong', 2010, 3, 'tt1191130'),
#  ('Movie', 'Hello Darling', 2010, 8, 'tt1191118'),
#  ('Movie', 'Tracks in Time', 2010, None, 'tt11916846'),
#  ('Movie', 'Corrado', 2010, 6, 'tt1193473'),
#  ('Movie', 'My Own Love Song', 2010, 4, 'tt1193507'),
#  ('Movie', 'Step Up 3D', 2010, 8, 'tt1193631'),
#  ('Movie', 'Get Educated: Paathshaala', 2010, 4, 'tt1194236'),
#  ('Movie', 'Casino Jack', 2010, 12, 'tt1194417'),
#  ('Movie', 'Jaane Kahan Se Aayi Hai', 2010, 4, 'tt1194232'),
#  ('Movie', 'Inhale', 2010, 10, 'tt1196340'),
#  ('Movie', 'Diary of a Wimpy Kid', 2010, 3, 'tt1196141'),
#  ('Movie', 'Cemetery Junction', 2021, 9, 'tt1196204'),
#  ('Movie', 'Pound of Flesh', 2010, None, 'tt1196338'),
#  ('Movie', 'Quit', 2010, 4, 'tt1196682'),
#  ('Movie', 'Lapse', 2010, 8, 'tt1198133'),
#  ('Movie', 'For Love Alone', 2010, 0, 'tt1197620'),
#  ('Movie', 'Kites', 2010, 5, 'tt1198101'),
#  ('Movie', 'Dog Jack', 2010, 8, 'tt1199552'),
#  ('Movie', 'One Too Many Mornings', 2010, 1, 'tt1200274'),
#  ('Movie', 'Assalto ao Santa Maria', 2010, 9, 'tt1202513'),
#  ('Movie', 'Lucky Life', 2013, 4, 'tt1206314'),
#  ('Movie', 'Next Time Ned', 2010, 5, 'tt1207009'),
#  ('Movie', 'Person of Interest', 2010, 10, 'tt1208716'),
#  ('Movie', 'Mbaku', 2010, None, 'tt12095436'),
#  ('Movie', 'Autopilot', 2010, None, 'tt1210029'),
#  ('Movie', 'Blood Done Sign My Name', 2010, 2, 'tt1210039'),
#  ('Movie', 'Flying Lessons', 2010, 2, 'tt1210059'),
#  ('Movie', 'One Wish', 2010, 11, 'tt1212434'),
#  ('Movie', 'Pokuda budet veter...', 2010, 11, 'tt12126806'),
#  ('Movie', 'Hereafter', 2011, 3, 'tt1212419'),
#  ('Movie',
#   'Odoru daisousasen the movie 3: Yatsura o kaihou seyo!',
#   2010,
#   7,
#   'tt1212453'),
#  ('Movie', 'An Invisible Sign', 2011, 4, 'tt1212454'),
#  ('Movie', 'Mercy', 2010, 6, 'tt1213590'),
#  ('Movie', 'London Boulevard', 2011, 2, 'tt1213648'),
#  ('Movie', 'SP: The motion picture yabô hen', 2010, 10, 'tt1214981'),
#  ('Movie', 'Lucy Island', 2010, None, 'tt12153448'),
#  ('Movie', 'Dry Run', 2010, 0, 'tt1216485'),
#  ('Movie', 'My First Movie', 2010, 0, 'tt12165450'),
#  ('Movie', 'Womb', 2011, 4, 'tt1216520'),
#  ('Movie', 'Paradise East', 2010, 0, 'tt1217060'),
#  ('Movie', 'Dou Khahar', 2010, 9, 'tt12171216'),
#  ('Movie', 'Las aventuras de Beto y Roberto', 2010, 3, 'tt12180606'),
#  ('Movie',
#   "Legend of the Guardians: The Owls of Ga'Hoole",
#   2010,
#   9,
#   'tt1219342'),
#  ('Movie', "Henry's Crime", 2011, 4, 'tt1220888'),
#  ('Movie', "Cupid's Arrow", 2010, None, 'tt1220625'),
#  ('Movie', 'Frankie & Alice', 2014, 8, 'tt1221208'),
#  ('Movie', 'Beneath the Blue', 2010, None, 'tt1222698'),
#  ('Movie', 'The Tested', 2012, None, 'tt1224136'),
#  ('Movie', 'The Will', 2010, 1, 'tt12246482'),
#  ('Movie', 'No Greater Love', 2010, 5, 'tt1225703'),
#  ('Movie', 'Love Equation', 2010, 0, 'tt1225680'),
#  ('Movie', 'Edge of Darkness', 2010, 1, 'tt1226273'),
#  ('Movie', 'Alphonso Bow', 2010, 2, 'tt1226737'),
#  ('Movie', 'The Debt', 2011, 9, 'tt1226753'),
#  ('Movie', 'Aashayein', 2010, 8, 'tt1227524'),
#  ('Movie', 'Around Hell', 2010, 10, 'tt12282568'),
#  ('Movie', 'Let Me In', 2011, 1, 'tt1228987'),
#  ('Movie', 'Hors la loi', 2010, 9, 'tt1229381'),
#  ('Movie', 'Puss', 2010, 8, 'tt1230196'),
#  ('Movie', 'Hwanghae', 2010, 12, 'tt1230385'),
#  ('Movie', 'Yohan - Barnevandrer', 2010, 3, 'tt1230478'),
#  ('Movie', 'Due Date', 2010, 11, 'tt1231583'),
#  ('Movie', 'Triple Dog', 2010, 9, 'tt1232838'),
#  ('Movie', 'Brighton Rock', 2011, 2, 'tt1233192'),
#  ('Movie', 'Hanni & Nanni', 2011, 8, 'tt1233290'),
#  ('Movie', 'Chico Xavier', 2010, 4, 'tt1234559'),
#  ('Movie', "'Master Harold' ... And the Boys", 2010, 3, 'tt1234546'),
#  ('Movie', 'Greenberg', 2010, 7, 'tt1234654'),
#  ('Movie', 'De vliegenierster van Kazbek', 2010, 4, 'tt1234540'),
#  ('Movie', 'Mahler auf der Couch', 2010, 7, 'tt1235537'),
#  ('Movie', 'VIPs', 2011, 3, 'tt1235548'),
#  ('Movie', 'Chico & Rita', 2010, 11, 'tt1235830'),
#  ('Movie', 'Contre toi', 2011, 4, 'tt1235853'),
#  ('Movie', 'Gigola', 2011, 1, 'tt1236250'),
#  ('Movie', 'Mistérios de Lisboa', 2011, 5, 'tt1236371'),
#  ('Movie', 'Revision - Apocalypse II', 2010, 9, 'tt1238300'),
#  ('Movie', 'Kvinden der drømte om en mand', 2010, 1, 'tt1239290'),
#  ('Movie', 'The Assignment', 2011, None, 'tt1239216'),
#  ('Movie', 'La cité', 2010, 2, 'tt1239430'),
#  ('Movie', 'The River Why', 2012, 7, 'tt1241329'),
#  ('Movie', 'The War Is Over', 2010, 10, 'tt1242529'),
#  ('Movie', 'Tour de Force', 2010, 1, 'tt1242787'),
#  ('Movie', 'Hisss', 2010, 10, 'tt1244093'),
#  ('Movie', 'Conviction', 2010, 11, 'tt1244754'),
#  ('Movie', 'Extraordinary Measures', 2010, 1, 'tt1244659'),
#  ('Movie', 'Burning Bright', 2012, 5, 'tt1244658'),
#  ('Movie', 'Wu', 2010, 5, 'tt1245094'),
#  ('Movie', '22 mei', 2011, 5, 'tt1245647'),
#  ('Movie', 'Magic Journey to Africa', 2010, 5, 'tt1247681'),
#  ('Movie', 'The Mountain Thief', 2010, 7, 'tt1247406'),
#  ('Movie', 'Bad Faith', 2010, 5, 'tt1247639'),
#  ('Movie', 'The Lazarus Papers', 2011, 7, 'tt1247400'),
#  ('Movie', 'Norman', 2010, 6, 'tt1247683'),
#  ('Movie', 'Fighting Fish', 2010, 4, 'tt1249170'),
#  ('Movie', 'The Nothing Men', 2010, 8, 'tt1251360'),
#  ('Movie', 'The Making of Plus One', 2010, None, 'tt1251756'),
#  ('Movie', 'Wo shi wai xing ren', 2010, None, 'tt12517866'),
#  ('Movie', 'Rosa Morena', 2011, 5, 'tt1252516'),
#  ('Movie', 'The Way Home', 2010, 10, 'tt1252507'),
#  ('Movie', 'Channa Sachi Muchi', 2010, 8, 'tt12526816'),
#  ('Movie', 'Czukor Show', 2010, 4, 'tt1254724'),
#  ('Movie', 'Northern Comfort', 2010, 5, 'tt1254966'),
#  ('Movie', 'Incendies', 2011, 2, 'tt1255953'),
#  ('Movie', 'Bodhisattva', 2010, 4, 'tt1258221'),
#  ('Movie', 'Hello Lonesome', 2010, None, 'tt1258201'),
#  ('Movie', 'Tu Hi Mor Balma', 2010, 6, 'tt12587652'),
#  ('Movie', 'SoulBoy', 2010, 9, 'tt1259227'),
#  ('Movie', 'Bon appétit', 2010, 11, 'tt1259520'),
#  ('Movie', "L'autre Dumas", 2010, 2, 'tt1259591'),
#  ('Movie', 'Carne de neón', 2011, 1, 'tt1259570'),
#  ('Movie', 'A Worthy Gentleman', 2010, 8, 'tt1260597'),
#  ('Movie', 'Icarus', 2010, 7, 'tt1261862'),
#  ('Movie', 'Sex and the City 2', 2010, 5, 'tt1261945'),
#  ('Movie', 'Coasting', 2010, 3, 'tt1262876'),
#  ('Movie', 'Endings', 2010, 6, 'tt1262892'),
#  ('Movie', 'Habitación en Roma', 2010, 5, 'tt1263750'),
#  ('Movie', 'The Trial', 2010, 9, 'tt1264115'),
#  ('Movie', 'Kao rani mraz', 2010, 4, 'tt1264889'),
#  ('Movie', 'Promises', 2010, None, 'tt1265620'),
#  ('Movie', 'Quartier lointain', 2011, 7, 'tt1266037'),
#  ('Movie', 'Boxhagener Platz', 2010, 3, 'tt1266025'),
#  ('Movie', 'Postales', 2010, 6, 'tt1267378'),
#  ('Movie', 'Un lugar lejano', 2010, 3, 'tt1267494'),
#  ('Movie', 'Lunatics, Lovers & Poets', 2010, 4, 'tt1268241'),
#  ('Movie', 'The Last Rites of Ransom Pride', 2020, 6, 'tt1268970'),
#  ('Movie', 'Çeto: Onlar Da Bir Zamanlar Çocuktu', 2010, None, 'tt12690734'),
#  ('Movie', 'Matthe Mungaaru', 2010, 8, 'tt12698048'),
#  ('Movie', 'Transfer', 2011, 9, 'tt1270120'),
#  ('Movie', 'Sympathy for Delicious', 2011, 4, 'tt1270277'),
#  ('Movie', 'Noruwei no mori', 2011, 1, 'tt1270842'),
#  ('Movie', 'Henri 4', 2010, 3, 'tt1270766'),
#  ('Movie', 'Shoot the DJ', 2010, 5, 'tt1270786'),
#  ('Movie', 'Kandagar', 2010, 2, 'tt1272018'),
#  ('Movie', 'Great Heights', 2010, 10, 'tt1273212'),
#  ('Movie', 'Al Kibar', 2010, 6, 'tt12729084'),
#  ('Movie', 'Brotherhood', 2010, 11, 'tt1273241'),
#  ('Movie', 'Art House', 2010, 4, 'tt1273194'),
#  ('Movie', 'Standing Firm', 2015, 3, 'tt1273236'),
#  ('Movie', 'The Tempest', 2011, 1, 'tt1274300'),
#  ('Movie', 'Listen to Your Heart', 2011, 5, 'tt1274296'),
#  ('Movie', 'La mosquitera', 2010, 11, 'tt1274645'),
#  ('Movie', 'Aita', 2012, 4, 'tt1274636'),
#  ('Movie', 'Now Here', 2010, 10, 'tt1276974'),
#  ('Movie', 'Summer Eleven', 2011, 4, 'tt1276988'),
#  ('Movie', 'Za rasuto messêji: Umizaru', 2010, 9, 'tt1277373'),
#  ('Movie', 'California Tango', 2010, 4, 'tt1277398'),
#  ('Movie', 'Unkraut im Paradies', 2010, 7, 'tt1277952'),
#  ('Movie', 'Cinerama', 2010, 3, 'tt1278025'),
#  ('Movie', 'Jack Goes Boating', 2010, 12, 'tt1278379'),
#  ('Movie', 'Bhojpuriya Don', 2010, None, 'tt12784884'),
#  ('Movie', 'Dos Veces Ana', 2010, None, 'tt1279326'),
#  ('Movie', 'Ramaa: The Saviour', 2010, 11, 'tt1279105'),
#  ('Movie', 'Banglar King Kong', 2010, 6, 'tt12798342'),
#  ('Movie', 'Cefalópodo', 2010, 9, 'tt1282136'),
#  ('Movie', 'O Estranho Caso de Angélica', 2011, 11, 'tt1282153'),
#  ('Movie', 'Brim', 2010, 9, 'tt1282135'),
#  ('Movie', 'Easy A', 2011, 2, 'tt1282140'),
#  ('Movie', "Anton Chekhov's The Duel", 2010, 4, 'tt1282041'),
#  ('Movie', 'Trooper', 2014, 11, 'tt1282093'),
#  ('Movie', "L'enfance du mal", 2010, 5, 'tt1282152'),
#  ('Movie', 'Sinister Heaven', 2010, 3, 'tt1283947'),
#  ('Movie', 'The Fiction', 2010, 12, 'tt1283900'),
#  ('Movie', 'Jetaa', 2010, None, 'tt12839046'),
#  ('Movie', 'The Social Network', 2010, 10, 'tt1285016'),
#  ('Movie', 'Lahore', 2010, 3, 'tt1285245'),
#  ('Movie', 'Der grosse Kater', 2010, 10, 'tt1285306'),
#  ('Movie', 'Gutter King', 2010, None, 'tt1286746'),
#  ('Movie', 'Weakness', 2010, 10, 'tt1286753'),
#  ('Movie', 'Shi', 2011, 2, 'tt1287878'),
#  ('Movie', 'A Goldfish of the Flame', 2010, 12, 'tt1288587'),
#  ('Movie', 'Die Fremde', 2010, 11, 'tt1288376'),
#  ('Movie', 'You Are Here', 2018, 8, 'tt1288411'),
#  ('Movie', 'N-Secure', 2010, 10, 'tt1289419'),
#  ('Movie', 'Everyday Black Man', 2010, 1, 'tt1289397'),
#  ('Movie', 'Circuit', 2010, 11, 'tt1289383'),
#  ('Movie', 'Lebanon, Pa.', 2010, 3, 'tt1290082'),
#  ('Movie', 'Arcadia Lost', 2010, 6, 'tt1290470'),
#  ('Movie', 'Obituary of the Sun', 2010, 9, 'tt1290476'),
#  ('Movie', 'Yi ye Taibei', 2010, 4, 'tt1291125'),
#  ('Movie', 'Rajneeti', 2010, 6, 'tt1291465'),
#  ('Movie', 'Snabba cash', 2010, 10, 'tt1291652'),
#  ('Movie', 'Meet Monica Velour', 2010, 4, 'tt1291549'),
#  ('Movie', 'Allah Ke Banday', 2010, 11, 'tt1292642'),
#  ('Movie',
#   'Reiruweizu: 49-sai de densha no untenshi ni natta otoko no monogatari',
#   2010,
#   5,
#   'tt1292561'),
#  ('Movie', 'Upside', 2010, 10, 'tt1294162'),
#  ('Movie', 'Shit Year', 2011, 8, 'tt1294212'),
#  ('Movie', 'The Last Song', 2010, 3, 'tt1294226'),
#  ('Movie', 'Last Night', 2011, 3, 'tt1294688'),
#  ('Movie', 'Iep!', 2010, 2, 'tt1295059'),
#  ('Movie', 'Starshaya zhena', 2010, 9, 'tt1296079'),
#  ('Movie', 'Anger Has a Secret', 2010, 8, 'tt1296171'),
#  ('Movie', 'Jen', 2010, 4, 'tt1296161'),
#  ('Movie', 'Wild Ride', 2010, 6, 'tt1296464'),
#  ('Movie', 'Waiting for Forever', 2011, 2, 'tt1296898'),
#  ('Movie', 'Christina', 2010, None, 'tt1297921'),
#  ('Movie', 'Blog', 2011, 1, 'tt1297920'),
#  ('Movie', 'Nonames', 2010, 3, 'tt1297938'),
#  ('Movie', 'La blonde aux seins nus', 2010, 6, 'tt1298831'),
#  ('Movie', 'Die grünen Hügel von Wales', 2010, 11, 'tt1301294'),
#  ('Movie', 'Agnipariksha', 2010, None, 'tt13017894'),
#  ('Movie', 'Every Day', 2012, 10, 'tt1301990'),
#  ('Movie', 'Harvest', 2011, 5, 'tt1302001'),
#  ('Movie', 'In the Drink', 2010, 6, 'tt1303743'),
#  ('Movie', 'The Ascent', 2010, None, 'tt1303680'),
#  ('Movie', 'Pelican Blood', 2010, None, 'tt1305059'),
#  ('Movie', 'The Bill Collector', 2010, 9, 'tt1305008'),
#  ('Movie', 'Last Letters from Monte Rosa', 2010, 8, 'tt1305039'),
#  ('Movie', 'Ghetto Physics', 2010, 10, 'tt1305587'),
#  ('Movie', 'Ostavljeni', 2010, 12, 'tt1305798'),
#  ('Movie', 'Ten Stories Tall', 2010, None, 'tt1307071'),
#  ('Movie', 'Shocking Blue', 2010, 8, 'tt1307010'),
#  ('Movie', 'Dance with the One', 2010, 3, 'tt1307892'),
#  ('Movie', 'Boku no sukina hito', 2010, 5, 'tt1308022'),
#  ('Movie', 'The Taqwacores', 2010, 10, 'tt1308165'),
#  ('Movie', 'Lovelorn', 2013, 4, 'tt1309181'),
#  ('Movie', 'Lamhaa: The Untold Story of Kashmir', 2010, 7, 'tt1309561'),
#  ('Movie', 'The Insides of a Lamb', 2010, 9, 'tt1309590'),
#  ('Movie', 'Toora Rickshaw Wala', 2010, 6, 'tt13099338'),
#  ('Movie', 'The Sparrow and the Tigress', 2010, 9, 'tt1310667'),
#  ('Movie', 'Made in Poland', 2011, 3, 'tt1311047'),
#  ('Movie', 'The Scientist', 2010, 4, 'tt1311087'),
#  ('Movie', 'The Human Resources Manager', 2010, 10, 'tt1311075'),
#  ('Movie', 'Skateland', 2011, 5, 'tt1312254'),
#  ('Movie', 'Animal Kingdom', 2011, 3, 'tt1313092'),
#  ('Movie', 'La mirada invisible', 2010, 8, 'tt1313254'),
#  ('Movie', '3 Backyards', 2010, None, 'tt1314190'),
#  ('Movie', 'Audrey the Trainwreck', 2010, None, 'tt1314161'),
#  ('Movie', 'Case 219', 2010, 4, 'tt1314169'),
#  ('Movie', 'Hanyo', 2010, 5, 'tt1314652'),
#  ('Movie', 'Cricket', 2010, 0, 'tt1314648'),
#  ('Movie', 'Cherry', 2011, 6, 'tt1315350'),
#  ('Movie', 'Black Mail', 2010, 0, 'tt1316077'),
#  ('Movie', 'Kong Hong: Lost in Love', 2010, 1, 'tt1316061'),
#  ('Movie', 'The Potential Inside', 2010, 9, 'tt1315963'),
#  ('Movie', 'Wrecked', 2011, 6, 'tt1316622'),
#  ('Movie', 'Toutes les filles pleurent', 2010, 3, 'tt1318042'),
#  ('Movie', 'Neka ostane medju nama', 2010, 3, 'tt1318029'),
#  ('Movie', 'Deeper and Deeper', 2010, 4, 'tt1319707'),
#  ('Movie', "It's a Wonderful Afterlife", 2010, 4, 'tt1319716'),
#  ('Movie', 'Chatroom', 2011, 5, 'tt1319704'),
#  ('Movie', 'A Little Help', 2011, 7, 'tt1319722'),
#  ('Movie', 'Morning', 2013, 9, 'tt1320103'),
#  ('Movie', 'Shank', 2010, 3, 'tt1320296'),
#  ('Movie', 'Grand Slammed', 2014, 4, 'tt1320260'),
#  ('Movie', 'A Gangland Love Story', 2010, 7, 'tt1320250'),
#  ('Movie', 'The Reef', 2011, 3, 'tt1320291'),
#  ('Movie', 'Zangaar', 2010, 8, 'tt13219106'),
#  ('Movie', 'América', 2011, 5, 'tt1322266'),
#  ('Movie', 'Chicas', 2010, 3, 'tt1322325'),
#  ('Movie', 'La hora cero', 2010, 10, 'tt1322302'),
#  ('Movie', 'Jhootha Hi Sahi', 2010, 10, 'tt1322257'),
#  ('Movie', 'The Dry Land', 2010, 1, 'tt1322264'),
#  ('Movie', 'Submarino', 2010, 9, 'tt1322385'),
#  ('Movie', 'SubHysteria', 2010, 5, 'tt1322384'),
#  ('Movie', 'The Obsession', 2010, None, 'tt1323027'),
#  ('Movie', 'Frozen', 2010, 3, 'tt1323045'),
#  ('Movie', 'Zena sa slomljenim nosem', 2011, 7, 'tt1324061'),
#  ('Movie', 'Az ember tragédiája', 2011, 12, 'tt0176694'),
#  ('Movie', 'Los pájaros se van con la muerte', 2011, 6, 'tt0247643'),
#  ('Movie', 'Lives No Longer Ours', 2011, None, 'tt0311448'),
#  ('Movie', 'The Wicker Tree', 2011, 7, 'tt0323808'),
#  ('Movie', 'Spy', 2011, 8, 'tt0372538'),
#  ('Movie', 'The Rum Diary', 2011, 12, 'tt0376136'),
#  ('Movie', 'Bubbles', 2011, None, 'tt0406282'),
#  ('Movie', 'Seven Fallen Objects', 2011, 5, 'tt0407194'),
#  ('Movie', 'El borde del tiempo', 2011, None, 'tt0425785'),
#  ('Movie', 'Real Steel', 2011, 11, 'tt0433035'),
#  ('Movie', 'Satin', 2011, 3, 'tt0433397'),
#  ('Movie', 'Moving Target', 2011, None, 'tt0439724'),
#  ('Movie', 'A Bird of the Air', 2011, 9, 'tt0448022'),
#  ('Movie', 'Generation P', 2011, 4, 'tt0459748'),
#  ('Movie', 'The Grasslands', 2012, 12, 'tt0460809'),
#  ('Movie', 'Silent Alarm', 2011, 1, 'tt0462536'),
#  ('Movie', 'Act Your Age', 2011, 4, 'tt0464891'),
#  ('Movie', 'Margaret', 2012, 6, 'tt0466893'),
#  ('Movie', 'Platinum Illusions', 2011, 6, 'tt0469158'),
#  ('Movie', 'The Pack', 2011, 10, 'tt0469152'),
#  ('Movie', 'Extremely Loud & Incredibly Close', 2012, 3, 'tt0477302'),
#  ('Movie', 'The Tree of Life', 2011, 6, 'tt0478304'),
#  ('Movie', 'Atlas Shrugged: Part I', 2011, 4, 'tt0480239'),
#  ('Movie', 'Abhishapt', 2014, None, 'tt0479807'),
#  ('Movie', 'Gente mala del norte', 2011, 2, 'tt0484037'),
#  ('Movie', 'Something Borrowed', 2011, 6, 'tt0491152'),
#  ('Movie', 'Double Tap', 2014, None, 'tt0490847'),
#  ('Movie', 'California Indian', 2011, 11, 'tt0770728'),
#  ('Movie', 'Drive', 2011, 11, 'tt0780504'),
#  ('Movie', 'Wilde Salomé', 2017, 4, 'tt0795459'),
#  ('Movie', 'Red Dog', 2011, 8, 'tt0803061'),
#  ('Movie', 'Spoon', 2011, None, 'tt0805617'),
#  ('Movie', 'The King Hector Lavoe', 2011, 2, 'tt0811069'),
#  ('Movie', 'Take Me Home Tonight', 2011, 3, 'tt0810922'),
#  ('Movie', 'Shanghai Hotel', 2014, 1, 'tt0816648'),
#  ('Movie', 'Où va la nuit', 2011, 5, 'tt0825282'),
#  ('Movie', 'Loot', 2011, 11, 'tt0847180'),
#  ('Movie', 'Mama I Want to Sing', 2011, 1, 'tt0880569'),
#  ('Movie', 'Sanctum', 2011, 3, 'tt0881320'),
#  ('Movie', 'Blur', 2011, 0, 'tt0893310'),
#  ('Movie', 'From Prada to Nada', 2011, 1, 'tt0893412'),
#  ('Movie', 'The Key Man', 2013, 2, 'tt0899154'),
#  ('Movie', 'Black Butterflies', 2011, 3, 'tt0906778'),
#  ('Movie', 'Periphery', 2011, 0, 'tt0918553'),
#  ('Movie', 'Source Code', 2011, 6, 'tt0945513'),
#  ('Movie', 'Hugo', 2012, 2, 'tt0970179'),
#  ('Movie', 'Funkytown', 2011, 3, 'tt0981286'),
#  ('Movie', 'Hanna', 2011, 4, 'tt0993842'),
#  ('Movie', 'The Unforgiven', 2011, None, 'tt0995867'),
#  ('Movie', 'Straw Dogs', 2011, 9, 'tt0999913'),
#  ('Movie', 'If You Only Knew', 2011, 0, 'tt1002569'),
#  ('Movie', 'The Iron Lady', 2012, 1, 'tt1007029'),
#  ('Movie', 'Colombian Interviews', 2011, None, 'tt1007941'),
#  ('Movie', 'The Magic Skin', 2011, None, 'tt10081374'),
#  ('Movie', 'The Murderer: Hamilton Palace', 2011, 8, 'tt10092776'),
#  ('Movie', 'Une rencontre, une histoire', 2011, None, 'tt10101080'),
#  ('Movie', 'JAI SHREE VEER BABA DEO', 2011, 1, 'tt10137436'),
#  ('Movie', 'Pax', 2011, 3, 'tt1016223'),
#  ('Movie', 'Qing gui tao ran ting', 2011, 10, 'tt10167142'),
#  ('Movie', 'Chon-cheol-sal-in', 2011, 2, 'tt10210336'),
#  ('Movie', 'Corazones en llamas', 2011, 11, 'tt10217352'),
#  ('Movie', 'Life Outside', 2011, None, 'tt10226816'),
#  ('Movie', 'Tôi Nay, 8 Gio!', 2011, 12, 'tt10229972'),
#  ('Movie', 'Session', 2011, 5, 'tt1024666'),
#  ('Movie', 'Neugierde', 2011, 8, 'tt10285580'),
#  ('Movie', 'Xing ying bu li', 2012, 5, 'tt1032763'),
#  ('Movie', 'The Descendants', 2012, 2, 'tt1033575'),
#  ('Movie', 'Somewhere Tonight', 2012, 6, 'tt1034293'),
#  ('Movie', 'The Eagle', 2011, 3, 'tt1034389'),
#  ('Movie', 'Manipulation', 2013, 1, 'tt1039613'),
#  ('Movie', 'You and I', 2011, 2, 'tt1046171'),
#  ('Movie', 'Rest im Glas', 2011, 5, 'tt10468786'),
#  ('Movie', 'Agawan Base', 2011, 8, 'tt10488450'),
#  ('Movie', 'Bhaucha Dhakka', 2011, 5, 'tt10516138'),
#  ('Movie', 'Destiny of Three', 2011, 9, 'tt10529820'),
#  ('Movie', 'Dreams Awake', 2011, 1, 'tt1053835'),
#  ('Movie', 'Hum Dono Rangeen', 2011, 2, 'tt10614048'),
#  ('Movie', 'The Ascension', 2011, None, 'tt1067062'),
#  ('Movie', 'Water for Elephants', 2011, 5, 'tt1067583'),
#  ('Movie', 'Footloose', 2011, 10, 'tt1068242'),
#  ('Movie', 'Nobody Fucks Nico', 2011, None, 'tt10732652'),
#  ('Movie', 'Crescent City', 2011, None, 'tt1084722'),
#  ('Movie', 'Karuvarai Pookkal', 2011, 2, 'tt10846126'),
#  ('Movie', 'Sans Rancune', 2011, 1, 'tt10863176'),
#  ('Movie', 'Megan Is Missing', 2011, 5, 'tt1087461'),
#  ('Movie', 'Priyappetta Nattukare', 2011, 8, 'tt10897902'),
#  ('Movie', 'Piyawa Bada Satawela', 2011, 10, 'tt11091864'),
#  ('Movie', 'The Bend', 2011, 4, 'tt1110208'),
#  ('Movie', 'Shodhu kuthe', 2011, 12, 'tt11102564'),
#  ('Movie', 'HaAfifonim shel Armand', 2011, 3, 'tt11112628'),
#  ('Movie', 'Kafra', 2011, 11, 'tt11113672'),
#  ('Movie', 'El cuento de Duna', 2011, 4, 'tt11157704'),
#  ('Movie', "King of Paper Chasin'", 2011, 1, 'tt1117668'),
#  ('Movie', 'Lathika', 2011, 3, 'tt11178210'),
#  ('Movie', 'The Ides of March', 2011, 10, 'tt1124035'),
#  ('Movie', 'Here', 2013, 1, 'tt1127886'),
#  ('Movie', "Avant l'aube", 2011, 3, 'tt1130982'),
#  ('Movie', 'Warrant the Mission', 2011, 9, 'tt11364306'),
#  ('Movie', 'Sonny Boy', 2011, 1, 'tt1138481'),
#  ('Movie', 'What an Idea Mai', 2011, 11, 'tt11396086'),
#  ('Movie', 'Son of Morning', 2011, 2, 'tt1144815'),
#  ('Movie', 'Un amor perfecto', 2011, 4, 'tt11457162'),
#  ('Movie', 'Ri Zhao Hao Ren', 2011, None, 'tt11496464'),
#  ('Movie', 'Zhong Yuan Nv Jing', 2011, None, 'tt11496452'),
#  ('Movie', 'Bai He', 2011, 3, 'tt11496440'),
#  ('Movie', "Deng En Ming's Childhood", 2011, 7, 'tt11496430'),
#  ('Movie', 'Beastly', 2011, 6, 'tt1152398'),
#  ('Movie', 'The Joneses', 2012, 4, 'tt1152830'),
#  ('Movie', 'Patang', 2017, 1, 'tt1153700'),
#  ('Movie', 'Down the Shore', 2011, 1, 'tt1155060'),
#  ('Movie', 'En Coma', 2011, 5, 'tt11562724'),
#  ('Movie', 'Circus Fantasticus', 2011, 2, 'tt1156528'),
#  ('Movie', 'The Rite', 2011, 3, 'tt1161864'),
#  ('Movie', 'Garibni Dikri Sasriya Ma Thikri', 2011, 11, 'tt11646372'),
#  ('Movie', 'Hu Tari Meera Ne Tu Maro Shyam Re', 2011, 1, 'tt11646570'),
#  ('Movie', 'Testing Life', 2014, 4, 'tt1172231'),
#  ('Movie',
#   'Wasak: True-to-Life Story of Jonaver Luklukan',
#   2011,
#   4,
#   'tt11743946'),
#  ('Movie', 'Djalioh', 2011, None, 'tt11754036'),
#  ('Movie', 'The Family Tree', 2011, 12, 'tt1175713'),
#  ('Movie', 'Wuthering Heights', 2012, 4, 'tt1181614'),
#  ('Movie', 'Diagnosis Superstar', 2011, None, 'tt1183930'),
#  ('Movie', 'Island', 2011, 4, 'tt1185393'),
#  ('Movie', 'La piel que habito', 2011, 11, 'tt1189073'),
#  ('Movie', 'The Lincoln Lawyer', 2011, 4, 'tt1189340'),
#  ('Movie', 'One/One Thousandth', 2011, None, 'tt1191969'),
#  ('Movie', 'Youngstown Shakedown', 2011, None, 'tt11936324'),
#  ('Movie',
#   'In Transition 1.0 - From Oil Dependence to Local Resilience',
#   2011,
#   None,
#   'tt11954890'),
#  ('Movie', "Phil Cobb's Dinner for Four", 2011, None, 'tt1196952'),
#  ('Movie', 'Cougars Inc.', 2012, 9, 'tt1198075'),
#  ('Movie', 'Think of Me', 2013, 3, 'tt1198199'),
#  ('Movie', 'Night in Bombay', 2011, None, 'tt1201641'),
#  ('Movie', 'Tyrannosaur', 2012, 1, 'tt1204340'),
#  ('Movie', 'Yue zhi lu', 2011, 12, 'tt1205564'),
#  ('Movie', 'Hick', 2012, 5, 'tt1205558'),
#  ('Movie', 'Behesht-e gomshodeh', 2019, 2, 'tt12093996'),
#  ('Movie', 'The Escort', 2011, 8, 'tt12100528'),
#  ('Movie', 'Moneyball', 2011, 11, 'tt1210166'),
#  ('Movie', 'The Disappearance of Jennifer Pope', 2011, None, 'tt12106140'),
#  ('Movie', 'The Mortician', 2013, 4, 'tt1211353'),
#  ('Movie', 'Seeking Justice', 2012, 5, 'tt1214962'),
#  ('Movie', 'Efeitos Secundários', 2011, 12, 'tt1219332'),
#  ('Movie', 'A Matter of Justice', 2011, 12, 'tt1221136'),
#  ('Movie', 'Madar-e payeezi', 2011, 0, 'tt12215402'),
#  ('Movie', 'Player', 2012, 10, 'tt1223414'),
#  ('Movie', 'Happy New Year', 2013, 5, 'tt1226274'),
#  ('Movie', 'Subject: I Love You', 2011, None, 'tt1227182'),
#  ('Movie', 'Jane Eyre', 2011, 9, 'tt1229822'),
#  ('Movie', 'The Saints of Mt. Christopher', 2011, None, 'tt1231577'),
#  ('Movie', 'Ironclad', 2011, 3, 'tt1233301'),
#  ('Movie', 'Pariah', 2012, 10, 'tt1233334'),
#  ('Movie', 'The Future', 2011, 9, 'tt1235170'),
#  ('Movie', 'Un mundo misterioso', 2011, 8, 'tt1235855'),
#  ('Movie', 'Medianeras', 2011, 10, 'tt1235841'),
#  ('Movie', 'The Truth About Angels', 2011, 10, 'tt1237932'),
#  ('Movie', 'Carré blanc', 2011, 9, 'tt1239429'),
#  ('Movie', 'We Need to Talk About Kevin', 2011, 12, 'tt1242460'),
#  ('Movie', 'Bellflower', 2012, 3, 'tt1242599'),
#  ('Movie', 'Dschungelkind', 2011, 2, 'tt1242543'),
#  ('Movie', "L'ordre et la morale", 2011, 11, 'tt1242521'),
#  ('Movie', 'Judas Kiss', 2011, 4, 'tt1242642'),
#  ('Movie', 'Fancypants', 2011, 9, 'tt1243630'),
#  ('Movie', 'The Abduction of Zack Butterfield', 2011, 4, 'tt1247673'),
#  ('Movie', 'Almost Perfect', 2013, 9, 'tt1249158'),
#  ('Movie', 'Salvation Boulevard', 2011, 7, 'tt1251743'),
#  ('Movie', 'Yun xia de ri zi', 2011, 3, 'tt12531268'),
#  ('Movie', 'Immortals', 2011, 11, 'tt1253864'),
#  ('Movie', 'Trabajador', 2011, 5, 'tt12541454'),
#  ('Movie', 'Qi yue yu he', 2011, 12, 'tt12563644'),
#  ('Movie', 'Ek Wada Pran Jaaie Par Vachan Na Jaaie', 2011, 5, 'tt12580488'),
#  ('Movie', 'Phoenix Falling', 2017, 11, 'tt1258205'),
#  ('Movie', 'On the Inside', 2012, 12, 'tt1260365'),
#  ('Movie', 'Pathfinders: In the Company of Strangers', 2011, 1, 'tt1260680'),
#  ('Movie', 'In My Pocket', 2013, 2, 'tt1261420'),
#  ('Movie', "All God's Creatures", 2011, 6, 'tt1261964'),
#  ('Movie', 'Saluda al diablo de mi parte', 2011, 8, 'tt1262415'),
#  ('Movie', 'Pig', 2015, 7, 'tt1262414'),
#  ('Movie', 'Fremdkörper', 2011, 4, 'tt1263743'),
#  ('Movie', 'Memphis Rising: Elvis Returns', 2011, 1, 'tt1265295'),
#  ('Movie', 'Wintertochter', 2011, 10, 'tt1266038'),
#  ('Movie', 'Bul Beni', 2011, None, 'tt12690500'),
#  ('Movie', 'Çok Mu Komik?', 2011, None, 'tt12691084'),
#  ('Movie', 'Dandam Dashagunam', 2011, 4, 'tt12700440'),
#  ('Movie', 'Danach', 2011, 2, 'tt1270256'),
#  ('Movie', "The Devil's Double", 2011, 9, 'tt1270262'),
#  ('Movie', 'Land Gold Women', 2011, 12, 'tt1270267'),
#  ('Movie', 'Gangaputrulu', 2011, 3, 'tt12735950'),
#  ('Movie', 'Gromozeka', 2011, 6, 'tt1273803'),
#  ('Movie', 'The Last Seven', 2013, 8, 'tt1274273'),
#  ('Movie', 'Henry', 2011, 9, 'tt12818344'),
#  ('Movie', 'Fort McCoy', 2014, 8, 'tt1282046'),
#  ('Movie', 'Marrow', 2011, 3, 'tt1282100'),
#  ('Movie', 'Guo ming yi', 2011, 7, 'tt12825922'),
#  ('Movie', 'Killadi Raman', 2011, 12, 'tt12828476'),
#  ('Movie', 'Kottarathil Kutty Bhootham', 2011, 6, 'tt12833086'),
#  ('Movie', 'Tamasha Haach Khel Udya Punha', 2011, None, 'tt12833442'),
#  ('Movie', 'Shrimathi', 2011, 7, 'tt12875806'),
#  ('Movie', "Jordan's River Movie", 2011, 8, 'tt12898366'),
#  ('Movie', 'Warrior', 2011, 10, 'tt1291584'),
#  ('Movie', 'The Ride of Tom & Valkyrie', 2011, None, 'tt1292650'),
#  ('Movie', 'Bloom', 2011, None, 'tt1293086'),
#  ('Movie', 'Code 207', 2011, None, 'tt1295026'),
#  ('Movie', 'The FP', 2011, 3, 'tt1296373'),
#  ('Movie', 'The Lady and the Taxi Driver', 2011, 0, 'tt1297282'),
#  ('Movie', 'Eva', 2011, 10, 'tt1298554'),
#  ('Movie', 'Juni', 2011, None, 'tt1298840'),
#  ('Movie', 'Mister Tangewala', 2011, 6, 'tt13011918'),
#  ('Movie', 'First Time for Everything', 2011, 10, 'tt1978440'),
#  ('Movie', 'Violent Blue', 2011, 1, 'tt1303773'),
#  ('Movie', 'Laifu, Laifu', 2011, 8, 'tt13038778'),
#  ('Movie', 'Kak possorilis...', 2011, None, 'tt13041650'),
#  ('Movie', 'The Story of Respect', 2011, 6, 'tt1304621'),
#  ('Movie', '50/50', 2011, 12, 'tt1306980'),
#  ('Movie', 'Patient 17', 2011, 0, 'tt1307067'),
#  ('Movie', 'All Stars 2: Old Stars', 2011, 10, 'tt1307859'),
#  ('Movie', 'Lost Saints and Other Stories', 2014, 6, 'tt1307875'),
#  ('Movie', 'Go for It!', 2011, 5, 'tt1307926'),
#  ('Movie', 'NokotaHeart', 2011, None, 'tt1307990'),
#  ('Movie', 'Bizim Büyük Çaresizligimiz', 2011, 4, 'tt1309178'),
#  ('Movie', 'Without Borders', 2012, 8, 'tt1309575'),
#  ('Movie', 'Last Will', 2011, 5, 'tt1312222'),
#  ('Movie', 'The Oranges', 2012, 10, 'tt1313139'),
#  ('Movie', 'Hagader', 2011, None, 'tt13148494'),
#  ('Movie', 'Shura no hado kanketsu-hen', 2011, None, 'tt13155850'),
#  ('Movie', 'Gokudo chushingura', 2011, None, 'tt13156092'),
#  ('Movie', 'The Gadarene Swine', 2011, None, 'tt1316047'),
#  ('Movie', 'Generosity', 2011, None, 'tt1316050'),
#  ('Movie', 'Last Winter', 2011, 1, 'tt1316062'),
#  ('Movie', 'Blaxican Brothers', 2021, 1, 'tt1315932'),
#  ('Movie', 'The Year Dolly Parton Was My Mom', 2011, 3, 'tt1316624'),
#  ('Movie', 'A torinói ló', 2011, 10, 'tt1316540'),
#  ('Movie', 'There Be Dragons', 2011, 3, 'tt1316616'),
#  ('Movie', 'Rise of the Planet of the Apes', 2011, 8, 'tt1318514'),
#  ('Movie', 'The Preening Swan', 2011, 11, 'tt1319730'),
#  ('Movie', 'The Beaver', 2011, 7, 'tt1321860'),
#  ('Movie', 'Mlyn i krzyz', 2011, 3, 'tt1324055'),
#  ('Movie', 'The Custom Mary', 2011, 8, 'tt1325019'),
#  ('Movie', 'The Twilight Saga: Breaking Dawn - Part 1', 2011, 11, 'tt1324999'),
#  ('Movie', 'Choose', 2012, 3, 'tt1325723'),
#  ('Movie', 'Far Rockaway', 2011, None, 'tt1326217'),
#  ('Movie', 'Victory Day', 2011, 3, 'tt1329456'),
#  ('Movie', 'Fiebre', 2011, 10, 'tt13299792'),
#  ('Movie', 'The Drifting Boat', 2011, None, 'tt13315710'),
#  ('Movie', 'Fasle Zendegi', 2011, None, 'tt13326392'),
#  ('Movie', 'The Resident', 2011, 4, 'tt1334102'),
#  ('Movie', 'A Time for Rain', 2011, 0, 'tt1334285'),
#  ('Movie', 'Au Pair, Kansas', 2018, 6, 'tt1334514'),
#  ('Movie', 'Aajoba Vayat Aale', 2011, None, 'tt13353186'),
#  ('Movie', 'Ratline', 2011, 7, 'tt1336005'),
#  ('Movie', 'Travellers', 2011, 1, 'tt1336253'),
#  ('Movie', 'Slaughter Creek', 2013, 4, 'tt1336106'),
#  ('Movie', 'Sollitharava', 2011, 1, 'tt13393344'),
#  ('Movie', 'Pazhagiyathe Pirivatharka', 2011, None, 'tt13393356'),
#  ('Movie', 'Vazhividu Kanney Vazhividu', 2011, 12, 'tt13394260'),
#  ('Movie', 'Tinker Tailor Soldier Spy', 2011, 12, 'tt1340800'),
#  ('Movie', 'Strings', 2011, 6, 'tt1340799'),
#  ('Movie', 'Youthful Journeys of the World', 2011, None, 'tt1341343'),
#  ('Movie', "A Warrior's Heart", 2011, 12, 'tt1341340'),
#  ('Movie', 'Naan Sivanagiren', 2011, 11, 'tt13427258'),
#  ('Movie', 'Neeye En Kadhali', 2011, 12, 'tt13426850'),
#  ('Movie', 'Marudhavelu', 2011, 11, 'tt13427348'),
#  ('Movie', 'Karuthakannan Rekla Race', 2011, 12, 'tt13426388'),
#  ('Movie', 'Mahaan Kanakku', 2011, 12, 'tt13426720'),
#  ('Movie', 'Padhinettan Kudi Ellai Arambam', 2011, None, 'tt13426466'),
#  ('Movie', 'Konjam Sirippu Konjam Kobam', 2011, 11, 'tt13427204'),
#  ('Movie', 'Keezha Theru Kicha', 2011, 10, 'tt13427144'),
#  ('Movie', 'Venmani', 2011, 12, 'tt13426944'),
#  ('Movie', 'Paavi', 2011, 12, 'tt13426624'),
#  ('Movie', 'Thigattadha Kadhal', 2011, 1, 'tt13435818'),
#  ('Movie', 'Aaranin Kaaval', 2011, 2, 'tt13439502'),
#  ('Movie', 'Aasaipadugiren', 2011, 6, 'tt13439254'),
#  ('Movie', 'Oru Santhippil', 2011, None, 'tt13439264'),
#  ('Movie', 'Arumbu Meesai Kurumbu Paarvai', 2011, 7, 'tt13439240'),
#  ('Movie', 'Mathikettan Saalai', 2011, 9, 'tt13439112'),
#  ('Movie', 'Ayudha Porattam', 2011, 9, 'tt13439124'),
#  ('Movie', 'Anaagarigam', 2011, 11, 'tt13439244'),
#  ('Movie', 'Sagakkal', 2011, 8, 'tt13439176'),
#  ('Movie', 'Mittai', 2011, 8, 'tt13439128'),
#  ('Movie', 'Kadhal Meipada', 2011, 4, 'tt13439348'),
#  ('Movie', 'Nalamdhana', 2011, None, 'tt13439632'),
#  ('Movie', 'Bodinayakanur Ganesan', 2011, 7, 'tt13439226'),
#  ('Movie', 'Konjam Mazhai Konjam Veyil', 2011, 8, 'tt13439184'),
#  ('Movie', 'Avargalum Ivargalum', 2011, 3, 'tt13439410'),
#  ('Movie', 'Minsaram', 2011, 3, 'tt13439440'),
#  ('Movie', 'Doo', 2011, 8, 'tt13439214'),
#  ('Movie', 'Sankarankovil', 2011, 8, 'tt13439150'),
#  ('Movie', 'Theneer Viduthi', 2011, 7, 'tt13439236'),
#  ('Movie', 'Sabash Sariyana Potti', 2011, 5, 'tt13439272'),
#  ('Movie', 'Thenkasi Pakkathula', 2011, None, 'tt13439364'),
#  ('Movie', 'Padai Soozha', 2011, 3, 'tt13439454'),
#  ('Movie', 'Aivar', 2011, 3, 'tt13439466'),
#  ('Movie', 'Ramanathapuram', 2011, None, 'tt13439192'),
#  ('Movie', 'Thappu', 2011, 3, 'tt13439544'),
#  ('Movie', 'Poova Thalaiya', 2011, 4, 'tt13439328'),
#  ('Movie', 'Breath of Hate', 2015, None, 'tt1344303'),
#  ('Movie', 'Margazhi 16', 2011, 2, 'tt13439478'),
#  ('Movie', 'Paasakaara Nanbargal', 2011, 5, 'tt13439312'),
#  ('Movie', 'Teenagers', 2016, 5, 'tt1344670'),
#  ('Movie', 'Exodus Fall', 2011, 4, 'tt1345466'),
#  ('Movie', 'Le premier homme', 2012, 4, 'tt1349457'),
#  ('Movie', 'Butter', 2012, 10, 'tt1349451'),
#  ('Movie', 'Strawberry Cliff', 2011, 12, 'tt1350510'),
#  ('Movie', 'My Sister Nina', 2011, None, 'tt1350542'),
#  ('Movie', 'Redemption', 2011, None, 'tt1350546'),
#  ('Movie', 'Hu yang shen chu shi wo jia', 2011, 4, 'tt13505984'),
#  ('Movie', 'Final Level', 2011, None, 'tt1352368'),
#  ('Movie', 'The Bad Penny', 2014, 4, 'tt1356392'),
#  ('Movie', 'The Girl with No Number', 2012, 1, 'tt1360843'),
#  ('Movie', 'The Honey Killer', 2018, 4, 'tt1362141'),
#  ('Movie', 'Deuta Raja', 2011, None, 'tt13624164'),
#  ('Movie', 'Naughty @ 40', 2011, 4, 'tt1363125'),
#  ('Movie', 'Chatur Singh Two Star', 2011, 8, 'tt1363363'),
#  ('Movie', 'Qasos', 2011, None, 'tt13641990'),
#  ('Movie', '3D Yuk po tuen: Gik lok bo gam', 2011, 4, 'tt1365048'),
#  ('Movie', 'Chargesheet', 2011, 9, 'tt1368453'),
#  ('Movie', 'Ogul', 2011, None, 'tt13706596'),
#  ('Movie', 'Kako su me ukrali Nemci', 2011, 6, 'tt1371628'),
#  ('Movie', 'Duet ming gam', 2011, 10, 'tt1371585'),
#  ('Movie', 'Coriolanus', 2012, 1, 'tt1372686'),
#  ('Movie', 'The Prodigies', 2011, 6, 'tt1374990'),
#  ('Movie', 'Lipstikka', 2012, 3, 'tt1374988'),
#  ('Movie', 'Alois Nebel', 2011, 9, 'tt1374985'),
#  ('Movie', 'Simon och ekarna', 2012, 9, 'tt1375669'),
#  ('Movie', 'Ma compagne de nuit', 2011, 3, 'tt1376427'),
#  ('Movie', 'Play', 2012, 5, 'tt1376717'),
#  ('Movie', 'My Angel', 2011, 12, 'tt1379721'),
#  ('Movie', 'Cesado', 2011, 1, 'tt1379736'),
#  ('Movie', 'Hero Nanalla', 2011, 12, 'tt13798036'),
#  ('Movie', 'Jedarahalli', 2011, 12, 'tt13801614'),
#  ('Movie', 'Vishnu', 2011, 12, 'tt13801640'),
#  ('Movie', 'Onde Ondu Saari', 2011, 12, 'tt13801624'),
#  ('Movie', 'We are all sinners', 2011, None, 'tt13808944'),
#  ('Movie', "Love Is a Thieves' Game", 2013, 1, 'tt1380912'),
#  ('Movie', 'Tatal fantoma', 2012, 3, 'tt1382728'),
#  ('Movie', 'Hella W', 2011, 1, 'tt1382722'),
#  ('Movie', 'Maya', 2011, None, 'tt13830144'),
#  ('Movie', 'American Disciples', 2013, 1, 'tt1383700'),
#  ('Movie', 'Bella Biondina', 2011, 8, 'tt1383444'),
#  ('Movie', 'Deuce of Spades', 2011, 4, 'tt1384586'),
#  ('Movie', 'Elle ne pleure pas, elle chante', 2011, 6, 'tt1384594'),
#  ('Movie', 'Death of a Superhero', 2012, 8, 'tt1384927'),
#  ('Movie', 'The Other End', 2011, None, 'tt1384928'),
#  ('Movie', 'Rokland', 2011, 1, 'tt1384929'),
#  ('Movie', 'This Is Not a Movie', 2011, 1, 'tt1386492'),
#  ('Movie', 'We Bought a Zoo', 2012, 4, 'tt1389137'),
#  ('Movie', 'Solos en la ciudad', 2011, 10, 'tt1388913'),
#  ('Movie', 'Texas Killing Fields', 2011, 12, 'tt1389127'),
#  ('Movie', 'Oscar', 2011, 6, 'tt13906690'),
#  ('Movie', '5 Idiots', 2011, 2, 'tt13907068'),
#  ('Movie', '106 Kanasu', 2011, 12, 'tt13906852'),
#  ('Movie', 'Kadhimaru', 2011, 5, 'tt13906648'),
#  ('Movie', '90', 2011, 9, 'tt13906590'),
#  ('Movie', 'Aptha', 2011, 2, 'tt13907008'),
#  ('Movie', 'Boss', 2011, 1, 'tt13907238'),
#  ('Movie', 'Mathond Madhuvena', 2011, 4, 'tt13906858'),
#  ('Movie', 'Hori', 2011, 4, 'tt13906802'),
#  ('Movie', 'Ellellu Neene Nannallu Neene', 2011, 4, 'tt13906848'),
#  ('Movie', 'Obavva', 2011, 10, 'tt13906390'),
#  ('Movie', 'Kalgejje', 2011, 2, 'tt13907174'),
#  ('Movie', 'Dudde Doddappa', 2011, 8, 'tt13906566'),
#  ('Movie', 'Lokave Helida Maatidu', 2011, 9, 'tt13906474'),
#  ('Movie', 'Manasology', 2011, 9, 'tt13906482'),
#  ('Movie', 'Namitha I Love You', 2011, 6, 'tt13906616'),
#  ('Movie', 'Panchamrutha', 2011, 8, 'tt13906584'),
#  ('Movie', 'Manasina Maathu', 2011, 1, 'tt13907186'),
#  ('Movie', 'Mallikarjuna', 2011, 5, 'tt13906630'),
#  ('Movie', 'Naavu Namma Hendthiru', 2011, 2, 'tt13907054'),
#  ('Movie', 'Nee Illadhe', 2011, 3, 'tt13906954'),
#  ('Movie', 'Bodyguard', 2011, 11, 'tt13906376'),
#  ('Movie', 'Rama Rama Raghu Rama', 2011, None, 'tt13906998'),
#  ('Movie', 'Thavarina Runa', 2011, 1, 'tt13907254'),
#  ('Movie', 'Aacharya', 2011, None, 'tt13906366'),
#  ('Movie', 'Puttakkana Highway', 2011, 5, 'tt13906718'),
#  ('Movie', 'Double Decker', 2011, 4, 'tt13906840'),
#  ('Movie', 'Pagal', 2011, 12, 'tt13906360'),
#  ('Movie', 'Mr. Duplicate', 2011, 7, 'tt13906558'),
#  ('Movie', 'Chinnada Thali', 2011, 7, 'tt13906550'),
#  ('Movie', 'Dhool', 2011, 4, 'tt13906828'),
#  ('Movie', 'Vinayaka Geleyara Balaga', 2011, 7, 'tt13906516'),
#  ('Movie', 'Taare', 2011, None, 'tt13906448'),
#  ('Movie', 'Uyyale', 2011, 3, 'tt13906976'),
#  ('Movie', 'Prema Chandrama', 2011, 4, 'tt13906876'),
#  ('Movie', 'Veera Bahu', 2011, 2, 'tt13907132'),
#  ('Movie', 'Devadas', 2011, 5, 'tt13906778'),
#  ('Movie', 'Atheetha', 2011, 7, 'tt13906598'),
#  ('Movie', 'Banna Bannada Loka', 2011, 7, 'tt13906544'),
#  ('Movie', 'Ishta', 2011, 10, 'tt13906418'),
#  ('Movie', 'Naanalla', 2011, 10, 'tt13906436'),
#  ('Movie', 'Shravana', 2011, 3, 'tt13906990'),
#  ('Movie', 'Yogaraj But', 2011, 7, 'tt13906524'),
#  ('Movie', 'Prince', 2011, 4, 'tt13906938'),
#  ('Movie', 'Putra', 2011, 10, 'tt13906460'),
#  ('Movie', 'Achchu Mechchu', 2011, 11, 'tt13906344'),
#  ('Movie', 'Suicide', 2011, 2, 'tt13907158'),
#  ('Movie', 'Sri Naga Shakthi', 2011, 1, 'tt13907264'),
#  ('Movie', 'Olave Mandara', 2011, 1, 'tt13907206'),
#  ('Movie', 'Journey', 2011, 4, 'tt13906900'),
#  ('Movie', 'Maryade Ramanna', 2011, 9, 'tt13906502'),
#  ('Movie', 'Bhadra', 2011, 8, 'tt13906572'),
#  ('Movie', 'Chennamma IPS', 2011, 7, 'tt13906610'),
#  ('Movie', 'Gun', 2011, 2, 'tt13907030'),
#  ('Movie', 'Saacha', 2011, 2, 'tt13907016'),
#  ('Movie', 'Kanteerava', 2011, 1, 'tt13907220'),
#  ('Movie', '1 Day', 2011, 2, 'tt13907164'),
#  ('Movie', 'Dushtaa', 2011, None, 'tt13906662'),
#  ('Movie', 'Maagiya Kaala', 2011, 6, 'tt13906704'),
#  ('Movie', 'Resistance', 2011, 11, 'tt1391116'),
#  ('Movie', 'Yondiradi Kuydiradi', 2011, None, 'tt13937768'),
#  ('Movie', 'Dispatch', 2011, 10, 'tt1394322'),
#  ('Movie', 'Sal', 2012, 5, 'tt1395065'),
#  ('Movie', 'Egression', 2011, 5, 'tt1400502'),
#  ('Movie', 'The Fields', 2011, 9, 'tt1401236'),
#  ('Movie', 'Aarambh', 2011, 2, 'tt14017846'),
#  ('Movie', "Bob's New Suit", 2011, 6, 'tt1403129'),
#  ('Movie', 'A Date with Fear', 2011, 2, 'tt1403990'),
#  ('Movie', 'An Insignificant Harvey', 2011, 10, 'tt1404386'),
#  ('Movie', 'The Moth Diaries', 2012, 5, 'tt1407065'),
#  ('Movie', 'Arrugas', 2012, 1, 'tt1407052'),
#  ('Movie', 'Stillleben', 2012, 1, 'tt1408089'),
#  ('Movie', 'Campus Radio', 2011, None, 'tt1409006'),
#  ('Movie', 'Albor', 2011, None, 'tt14099204'),
#  ('Movie', 'Jin ling shi san chai', 2011, 12, 'tt1410063'),
#  ('Movie', 'Retreat', 2012, 4, 'tt1410051'),
#  ('Movie', 'The Best Exotic Marigold Hotel', 2012, 3, 'tt1412386'),
#  ('Movie', 'Ardha Gangu Ardha Gondya', 2011, None, 'tt14130008'),
#  ('Movie', 'Extinction: The G.M.O. Chronicles', 2011, 11, 'tt1416336'),
#  ('Movie', 'Kill the Irishman', 2012, 5, 'tt1416801'),
#  ('Movie', 'In Darkness', 2013, 5, 'tt1417075'),
#  ('Movie', 'Tumar Khabar', 2011, 10, 'tt14182648'),
#  ('Movie', 'Land of Nod', 2011, 2, 'tt14191150'),
#  ('Movie', 'Kardelen', 2011, 2, 'tt1420553'),
#  ('Movie', 'Headlock', 2011, 10, 'tt1420547'),
#  ('Movie', 'Apon Shatru', 2011, 1, 'tt14230734'),
#  ('Movie', 'Agnisakshi', 2011, 1, 'tt14230748'),
#  ('Movie', 'Superstar - A Love Story', 2011, None, 'tt14230956'),
#  ('Movie', 'Bangla Bachao', 2011, 1, 'tt14230790'),
#  ('Movie', 'Piriti Kathaler Aatha', 2011, 2, 'tt14230858'),
#  ('Movie', 'Ekdin Thik', 2011, 3, 'tt14231026'),
#  ('Movie', 'Ohh My Love', 2011, 2, 'tt14230836'),
#  ('Movie', 'Run', 2011, 4, 'tt14231244'),
#  ('Movie', 'Love Birds - The Symbol of Love', 2011, 4, 'tt14231268'),
#  ('Movie', 'Cholte Cholte', 2011, 4, 'tt14231328'),
#  ('Movie', 'Aami Adu', 2011, 2, 'tt14230918'),
#  ('Movie', 'Tupi Diye Topor', 2011, 2, 'tt14230884'),
#  ('Movie', 'Punorutthan', 2011, 3, 'tt14231008'),
#  ('Movie', 'Ogo Bideshini', 2011, 5, 'tt14231706'),
#  ('Movie', 'Jibon Rong Berong', 2011, 4, 'tt14231296'),
#  ('Movie', 'Tiger Number One', 2011, 8, 'tt14232454'),
#  ('Movie', 'Duti Mon', 2011, 4, 'tt14231578'),
#  ('Movie', 'Ei Aranya', 2011, 3, 'tt14231118'),
#  ('Movie', 'Tenida', 2011, None, 'tt14233106'),
#  ('Movie', 'Bajikar', 2011, 4, 'tt14231208'),
#  ('Movie', 'Ek Poloke Ektu Dekha', 2011, 5, 'tt14232192'),
#  ('Movie', 'Street Light', 2011, 3, 'tt14231100'),
#  ('Movie', 'Amio Nebo Challenge', 2011, 6, 'tt14232268'),
#  ('Movie', 'Moubane Aaj', 2011, 10, 'tt14232818'),
#  ('Movie', 'Murder', 2011, 12, 'tt14233030'),
#  ('Movie', 'Keloda in Kashmir', 2011, 9, 'tt14232664'),
#  ('Movie', 'Bindas Prem', 2011, 6, 'tt14232302'),
#  ('Movie', 'Baaz', 2011, 4, 'tt14231538'),
#  ('Movie', 'Tomay Bhalobashi', 2011, 8, 'tt14232370'),
#  ('Movie', 'Bhul Bhal', 2011, 9, 'tt14232482'),
#  ('Movie', 'Jaan Kurbaan', 2011, None, 'tt14232426'),
#  ('Movie', 'Best Friend', 2011, 11, 'tt14232848'),
#  ('Movie', 'Bhorer Pakhi', 2011, 12, 'tt14233154'),
#  ('Movie', 'Mone Mone Bhalobasha', 2011, 10, 'tt14232740'),
#  ('Movie', 'Trishanku', 2011, 12, 'tt14232928'),
#  ('Movie', 'De tu ventana a la mía', 2012, 3, 'tt1423922'),
#  ('Movie', 'The Blue of Noon', 2011, None, 'tt1423635'),
#  ('Movie', 'Billy Bad', 2011, 2, 'tt14261736'),
#  ('Movie', 'Wie man leben soll', 2011, 10, 'tt1428464'),
#  ('Movie', 'Mening akam boydoq', 2011, None, 'tt14296152'),
#  ('Movie', 'Valley of the Sun', 2011, 5, 'tt1429411'),
#  ('Movie', 'Hellgate', 2011, 6, 'tt1430116'),
#  ('Movie', 'Act Naturally', 2020, 6, 'tt1430070'),
#  ('Movie', 'Arthur Christmas', 2011, 11, 'tt1430607'),
#  ('Movie', "Woman's Picture", 2011, 7, 'tt1432161'),
#  ('Movie', 'Small Hours', 2011, 4, 'tt1432256'),
#  ('Movie', 'The Details', 2016, 3, 'tt1433207'),
#  ('Movie', 'Kirjad Inglile', 2011, 1, 'tt1433851'),
#  ('Movie', 'Poley Poley Urey Mon', 2011, 5, 'tt14344094'),
#  ('Movie', 'Man Without a Head', 2011, None, 'tt1436035'),
#  ('Movie', 'Assassination Games', 2012, 1, 'tt1436568'),
#  ('Movie', 'Café', 2011, 10, 'tt1436572'),
#  ('Movie', 'Mientras duermes', 2012, 7, 'tt1437358'),
#  ('Movie', 'Faust', 2012, 2, 'tt1437357'),
#  ('Movie', 'One Kine Day', 2011, 3, 'tt1438214'),
#  ('Movie', 'Perfect Sense', 2012, 1, 'tt1439572'),
#  ('Movie', 'Arzanda', 2011, None, 'tt14399084'),
#  ('Movie', 'A Beautiful Belly', 2011, 4, 'tt1440110'),
#  ('Movie', 'A Little Bit of Heaven', 2012, 5, 'tt1440161'),
#  ('Movie', 'This Must Be the Place', 2012, 4, 'tt1440345'),
#  ('Movie', 'Martha Marcy May Marlene', 2012, 4, 'tt1441326'),
#  ('Movie', 'Hahithalfut', 2012, 4, 'tt1441368'),
#  ('Movie', 'Salmon Fishing in the Yemen', 2012, 5, 'tt1441952'),
#  ('Movie', 'The Jonestown Defense', 2011, None, 'tt1441954'),
#  ('Movie', 'Biester müssen sterben', 2011, 0, 'tt1442205'),
#  ('Movie', 'Taj', 2011, 10, 'tt1444329'),
#  ('Movie', 'Hearat Shulayim', 2012, 4, 'tt1445520'),
#  ('Movie', 'Paapi', 2011, 2, 'tt14465326'),
#  ('Movie', 'Leave', 2011, 5, 'tt1446695'),
#  ...]

# %%
len(lista_json_anios)
# Out:
# 82

# %%
encabezado = ["Tipo", "Título", "Año", "Mes", "ID"]

# %%
df_drama_2000_2023 = pd.DataFrame(datos_final, columns = encabezado)

df_drama_2000_2023
# Out:
#         Tipo                    Título     Año  Mes         ID
# 0      Movie               Pál Adrienn  2011.0  6.0  tt0146592
# 1      Movie            Oda az igazság  2010.0  2.0  tt0154039
# 2      Movie  A zöld sárkány gyermekei  2011.0  4.0  tt0162942
# 3      Movie         The Final Journey  2010.0  9.0  tt0230212
# 4      Movie               In My Sleep  2010.0  4.0  tt0326965
# ...      ...                       ...     ...  ...        ...
# 40995  Short              When in Rome  2009.0  2.0  tt1362332
# 40996  Short               Perspective  2009.0  0.0  tt1362288
# 40997  Short                 Communion  2009.0  NaN  tt1362385
# 40998  Short                   Closure  2009.0  6.0  tt1362383
# 40999  Short           A Second Chance  2009.0  4.0  tt1362306
#
# [41000 rows x 5 columns]

# %%
df_drama_2000_2023.to_csv("drama.csv")
