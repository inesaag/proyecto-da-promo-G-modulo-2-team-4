# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import numpy as np

import re
import random

# %%
df_action = pd.read_csv("action.csv", index_col = 0)
df_comedy = pd.read_csv("comedy.csv", index_col = 0)
df_drama = pd.read_csv("drama_no_duplicado.csv", index_col = 0)

# %%
df = pd.read_csv("segundo_acto_imbd_drama.csv", index_col = 0)

# %%
segundoacto_drama_imdb= df.values.tolist()

# %%
segundoacto_drama_api= df_drama.values.tolist()[10001:16000]

# %%
# 10001 - 16000
# 16001 -24001

# %%
len(segundoacto_drama_imdb)
# Out:
# 5999

# %%
len(segundoacto_drama_api)
# Out:
# 5999

# %%
segundoacto_drama_imdb[2000]
# Out:
# ['6.4',
#  'Yuriy Kara',
#  'Mikhail A. Bulgakov, Yuriy Kara',
#  "Interwoven are a satire of the 1930's under Stalin, the inner struggle of Pontius Pilate around the execution of Jesus, and the love story between a writer in Moscow and his lover Margarita.",
#  '125',
#  'Master i Margarita']

# %%
segundoacto_drama_api[2000]
# Out:
# ['Movie', 'Master i Margarita', 2011.0, 4.0, 'tt0110476']

# %%
#NO USAR!! ES PARA CONPROBAR SI HEMOS HECHO BIEN LAS EXTRACCIONES

for i, pelicula in enumerate(lista_drama_api):
    for ind, peli in enumerate(primeras_drama_8000_imdb):
        
        if lista_drama_api[i][1] == primeras_drama_8000_imdb[i][5]:
            print("----",lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
        else:
            print(lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
        break

# %%
# Inicializar navegador
def datos_tomatoes (lista_imdb, lista_API):

    driver = webdriver.Chrome() 

    # URL Google para extraer la información solicitada. 

    url = "https://www.google.com/" 

    # Hacer una solicitud GET a la URL especificada.

    driver.get(url)  

    # Maximizar la ventana

    driver.maximize_window()
    


    sleep(5)

    # Aceptar cookies

    driver.find_element("css selector", "#L2AGLb > div").click()

    # Creamos lista vacía para introducir el resultado de las puntuaciones (tomatometer) de cada pelicula.

    #total_puntuacion_tomatoes = []

    # Iniciamos bucle for por cada pelicula de los csv que tenemos accediendo por su indice.

    for i, pelicula in enumerate(lista_imdb): 
        for peli in lista_API:
        

            sleep(random.randint(3,10))
            #creamos un string para pasarle a Google el nombre y el año de la pelicula extraidos de IMDB
            peticion = f"'Tomatometer de {lista_imdb[i][5]} del año {lista_API[i][2]}'"
            print(peticion)
            #incluimos el string en la barra de busqueda de Google
            driver.find_element("css selector","#APjFqb").send_keys(peticion, Keys.ENTER)  

            #puntuación (tomatometer)
            
            try:

                #creamos una variable con el nombre de la primera pelicula que aparece en Google
                nombre_peli_google = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text
                print(nombre_peli_google)
                print()

                #si el nombre es igual al nombre de la pelicula que pedimos la añadimos a la lista
                if nombre_peli_google == lista_imdb[i][5]:
                    
                    puntuacion = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                    total_puntuacion_tomatoes.append(puntuacion)
                    print(puntuacion)
                #si el nombre no coincide lo intentamos con la segunda opcion que aparece en google
                else:
                    try:
                        nombre_peli_google2 = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text

                        if nombre_peli_google2 == lista_imdb[i][5]:
                    
                            puntuacion = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                            total_puntuacion_tomatoes.append(puntuacion)
                            print(puntuacion)
                        else:
                            total_puntuacion_tomatoes.append("No tiene datos")
                            print("No tiene datos")
                    except:
                        total_puntuacion_tomatoes.append("No tiene datos")
                        print("No tiene datos")
            except: 

                total_puntuacion_tomatoes.append("No tiene datos")
                print("No tiene datos")
            
        
            # Salimos a la pag.principal del navegador
            
            driver.back()
            break

    return total_puntuacion_tomatoes    # Impresion lista total

# %%
total_puntuacion_tomatoes = []

# %%
#llamamos a la funcion
primeracto_drama_tomatoes = datos_tomatoes(primeracto_drama_imdb, primeracto_drama_api)
# Out:
# 'Tomatometer de Crimen y castigo del año 2002.0'
# No tiene datos
# 'Tomatometer de Pasos de baile del año 2004.0'
# No tiene datos
# 'Tomatometer de Random Shooting in L.A. del año 2002.0'
# 140 Essential Action Movies To Watch Now
#
# No tiene datos
# 'Tomatometer de Frida del año 2003.0'
# Frida
#
# 76
# 'Tomatometer de Shivam del año 2002.0'
# No tiene datos
# 'Tomatometer de The Good War del año 2002.0'
# The Good War
#
# No tiene datos
# 'Tomatometer de The Bacchae del año 2002.0'
# No tiene datos
# 'Tomatometer de Easter del año 2002.0'
# No tiene datos
# 'Tomatometer de António, Um Rapaz de Lisboa del año 2002.0'
# No tiene datos
# 'Tomatometer de White Boy del año 2002.0'
# White Boy
#
# 17
# 'Tomatometer de Three Days of Rain del año 2003.0'
# Three Days of Rain
#
# 40
# 'Tomatometer de Pánico nuclear del año 2002.0'
# The Sum of All Fears
#
# No tiene datos
# 'Tomatometer de La ciudad de los fantasmas del año 2003.0'
# City of Ghosts - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Highway del año 2002.0'
# Highway
#
# 69
# 'Tomatometer de Interstate 60: Episodios de carretera del año 2003.0'
# Interstate 60
#
# No tiene datos
# 'Tomatometer de Spirit: El corcel indomable del año 2002.0'
# No tiene datos
# 'Tomatometer de Antwone Fisher del año 2003.0'
# Antwone Fisher
#
# 78
# 'Tomatometer de El señor de los anillos: Las dos torres del año 2002.0'
# The Lord of the Rings: The Two Towers
#
# No tiene datos
# 'Tomatometer de La balsa de piedra del año 2002.0'
# The Stoneraft
#
# No tiene datos
# 'Tomatometer de O Delfim del año 2002.0'
# No tiene datos
# 'Tomatometer de The Story of O: Untold Pleasures del año 2002.0'
# The Story of O: Untold Pleasures
#
# No tiene datos
# 'Tomatometer de El compromiso del año 2002.0'
# Moonlight Mile (película) - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Dead Man's Dream del año 2002.0'
# Dead Man
#
# No tiene datos
# 'Tomatometer de Maryam del año 2002.0'
# No tiene datos
# 'Tomatometer de Falsa amistad del año 2002.0'
# No tiene datos
# 'Tomatometer de The gang (Golpe perfecto) del año 2004.0'
# No tiene datos
# 'Tomatometer de O Gotejar da Luz del año 2002.0'
# Gotas de luz (2002)
#
# No tiene datos
# 'Tomatometer de Meet Prince Charming del año 1999.0'
# Meet Prince Charming
#
# 49
# 'Tomatometer de Looking for Leonard del año 2002.0'
# Looking for Leonard
#
# 80
# 'Tomatometer de Viva la scimmia del año 2002.0'
# No tiene datos
# 'Tomatometer de A Falha del año 2002.0'
# No tiene datos
# 'Tomatometer de Secret Pleasures del año 2002.0'
# Secret Pleasures
#
# No tiene datos
# 'Tomatometer de Tornare indietro del año 2002.0'
# No tiene datos
# 'Tomatometer de Johan Padan a la descoverta de le Americhe del año 2002.0'
# Sin título
#
# No tiene datos
# 'Tomatometer de 2 Birds with 1 Stallone del año 2002.0'
# No tiene datos
# 'Tomatometer de Alma Mater del año 2002.0'
# Alma Mater
#
# No tiene datos
# 'Tomatometer de The Water Game del año 2002.0'
# The 100 Best 2000s Horror Movies
#
# No tiene datos
# 'Tomatometer de El misterio de Ginostra del año 2003.0'
# Ginostra
#
# No tiene datos
# 'Tomatometer de Ken Park del año 2003.0'
# Ken Park
#
# 46
# 'Tomatometer de Looking for Jimmy del año 2002.0'
# No tiene datos
# 'Tomatometer de Road Dogz del año 2002.0'
# Road Dogz
#
# 86
# 'Tomatometer de La selva del año 2002.0'
# The Emperor's New Groove - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Los banqueros de Dios del año 2002.0'
# No tiene datos
# 'Tomatometer de The Tracker del año 2002.0'
# The Tracker
#
# 88
# 'Tomatometer de The Streetsweeper del año 2002.0'
# No tiene datos
# 'Tomatometer de Asesinato en lunes de carnaval del año 2002.0'
# No tiene datos
# 'Tomatometer de Cuba del año 2002.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Searching for Paradise del año 2002.0'
# Searching for Paradise
#
# 71
# 'Tomatometer de La redención del fantasma del año 2002.0'
# Redemption of the Ghost
#
# No tiene datos
# 'Tomatometer de Amor sin condiciones del año 2002.0'
# Amor sin condiciones (2002)
#
# No tiene datos
# 'Tomatometer de Gangs of New York del año 2003.0'
# Gangs of New York
#
# 73
# 'Tomatometer de The Last Place on Earth del año 2002.0'
# The Last Place on Earth
#
# 60
# 'Tomatometer de Séraphin: un homme et son péché del año 2002.0'
# Séraphin: Heart of Stone (2002)
#
# No tiene datos
# 'Tomatometer de Juego deshonesto del año 2002.0'
# No tiene datos
# 'Tomatometer de Hum Tumhare Hain Sanam del año 2002.0'
# Hum Tumhare Hain Sanam
#
# 48
# 'Tomatometer de Temporal del año 2002.0'
# "Las horas", de Stephen Daldry (V.O.S.E.)
#
# No tiene datos
# 'Tomatometer de 24 heures de la vie d'une femme del año 2003.0'
# No tiene datos
# 'Tomatometer de O Fato Completo Ou À Procura De Alberto del año 2002.0'
# No tiene datos
# 'Tomatometer de McAllister Affair: The Gathering del año 2003.0'
# No tiene datos
# 'Tomatometer de Jóvenes salvajes del año 2002.0'
# Deuces Wild
#
# No tiene datos
# 'Tomatometer de Escapando del año 2003.0'
# Panic in Year Zero
#
# No tiene datos
# 'Tomatometer de The Cross del año 2007.0'
# No tiene datos
# 'Tomatometer de Daño colateral del año 2002.0'
# Collateral Damage
#
# No tiene datos
# 'Tomatometer de Después de la vida del año 2003.0'
# No tiene datos
# 'Tomatometer de The Salton Sea del año 2002.0'
# The Salton Sea
#
# 63
# 'Tomatometer de Wicked Spring del año 2007.0'
# Wicked Spring
#
# 56
# 'Tomatometer de La reina de los condenados del año 2002.0'
# Queen of the Damned
#
# No tiene datos
# 'Tomatometer de Devdas del año 2002.0'
# Devdas
#
# 86
# 'Tomatometer de Equilibrium del año 2003.0'
# Equilibrium
#
# 40
# 'Tomatometer de La peligrosa vida de los altar boys del año 2002.0'
# The Dangerous Lives of Altar Boys
#
# No tiene datos
# 'Tomatometer de Florida City del año 2002.0'
# No tiene datos
# 'Tomatometer de El pequeño angel del año 2002.0'
# El pequeño ángel (2002)
#
# No tiene datos
# 'Tomatometer de Till Human Voices Wake Us del año 2003.0'
# Till Human Voices Wake Us
#
# 25
# 'Tomatometer de Halalabad Blues del año 2002.0'
# No tiene datos
# 'Tomatometer de Las cuatro plumas del año 2002.0'
# The Four Feathers
#
# No tiene datos
# 'Tomatometer de Féroce del año 2002.0'
# No tiene datos
# 'Tomatometer de Sweetie Pie del año 2002.0'
# Welcome to Sweetie Pie's (2014 - 2016)
#
# No tiene datos
# 'Tomatometer de Par 6 del año 2002.0'
# No tiene datos
# 'Tomatometer de A Time for Dancing del año 2002.0'
# A Time for Dancing
#
# 75
# 'Tomatometer de The Final Curtain (El último acto) del año 2002.0'
# No tiene datos
# 'Tomatometer de Cottonmouth del año 2002.0'
# No tiene datos
# 'Tomatometer de XX/XY del año 2003.0'
# XX/XY
#
# 42
# 'Tomatometer de Beso en Manhattan del año 2003.0'
# No tiene datos
# 'Tomatometer de Cruel Game del año 2002.0'
# No tiene datos
# 'Tomatometer de Windtalkers del año 2002.0'
# Windtalkers
#
# 33
# 'Tomatometer de La venganza del conde de Montecristo del año 2002.0'
# The Count of Monte Cristo
#
# No tiene datos
# 'Tomatometer de King Rikki del año 2002.0'
# No tiene datos
# 'Tomatometer de Heaven, de Tom Tykwer del año 2002.0'
# Heaven
#
# No tiene datos
# 'Tomatometer de Dummy, el muñeco del año 2003.0'
# No tiene datos
# 'Tomatometer de Julie vuelve a casa del año 2003.0'
# Julie Walking Home
#
# No tiene datos
# 'Tomatometer de Juwanna Mann del año 2002.0'
# Juwanna Mann
#
# 10
# 'Tomatometer de Aap Mujhe Achche Lagne Lage del año 2002.0'
# No tiene datos
# 'Tomatometer de The Trip del año 2002.0'
# The Trip
#
# 38
# 'Tomatometer de Even Steven del año 2002.0'
# Even Stevens
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Jumping for Joy del año 2002.0'
# Jumping for Joy
#
# No tiene datos
# 'Tomatometer de Umur del año 2002.0'
# No tiene datos
# 'Tomatometer de Leaving the Land del año 2002.0'
# Rotten Tomatoes
#
# No tiene datos
# 'Tomatometer de Infiel del año 2002.0'
# No tiene datos
# 'Tomatometer de Baby of the Family del año 2002.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Turn of Faith del año 2002.0'
# Turn of Faith
#
# 14
# 'Tomatometer de John Q del año 2002.0'
# John Q
#
# 26
# 'Tomatometer de La guerra de Hart del año 2002.0'
# Hart's War
#
# No tiene datos
# 'Tomatometer de Sucedió en Manhattan del año 2003.0'
# Maid in Manhattan
#
# No tiene datos
# 'Tomatometer de 97 Brooks del año 2002.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Generación robada del año 2003.0'
# Rabbit-Proof Fence
#
# No tiene datos
# 'Tomatometer de Suavemente me mata del año 2002.0'
# No tiene datos
# 'Tomatometer de Don't Let Go del año 2002.0'
# Don't Let Go
#
# No tiene datos
# 'Tomatometer de El pianista del año 2002.0'
# The Pianist
#
# No tiene datos
# 'Tomatometer de Now & Forever del año 2002.0'
# Now & Forever
#
# 20
# 'Tomatometer de Camino a la perdición del año 2002.0'
# Road to Perdition
#
# No tiene datos
# 'Tomatometer de Purpose del año 2002.0'
# Purpose
#
# 55
# 'Tomatometer de Die Frau die an Dr. Fabian zweifelte del año 2002.0'
# No tiene datos
# 'Tomatometer de Posesión del año 2002.0'
# No tiene datos
# 'Tomatometer de Bolivar soy yo del año 2002.0'
# Bolivar Is Me
#
# No tiene datos
# 'Tomatometer de Toda la verdad del año 2002.0'
# High Crimes - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de A propósito de Schmidt del año 2002.0'
# About Schmidt
#
# No tiene datos
# 'Tomatometer de La habitación del pánico del año 2002.0'
# Panic Room
#
# No tiene datos
# 'Tomatometer de El americano impasible del año 2003.0'
# The Quiet American
#
# No tiene datos
# 'Tomatometer de Dragonfly (La sombra de la libélula) del año 2002.0'
# Dragonfly
#
# No tiene datos
# 'Tomatometer de Mi gran boda griega del año 2002.0'
# My Big Fat Greek Wedding
#
# No tiene datos
# 'Tomatometer de Paid in Full del año 2002.0'
# Paid in Full
#
# 53
# 'Tomatometer de Simone del año 2002.0'
# Simone
#
# 51
# 'Tomatometer de CortoMaltés: La película del año 2002.0'
# Corto Maltese
#
# No tiene datos
# 'Tomatometer de El misterio de Wells del año 2004.0'
# The Reckoning
#
# No tiene datos
# 'Tomatometer de Swimming Upstream del año 2002.0'
# Swimming Upstream
#
# 61
# 'Tomatometer de Cazador de sombras del año 2002.0'
# No tiene datos
# 'Tomatometer de The Ring of the Buddha del año 2003.0'
# The Lord of the Rings: The Return of the King
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Mischka del año 2002.0'
# No tiene datos
# 'Tomatometer de Un juego de caballeros del año 2004.0'
# Conoce la mejor y peor película de Batman según Rotten ...
#
# No tiene datos
# 'Tomatometer de Empire del año 2002.0'
# Empire
#
# 21
# 'Tomatometer de Como el gato y el ratón del año 2002.0'
# Como el gato y el ratón (Like Cat and Mouse)
#
# No tiene datos
# 'Tomatometer de Al límite de la verdad del año 2002.0'
# Changing Lanes
#
# No tiene datos
# 'Tomatometer de El embrujo de Shanghái del año 2002.0'
# The Shanghai Spell
#
# No tiene datos
# 'Tomatometer de Mucho más que un cachorro del año 2002.0'
# No tiene datos
# 'Tomatometer de Oscura perversión del año 2002.0'
# Oscura perversión (2002)
#
# No tiene datos
# 'Tomatometer de Thank You, Good Night del año 2002.0'
# Thank You, Good Night
#
# No tiene datos
# 'Tomatometer de Mothman: La última profecía del año 2002.0'
# The Mothman Prophecies
#
# No tiene datos
# 'Tomatometer de Pumpkin del año 2004.0'
# No tiene datos
# 'Tomatometer de Men with Brooms del año 2002.0'
# Men With Brooms
#
# No tiene datos
# 'Tomatometer de Atrápame si puedes del año 2003.0'
# Catch Me if You Can
#
# No tiene datos
# 'Tomatometer de Black Mask 2 del año 2003.0'
# Black Mask 2: City of Masks
#
# No tiene datos
# 'Tomatometer de Just Can't Get Enough del año 2002.0'
# Just Can't Get Enough
#
# 57
# 'Tomatometer de Las perversiones de Livia del año 2002.0'
# Las perversiones de Livia - Película 2002
#
# No tiene datos
# 'Tomatometer de La desaparición de Embry del año 2002.0'
# Abandon
#
# No tiene datos
# 'Tomatometer de Retratos de una obsesión del año 2002.0'
# No tiene datos
# 'Tomatometer de Der Felsen del año 2002.0'
# No tiene datos
# 'Tomatometer de The Abduction Club del año 2002.0'
# The Abduction Club
#
# 40
# 'Tomatometer de Strange Hearts del año 2002.0'
# Strange Hearts (2002)
#
# No tiene datos
# 'Tomatometer de El juego de Ripley del año 2003.0'
# Ripley's Game
#
# No tiene datos
# 'Tomatometer de Tiro de gracia del año 2002.0'
# No tiene datos
# 'Tomatometer de K-19: The Widowmaker del año 2002.0'
# K-19: The Widowmaker
#
# 60
# 'Tomatometer de Stray Dogs del año 2002.0'
# Stray Dogs
#
# 73
# 'Tomatometer de El novato del año 2002.0'
# The Rookie
#
# No tiene datos
# 'Tomatometer de Smoochy del año 2002.0'
# No tiene datos
# 'Tomatometer de Chicago Streets del año 2002.0'
# Chicago
#
# No tiene datos
# 'Tomatometer de Petites misères del año 2002.0'
# No tiene datos
# 'Tomatometer de L'italiano del año 2002.0'
# No tiene datos
# 'Tomatometer de Close Enough to Touch del año 2002.0'
# Close Enough to Touch
#
# No tiene datos
# 'Tomatometer de Adaptation (El ladrón de orquídeas) del año 2003.0'
# Adaptation
#
# No tiene datos
# 'Tomatometer de Hundtricket: The Movie del año 2002.0'
# Hundtricket the Movie
#
# No tiene datos
# 'Tomatometer de No somos nadie del año 2002.0'
# God is On Air - Movie Reviews
#
# No tiene datos
# 'Tomatometer de The Greatest Adventure of My Life del año 2002.0'
# The Greatest Adventure of My Life
#
# No tiene datos
# 'Tomatometer de Condenado (City by the Sea) del año 2002.0'
# City by the Sea
#
# No tiene datos
# 'Tomatometer de Em Volta del año 2002.0'
# John Travolta
#
# No tiene datos
# 'Tomatometer de Una roquera de cuidado del año 2002.0'
# No tiene datos
# 'Tomatometer de Salvoconducto del año 2002.0'
# No tiene datos
# 'Tomatometer de Raat Chali Hai Jhoom Ke del año 2002.0'
# No tiene datos
# 'Tomatometer de American Gun del año 2003.0'
# American Gun
#
# 39
# 'Tomatometer de Felhö a Gangesz felett del año 2002.0'
# No tiene datos
# 'Tomatometer de Chico Malo del año 2002.0'
# Jorge Avila Andrade Movie Reviews & Previews
#
# No tiene datos
# 'Tomatometer de Teknolust del año 2010.0'
# No tiene datos
# 'Tomatometer de Hollywood Vampyr del año 2003.0'
# Hollywood Vampyr
#
# No tiene datos
# 'Tomatometer de Mujhse Dosti Karoge! del año 2002.0'
# Mujse Dosti Karoge
#
# No tiene datos
# 'Tomatometer de Black Swan del año 2002.0'
# Black Swan
#
# 85
# 'Tomatometer de El adversario del año 2003.0'
# Daredevil
#
# No tiene datos
# 'Tomatometer de The Other Brother del año 2004.0'
# The Other Brother
#
# 33
# 'Tomatometer de Bark! del año 2002.0'
# No tiene datos
# 'Tomatometer de Hus i helvete del año 2002.0'
# No tiene datos
# 'Tomatometer de Confesiones de una mente peligrosa del año 2003.0'
# Confessions of a Dangerous Mind
#
# No tiene datos
# 'Tomatometer de Renacuajo del año 2002.0'
# No tiene datos
# 'Tomatometer de Jane White Is Sick & Twisted del año 2002.0'
# Jane White Is Sick and Twisted
#
# No tiene datos
# 'Tomatometer de Feliz aquí y ahora del año 2003.0'
# No tiene datos
# 'Tomatometer de Narc del año 2003.0'
# Narc
#
# 83
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Zig Zag del año 2002.0'
# ZigZag
#
# No tiene datos
# 'Tomatometer de Joshua del año 2004.0'
# Joshua
#
# 22
# 'Tomatometer de Embriagado de amor del año 2003.0'
# Punch-Drunk Love
#
# No tiene datos
# 'Tomatometer de Pyar Ki Dhun del año 2002.0'
# No tiene datos
# 'Tomatometer de Alerta: Évola del año 2002.0'
# Contagion (película de 2002)
#
# No tiene datos
# 'Tomatometer de Beauty Betrayed del año 2002.0'
# No tiene datos
# 'Tomatometer de Ararat del año 2002.0'
# No tiene datos
# 'Tomatometer de 24 Hour Party People del año 2003.0'
# 24 Hour Party People
#
# 87
# 'Tomatometer de Última jugada del año 2003.0'
# No tiene datos
# 'Tomatometer de Orange County (Colgado, pringado y sin carrera) del año 2003.0'
# Orange County
#
# No tiene datos
# 'Tomatometer de Le doux amour des hommes del año 2002.0'
# Le doux amour des hommes (2002)
#
# No tiene datos
# 'Tomatometer de Chacho Rom del año 2002.0'
# No tiene datos
# 'Tomatometer de Callas Forever del año 2002.0'
# Callas Forever
#
# 41
# 'Tomatometer de Club Le Monde del año 2002.0'
# Club Le Monde
#
# 80
# 'Tomatometer de Pyaar Diwana Hota Hai del año 2002.0'
# Pyaar Diwana Hota Hai
#
# 20
# 'Tomatometer de Las horas del año 2003.0'
# Las Horas Del Dia
#
# No tiene datos
# 'Tomatometer de Maquilladas del año 2002.0'
# 0% en Rotten Tomatoes: las peores películas de la historia
#
# No tiene datos
# 'Tomatometer de La secretaria del año 2003.0'
# Secretary
#
# No tiene datos
# 'Tomatometer de Intervención divina del año 2003.0'
# No tiene datos
# 'Tomatometer de Nothing So Strange del año 2006.0'
# No tiene datos
# 'Tomatometer de Relaciones confidenciales del año 2004.0'
# People I Know - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Sin destino del año 2002.0'
# No tiene datos
# 'Tomatometer de The Decay of Fiction del año 2003.0'
# The Decay of Fiction
#
# 86
# 'Tomatometer de Crossroads: hasta el final del año 2002.0'
# Crossroads
#
# No tiene datos
# 'Tomatometer de Víctima de guerra del año 2003.0'
# No tiene datos
# 'Tomatometer de *Corpus Callosum del año 2002.0'
# Corpus Callosum
#
# No tiene datos
# 'Tomatometer de Rue des plaisirs del año 2002.0'
# Rue des Plaisirs
#
# No tiene datos
# 'Tomatometer de Ciao America del año 2002.0'
# No tiene datos
# 'Tomatometer de Lilo & Stitch del año 2002.0'
# No tiene datos
# 'Tomatometer de Atrapados en la niebla del año 2002.0'
# No tiene datos
# 'Tomatometer de All Night Bodega del año 2004.0'
# All Night Bodega
#
# No tiene datos
# 'Tomatometer de Un niño grande del año 2002.0'
# About a Boy
#
# No tiene datos
# 'Tomatometer de Never Get Outta the Boat del año 2002.0'
# Never Get Outta the Boat
#
# 78
# 'Tomatometer de Histoire de Pen del año 2002.0'
# No tiene datos
# 'Tomatometer de Máxima velocidad del año 2002.0'
# No tiene datos
# 'Tomatometer de Cuando éramos soldados del año 2002.0'
# We Were Soldiers
#
# No tiene datos
# 'Tomatometer de Shooters del año 2002.0'
# No tiene datos
# 'Tomatometer de Air panic del año 2006.0'
# No tiene datos
# 'Tomatometer de Contra la ley del año 2002.0'
# No tiene datos
# 'Tomatometer de Clover Bend: Un pueblo tranquilo del año 2002.0'
# Clover Bend
#
# No tiene datos
# 'Tomatometer de Nunca más del año 2002.0'
# Enough
#
# No tiene datos
# 'Tomatometer de Insomnio del año 2002.0'
# No tiene datos
# 'Tomatometer de The Good Girl del año 2003.0'
# The Good Girl
#
# 82
# 'Tomatometer de Heart of America del año 2002.0'
# Heart of America
#
# 20
# 'Tomatometer de Castigo maligno del año 2002.0'
# Críticas de Castigo maligno (Time of Fear) (2002)
#
# No tiene datos
# 'Tomatometer de Spider del año 2003.0'
# No tiene datos
# 'Tomatometer de Jack & Ella del año 2002.0'
# Jack & Ella
#
# No tiene datos
# 'Tomatometer de Dark Blue del año 2003.0'
# No tiene datos
# 'Tomatometer de La importancia de llamarse Ernesto del año 2002.0'
# The Importance of Being Earnest
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Clan Ya-Ya del año 2002.0'
# Divine Secrets of the Ya-Ya Sisterhood
#
# No tiene datos
# 'Tomatometer de Jedermanns Fest del año 2002.0'
# No tiene datos
# 'Tomatometer de EvenHand del año 2002.0'
# No tiene datos
# 'Tomatometer de Las caras de la luna del año 2002.0'
# No tiene datos
# 'Tomatometer de Les amants du Nil del año 2002.0'
# No tiene datos
# 'Tomatometer de Ella no es un ángel del año 2002.0'
# She's No Angel
#
# No tiene datos
# 'Tomatometer de Atrapada del año 2003.0'
# No tiene datos
# 'Tomatometer de Better Luck Tomorrow del año 2003.0'
# Better Luck Tomorrow
#
# 81
# 'Tomatometer de Miércoles de ceniza del año 2004.0'
# Cenizas del cielo
#
# No tiene datos
# 'Tomatometer de Dina del año 2002.0'
# I Am Dina
#
# No tiene datos
# 'Tomatometer de Baby del año 2003.0'
# Anexo:Películas con un 0% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de La gran caída de Igby del año 2003.0'
# Igby Goes Down
#
# No tiene datos
# 'Tomatometer de Femme Fatale del año 2002.0'
# Femme Fatale
#
# 49
# 'Tomatometer de Invicto del año 2002.0'
# No tiene datos
# 'Tomatometer de El gran golpe del año 2002.0'
# No tiene datos
# 'Tomatometer de Gebürtig del año 2002.0'
# No tiene datos
# 'Tomatometer de Atrapados por el fuego del año 2002.0'
# No tiene datos
# 'Tomatometer de Carnages del año 2002.0'
# Carnage
#
# No tiene datos
# 'Tomatometer de Bloody Sunday del año 2003.0'
# Bloody Sunday
#
# 92
# 'Tomatometer de Amén. del año 2003.0'
# No tiene datos
# 'Tomatometer de Amigas a la fuerza del año 2002.0'
# The Banger Sisters - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de En el punto de mira del año 2002.0'
# En el punto de mira (2002)
#
# No tiene datos
# 'Tomatometer de Pacino Is Missing del año 2002.0'
# Pacino Is Missing
#
# No tiene datos
# 'Tomatometer de Bella Bettien del año 2002.0'
# Bella Bettien
#
# No tiene datos
# 'Tomatometer de Dinero a la fuga del año 2005.0'
# Dinero a la fuga (29 Palms) (2002)
#
# No tiene datos
# 'Tomatometer de Woman on Fire del año 2002.0'
# Portrait of a Lady on Fire
#
# No tiene datos
# 'Tomatometer de El bosque mágico de Tuck del año 2002.0'
# Tuck Everlasting
#
# No tiene datos
# 'Tomatometer de La flor del mal del año 2003.0'
# The Flower of Evil
#
# No tiene datos
# 'Tomatometer de Amida-do dayori del año 2002.0'
# No tiene datos
# 'Tomatometer de Children of the Flag del año 2002.0'
# No tiene datos
# 'Tomatometer de Flores de sangre del año 2002.0'
# No tiene datos
# 'Tomatometer de Spun del año 2003.0'
# Spin
#
# No tiene datos
# 'Tomatometer de Le loup de la côte Ouest del año 2002.0'
# No tiene datos
# 'Tomatometer de Un paseo para recordar del año 2002.0'
# A Walk to Remember
#
# No tiene datos
# 'Tomatometer de Vu khúc con cò del año 2003.0'
# No tiene datos
# 'Tomatometer de El buen ladrón del año 2003.0'
# Pig: La película con Nicolas Cage recibe un excelente ...
#
# No tiene datos
# 'Tomatometer de Quicksand del año 2002.0'
# Quicksand
#
# 7
# 'Tomatometer de Héroe solitario del año 2002.0'
# El destino del guerrero: todo sobre el nacimiento de los ...
#
# No tiene datos
# 'Tomatometer de Gangsters del año 2002.0'
# No tiene datos
# 'Tomatometer de Kondaveeti Simhasanam del año 2002.0'
# No tiene datos
# 'Tomatometer de La repentie del año 2002.0'
# The Repentant
#
# No tiene datos
# 'Tomatometer de West of Here del año 2002.0'
# West of Here
#
# No tiene datos
# 'Tomatometer de Con amor, Liza del año 2003.0'
# Love Liza
#
# No tiene datos
# 'Tomatometer de Sombras del pasado del año 2002.0'
# Sombras del pasado (2002)
#
# No tiene datos
# 'Tomatometer de Hot Dog del año 2002.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Rok dábla del año 2002.0'
# No tiene datos
# 'Tomatometer de Seung fei del año 2002.0'
# No tiene datos
# 'Tomatometer de Chance del año 2002.0'
# Chance
#
# 77
# 'Tomatometer de Vivante del año 2002.0'
# Resident Evil
#
# No tiene datos
# 'Tomatometer de El ascenso del año 2002.0'
# El ascenso
#
# No tiene datos
# 'Tomatometer de Días de garaje del año 2002.0'
# Garage Days
#
# No tiene datos
# 'Tomatometer de Miradas del año 2002.0'
# Disney: 100 Years, 100 Essential Movies
#
# No tiene datos
# 'Tomatometer de El beso del oso del año 2003.0'
# El beso del sueño
#
# No tiene datos
# 'Tomatometer de The Rose Technique del año 2002.0'
# The Rose Technique
#
# No tiene datos
# 'Tomatometer de Asesinato a ritmo de tango del año 2003.0'
# Assassination Tango
#
# No tiene datos
# 'Tomatometer de Shottas del año 2002.0'
# Shottas
#
# 18
# 'Tomatometer de Engaño mortal del año 2002.0'
# No tiene datos
# 'Tomatometer de Mother Ghost del año 2002.0'
# Mother Ghost
#
# 52
# 'Tomatometer de Skins del año 2002.0'
# No tiene datos
# 'Tomatometer de Charlotte Sometimes del año 2002.0'
# No tiene datos
# 'Tomatometer de Peau d'ange del año 2002.0'
# No tiene datos
# 'Tomatometer de Shararat del año 2002.0'
# No tiene datos
# 'Tomatometer de Training Wheels del año 2002.0'
# No tiene datos
# 'Tomatometer de Lunes por la mañana del año 2002.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2003.0'
# No tiene datos
# 'Tomatometer de 1 na 1 del año 2002.0'
# No tiene datos
# 'Tomatometer de Y ahora, damas y caballeros del año 2002.0'
# No tiene datos
# 'Tomatometer de Bâtards del año 2002.0'
# No tiene datos
# 'Tomatometer de Nogo del año 2002.0'
# 28 Days Later
#
# No tiene datos
# 'Tomatometer de Una casa de locos del año 2002.0'
# No tiene datos
# 'Tomatometer de Children on Their Birthdays del año 2002.0'
# Children on Their Birthdays
#
# 68
# 'Tomatometer de Demonlover del año 2002.0'
# Demonlover
#
# 53
# 'Tomatometer de Desaparecidos: La resistencia del año 2002.0'
# Desaparecidos: La resistencia (2002)
#
# No tiene datos
# 'Tomatometer de Walking on Water del año 2002.0'
# Walking on Water
#
# 83
# 'Tomatometer de Fanática del año 2003.0'
# All Stephen King TV Series, Miniseries, TV Movies Ranked
#
# No tiene datos
# 'Tomatometer de The Emperor's Club (El club de los emperadores) del año 2003.0'
# The Emperor's Club
#
# No tiene datos
# 'Tomatometer de Chopin. Pragnienie milosci del año 2002.0'
# No tiene datos
# 'Tomatometer de Atrapadas por la mafia del año 2002.0'
# Críticas de Atrapadas por la mafia (2002)
#
# No tiene datos
# 'Tomatometer de El manual del anarquista del año 2002.0'
# No tiene datos
# 'Tomatometer de Australian Rules del año 2002.0'
# Australian Rules
#
# 74
# 'Tomatometer de Coastlines del año 2002.0'
# No tiene datos
# 'Tomatometer de Cacería del año 2002.0'
# Alien Hunter - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Ted Bundy del año 2002.0'
# Ted Bundy
#
# 41
# 'Tomatometer de Farewell to Harry del año 2002.0'
# Farewell to Harry
#
# 71
# 'Tomatometer de Hi Frank! del año 2002.0'
# No tiene datos
# 'Tomatometer de Cube 2: Hypercube del año 2003.0'
# Cube 2: Hypercube
#
# 45
# 'Tomatometer de Epsteins Nacht del año 2002.0'
# No tiene datos
# 'Tomatometer de Respiro del año 2003.0'
# Respiro
#
# 77
# 'Tomatometer de Coney Island Baby del año 2002.0'
# Coney Island Baby
#
# 50
# 'Tomatometer de La chatte à deux têtes del año 2002.0'
# No tiene datos
# 'Tomatometer de Da zero a dieci del año 2002.0'
# Da zero a dieci
#
# No tiene datos
# 'Tomatometer de Tattoo (Tatuaje) del año 2002.0'
# No tiene datos
# 'Tomatometer de Quiero ser como Beckham del año 2002.0'
# No tiene datos
# 'Tomatometer de Musikk for bryllup og begravelser del año 2002.0'
# Musikk for bryllup og begravelser (Music for Weddings and ...
#
# No tiene datos
# 'Tomatometer de Revengers Tragedy del año 2003.0'
# No tiene datos
# 'Tomatometer de La bande du drugstore del año 2002.0'
# Dandy
#
# No tiene datos
# 'Tomatometer de Crazy as hell del año 2002.0'
# Crazy as Hell
#
# No tiene datos
# 'Tomatometer de L.A. X del año 2002.0'
# XXX
#
# No tiene datos
# 'Tomatometer de Bánk bán del año 2003.0'
# The 200 Best Movies of the 2010s
#
# No tiene datos
# 'Tomatometer de Five Years del año 2006.0'
# Five Years
#
# No tiene datos
# 'Tomatometer de Edge of Madness del año 2002.0'
# No tiene datos
# 'Tomatometer de King's Highway del año 2008.0'
# King's Highway - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Escuela de asesinos del año 2008.0'
# Pathology - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Todo o nada del año 2003.0'
# Las 40 películas dirigidas por Clint Eastwood ordenadas ...
#
# No tiene datos
# 'Tomatometer de Deathwatch del año 2002.0'
# No tiene datos
# 'Tomatometer de La casa de al lado del año 2002.0'
# House at the End of the Street
#
# No tiene datos
# 'Tomatometer de Señales del año 2002.0'
# Signs
#
# No tiene datos
# 'Tomatometer de 28 días después del año 2003.0'
# No tiene datos
# 'Tomatometer de Folk flest bor i Kina del año 2002.0'
# Folk flest bor i Kina (2002)
#
# No tiene datos
# 'Tomatometer de El lugar donde estuvo el paraíso del año 2002.0'
# The Other Side of Heaven - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Dahmer, el carnicero de Milwaukee del año 2019.0'
# Dahmer
#
# No tiene datos
# 'Tomatometer de Terapia de sexo del año 2002.0'
# No tiene datos
# 'Tomatometer de Hable con ella del año 2002.0'
# Talk to Her
#
# No tiene datos
# 'Tomatometer de Passionada del año 2002.0'
# No tiene datos
# 'Tomatometer de Stolen Summer del año 2003.0'
# Stolen Summer
#
# 36
# 'Tomatometer de Al caer la noche del año 2002.0'
# http://www.rottentomatoes.com/search/full_search.p...
#
# No tiene datos
# 'Tomatometer de La tierra prometida del año 2002.0'
# Equilibrium
#
# No tiene datos
# 'Tomatometer de Mou han fou wut del año 2002.0'
# No tiene datos
# 'Tomatometer de Deseo del año 2002.0'
# No tiene datos
# 'Tomatometer de La soledad era esto del año 2002.0'
# Críticas profesionales de La soledad era esto 2002
#
# No tiene datos
# 'Tomatometer de Hipo del año 2003.0'
# No tiene datos
# 'Tomatometer de Nos miran del año 2002.0'
# No tiene datos
# 'Tomatometer de La curva de la felicidad del año 2003.0'
# The Mystery of Happiness - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Choses secrètes del año 2002.0'
# No tiene datos
# 'Tomatometer de La marcha verde del año 2002.0'
# The Green March
#
# No tiene datos
# 'Tomatometer de La guerre à Paris del año 2002.0'
# No tiene datos
# 'Tomatometer de Angela del año 2002.0'
# No tiene datos
# 'Tomatometer de Ultimo stadio del año 2002.0'
# The Sum of All Fears (película)
#
# No tiene datos
# 'Tomatometer de Los últimos días de Emmett Young del año 2003.0'
# Los últimos días de Emmett Young (2002)
#
# No tiene datos
# 'Tomatometer de Ni vivo, ni muerto del año 2002.0'
# Ni vivo ni muerto (2002)
#
# No tiene datos
# 'Tomatometer de Les percutés del año 2002.0'
# No tiene datos
# 'Tomatometer de Le frère du guerrier del año 2002.0'
# Le Frere Du Guerrier
#
# No tiene datos
# 'Tomatometer de The Year That Trembled del año 2002.0'
# The Year That Trembled
#
# 32
# 'Tomatometer de Before You Go del año 2002.0'
# Before You Go
#
# 27
# 'Tomatometer de El dragón rojo del año 2002.0'
# Red Dragon
#
# No tiene datos
# 'Tomatometer de Tabú del año 2003.0'
# Taboo
#
# No tiene datos
# 'Tomatometer de Entre extraños del año 2002.0'
# No tiene datos
# 'Tomatometer de Malévolo del año 2002.0'
# No tiene datos
# 'Tomatometer de Blood relations del año 2002.0'
# Blood relations (2002)
#
# No tiene datos
# 'Tomatometer de Patul lui Procust del año 2002.0'
# No tiene datos
# 'Tomatometer de Big Ain't Bad del año 2005.0'
# Big Ain't Bad
#
# No tiene datos
# 'Tomatometer de Výlet del año 2002.0'
# No tiene datos
# 'Tomatometer de La última fase del año 2002.0'
# No tiene datos
# 'Tomatometer de Potestad del año 2003.0'
# No tiene datos
# 'Tomatometer de Blue Car del año 2003.0'
# No tiene datos
# 'Tomatometer de Almodou del año 2002.0'
# No tiene datos
# 'Tomatometer de Lo más cercano al cielo del año 2002.0'
# Lo más cercano al cielo (2002)
#
# No tiene datos
# 'Tomatometer de A Light in the Darkness del año 2002.0'
# A Light in the Darkness
#
# No tiene datos
# 'Tomatometer de Max del año 2003.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Mi vida empieza hoy del año 2002.0'
# Mi vida empieza hoy (2002)
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2003.0'
# No tiene datos
# 'Tomatometer de Mille millièmes del año 2002.0'
# No tiene datos
# 'Tomatometer de Sin motivo aparente del año 2014.0'
# No tiene datos
# 'Tomatometer de Lola vende cá del año 2002.0'
# Lola vende cá
#
# No tiene datos
# 'Tomatometer de L'idole del año 2003.0'
# No tiene datos
# 'Tomatometer de Fixing Frank del año 2002.0'
# Fixing Frank
#
# 56
# 'Tomatometer de El sueño de Ibiza del año 2002.0'
# El Sueño de Ibiza
#
# No tiene datos
# 'Tomatometer de Novo del año 2002.0'
# Desnudos Tete Delgado
#
# No tiene datos
# 'Tomatometer de Local Boys del año 2002.0'
# Local Boys
#
# 82
# 'Tomatometer de Figure in the Forest del año 2002.0'
# No tiene datos
# 'Tomatometer de Entre chiens et loups del año 2002.0'
# No tiene datos
# 'Tomatometer de Irreversible del año 2002.0'
# Irréversible
#
# No tiene datos
# 'Tomatometer de Los diablos del año 2002.0'
# No tiene datos
# 'Tomatometer de Aro Tolbukhin - En la mente del asesino del año 2002.0'
# Aro Tolbukhin in the Mind of a Killer
#
# No tiene datos
# 'Tomatometer de Rifles del año 2002.0'
# No Time to Die
#
# No tiene datos
# 'Tomatometer de El caballero Don Quijote del año 2002.0'
# Don Quixote
#
# No tiene datos
# 'Tomatometer de Ulvepigen Tinke del año 2003.0'
# No tiene datos
# 'Tomatometer de The Round and Round del año 2002.0'
# The Round and Round
#
# No tiene datos
# 'Tomatometer de Besen a quien quieran del año 2002.0'
# No tiene datos
# 'Tomatometer de Une femme de ménage del año 2002.0'
# No tiene datos
# 'Tomatometer de Fasuna to Chibusa del año 2002.0'
# No tiene datos
# 'Tomatometer de Summer del año 2002.0'
# Summer
#
# 86
# 'Tomatometer de Dracula the Impaler del año 2002.0'
# No tiene datos
# 'Tomatometer de Guerreros del año 2002.0'
# No tiene datos
# 'Tomatometer de The Wild Dogs del año 2002.0'
# The Wild Dogs
#
# 57
# 'Tomatometer de Perfect Pie del año 2002.0'
# Perfect Pie
#
# 52
# 'Tomatometer de Balzac y la joven costurera china del año 2002.0'
# Balzac y la joven costurera china (2002)
#
# No tiene datos
# 'Tomatometer de Marie-Jo y sus dos amores del año 2002.0'
# Marie-Jo and Her 2 Lovers
#
# No tiene datos
# 'Tomatometer de Love in the Time of Money del año 2002.0'
# Love in the Time of Money
#
# 18
# 'Tomatometer de El precio de la ambicion del año 2005.0'
# El Precio De La Ambición - Película Completa en Español ...
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2003.0'
# No tiene datos
# 'Tomatometer de Historias mínimas del año 2003.0'
# Minimal Stories
#
# No tiene datos
# 'Tomatometer de Wheatfield with Crows del año 2002.0'
# No tiene datos
# 'Tomatometer de Todas las azafatas van al cielo del año 2002.0'
# Every Stewardess Goes to Heaven
#
# No tiene datos
# 'Tomatometer de Monsieur Batignole del año 2002.0'
# Monsieur Batignole
#
# 80
# 'Tomatometer de Nelson Gonçalves del año 2002.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de The Piano Player del año 2004.0'
# They Shot the Piano Player
#
# No tiene datos
# 'Tomatometer de La vida sexual de los peces del año 2002.0'
# No tiene datos
# 'Tomatometer de Saat sau kwong lung del año 2002.0'
# No tiene datos
# 'Tomatometer de Face del año 2002.0'
# No tiene datos
# 'Tomatometer de La maîtresse en maillot de bain del año 2002.0'
# No tiene datos
# 'Tomatometer de Crazy Jones del año 2002.0'
# No tiene datos
# 'Tomatometer de Filles perdues, cheveux gras del año 2002.0'
# https://www.rottentomatoes.com/search?search=Fille...
#
# No tiene datos
# 'Tomatometer de Friday After Next del año 2002.0'
# Friday After Next
#
# 26
# 'Tomatometer de Until Death del año 2002.0'
# Until Death
#
# No tiene datos
# 'Tomatometer de Mitr: My Friend del año 2002.0'
# Mitr, My Friend
#
# No tiene datos
# 'Tomatometer de Solitude del año 2002.0'
# Solitude
#
# 67
# 'Tomatometer de Las reglas del juego del año 2002.0'
# No tiene datos
# 'Tomatometer de 800 balas del año 2002.0'
# 800 Bullets
#
# No tiene datos
# 'Tomatometer de Okay del año 2002.0'
# Okay
#
# 64
# 'Tomatometer de The Flats del año 2002.0'
# No tiene datos
# 'Tomatometer de Silent Cry del año 2002.0'
# Silent Cry
#
# 75
# 'Tomatometer de Hungry Hearts del año 2002.0'
# Hungry Hearts
#
# 63
# 'Tomatometer de Kaante del año 2002.0'
# No tiene datos
# 'Tomatometer de Aime ton père del año 2002.0'
# No tiene datos
# 'Tomatometer de La turbulence des fluides del año 2002.0'
# La turbulence des fluides (2002)
#
# No tiene datos
# 'Tomatometer de Solino del año 2002.0'
# No tiene datos
# 'Tomatometer de Converging with Angels del año 2002.0'
# No tiene datos
# 'Tomatometer de A Paixão de Jacobina del año 2002.0'
# A Paixão de Jacobina (2002)
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2002.0'
# No tiene datos
# 'Tomatometer de Au fil de l'eau del año 2002.0'
# No tiene datos
# 'Tomatometer de 2009: Lost Memories del año 2002.0'
# 2009: Lost Memories
#
# 43
# 'Tomatometer de Dracula: Pages from a Virgin's Diary del año 2003.0'
# Dracula: Pages From a Virgin's Diary
#
# No tiene datos
# 'Tomatometer de Role of a Lifetime del año 2002.0'
# Role of a Lifetime
#
# No tiene datos
# 'Tomatometer de Rencor del año 2002.0'
# No tiene datos
# 'Tomatometer de Az utolsó blues del año 2002.0'
# No tiene datos
# 'Tomatometer de Zatracení del año 2002.0'
# No tiene datos
# 'Tomatometer de La vida prometida del año 2003.0'
# Strange Way of Life
#
# No tiene datos
# 'Tomatometer de Leaving Metropolis del año 2002.0'
# Leaving Metropolis
#
# 17
# 'Tomatometer de Promised Land del año 2003.0'
# The Promised Land
#
# 53
# 'Tomatometer de Sudeste del año 2003.0'
# No tiene datos
# 'Tomatometer de Into the Flames del año 2002.0'
# Into the Flames
#
# No tiene datos
# 'Tomatometer de Final Breakdown del año 2002.0'
# No tiene datos
# 'Tomatometer de Viernes noche del año 2002.0'
# Las mejores películas de Edward Norton, según la crítica ...
#
# No tiene datos
# 'Tomatometer de Volver a empezar del año 2010.0'
# To Begin Again
#
# No tiene datos
# 'Tomatometer de Personal Velocity: Three Portraits del año 2004.0'
# Personal Velocity: Three Portraits
#
# 69
# 'Tomatometer de October Holiday del año 2002.0'
# All I Want for Christmas
#
# No tiene datos
# 'Tomatometer de KL Menjerit del año 2002.0'
# No tiene datos
# 'Tomatometer de The Hawk & the Dove del año 2002.0'
# No tiene datos
# 'Tomatometer de Deux del año 2002.0'
# No tiene datos
# 'Tomatometer de If Wishes Were Horses del año 2002.0'
# If Wishes Were Horses
#
# No tiene datos
# 'Tomatometer de Sólo un sueño del año 2002.0'
# Revolutionary Road
#
# No tiene datos
# 'Tomatometer de Sur le bout des doigts del año 2002.0'
# No tiene datos
# 'Tomatometer de Puedes besar a la novia del año 2002.0'
# No tiene datos
# 'Tomatometer de Kald mig bare Aksel del año 2003.0'
# No tiene datos
# 'Tomatometer de Master of the Game del año 2004.0'
# Master of the Game
#
# 57
# 'Tomatometer de Lejos del cielo del año 2003.0'
# No tiene datos
# 'Tomatometer de Mr. Smith Gets a Hustler del año 2003.0'
# Mr. Smith Gets a Hustler
#
# 0
# 'Tomatometer de Vivir mata del año 2002.0'
# Living Kills - Movie Reviews
#
# No tiene datos
# 'Tomatometer de El que cambia los tiempos del año 2016.0'
# No tiene datos
# 'Tomatometer de Un viaggio chiamato amore del año 2002.0'
# Un viaggio chiamato amore (2002)
#
# No tiene datos
# 'Tomatometer de Las mujeres de verdad tienen curvas del año 2002.0'
# Real Women Have Curves
#
# No tiene datos
# 'Tomatometer de Il più bel giorno della mia vita del año 2003.0'
# The Best Day of My Life
#
# No tiene datos
# 'Tomatometer de Nha Fala del año 2003.0'
# No tiene datos
# 'Tomatometer de Brown Sugar del año 2002.0'
# Brown Sugar
#
# 66
# 'Tomatometer de Tenfold del año 2002.0'
# Tenfold
#
# No tiene datos
# 'Tomatometer de Beneath Clouds del año 2002.0'
# Beneath Clouds
#
# 85
# 'Tomatometer de Lara del año 2002.0'
# Series más populares del momento, según Rotten Tomatoes
#
# No tiene datos
# 'Tomatometer de Bäst i Sverige! del año 2002.0'
# Bäst i Sverige! (2002)
#
# No tiene datos
# 'Tomatometer de 17 fois Cécile Cassard del año 2002.0'
# 17 Times Cecile Cassard
#
# No tiene datos
# 'Tomatometer de Furia del año 2002.0'
# No tiene datos
# 'Tomatometer de Cathedral del año 2002.0'
# No tiene datos
# 'Tomatometer de Company del año 2002.0'
# Bad Company
#
# No tiene datos
# 'Tomatometer de Alla älskar Alice del año 2002.0'
# No tiene datos
# 'Tomatometer de Nancy & Frank - A Manhattan Love Story del año 2002.0'
# No tiene datos
# 'Tomatometer de Le chignon d'Olga del año 2002.0'
# No tiene datos
# 'Tomatometer de Irène del año 2002.0'
# No tiene datos
# 'Tomatometer de Fais-moi des vacances del año 2002.0'
# No tiene datos
# 'Tomatometer de La cage del año 2002.0'
# XXX
#
# No tiene datos
# 'Tomatometer de Reckoning del año 2002.0'
# No tiene datos
# 'Tomatometer de 8 millas del año 2003.0'
# No tiene datos
# 'Tomatometer de Jonás: Una película de los VeggieTales del año 2002.0'
# No tiene datos
# 'Tomatometer de En América del año 2003.0'
# In America
#
# No tiene datos
# 'Tomatometer de A Mulher Polícia del año 2003.0'
# 12 filmes perturbadores de terror psicológico (parte 2)
#
# No tiene datos
# 'Tomatometer de American Reel del año 2003.0'
# American Reel
#
# No tiene datos
# 'Tomatometer de One Last Dance del año 2004.0'
# One Last Dance
#
# 51
# 'Tomatometer de Cold Mountain del año 2004.0'
# Cold Mountain
#
# 70
# 'Tomatometer de El señor de los anillos: El retorno del rey del año 2003.0'
# The Lord of the Rings: The Return of the King
#
# No tiene datos
# 'Tomatometer de Baggage del año 2003.0'
# No tiene datos
# 'Tomatometer de The Fighting Temptations del año 2004.0'
# The Fighting Temptations
#
# 42
# 'Tomatometer de Jersey Guy del año 2003.0'
# No tiene datos
# 'Tomatometer de Where the Red Fern Grows del año 2003.0'
# Where the Red Fern Grows
#
# 67
# 'Tomatometer de Black Ball del año 2003.0'
# Blackball
#
# No tiene datos
# 'Tomatometer de Osmose del año 2004.0'
# Osmosis Jones
#
# No tiene datos
# 'Tomatometer de Scardanelli del año 2003.0'
# No tiene datos
# 'Tomatometer de Greasewood Flat del año 2015.0'
# No tiene datos
# 'Tomatometer de Pasado oculto del año 2003.0'
# Pasado oculto (2003)
#
# No tiene datos
# 'Tomatometer de El rey de los ladrones del año 2003.0'
# http://www.rottentomatoes.com/search/full_search.p...
#
# No tiene datos
# 'Tomatometer de Paradise Grove del año 2003.0'
# No tiene datos
# 'Tomatometer de Rose's del año 1999.0'
# Rose's
#
# No tiene datos
# 'Tomatometer de Ciudad del sol del año 2003.0'
# Ciudad del sol
#
# No tiene datos
# 'Tomatometer de House of the Generals del año 2003.0'
# House of the Dead
#
# No tiene datos
# 'Tomatometer de Terror in the Darkness del año 2003.0'
# Terror in the Darkness
#
# No tiene datos
# 'Tomatometer de Examen del año 2003.0'
# Exam
#
# No tiene datos
# 'Tomatometer de Silver Man del año 2003.0'
# Saving Silverman
#
# No tiene datos
# 'Tomatometer de Chasing Holden del año 2003.0'
# No tiene datos
# 'Tomatometer de Alvarez & Cruz del año 2003.0'
# No tiene datos
# 'Tomatometer de Finding Home del año 2005.0'
# Finding Home
#
# 30
# 'Tomatometer de Road Dogs del año 2003.0'
# Road Dogz
#
# No tiene datos
# 'Tomatometer de The Deserter del año 2003.0'
# The Deserter
#
# No tiene datos
# 'Tomatometer de Ish HaHashmal del año 2003.0'
# No tiene datos
# 'Tomatometer de Sleeping Pills del año 2003.0'
# No tiene datos
# 'Tomatometer de Sem Ela del año 2004.0'
# No tiene datos
# 'Tomatometer de El lenguaje de los sueños del año 2003.0'
# El lenguaje de los sueños (2003)
#
# No tiene datos
# 'Tomatometer de How It All Went Down del año 2003.0'
# The Way It All Went Down
#
# No tiene datos
# 'Tomatometer de The Invitation del año 2003.0'
# The Invitation
#
# 7
# 'Tomatometer de Just Like Mona del año 2003.0'
# Mona Lisa Smile
#
# No tiene datos
# 'Tomatometer de Escape from Cuba del año 2003.0'
# No tiene datos
# 'Tomatometer de PTU del año 2003.0'
# No tiene datos
# 'Tomatometer de Nobody Needs to Know del año 2003.0'
# Nobody Needs to Know
#
# No tiene datos
# 'Tomatometer de Sangre de Cuba del año 2006.0'
# Sangre de Cuba - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de An American Reunion del año 2004.0'
# American Reunion
#
# No tiene datos
# 'Tomatometer de Koi... Mil Gaya del año 2003.0'
# No tiene datos
# 'Tomatometer de The Trade del año 2003.0'
# The Trade
#
# 60
# 'Tomatometer de Héroe ocasional del año 2003.0'
# No tiene datos
# 'Tomatometer de Emotional Backgammon del año 2003.0'
# No tiene datos
# 'Tomatometer de Desmadre en la nieve del año 2003.0'
# No tiene datos
# 'Tomatometer de Trinity del año 2005.0'
# They Call Me Trinity
#
# No tiene datos
# 'Tomatometer de Atajo a la felicidad del año 2007.0'
# No tiene datos
# 'Tomatometer de Niñera a la fuerza del año 2004.0'
# No tiene datos
# 'Tomatometer de Basic del año 2003.0'
# No tiene datos
# 'Tomatometer de La primera noche del año 2003.0'
# No tiene datos
# 'Tomatometer de Kill Bill: Volumen 1 del año 2003.0'
# Kill Bill: Vol. 1
#
# No tiene datos
# 'Tomatometer de Diablo (A Man Apart) del año 2003.0'
# A Man Apart
#
# No tiene datos
# 'Tomatometer de Main Prem Ki Diwani Hoon del año 2003.0'
# Main Prem Ki Diwani Hoon
#
# 53
# 'Tomatometer de Mr. Id del año 2007.0'
# No tiene datos
# 'Tomatometer de The Hunted (La presa) del año 2003.0'
# The Hunted
#
# No tiene datos
# 'Tomatometer de Everyday del año 2003.0'
# Every Day
#
# No tiene datos
# 'Tomatometer de Quicksand (Juego sucio) del año 2005.0'
# Quicksand
#
# No tiene datos
# 'Tomatometer de Crust del año 2003.0'
# No tiene datos
# 'Tomatometer de Rhythm of the Saints del año 2003.0'
# Rhythm of the Saints
#
# No tiene datos
# 'Tomatometer de Tres solteros y un biberón: 18 años después del año 2004.0'
# Tres solteros y un biberón: 18 años después (2003)
#
# No tiene datos
# 'Tomatometer de The Forgotten del año 2003.0'
# The Forgotten
#
# 31
# 'Tomatometer de It's All About Love (Todo es por amor) del año 2004.0'
# It's All About Love
#
# No tiene datos
# 'Tomatometer de Vera del año 2003.0'
# Vera
#
# No tiene datos
# 'Tomatometer de Out of Bounds del año 2003.0'
# Out of Bounds
#
# No tiene datos
# 'Tomatometer de Dogville del año 2003.0'
# No tiene datos
# 'Tomatometer de El misterio del Trinidad del año 2003.0'
# El Misterio del Trinidad
#
# No tiene datos
# 'Tomatometer de Undermind del año 2003.0'
# No tiene datos
# 'Tomatometer de My Dinner with Jimi del año 2007.0'
# My Dinner With Jimi
#
# No tiene datos
# 'Tomatometer de Dioses y generales del año 2003.0'
# No tiene datos
# 'Tomatometer de A Touch of Fate del año 2003.0'
# A Touch of Fate
#
# No tiene datos
# 'Tomatometer de Heartland del año 2005.0'
# http://www.rottentomatoes.com/search/full_search.p...
#
# 100
# 'Tomatometer de Bloom del año 2004.0'
# Bloom
#
# 39
# 'Tomatometer de Devastación del año 2003.0'
# No tiene datos
# 'Tomatometer de Malamor del año 2004.0'
# No tiene datos
# 'Tomatometer de Les marins perdus del año 2003.0'
# Les Marins perdus (Lost Seamen)
#
# No tiene datos
# 'Tomatometer de Ascolta la canzone del vento del año 2004.0'
# No tiene datos
# 'Tomatometer de Lost Junction del año 2003.0'
# Lost Junction
#
# 35
# 'Tomatometer de Happy Hour del año 2003.0'
# Happy Hour
#
# 35
# 'Tomatometer de El Polaquito del año 2003.0'
# The Little Polish
#
# No tiene datos
# 'Tomatometer de Zakka West del año 2003.0'
# No tiene datos
# 'Tomatometer de Detrás de la puerta roja del año 2003.0'
# Insidious: The Red Door
#
# No tiene datos
# 'Tomatometer de Red Betsy del año 2003.0'
# Red Betsy
#
# 75
# 'Tomatometer de Learning Curves del año 2003.0'
# Learning Curves
#
# No tiene datos
# 'Tomatometer de Los jardines de la memoria del año 2003.0'
# No tiene datos
# 'Tomatometer de El cazador de sueños del año 2003.0'
# Dreamcatcher
#
# No tiene datos
# 'Tomatometer de Dunsmore del año 2003.0'
# No tiene datos
# 'Tomatometer de Van God Los del año 2003.0'
# No tiene datos
# 'Tomatometer de Chick Street Fighter del año 2003.0'
# No tiene datos
# 'Tomatometer de Un sueño para ella del año 2003.0'
# What a Girl Wants
#
# No tiene datos
# 'Tomatometer de Bienvenidos a Belleville del año 2003.0'
# The Triplets of Belleville
#
# No tiene datos
# 'Tomatometer de Owning Mahowny del año 2003.0'
# Owning Mahowny
#
# 78
# 'Tomatometer de Milwaukee, Minnesota del año 2005.0'
# No tiene datos
# 'Tomatometer de Hurt del año 2003.0'
# 16 Years of Alcohol
#
# 71
# 'Tomatometer de Paradise Found del año 2003.0'
# Paradise Found
#
# 33
# 'Tomatometer de Esmeraldero del año 2004.0'
# Contrabando de Esmeraldas
#
# No tiene datos
# 'Tomatometer de Searching for Wooden Watermelons del año 2003.0'
# No tiene datos
# 'Tomatometer de Zelary del año 2003.0'
# No tiene datos
# 'Tomatometer de Young Adam del año 2003.0'
# Young Adam
#
# 62
# 'Tomatometer de No tiene datos del año 2004.0'
# No tiene datos
# 'Tomatometer de La vida de David Gale del año 2003.0'
# The Life of David Gale
#
# No tiene datos
# 'Tomatometer de Green Card Fever del año 2003.0'
# Green Card Fever
#
# 40
# 'Tomatometer de Presa del amor del año 2003.0'
# No tiene datos
# 'Tomatometer de Crimen en portada del año 2003.0'
# No tiene datos
# 'Tomatometer de My Father, Rua Alguem 5555 del año 2006.0'
# My Father, Rua Alguem 5555
#
# No tiene datos
# 'Tomatometer de Siraba, la grande voie del año 2003.0'
# No tiene datos
# 'Tomatometer de Down with the Joneses del año 2003.0'
# Keeping Up With the Joneses
#
# No tiene datos
# 'Tomatometer de Welcome to the Neighborhood del año 2003.0'
# Welcome to the Neighborhood
#
# No tiene datos
# 'Tomatometer de El vientre de Juliette del año 2003.0'
# No tiene datos
# 'Tomatometer de Carandiru del año 2003.0'
# Carandiru
#
# 68
# 'Tomatometer de Gedebe del año 2003.0'
# No tiene datos
# 'Tomatometer de Amar peligrosamente del año 2004.0'
# Beyond Borders
#
# No tiene datos
# 'Tomatometer de Noctivagant del año 2003.0'
# No tiene datos
# 'Tomatometer de Les côtelettes del año 2003.0'
# Les Côtelettes
#
# No tiene datos
# 'Tomatometer de Mia thalassa makria del año 2003.0'
# No tiene datos
# 'Tomatometer de Back Spot Turn del año 2003.0'
# 25 Best Horror Movies of Each Year Since 1998
#
# No tiene datos
# 'Tomatometer de En territoire indien del año 2003.0'
# No tiene datos
# 'Tomatometer de Rosenstrasse del año 2003.0'
# Rosenstraße
#
# No tiene datos
# 'Tomatometer de Toujours tout droit del año 2003.0'
# No tiene datos
# 'Tomatometer de Collusion del año 2003.0'
# Collusion
#
# No tiene datos
# 'Tomatometer de The Devil's Tattoo del año 2003.0'
# No tiene datos
# 'Tomatometer de La pérdida del año 2004.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2004.0'
# No tiene datos
# 'Tomatometer de El regreso del año 2003.0'
# El regreso (película de 2003)
#
# No tiene datos
# 'Tomatometer de Ni a favor ni en contra (sino todo lo contrario) del año 2003.0'
# Ni a favor ni en contra (sino todo lo contrario) (2003)
#
# No tiene datos
# 'Tomatometer de The Favourite Game del año 2003.0'
# The Favourite Game
#
# 33
# 'Tomatometer de Chicas de verdad del año 2003.0'
# Las 25 mejores miniseries de HBO Max, según Rotten ...
#
# No tiene datos
# 'Tomatometer de El castillo soñado del año 2003.0'
# Las 100 mejores películas de fantasía de la historia del cine
#
# No tiene datos
# 'Tomatometer de Kart Racer (Coches de fuego) del año 2004.0'
# Kart Racer
#
# No tiene datos
# 'Tomatometer de Good bye, Lenin! del año 2003.0'
# Good Bye Lenin!
#
# No tiene datos
# 'Tomatometer de Robot stories del año 2004.0'
# Robot Stories
#
# No tiene datos
# 'Tomatometer de Max's Dreaming del año 2003.0'
# No tiene datos
# 'Tomatometer de Visitors del año 2003.0'
# Visitors
#
# 23
# 'Tomatometer de Deliver Us from Eva del año 2003.0'
# Deliver Us From Eva
#
# No tiene datos
# 'Tomatometer de Wash Dry and Spin Out del año 2003.0'
# No tiene datos
# ...
# 'Tomatometer de FAQs del año 2005.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2005.0'
# No tiene datos
# 'Tomatometer de The King del año 2006.0'
# The King
#
# 58
# 'Tomatometer de No tiene datos del año 2005.0'
# No tiene datos
# 'Tomatometer de Memorias de una geisha del año 2006.0'
# No tiene datos
# 'Tomatometer de Man to man del año 2005.0'
# Man to Man
#
# No tiene datos
# 'Tomatometer de La esperanza del año 2005.0'
# Esperanza
#
# No tiene datos
# 'Tomatometer de Game Over del año 2006.0'
# No tiene datos
# 'Tomatometer de La llave del mal del año 2005.0'
# The Skeleton Key
#
# No tiene datos
# 'Tomatometer de A fény ösvényei del año 2005.0'
# No tiene datos
# 'Tomatometer de Sin control del año 2005.0'
# Derailed - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Obaba del año 2005.0'
# Obaba
#
# 53
# 'Tomatometer de En el valle del año 2005.0'
# Nausicaä del Valle del Viento (película)
#
# No tiene datos
# 'Tomatometer de Stress, Orgasms, and Salvation del año 2005.0'
# No tiene datos
# 'Tomatometer de Special Ed del año 2006.0'
# Special Ed
#
# 20
# 'Tomatometer de Asalto al distrito 13 del año 2005.0'
# Assault on Precinct 13
#
# No tiene datos
# 'Tomatometer de Dicen por ahí... del año 2006.0'
# Rumor Has It
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2005.0'
# No tiene datos
# 'Tomatometer de Nordeste del año 2005.0'
# No tiene datos
# 'Tomatometer de Duane Hopwood del año 2006.0'
# No tiene datos
# 'Tomatometer de Ambulancen del año 2005.0'
# La muerte del Sr. Lazarescu - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Sum of Existence del año 2005.0'
# Sum of Existence
#
# No tiene datos
# 'Tomatometer de Bag det stille ydre del año 2005.0'
# No tiene datos
# 'Tomatometer de Mei ren yi jiu del año 2005.0'
# No tiene datos
# 'Tomatometer de El final del espíritu del año 2006.0'
# The Pursuit of Happyness
#
# No tiene datos
# 'Tomatometer de Y tan amigos del año 2005.0'
# No tiene datos
# 'Tomatometer de El señor de la guerra del año 2005.0'
# Lord of War
#
# No tiene datos
# 'Tomatometer de Una historia de violencia del año 2005.0'
# A History of Violence
#
# No tiene datos
# 'Tomatometer de La cosecha de hielo del año 2006.0'
# The Ice Harvest
#
# No tiene datos
# 'Tomatometer de Die blaue Grenze del año 2005.0'
# No tiene datos
# 'Tomatometer de Lepel del año 2005.0'
# No tiene datos
# 'Tomatometer de Chanthupottu del año 2005.0'
# No tiene datos
# 'Tomatometer de Brooklyn Lobster del año 2005.0'
# No tiene datos
# 'Tomatometer de Dancing in Twilight del año 2005.0'
# Dancing in Twilight
#
# 71
# 'Tomatometer de Gente poco corriente del año 2006.0'
# No tiene datos
# 'Tomatometer de Tamara del año 2006.0'
# No tiene datos
# 'Tomatometer de Xiang ri kui del año 2007.0'
# No tiene datos
# 'Tomatometer de C.R.A.Z.Y. del año 2006.0'
# C.R.A.Z.Y.
#
# 100
# 'Tomatometer de Say Uncle del año 2005.0'
# Say Uncle
#
# 16
# 'Tomatometer de Beowulf & Grendel: el retorno de la bestia del año 2006.0'
# Beowulf & Grendel
#
# No tiene datos
# 'Tomatometer de Campeón de campeones (Chok Dee) del año 2005.0'
# Chok Dee
#
# No tiene datos
# 'Tomatometer de Un golpe de suerte del año 2005.0'
# Golpe de suerte
#
# No tiene datos
# 'Tomatometer de El imperio de los lobos del año 2005.0'
# Empire of the Wolves
#
# No tiene datos
# 'Tomatometer de El osito polar: la isla misteriosa del año 2006.0'
# No tiene datos
# 'Tomatometer de New York City del año 2006.0'
# No tiene datos
# 'Tomatometer de East of Sunset del año 2005.0'
# No tiene datos
# 'Tomatometer de Unge Andersen del año 2005.0'
# Young Andersen
#
# No tiene datos
# 'Tomatometer de At Last del año 2005.0'
# At Last
#
# 0
# 'Tomatometer de El nuevo mundo del año 2006.0'
# Off-Off-Critica
#
# No tiene datos
# 'Tomatometer de Casanova del año 2006.0'
# Casanova
#
# 45
# 'Tomatometer de Supercross del año 2005.0'
# No tiene datos
# 'Tomatometer de Caos del año 2006.0'
# No tiene datos
# 'Tomatometer de Last Days del año 2005.0'
# Last Days
#
# 58
# 'Tomatometer de Les mauvais joueurs del año 2005.0'
# No tiene datos
# 'Tomatometer de State Property 2 del año 2005.0'
# State Property 2
#
# 14
# 'Tomatometer de Uno para todas del año 2005.0'
# Rotten Tomatoes - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de La migra del año 2005.0'
# No tiene datos
# 'Tomatometer de Bettie Page: la chica de las revistas del año 2006.0'
# No tiene datos
# 'Tomatometer de Silicon Valley del año 2005.0'
# Silicon Valley
#
# 94
# 'Tomatometer de Solkongen del año 2005.0'
# No tiene datos
# 'Tomatometer de El camino del diablo del año 2005.0'
# No tiene datos
# 'Tomatometer de Nordkraft del año 2005.0'
# No tiene datos
# 'Tomatometer de Sobre ruedas del año 2005.0'
# No tiene datos
# 'Tomatometer de Simiosis del año 2005.0'
# No tiene datos
# 'Tomatometer de Todo está iluminado del año 2005.0'
# Everything Is Illuminated
#
# No tiene datos
# 'Tomatometer de El exorcismo de Emily Rose del año 2005.0'
# The Exorcism of Emily Rose
#
# No tiene datos
# 'Tomatometer de Chasing ghosts (la caza) del año 2005.0'
# Chasing Ghosts
#
# No tiene datos
# 'Tomatometer de Rosas rojas... rojas del año 2005.0'
# No tiene datos
# 'Tomatometer de Sametoví vrazi del año 2005.0'
# Sametoví vrazi (2005)
#
# No tiene datos
# 'Tomatometer de E ridendo l'uccise del año 2005.0'
# No tiene datos
# 'Tomatometer de Nearing Grace del año 2005.0'
# Nearing Grace
#
# 48
# 'Tomatometer de Loggerheads del año 2007.0'
# No tiene datos
# 'Tomatometer de El acuerdo del año 2005.0'
# No tiene datos
# 'Tomatometer de Barfuss del año 2005.0'
# Barfuss (Barefoot) (2005)
#
# No tiene datos
# 'Tomatometer de Algo parecido a la felicidad del año 2005.0'
# Algo parecido a la felicidad (2005)
#
# No tiene datos
# 'Tomatometer de Weiße Stille del año 2005.0'
# No tiene datos
# 'Tomatometer de La ganadora del año 2007.0'
# No tiene datos
# 'Tomatometer de A Year and a Day del año 2005.0'
# A Year Without Love
#
# No tiene datos
# 'Tomatometer de Historia de un secuestro del año 2006.0'
# No tiene datos
# 'Tomatometer de Dobro ustimani mrtvaci del año 2005.0'
# Dobro ustimani mrtvaci (2005)
#
# No tiene datos
# 'Tomatometer de Lorelei del año 2005.0'
# Lorelei I-507
#
# 90
# 'Tomatometer de No tiene datos del año 2005.0'
# No tiene datos
# 'Tomatometer de Transamérica del año 2006.0'
# No tiene datos
# 'Tomatometer de Le survenant del año 2005.0'
# No tiene datos
# 'Tomatometer de Krev zmizelého del año 2005.0'
# No tiene datos
# 'Tomatometer de Sílení del año 2005.0'
# Lunacy
#
# No tiene datos
# 'Tomatometer de Our Very Own del año 2005.0'
# Our Very Own
#
# 42
# 'Tomatometer de The Sisters del año 2008.0'
# The Dolly Sisters - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Satellite del año 2005.0'
# No tiene datos
# 'Tomatometer de Príbehy obycejného sílenství del año 2005.0'
# Wrong Side Up
#
# No tiene datos
# 'Tomatometer de Voksne mennesker del año 2006.0'
# No tiene datos
# 'Tomatometer de Raul - Diritto di uccidere del año 2005.0'
# No tiene datos
# 'Tomatometer de La joven de las especias del año 2006.0'
# No tiene datos
# 'Tomatometer de Lost in the Wash del año 2005.0'
# No tiene datos
# 'Tomatometer de Múnich del año 2006.0'
# Munich
#
# No tiene datos
# 'Tomatometer de Knetter del año 2005.0'
# No tiene datos
# 'Tomatometer de Alex del año 2005.0'
# Alexander
#
# No tiene datos
# 'Tomatometer de Wrong Turn del año 2005.0'
# Wrong Turn
#
# 40
# 'Tomatometer de No tiene datos del año 2005.0'
# No tiene datos
# 'Tomatometer de Come Away Home del año 2005.0'
# Come Away Home
#
# 63
# 'Tomatometer de New Town Original del año 2005.0'
# New Town Original
#
# No tiene datos
# 'Tomatometer de Las muñecas rusas del año 2005.0'
# No tiene datos
# 'Tomatometer de El guerrero del año 2005.0'
# Las 25 películas basadas en videojuegos mejor valoradas ...
#
# No tiene datos
# 'Tomatometer de White Nights del año 2005.0'
# White Nights
#
# 46
# 'Tomatometer de Shabd del año 2005.0'
# No tiene datos
# 'Tomatometer de La noche del hermano del año 2005.0'
# The Night of the Brother
#
# No tiene datos
# 'Tomatometer de Un toque de seducción del año 2006.0'
# Un toque de seducción (2005)
#
# No tiene datos
# 'Tomatometer de Resurrection: The J.R. Richard Story del año 2005.0'
# No tiene datos
# 'Tomatometer de Lying in Bed del año 2005.0'
# No tiene datos
# 'Tomatometer de La petite Chartreuse del año 2005.0'
# La petite chartreuse
#
# No tiene datos
# 'Tomatometer de On a Clear Day del año 2006.0'
# On a Clear Day
#
# 69
# 'Tomatometer de Oublier Cheyenne del año 2006.0'
# No tiene datos
# 'Tomatometer de Hustle & Flow del año 2005.0'
# Hustle & Flow
#
# 82
# 'Tomatometer de Flores rotas del año 2005.0'
# No tiene datos
# 'Tomatometer de The Mighty Celt del año 2005.0'
# The Mighty Celt
#
# 71
# 'Tomatometer de The Dark del año 2006.0'
# The Dark
#
# 40
# 'Tomatometer de Tideland del año 2006.0'
# Tideland
#
# 30
# 'Tomatometer de Yatna del año 2005.0'
# No tiene datos
# 'Tomatometer de Mi mejor enemigo del año 2005.0'
# Mi Mejor Enemigo
#
# No tiene datos
# 'Tomatometer de Tre giorni di anarchia del año 2006.0'
# No tiene datos
# 'Tomatometer de Slingshot del año 2005.0'
# No tiene datos
# 'Tomatometer de Todos los niños invisibles del año 2006.0'
# All the Invisible Children - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Black Days del año 2005.0'
# No tiene datos
# 'Tomatometer de Desayuno en Plutón del año 2006.0'
# Breakfast on Pluto
#
# No tiene datos
# 'Tomatometer de Being Cyrus del año 2006.0'
# Being Cyrus
#
# 76
# 'Tomatometer de Burt Munro. Un sueño, una leyenda del año 2006.0'
# The World's Fastest Indian
#
# No tiene datos
# 'Tomatometer de Como mariposas en la luz del año 2006.0'
# No tiene datos
# 'Tomatometer de L'annulaire del año 2005.0'
# No tiene datos
# 'Tomatometer de De latir mi corazón se ha parado del año 2005.0'
# The Beat That My Heart Skipped
#
# No tiene datos
# 'Tomatometer de El secreto de Anthony Zimmer del año 2005.0'
# Anthony Zimmer
#
# No tiene datos
# 'Tomatometer de WTC View del año 2005.0'
# No tiene datos
# 'Tomatometer de Secretos enterrados del año 2005.0'
# No tiene datos
# 'Tomatometer de Mrs. Henderson presenta del año 2005.0'
# Mrs. Henderson Presents
#
# No tiene datos
# 'Tomatometer de Durch diese Nacht sehe ich keinen einzigen Stern del año 2005.0'
# No tiene datos
# 'Tomatometer de Orlando Vargas del año 2005.0'
# No tiene datos
# 'Tomatometer de The War Within del año 2005.0'
# The War Within
#
# 71
# 'Tomatometer de What's Bugging Seth del año 2005.0'
# What's Bugging Seth
#
# No tiene datos
# 'Tomatometer de A porcelánbaba del año 2005.0'
# No tiene datos
# 'Tomatometer de Pride & Prejudice (Orgullo y prejuicio) del año 2005.0'
# Pride & Prejudice
#
# No tiene datos
# 'Tomatometer de Der grosse Schlaf del año 2005.0'
# No tiene datos
# 'Tomatometer de Souled Out del año 2005.0'
# Souled Out Comedy
#
# No tiene datos
# 'Tomatometer de Az igazi Mikulás del año 2005.0'
# No tiene datos
# 'Tomatometer de Sulanga Enu Pinisa del año 2006.0'
# The Forsaken Land
#
# No tiene datos
# 'Tomatometer de Greener Mountains del año 2005.0'
# No tiene datos
# 'Tomatometer de Heart of the Beholder del año 2005.0'
# Heart of the Beholder
#
# 83
# 'Tomatometer de Tú, yo y todos los demás del año 2006.0'
# Tú, yo y todos los demás (2005)
#
# No tiene datos
# 'Tomatometer de Beed-e majnoon del año 2005.0'
# No tiene datos
# 'Tomatometer de Believers Among Us del año 2005.0'
# No tiene datos
# 'Tomatometer de Puritan del año 2006.0'
# No tiene datos
# 'Tomatometer de Kinamand del año 2005.0'
# No tiene datos
# 'Tomatometer de Los ojos claros del año 2005.0'
# No tiene datos
# 'Tomatometer de 37 og et halvt del año 2005.0'
# No tiene datos
# 'Tomatometer de River's End del año 2005.0'
# River's End
#
# 63
# 'Tomatometer de Dus del año 2005.0'
# Dus
#
# 64
# 'Tomatometer de The Unseen del año 2005.0'
# The Unseen
#
# 40
# 'Tomatometer de Off Screen del año 2005.0'
# Off Screen
#
# 65
# 'Tomatometer de Vinterkyss del año 2005.0'
# No tiene datos
# 'Tomatometer de Wassup Rockers del año 2006.0'
# Wassup Rockers
#
# 37
# 'Tomatometer de Boy s tenyu del año 2005.0'
# No tiene datos
# 'Tomatometer de Para que no me olvides del año 2005.0'
# Para que no me olvides (2005)
#
# No tiene datos
# 'Tomatometer de Escape del año 2005.0'
# Escape
#
# No tiene datos
# 'Tomatometer de Amu del año 2005.0'
# Amu
#
# 82
# 'Tomatometer de Azucena del año 2005.0'
# No tiene datos
# 'Tomatometer de El silencio del año 2005.0'
# Silence Is a Falling Body (El silencio es un cuerpo que cae)
#
# No tiene datos
# 'Tomatometer de Marock del año 2006.0'
# No tiene datos
# 'Tomatometer de Man of God del año 2005.0'
# Man of God
#
# No tiene datos
# 'Tomatometer de Match Point del año 2006.0'
# Match Point
#
# 77
# 'Tomatometer de Lemming del año 2005.0'
# No tiene datos
# 'Tomatometer de American Gun del año 2007.0'
# American Gun
#
# 39
# 'Tomatometer de Hate Crime del año 2005.0'
# Hate Crime
#
# 6
# 'Tomatometer de Red Doors del año 2006.0'
# Red Doors
#
# 64
# 'Tomatometer de Crazylove del año 2006.0'
# Crazy Love - Movie Reviews
#
# No tiene datos
# 'Tomatometer de God Wears My Underwear del año 2010.0'
# No tiene datos
# 'Tomatometer de Dishdogz del año 2005.0'
# Dishdogz
#
# 52
# 'Tomatometer de Don't Tell del año 2005.0'
# Don't Tell
#
# 25
# 'Tomatometer de Room del año 2009.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Belhorizon del año 2006.0'
# No tiene datos
# 'Tomatometer de El tiempo que queda del año 2005.0'
# No tiene datos
# 'Tomatometer de Confession del año 2005.0'
# Confession
#
# 71
# 'Tomatometer de Kontakt del año 2005.0'
# No tiene datos
# 'Tomatometer de El fin de la inocencia del año 2006.0'
# El fin de la inocencia (2006)
#
# No tiene datos
# 'Tomatometer de 9 rota del año 2005.0'
# No tiene datos
# 'Tomatometer de Les mots bleus del año 2005.0'
# Les mots bleus (2005)
#
# No tiene datos
# 'Tomatometer de L'avion del año 2005.0'
# No tiene datos
# 'Tomatometer de Apostando al límite del año 2006.0'
# Two for the Money
#
# No tiene datos
# 'Tomatometer de Judíos en el espacio (o por que es diferente esta noche a las demás noches) del año 2006.0'
# Jews in Space (Judios en el espacio)
#
# No tiene datos
# 'Tomatometer de Hank Williams First Nation del año 2005.0'
# Hank Williams First Nation
#
# 40
# 'Tomatometer de Factótum del año 2006.0'
# Factotum
#
# No tiene datos
# 'Tomatometer de The Hangman del año 2010.0'
# http://www.rottentomatoes.com/search/full_search.p...
#
# No tiene datos
# 'Tomatometer de Little Athens del año 2005.0'
# Little Athens
#
# 40
# 'Tomatometer de Cruel But Necessary del año 2005.0'
# Cruel but Necessary
#
# No tiene datos
# 'Tomatometer de Quando sei nato non puoi più nasconderti del año 2005.0'
# Once You're Born You Can No Longer Hide
#
# No tiene datos
# 'Tomatometer de La promesa: la leyenda de los caballeros del viento del año 2006.0'
# La promesa: La leyenda de los Caballeros del Viento (2005)
#
# No tiene datos
# 'Tomatometer de Las manzanas de Adam del año 2007.0'
# No tiene datos
# 'Tomatometer de Manual de amor del año 2007.0'
# Manuale d'amore
#
# No tiene datos
# 'Tomatometer de Die Hitlerkantate del año 2006.0'
# No tiene datos
# 'Tomatometer de El libro mágico del año 2006.0'
# La gran aventura de los Lunnis y el libro mágico
#
# No tiene datos
# 'Tomatometer de Un año sin amor del año 2006.0'
# A Year Without Love
#
# No tiene datos
# 'Tomatometer de La maison de Nina del año 2005.0'
# La Maison de Nina
#
# No tiene datos
# 'Tomatometer de Lie with Me: El diario íntimo de Leila del año 2006.0'
# Lie with Me
#
# No tiene datos
# 'Tomatometer de Alta sociedad del año 2006.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2006.0'
# TV Shows | Movie Trailers | Reviews
#
# No tiene datos
# 'Tomatometer de Hijas de su madre: Las Buenrostro del año 2006.0'
# No tiene datos
# 'Tomatometer de Mi hermano Nikhil del año 2005.0'
# My Brother ... Nikhil
#
# No tiene datos
# 'Tomatometer de Unkenrufe del año 2005.0'
# No tiene datos
# 'Tomatometer de Steal Me del año 2005.0'
# Steal Me
#
# 44
# 'Tomatometer de Disparando a perros del año 2006.0'
# Disparando a perros - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Treasure n tha Hood del año 2005.0'
# Treasure N tha Hood
#
# No tiene datos
# 'Tomatometer de Adam Meets Eve del año 2005.0'
# National Lampoon's Adam & Eve
#
# No tiene datos
# 'Tomatometer de Volviéndose verde del año 2005.0'
# Volviéndose Verde - Apple TV (EC)
#
# No tiene datos
# 'Tomatometer de El espía durmiente del año 2005.0'
# No tiene datos
# 'Tomatometer de Revati del año 2005.0'
# No tiene datos
# 'Tomatometer de Portrait of Eve del año 2005.0'
# No tiene datos
# 'Tomatometer de El sueño del regreso del año 2005.0'
# El sueño del regreso
#
# No tiene datos
# 'Tomatometer de El aura del año 2005.0'
# The Aura
#
# No tiene datos
# 'Tomatometer de Ma quando arrivano le ragazze? del año 2005.0'
# Ma quando arrivano le ragazze?
#
# 65
# 'Tomatometer de Master i Margarita del año 2011.0'
# No tiene datos

# %%
#convertimos la lista a dataframe

# total_puntuacion_tomatoes # si da error ponemos esta abajo. **

df_dram_tomatoes = pd.DataFrame(primeracto_drama_tomatoes)

df_dram_tomatoes
# Out:
#                    0
# 0     No tiene datos
# 1     No tiene datos
# 2     No tiene datos
# 3                 76
# 4     No tiene datos
# ...              ...
# 1996  No tiene datos
# 1997  No tiene datos
# 1998  No tiene datos
# 1999              65
# 2000  No tiene datos
#
# [2001 rows x 1 columns]

# %%
#convertimos el dataframe a csv
df_dram_tomatoes.to_csv("drama_tomatoes_primeracto.csv")
