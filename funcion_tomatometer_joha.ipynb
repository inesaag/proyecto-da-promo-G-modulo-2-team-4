# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import numpy as np

import re
import random

# %%
df_action = pd.read_csv("action.csv", index_col = 0)
df_comedy = pd.read_csv("comedy.csv", index_col = 0)
df_drama = pd.read_csv("drama_no_duplicado.csv", index_col = 0)

# %%
df = pd.read_csv("tercer_acto_imbd_drama.csv", index_col = 0)

# %%
terceracto_drama_imdb= df.values.tolist()

# %%
terceracto_drama_api= df_drama.values.tolist()[16000:24000]

# %%
# 10001 - 16000
# 16001 -24001

# %%
len(terceracto_drama_imdb)
# Out:
# 8000

# %%
len(terceracto_drama_api)
# Out:
# 8000

# %%
terceracto_drama_imdb[7999]
# Out:
# ['No tiene datos',
#  'Malcolm Abbey',
#  'Daniel Steven Di, Vito',
#  'No tiene argumento',
#  '19',
#  'A Second Chance']

# %%
terceracto_drama_api[7999]
# Out:
# ['Short', 'A Second Chance', 2009.0, 4.0, 'tt1362306']

# %%
#NO USAR!! ES PARA CONPROBAR SI HEMOS HECHO BIEN LAS EXTRACCIONES

for i, pelicula in enumerate(lista_drama_api):
    for ind, peli in enumerate(primeras_drama_8000_imdb):
        
        if lista_drama_api[i][1] == primeras_drama_8000_imdb[i][5]:
            print("----",lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
        else:
            print(lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
        break

# %%
# Inicializar navegador
def datos_tomatoes (lista_imdb, lista_API):

    driver = webdriver.Chrome() 

    # URL Google para extraer la información solicitada. 

    url = "https://www.google.com/" 

    # Hacer una solicitud GET a la URL especificada.

    driver.get(url)  

    # Maximizar la ventana

    driver.maximize_window()
    


    sleep(5)

    # Aceptar cookies

    driver.find_element("css selector", "#L2AGLb > div").click()

    # Creamos lista vacía para introducir el resultado de las puntuaciones (tomatometer) de cada pelicula.

    #total_puntuacion_tomatoes = []

    # Iniciamos bucle for por cada pelicula de los csv que tenemos accediendo por su indice.

    for i, pelicula in enumerate(lista_imdb): 
        for peli in lista_API:
        

            sleep(random.randint(3,10))
            #creamos un string para pasarle a Google el nombre y el año de la pelicula extraidos de IMDB
            peticion = f"'Tomatometer de {lista_imdb[i][5]} del año {lista_API[i][2]}'"
            print(peticion)
            #incluimos el string en la barra de busqueda de Google
            driver.find_element("css selector","#APjFqb").send_keys(peticion, Keys.ENTER)  

            #puntuación (tomatometer)
            
            try:

                #creamos una variable con el nombre de la primera pelicula que aparece en Google
                nombre_peli_google = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text
                print(nombre_peli_google)
                print()

                #si el nombre es igual al nombre de la pelicula que pedimos la añadimos a la lista
                if nombre_peli_google == lista_imdb[i][5]:
                    
                    puntuacion = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                    total_puntuacion_tomatoes.append(puntuacion)
                    print(puntuacion)
                #si el nombre no coincide lo intentamos con la segunda opcion que aparece en google
                else:
                    try:
                        nombre_peli_google2 = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text

                        if nombre_peli_google2 == lista_imdb[i][5]:
                    
                            puntuacion = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                            total_puntuacion_tomatoes.append(puntuacion)
                            print(puntuacion)
                        else:
                            total_puntuacion_tomatoes.append("No tiene datos")
                            print("No tiene datos")
                    except:
                        total_puntuacion_tomatoes.append("No tiene datos")
                        print("No tiene datos")
            except: 

                total_puntuacion_tomatoes.append("No tiene datos")
                print("No tiene datos")
            
        
            # Salimos a la pag.principal del navegador
            
            driver.back()
            break

    return total_puntuacion_tomatoes    # Impresion lista total

# %%
total_puntuacion_tomatoes = []

# %%
#llamamos a la funcion
terceracto_drama_tomatoes = datos_tomatoes(terceracto_drama_imdb, terceracto_drama_api)
# Out:
# 'Tomatometer de Menace Commune del año 2018.0'
# No tiene datos
# 'Tomatometer de Kadogo del año 2018.0'
# No tiene datos
# 'Tomatometer de Neon Passion del año 2018.0'
# No tiene datos
# 'Tomatometer de Brotherly Love del año 2018.0'
# Brotherly Love
#
# 14
# 'Tomatometer de A Bloc del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Form 1 del año 2018.0'
# No tiene datos
# 'Tomatometer de Fragments del año 2018.0'
# Fragments
#
# No tiene datos
# 'Tomatometer de At the Crossroads Down Yonder del año 2018.0'
# No tiene datos
# 'Tomatometer de Selflove del año 2018.0'
# No tiene datos
# 'Tomatometer de The Day Dreams del año 2018.0'
# Daydream
#
# No tiene datos
# 'Tomatometer de Half the Battle del año 2018.0'
# Hacksaw Ridge
#
# No tiene datos
# 'Tomatometer de C/o Krishnanagar del año 2018.0'
# No tiene datos
# 'Tomatometer de Akif del año 2018.0'
# No tiene datos
# 'Tomatometer de Dream Expo del año 2018.0'
# No tiene datos
# 'Tomatometer de Past Due del año 2018.0'
# No tiene datos
# 'Tomatometer de Flamboyante del año 2018.0'
# The Shadow Dancer - Movie Reviews
#
# No tiene datos
# 'Tomatometer de 22 del año 2018.0'
# No tiene datos
# 'Tomatometer de Asphalt Saints del año 2018.0'
# No tiene datos
# 'Tomatometer de M Like Mobius del año 2018.0'
# No tiene datos
# 'Tomatometer de Endgame del año 2018.0'
# No tiene datos
# 'Tomatometer de The Cherry Orchard del año 2018.0'
# The Cherry Orchard
#
# 54
# 'Tomatometer de The Greener the Grass del año 2018.0'
# Greener Grass
#
# No tiene datos
# 'Tomatometer de B-167-980-098 del año 2018.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de Turn the Switch Off del año 2018.0'
# No tiene datos
# 'Tomatometer de Day Out del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Forget Me Not del año 2018.0'
# Forget Me Not
#
# 69
# 'Tomatometer de Open House del año 2018.0'
# The Open House
#
# No tiene datos
# 'Tomatometer de Perfekte vegger del año 2018.0'
# No tiene datos
# 'Tomatometer de The Guide del año 2018.0'
# Best Movies 2018: Wide Release
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de The Other Side del año 2018.0'
# The Otherside
#
# No tiene datos
# 'Tomatometer de Rupkothar Kahini del año 2018.0'
# No tiene datos
# 'Tomatometer de I Love When You Sing to Me del año 2018.0'
# Past Lives
#
# No tiene datos
# 'Tomatometer de Young Grandpa del año 2018.0'
# Dirty Grandpa
#
# No tiene datos
# 'Tomatometer de 100 Inscritos del año 2018.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Eddy del año 2018.0'
# No tiene datos
# 'Tomatometer de The Veil del año 2018.0'
# The Veil
#
# 21
# 'Tomatometer de A Story Told From The End del año 2018.0'
# No tiene datos
# 'Tomatometer de Clout del año 2018.0'
# Clutch
#
# No tiene datos
# 'Tomatometer de Runner del año 2018.0'
# Runner
#
# No tiene datos
# 'Tomatometer de Shed del año 2018.0'
# The Shed
#
# No tiene datos
# 'Tomatometer de Treasure del año 2018.0'
# Treasure
#
# No tiene datos
# 'Tomatometer de Father 'n' Son del año 2018.0'
# Father to Son
#
# No tiene datos
# 'Tomatometer de Beautiful World del año 2018.0'
# No tiene datos
# 'Tomatometer de Outfox del año 2018.0'
# No tiene datos
# 'Tomatometer de The Woman at the Other End of the Line del año 2018.0'
# The Other End of the Line
#
# No tiene datos
# 'Tomatometer de Cycle del año 2018.0'
# Cycle
#
# No tiene datos
# 'Tomatometer de The Accusation del año 2018.0'
# The Accusation
#
# 88
# 'Tomatometer de La última oportunidad del año 2018.0'
# No tiene datos
# 'Tomatometer de The Best Man del año 2018.0'
# The Best Man
#
# 33
# 'Tomatometer de The Drifting Post del año 2018.0'
# The Drifting Post
#
# No tiene datos
# 'Tomatometer de Worship Me del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Battue del año 2018.0'
# No tiene datos
# 'Tomatometer de Inertia del año 2018.0'
# Inertia
#
# No tiene datos
# 'Tomatometer de Bingo Night del año 2018.0'
# National Bingo Night Season 1
#
# No tiene datos
# 'Tomatometer de Confessional del año 2018.0'
# Confessional
#
# 60
# 'Tomatometer de Incoming Calls del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Sand. Rock. Palm. del año 2018.0'
# Jareth - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Barco de Papel del año 2018.0'
# No tiene datos
# 'Tomatometer de Assunta del año 2018.0'
# No tiene datos
# 'Tomatometer de Audition del año 2018.0'
# Audition
#
# 80
# 'Tomatometer de Picture Day del año 2018.0'
# 2018
#
# 80
# 'Tomatometer de Believe Her del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Land of Flat Dirt del año 2018.0'
# No tiene datos
# 'Tomatometer de Kindling del año 2018.0'
# Kindling
#
# 89
# 'Tomatometer de Blink del año 2018.0'
# Blink
#
# No tiene datos
# 'Tomatometer de Alone Together del año 2018.0'
# Alone Together
#
# 64
# 'Tomatometer de La cáscara del año 2018.0'
# No tiene datos
# 'Tomatometer de Odds & Ends del año 2018.0'
# Odds and Ends
#
# No tiene datos
# 'Tomatometer de Journey of Three Worlds del año 2018.0'
# Three Worlds
#
# No tiene datos
# 'Tomatometer de The Man Behind the Glass del año 2018.0'
# Lamborghini: The Man Behind the Legend
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de Man del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Searching del año 2018.0'
# Searching
#
# 92
# 'Tomatometer de Gatita del año 2018.0'
# The Amazing Catfish - Movie Reviews
#
# No tiene datos
# 'Tomatometer de L'intermediaire del año 2018.0'
# No tiene datos
# 'Tomatometer de They Live Outside del año 2018.0'
# They Live
#
# No tiene datos
# 'Tomatometer de À bout de ressources del año 2018.0'
# No tiene datos
# 'Tomatometer de It's Who You Know del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Affinity - The Series del año 2018.0'
# No tiene datos
# 'Tomatometer de Her Water Drum del año 2018.0'
# 100 Best Movies on Disney Plus (February 2024)
#
# No tiene datos
# 'Tomatometer de She's Not for Me del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Fever del año 2018.0'
# Fever
#
# 60
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de One More Meal del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Woodside del año 2018.0'
# No tiene datos
# 'Tomatometer de You del año 2018.0'
# You
#
# 91
# 'Tomatometer de From the Other Side del año 2018.0'
# From the Other Side
#
# 60
# 'Tomatometer de Les jours heureux del año 2018.0'
# Days of Happiness
#
# No tiene datos
# 'Tomatometer de A Tap At The Window del año 2018.0'
# No tiene datos
# 'Tomatometer de Red Velvet del año 2018.0'
# Red Velvet
#
# 50
# 'Tomatometer de When I've Wanted to Die del año 2018.0'
# Those Who Wish Me Dead
#
# No tiene datos
# 'Tomatometer de Madal pilvelõhkuja/The Low Skyscraper del año 2018.0'
# No tiene datos
# 'Tomatometer de Emily's Hands del año 2018.0'
# Sicario
#
# No tiene datos
# 'Tomatometer de BÓXERS del año 2018.0'
# No tiene datos
# 'Tomatometer de Anhedonia del año 2018.0'
# Anhedonia
#
# No tiene datos
# 'Tomatometer de I'm Sorry Mum'ma del año 2018.0'
# Rookie of the Year
#
# No tiene datos
# 'Tomatometer de Whisper del año 2018.0'
# Whisper
#
# No tiene datos
# 'Tomatometer de 4:13 del año 2018.0'
# No tiene datos
# 'Tomatometer de Out in the Woods del año 2018.0'
# Out of the Woods
#
# No tiene datos
# 'Tomatometer de Flow del año 2018.0'
# Flow
#
# 67
# 'Tomatometer de Desiree del año 2018.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Green Dust del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Ban Cùng Phòng del año 2018.0'
# No tiene datos
# 'Tomatometer de Última Noite em Viena del año 2018.0'
# El portero de noche - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de A Good Day del año 2018.0'
# A Good Day - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Triple Talaq del año 2018.0'
# No tiene datos
# 'Tomatometer de Miss Ella del año 2018.0'
# Las 25 películas de Netflix mejor valoradas por la crítica en ...
#
# No tiene datos
# 'Tomatometer de Skewed Conception del año 2018.0'
# No tiene datos
# 'Tomatometer de Remember del año 2018.0'
# Remember?
#
# No tiene datos
# 'Tomatometer de My Megan del año 2018.0'
# The Meg
#
# No tiene datos
# 'Tomatometer de Mary's Wise Men del año 2018.0'
# Exodus: Gods and Kings
#
# No tiene datos
# 'Tomatometer de Kat del año 2018.0'
# No tiene datos
# 'Tomatometer de 9 Am del año 2018.0'
# No tiene datos
# 'Tomatometer de Wake Up Girl del año 2018.0'
# No tiene datos
# 'Tomatometer de Billy's Restaurant del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de The Ghost of Hamlet's Father del año 2018.0'
# No tiene datos
# 'Tomatometer de Dream of Love del año 2018.0'
# No tiene datos
# 'Tomatometer de The Girl from Exarcheia del año 2018.0'
# Girl
#
# No tiene datos
# 'Tomatometer de Nous sommes nuit ils sont jour del año 2018.0'
# No tiene datos
# 'Tomatometer de Anxiety del año 2018.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Fifteen del año 2018.0'
# Fifteen-Love
#
# No tiene datos
# 'Tomatometer de Hoe Dan? del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Kolory Listopada del año 2018.0'
# No tiene datos
# 'Tomatometer de The Power of Inclusion del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de FORTY-EIGHT.ONE del año 2018.0'
# Hereditary
#
# No tiene datos
# 'Tomatometer de Dar Açi del año 2018.0'
# No tiene datos
# 'Tomatometer de Leave Me with a Smile del año 2018.0'
# No tiene datos
# 'Tomatometer de The Power of Inclusion del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Jane del año 2018.0'
# Jane
#
# 73
# 'Tomatometer de Endotermia del año 2018.0'
# No tiene datos
# 'Tomatometer de The Veil del año 2018.0'
# The Veil
#
# 21
# 'Tomatometer de Lembra del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Where is 'me'? del año 2018.0'
# No tiene datos
# 'Tomatometer de Dream of Blood and Soul del año 2018.0'
# Hereditary
#
# No tiene datos
# 'Tomatometer de Greece del año 2018.0'
# Netflix acaba con la esperanzas de Michelle Yeoh y ...
#
# No tiene datos
# 'Tomatometer de I Hope I'm Loud When I'm Dead del año 2018.0'
# I Hope I'm Loud When I'm Dead
#
# No tiene datos
# 'Tomatometer de Extension del año 2018.0'
# Extinction
#
# No tiene datos
# 'Tomatometer de Vassileia del año 2018.0'
# No tiene datos
# 'Tomatometer de Cada cuarenta segundos del año 2018.0'
# No tiene datos
# 'Tomatometer de Ljetne jagode/summer strawberries del año 2018.0'
# No tiene datos
# 'Tomatometer de Beau del año 2018.0'
# Beau Is Afraid
#
# No tiene datos
# 'Tomatometer de As a Woman del año 2018.0'
# No tiene datos
# 'Tomatometer de Show del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Guardami ora del año 2018.0'
# No tiene datos
# 'Tomatometer de Rattled del año 2018.0'
# Rattled
#
# No tiene datos
# 'Tomatometer de The Unknown Outlaw del año 2018.0'
# Extinction
#
# No tiene datos
# 'Tomatometer de 'Wag mo 'kong kausapin del año 2018.0'
# No tiene datos
# 'Tomatometer de La vie nous appartient del año 2018.0'
# No tiene datos
# 'Tomatometer de Baguio Address No. 10 del año 2018.0'
# No tiene datos
# 'Tomatometer de Mercury on Fifth del año 2018.0'
# No tiene datos
# 'Tomatometer de Ludo del año 2018.0'
# Ludo
#
# 80
# 'Tomatometer de Madugo ang gabi del año 2018.0'
# No tiene datos
# 'Tomatometer de My Escape del año 2018.0'
# The Escape
#
# No tiene datos
# 'Tomatometer de Tembong del año 2018.0'
# No tiene datos
# 'Tomatometer de Balai del año 2018.0'
# No tiene datos
# 'Tomatometer de Sa among agwat del año 2018.0'
# Fast & Furious Presents: Hobbs & Shaw
#
# No tiene datos
# 'Tomatometer de Gabi ng kababalaghan del año 2018.0'
# No tiene datos
# 'Tomatometer de Feed Me del año 2018.0'
# Feed Me
#
# 73
# 'Tomatometer de Heart and Soul del año 2018.0'
# Heart & Soul Season 1
#
# No tiene datos
# 'Tomatometer de Sadharan - a little thought del año 2018.0'
# No tiene datos
# 'Tomatometer de Closer to Heaven del año 2018.0'
# No tiene datos
# 'Tomatometer de Mar del año 2018.0'
# No tiene datos
# 'Tomatometer de Die Ongenooides del año 2018.0'
# Extinction
#
# No tiene datos
# 'Tomatometer de Lawrence and Bently del año 2018.0'
# 37 Worst Superhero Movies of All Time
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de Benjamin del año 2018.0'
# Benjamin
#
# 90
# 'Tomatometer de The White Camera del año 2018.0'
# White Chamber
#
# No tiene datos
# 'Tomatometer de Impact del año 2018.0'
# No tiene datos
# 'Tomatometer de Sophie del año 2018.0'
# Sofia
#
# No tiene datos
# 'Tomatometer de Click-Click del año 2018.0'
# Click
#
# No tiene datos
# 'Tomatometer de The Grave Digger of Kapu del año 2018.0'
# No tiene datos
# 'Tomatometer de The Edge With Us del año 2018.0'
# The Edge of Seventeen
#
# No tiene datos
# 'Tomatometer de The True History of Billie The Kid del año 2018.0'
# Billy the Kid
#
# No tiene datos
# 'Tomatometer de Feathers del año 2018.0'
# Feathers
#
# No tiene datos
# 'Tomatometer de Gustaakh del año 2018.0'
# No tiene datos
# 'Tomatometer de Cruising del año 2018.0'
# Cruising
#
# 51
# 'Tomatometer de Bamboe del año 2018.0'
# No tiene datos
# 'Tomatometer de Our Ladies of 121st Street del año 2018.0'
# No tiene datos
# 'Tomatometer de Aquarium del año 2018.0'
# Aquarium
#
# No tiene datos
# 'Tomatometer de Little Lights del año 2018.0'
# No tiene datos
# 'Tomatometer de Hourglass del año 2018.0'
# Hourglass
#
# 36
# 'Tomatometer de Spider del año 2018.0'
# Spider-Man: Into the Spider-Verse
#
# No tiene datos
# 'Tomatometer de Hot Milk del año 2018.0'
# Hot Milk
#
# No tiene datos
# 'Tomatometer de Without a Map del año 2018.0'
# L.A. Without a Map
#
# No tiene datos
# 'Tomatometer de Smoker del año 2018.0'
# Ocean's 8
#
# No tiene datos
# 'Tomatometer de 15.7 km del año 2018.0'
# No tiene datos
# 'Tomatometer de MR.SOAP del año 2018.0'
# Cadillac Records - Movie Reviews
#
# No tiene datos
# 'Tomatometer de 3rd and 4th Chapters del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Le Naufragé del año 2018.0'
# No tiene datos
# 'Tomatometer de Odgoj mladezi del año 2018.0'
# No tiene datos
# 'Tomatometer de Contre le Courant del año 2018.0'
# No tiene datos
# 'Tomatometer de Zoe del año 2018.0'
# Zoe
#
# 32
# 'Tomatometer de Magister del año 2018.0'
# Father of the Year
#
# No tiene datos
# 'Tomatometer de Colapso del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de What Separates Us from the Beasts del año 2018.0'
# No tiene datos
# 'Tomatometer de Tuda del año 2018.0'
# No tiene datos
# 'Tomatometer de Prototypical del año 2018.0'
# Level 16
#
# No tiene datos
# 'Tomatometer de The Wild Women del año 2018.0'
# Wild Women - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Part Time del año 2018.0'
# No tiene datos
# 'Tomatometer de Ensaio Sobre a Morte del año 2018.0'
# No tiene datos
# 'Tomatometer de A Luz dos Dias Compridos del año 2018.0'
# No tiene datos
# 'Tomatometer de $7.32 del año 2018.0'
# No tiene datos
# 'Tomatometer de Demolding a Daughter del año 2018.0'
# No tiene datos
# 'Tomatometer de O Mar Enrola na Areia del año 2018.0'
# No tiene datos
# 'Tomatometer de Subito del año 2018.0'
# Las 40 películas dirigidas por Clint Eastwood ordenadas ...
#
# No tiene datos
# 'Tomatometer de The Third Sorrow del año 2018.0'
# The Third Sorrow (Short 2018)
#
# No tiene datos
# 'Tomatometer de Rádio Coração del año 2018.0'
# Radio Corazón - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Black Girl, Magic del año 2018.0'
# No tiene datos
# 'Tomatometer de Personal Issues del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Inner City del año 2018.0'
# No tiene datos
# 'Tomatometer de Eat Up! del año 2018.0'
# Eat Up
#
# No tiene datos
# 'Tomatometer de mum & me. del año 2018.0'
# No tiene datos
# 'Tomatometer de All Call del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Nostalgia del año 2020.0'
# Of an Age
#
# No tiene datos
# 'Tomatometer de Delivery del año 2018.0'
# Rotten Tomatoes - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Ngiti ni Nazareno del año 2018.0'
# No tiene datos
# 'Tomatometer de Nagmamahal, Sal del año 2018.0'
# No tiene datos
# 'Tomatometer de Living Together del año 2018.0'
# Living Together
#
# No tiene datos
# 'Tomatometer de The Watcher del año 2018.0'
# The Watcher
#
# 54
# 'Tomatometer de Remember del año 2018.0'
# Remember?
#
# No tiene datos
# 'Tomatometer de Trebuchet del año 2018.0'
# No tiene datos
# 'Tomatometer de Terima Kasih del año 2018.0'
# No tiene datos
# 'Tomatometer de Cat Cafe in LA! With SuicideGirls del año 2018.0'
# Cat Cafe in LA! With SuicideGirls (Corto 2018)
#
# No tiene datos
# 'Tomatometer de Les choses du dimanche del año 2018.0'
# No tiene datos
# 'Tomatometer de Distraktion del año 2018.0'
# Those Who Wish Me Dead
#
# No tiene datos
# 'Tomatometer de Candle Magic del año 2018.0'
# No tiene datos
# 'Tomatometer de Oliver's Owl del año 2018.0'
# No tiene datos
# 'Tomatometer de Eunice del año 2018.0'
# Eunice
#
# 80
# 'Tomatometer de Addicted del año 2018.0'
# https://www.rottentomatoes.com/search/?search=ADDicted
#
# No tiene datos
# 'Tomatometer de The Program del año 2018.0'
# The Program
#
# 62
# 'Tomatometer de Message Received del año 2018.0'
# No tiene datos
# 'Tomatometer de Byvshie del año 2018.0'
# No tiene datos
# 'Tomatometer de Abbasc' del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Welcome Home del año 2018.0'
# Welcome Home
#
# 10
# 'Tomatometer de No estoy aquí del año 2018.0'
# I'm No Longer Here
#
# No tiene datos
# 'Tomatometer de Out of Frame/Hors Champ del año 2018.0'
# No tiene datos
# 'Tomatometer de Mindset del año 2018.0'
# No tiene datos
# 'Tomatometer de A Portrait of the Artist Angus Fairhurst del año 2018.0'
# No tiene datos
# 'Tomatometer de The Unnecessary Thing del año 2018.0'
# No tiene datos
# 'Tomatometer de Just One Bite del año 2018.0'
# Just One Bite
#
# No tiene datos
# 'Tomatometer de Agnès del año 2018.0'
# The Beaches of Agnès - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Le Mime del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de When the Music Stops del año 2018.0'
# The Best Movies of 2022: Every Certified Fresh Film ...
#
# No tiene datos
# 'Tomatometer de In the Process of Losing Faith del año 2018.0'
# The Best Movies of 2020, Ranked by Tomatometer
#
# No tiene datos
# 'Tomatometer de The Hunt del año 2018.0'
# The Hunt
#
# 57
# 'Tomatometer de The Unicorn del año 2018.0'
# The Unicorn
#
# 91
# 'Tomatometer de The bird fights its way out of the egg del año 2018.0'
# No tiene datos
# 'Tomatometer de A Dios del año 2018.0'
# No tiene datos
# 'Tomatometer de Cosmo del año 2018.0'
# Shōgun (serie de televisión de 2024)
#
# No tiene datos
# 'Tomatometer de Schneidewege del año 2018.0'
# No tiene datos
# 'Tomatometer de GGW-0045 del año 2018.0'
# No tiene datos
# 'Tomatometer de Le Flaneur del año 2018.0'
# No tiene datos
# 'Tomatometer de Permission del año 2018.0'
# Permission
#
# 67
# 'Tomatometer de Angst del año 2018.0'
# Angst
#
# No tiene datos
# 'Tomatometer de Selfie del año 2018.0'
# Selfie From Hell
#
# No tiene datos
# 'Tomatometer de Convergence del año 2018.0'
# Convergence
#
# 41
# 'Tomatometer de Rio Nova del año 2018.0'
# Uploaded premium link generator descargas ilimitadas mx ...
#
# No tiene datos
# 'Tomatometer de Temporary del año 2018.0'
# Temporary
#
# No tiene datos
# 'Tomatometer de Baby Doll del año 2018.0'
# Baby Doll
#
# No tiene datos
# 'Tomatometer de Emily's Story del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Quiet Denial del año 2018.0'
# A Quiet Place
#
# No tiene datos
# 'Tomatometer de Ratas Nocturnas del año 2018.0'
# No tiene datos
# 'Tomatometer de Poddya Bidya del año 2018.0'
# No tiene datos
# 'Tomatometer de Manja: Kite Thread del año 2018.0'
# No tiene datos
# 'Tomatometer de Look at the sky del año 2018.0'
# What Do We See When We Look at the Sky?
#
# No tiene datos
# 'Tomatometer de Dead Fish del año 2018.0'
# Dead Fish
#
# 38
# 'Tomatometer de Le mal de Mère del año 2018.0'
# No tiene datos
# 'Tomatometer de Grief del año 2018.0'
# No tiene datos
# 'Tomatometer de Two Young Men Thinking About Love del año 2018.0'
# Teen Titans GO! to the Movies
#
# No tiene datos
# 'Tomatometer de Rush to the Night del año 2018.0'
# No tiene datos
# 'Tomatometer de I'm Coming Isaline del año 2018.0'
# No tiene datos
# 'Tomatometer de Imminent del año 2018.0'
# Imminent Threat
#
# No tiene datos
# 'Tomatometer de Jaded. del año 2018.0'
# Teen Titans GO! to the Movies
#
# No tiene datos
# 'Tomatometer de Pablo del año 2018.0'
# Loving Pablo
#
# No tiene datos
# 'Tomatometer de The Way of Man del año 2018.0'
# Wrath of Man
#
# No tiene datos
# 'Tomatometer de Isabella del año 2018.0'
# No tiene datos
# 'Tomatometer de Burans del año 2018.0'
# No tiene datos
# 'Tomatometer de Blessed Is the Man del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Pachyderm del año 2018.0'
# No tiene datos
# 'Tomatometer de Tin del año 2018.0'
# Teen Titans GO! to the Movies
#
# No tiene datos
# 'Tomatometer de Huajiang Girls del año 2018.0'
# No tiene datos
# 'Tomatometer de I Belong del año 2018.0'
# Belong to Us
#
# No tiene datos
# 'Tomatometer de Slowly, But Surely del año 2018.0'
# Peppermint
#
# No tiene datos
# 'Tomatometer de Taboo del año 2018.0'
# Taboo
#
# 76
# 'Tomatometer de One Way Ticket del año 2018.0'
# One-Way Ticket
#
# No tiene datos
# 'Tomatometer de Off Target del año 2018.0'
# Target
#
# No tiene datos
# 'Tomatometer de Affogare del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Peanuts del año 2018.0'
# The Peanuts Movie
#
# No tiene datos
# 'Tomatometer de Mind Afloat del año 2018.0'
# The Last Voyage of the Demeter
#
# No tiene datos
# 'Tomatometer de Shakespeare in the Sphere: King Lear, Edmund del año 2018.0'
# Shakespeare in the Sphere: King Lear, Edmund
#
# No tiene datos
# 'Tomatometer de Not in Love del año 2018.0'
# I'm Not in Love
#
# No tiene datos
# 'Tomatometer de Amábile del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Nýr dagur í Eyjafirði del año 2018.0'
# No tiene datos
# 'Tomatometer de De mooiste week van m'n leven del año 2018.0'
# No tiene datos
# 'Tomatometer de KAPOW del año 2018.0'
# Kody Kapow Season 1
#
# No tiene datos
# 'Tomatometer de These Walls del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Can Spring Be Far Behind? del año 2018.0'
# No tiene datos
# 'Tomatometer de Therapy del año 2018.0'
# Therapy
#
# No tiene datos
# 'Tomatometer de Full Stop del año 2018.0'
# Past Lives
#
# No tiene datos
# 'Tomatometer de Meant To Be del año 2018.0'
# Meant to Be
#
# No tiene datos
# 'Tomatometer de Fool - Directors Cut del año 2018.0'
# Queenpins
#
# No tiene datos
# 'Tomatometer de Prom Time! del año 2018.0'
# Senior Year
#
# No tiene datos
# 'Tomatometer de God's Door del año 2018.0'
# mother!
#
# No tiene datos
# 'Tomatometer de Boundaries del año 2018.0'
# Boundaries
#
# 49
# 'Tomatometer de Eco de trompeta del año 2018.0'
# No tiene datos
# 'Tomatometer de Joy del año 2018.0'
# Joy
#
# 93
# 'Tomatometer de Fine del año 2018.0'
# No tiene datos
# 'Tomatometer de 1304 pasos del año 2018.0'
# No tiene datos
# 'Tomatometer de If It Ain't Got del año 2018.0'
# It Ain't Over
#
# No tiene datos
# 'Tomatometer de To the Ends of the Earth del año 2018.0'
# To the Ends of the Earth
#
# 93
# 'Tomatometer de Short del año 2018.0'
# No tiene datos
# 'Tomatometer de Wild Gyal del año 2018.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Desarraigo del año 2018.0'
# No tiene datos
# 'Tomatometer de Conceiving del año 2018.0'
# Never Rarely Sometimes Always
#
# No tiene datos
# 'Tomatometer de Mrs. Rozgonyi del año 2018.0'
# No tiene datos
# 'Tomatometer de Palos Verdes del año 2018.0'
# No tiene datos
# 'Tomatometer de Blood Money del año 2018.0'
# Blood Money Season 1
#
# 50
# 'Tomatometer de Palidhje del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Waiting for you del año 2018.0'
# Waiting for You
#
# No tiene datos
# 'Tomatometer de Cookie Jar del año 2018.0'
# The Cookie Jar
#
# No tiene datos
# 'Tomatometer de Fruit of May del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Behind Closed Doors del año 2018.0'
# Behind Closed Doors
#
# No tiene datos
# 'Tomatometer de Sátiro del año 2018.0'
# No tiene datos
# 'Tomatometer de When Saturn Returns del año 2018.0'
# Saturn Returns
#
# No tiene datos
# 'Tomatometer de Lost and Found del año 2018.0'
# Lost & Found
#
# No tiene datos
# 'Tomatometer de Somebody's knocking - bussano del año 2018.0'
# No tiene datos
# 'Tomatometer de The Quiet Revolution del año 2018.0'
# The Silent Revolution
#
# No tiene datos
# 'Tomatometer de Cherish del año 2018.0'
# Cherish
#
# 51
# 'Tomatometer de Eve's Dinner del año 2018.0'
# 140 Essential Action Movies To Watch Now
#
# No tiene datos
# 'Tomatometer de Alice del año 2018.0'
# Alice
#
# 90
# 'Tomatometer de Stockholm Syndrome del año 2018.0'
# Stockholm Syndrome
#
# No tiene datos
# 'Tomatometer de Along Came Blue del año 2018.0'
# Along Came Polly
#
# No tiene datos
# 'Tomatometer de Riscados pela Memória del año 2018.0'
# No tiene datos
# 'Tomatometer de Sparked del año 2018.0'
# 13 Going on 30
#
# No tiene datos
# 'Tomatometer de Desamparo del año 2018.0'
# No tiene datos
# 'Tomatometer de uBizo del año 2018.0'
# No tiene datos
# 'Tomatometer de El Rey del año 2018.0'
# El Rey
#
# No tiene datos
# 'Tomatometer de La Puntualidad del Sr. Martínez del año 2018.0'
# Aurora Martínez
#
# No tiene datos
# 'Tomatometer de Junior del año 2018.0'
# No tiene datos
# 'Tomatometer de By the Sea del año 2018.0'
# By the Sea
#
# 35
# 'Tomatometer de The Last Chance del año 2018.0'
# Insidious: The Last Key
#
# No tiene datos
# 'Tomatometer de Codename 3838 del año 2018.0'
# No tiene datos
# 'Tomatometer de Georgina Hedges - Because Of You del año 2018.0'
# No tiene datos
# 'Tomatometer de Wet del año 2018.0'
# No tiene datos
# 'Tomatometer de Supporting Role del año 2018.0'
# Best Supporting Role
#
# No tiene datos
# 'Tomatometer de A Hunger Artist del año 2018.0'
# The Hunger Artist - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Scapegoat del año 2018.0'
# The Scapegoat
#
# No tiene datos
# 'Tomatometer de The Apology del año 2018.0'
# The Apology
#
# 52
# 'Tomatometer de Breathe - Georgina Hedges del año 2018.0'
# No tiene datos
# 'Tomatometer de The Audacious Miracle of Christmas del año 2018.0'
# No tiene datos
# 'Tomatometer de Room Service del año 2018.0'
# Room Service
#
# No tiene datos
# 'Tomatometer de Adjournment del año 2018.0'
# No tiene datos
# 'Tomatometer de Erotica del año 2018.0'
# Fotos: Las 69 películas eróticas mejor valoradas en Rotten ...
#
# No tiene datos
# 'Tomatometer de Lily del año 2018.0'
# Silent Night
#
# No tiene datos
# 'Tomatometer de Half Blood del año 2018.0'
# Harry Potter and the Half-Blood Prince
#
# No tiene datos
# 'Tomatometer de Like Happy del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Hoermanns del año 2018.0'
# Citizen Kane
#
# No tiene datos
# 'Tomatometer de On my Way to the Cinema del año 2018.0'
# No tiene datos
# 'Tomatometer de The Sun is Going to Set del año 2018.0'
# Hunter Killer
#
# No tiene datos
# 'Tomatometer de Damaged del año 2018.0'
# Damaged
#
# No tiene datos
# 'Tomatometer de Polaroid del año 2018.0'
# Polaroid
#
# No tiene datos
# 'Tomatometer de Tragedy in Ten Scenes del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Plum Raindrops del año 2018.0'
# No tiene datos
# 'Tomatometer de Isstuplenie del año 2018.0'
# No tiene datos
# 'Tomatometer de Hidden del año 2018.0'
# Hidden Figures
#
# No tiene datos
# 'Tomatometer de Kakuri del año 2018.0'
# No tiene datos
# 'Tomatometer de Rising Sun del año 2019.0'
# Rising Sun
#
# 33
# 'Tomatometer de Lichao del año 2018.0'
# No tiene datos
# 'Tomatometer de Hollowed del año 2018.0'
# No tiene datos
# 'Tomatometer de Silent Ruin del año 2018.0'
# The 100 Best 2000s Horror Movies
#
# No tiene datos
# 'Tomatometer de Ding zi hua del año 2018.0'
# No tiene datos
# 'Tomatometer de It's Snowing There del año 2018.0'
# Peppermint
#
# No tiene datos
# 'Tomatometer de Finder del año 2018.0'
# No tiene datos
# 'Tomatometer de Tail End of the Year del año 2018.0'
# Tail End of the Year (C) (2018)
#
# No tiene datos
# 'Tomatometer de The Character Project del año 2018.0'
# No tiene datos
# 'Tomatometer de The Tour del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Guilty of Love del año 2018.0'
# Hunter Killer
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2018.0'
# No tiene datos
# 'Tomatometer de Mookuthi del año 2018.0'
# No tiene datos
# 'Tomatometer de Days Before We Left del año 2018.0'
# No tiene datos
# 'Tomatometer de Jeu de fille del año 2018.0'
# No tiene datos
# 'Tomatometer de Incident in the Gulf del año 2018.0'
# Ghostland
#
# No tiene datos
# 'Tomatometer de Saving Da'Lenzi del año 2018.0'
# No tiene datos
# 'Tomatometer de Staying True del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Inside the Piano Shop del año 2018.0'
# No tiene datos
# 'Tomatometer de Los fuegos artificiales del año 2018.0'
# No tiene datos
# 'Tomatometer de Fall del año 2018.0'
# Fall
#
# 79
# 'Tomatometer de Eden Hotel del año 2018.0'
# No tiene datos
# 'Tomatometer de Ryker del año 2018.0'
# Sergeant Ryker
#
# No tiene datos
# 'Tomatometer de Can We Talk del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Milk del año 2018.0'
# Milk
#
# 93
# 'Tomatometer de Romy del año 2018.0'
# Romy
#
# No tiene datos
# 'Tomatometer de Two Blinks del año 2018.0'
# Alicornio para colorear cultura - inlalude.top
#
# No tiene datos
# 'Tomatometer de Tulipanes de Papel del año 2018.0'
# No tiene datos
# 'Tomatometer de Reminiscent del año 2018.0'
# Reminiscence
#
# No tiene datos
# 'Tomatometer de Como un lastre del año 2018.0'
# No tiene datos
# 'Tomatometer de Samakalikam del año 2018.0'
# No tiene datos
# 'Tomatometer de Broken del año 2018.0'
# Broken
#
# 73
# 'Tomatometer de One block too far del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Voicemail del año 2018.0'
# Voicemail
#
# No tiene datos
# 'Tomatometer de Boys Will Be Boys: An Elaborate Excuse for a Fight Scene del año 2018.0'
# Boys Will Be Boys
#
# No tiene datos
# 'Tomatometer de The Perfect Exterior del año 2018.0'
# No tiene datos
# 'Tomatometer de The Art of Parenting del año 2018.0'
# Gia - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Golden Rose del año 2018.0'
# No tiene datos
# 'Tomatometer de Intertwined del año 2018.0'
# No tiene datos
# 'Tomatometer de Turn on Your Own del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de In the Palace del año 2019.0'
# The Palace
#
# No tiene datos
# 'Tomatometer de Knock Twice del año 2018.0'
# Don't Knock Twice
#
# No tiene datos
# 'Tomatometer de Blood, Sweat & Cabernet del año 2018.0'
# Blood, Sweat and Terrors
#
# No tiene datos
# 'Tomatometer de Confront your destiny del año 2018.0'
# Past Lives
#
# No tiene datos
# 'Tomatometer de Unintended del año 2018.0'
# No tiene datos
# 'Tomatometer de Go Left, Go Right del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Three Stages of Consciousness del año 2018.0'
# Peppermint
#
# No tiene datos
# 'Tomatometer de Horse on Wheels del año 2018.0'
# Critics Pick the Best TV Shows of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Siempre el amor del año 2018.0'
# No tiene datos
# 'Tomatometer de The Ville del año 2018.0'
# The Angel
#
# No tiene datos
# 'Tomatometer de White Elephant del año 2018.0'
# White Elephant
#
# 13
# 'Tomatometer de Report Card del año 2018.0'
# No tiene datos
# 'Tomatometer de Letting Her Go del año 2018.0'
# The Edge of Seventeen
#
# No tiene datos
# 'Tomatometer de The Empty Ring del año 2018.0'
# No tiene datos
# 'Tomatometer de Abhilasha del año 2018.0'
# No tiene datos
# 'Tomatometer de Cold Coffee del año 2018.0'
# No tiene datos
# 'Tomatometer de Bond del año 2018.0'
# No tiene datos
# 'Tomatometer de Absalon del año 2018.0'
# No tiene datos
# 'Tomatometer de Pregnancy del año 2018.0'
# 65
#
# No tiene datos
# 'Tomatometer de Echoes of War del año 2018.0'
# No tiene datos
# 'Tomatometer de Ayah del año 2018.0'
# Ocean's 8
#
# No tiene datos
# 'Tomatometer de I'll Be Fine del año 2018.0'
# I Give It a Year
#
# No tiene datos
# 'Tomatometer de Will rather than heart del año 2018.0'
# No tiene datos
# 'Tomatometer de Valencia del año 2018.0'
# Rotten Tomatoes - Wikipedia, la enciclopedia libre
#
# No tiene datos
# 'Tomatometer de Date Night del año 2018.0'
# Date Night
#
# 67
# 'Tomatometer de Different del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de The Job Interview del año 2018.0'
# Job Interview
#
# No tiene datos
# 'Tomatometer de Wight Christmas del año 2018.0'
# No tiene datos
# 'Tomatometer de Nothing personal del año 2018.0'
# David Spade: Nothing Personal
#
# No tiene datos
# 'Tomatometer de Dominic del año 2018.0'
# Best Horror Movies of 2018 by Tomatometer
#
# No tiene datos
# 'Tomatometer de Somebody's knocking del año 2018.0'
# No tiene datos
# 'Tomatometer de Rock. Paper. Scissors. del año 2018.0'
# Rock, Paper, Scissors
#
# No tiene datos
# 'Tomatometer de Locus Amoenus del año 2018.0'
# No tiene datos
# 'Tomatometer de Proches del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Dostluk Ekspresi/Friendship Express del año 2018.0'
# No tiene datos
# 'Tomatometer de Saturno del año 2018.0'
# No tiene datos
# 'Tomatometer de Azure del año 2018.0'
# No tiene datos
# 'Tomatometer de Julia del año 2018.0'
# Julia
#
# 96
# 'Tomatometer de The Shadows Between Us del año 2018.0'
# No tiene datos
# 'Tomatometer de 3 Días del año 2018.0'
# No tiene datos
# 'Tomatometer de Nameless del año 2018.0'
# The Nameless - Movie Reviews
#
# No tiene datos
# 'Tomatometer de System Failure del año 2018.0'
# No tiene datos
# 'Tomatometer de El Secreto de Ana del año 2018.0'
# No tiene datos
# 'Tomatometer de 1986 del año 2018.0'
# No tiene datos
# 'Tomatometer de Preference del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Before my mom becomes 60 del año 2018.0'
# No tiene datos
# 'Tomatometer de Under the Stars del año 2018.0'
# Under the Stars
#
# No tiene datos
# 'Tomatometer de Touch of Darkness del año 2018.0'
# The Best Movies of 2022: Every Certified Fresh Film ...
#
# No tiene datos
# 'Tomatometer de The Drawing Man del año 2018.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Paraíso 63 del año 2018.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Tumultueuses del año 2018.0'
# No tiene datos
# 'Tomatometer de Make Do or Mend del año 2018.0'
# 25 Best Horror Movies of Each Year Since 1998
#
# No tiene datos
# 'Tomatometer de Job Season del año 2018.0'
# No tiene datos
# 'Tomatometer de That's Life X del año 2018.0'
# That's Life!
#
# No tiene datos
# 'Tomatometer de Her Hair del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Chirp del año 2018.0'
# No tiene datos
# 'Tomatometer de Together We Are Lonely del año 2018.0'
# Past Lives
#
# No tiene datos
# 'Tomatometer de Is/Isn't Was/Wasn't del año 2018.0'
# The Edge of Seventeen
#
# No tiene datos
# 'Tomatometer de I am the happiest del año 2018.0'
# No tiene datos
# 'Tomatometer de Timing del año 2018.0'
# Peppermint
#
# No tiene datos
# 'Tomatometer de Real Tour del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de The Dark Wood del año 2018.0'
# No tiene datos
# 'Tomatometer de XXY? del año 2018.0'
# XXY - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Recover del año 2018.0'
# No tiene datos
# 'Tomatometer de Russian six del año 2018.0'
# No tiene datos
# 'Tomatometer de Descenso del año 2018.0'
# Las 30 mejores películas de terror de 2023 para pasar miedo
#
# No tiene datos
# 'Tomatometer de Drapeau Blanc del año 2018.0'
# No tiene datos
# 'Tomatometer de Mercy del año 2018.0'
# The Mercy
#
# No tiene datos
# 'Tomatometer de Tempo de Ir, Tempo de Voltar del año 2018.0'
# No tiene datos
# 'Tomatometer de The Used del año 2018.0'
# Somebody I Used To Know
#
# No tiene datos
# 'Tomatometer de The Woman with Ivory Gloves del año 2018.0'
# No tiene datos
# 'Tomatometer de Deep Water del año 2018.0'
# Deep Water
#
# 35
# 'Tomatometer de La piedra en el río del año 2018.0'
# No tiene datos
# 'Tomatometer de Narkomany del año 2018.0'
# No tiene datos
# 'Tomatometer de Parabolic del año 2018.0'
# No tiene datos
# 'Tomatometer de Free del año 2018.0'
# No tiene datos
# 'Tomatometer de Nightingale del año 2018.0'
# The Nightingale
#
# No tiene datos
# 'Tomatometer de Lintu del año 2018.0'
# No tiene datos
# 'Tomatometer de Lil Bro del año 2018.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Go Fetch del año 2018.0'
# No tiene datos
# 'Tomatometer de Thank You for Your Time del año 2018.0'
# Thank You for Your Service
#
# No tiene datos
# 'Tomatometer de My Name Is Stutter del año 2018.0'
# My Name Is Stutter (Short 2018)
#
# No tiene datos
# 'Tomatometer de The Meeting del año 2018.0'
# The Meeting
#
# No tiene datos
# 'Tomatometer de Deal Done del año 2018.0'
# 2018
#
# No tiene datos
# 'Tomatometer de Creation del año 2019.0'
# No tiene datos
# 'Tomatometer de Solatium del año 2018.0'
# No tiene datos
# 'Tomatometer de Clipped del año 2018.0'
# Past Lives
#
# No tiene datos
# 'Tomatometer de Cortando Sangre del año 2018.0'
# No tiene datos
# 'Tomatometer de SILO del año 2018.0'
# Silo
#
# No tiene datos
# 'Tomatometer de Ombligo de Agua del año 2018.0'
# No tiene datos
# 'Tomatometer de Conditions Épicées del año 2018.0'
# No tiene datos
# 'Tomatometer de Kissing Carmen del año 2019.0'
# Kissing Carmen
#
# No tiene datos
# 'Tomatometer de DNA del año 2019.0'
# DNA
#
# 88
# 'Tomatometer de Where Were You del año 2019.0'
# No tiene datos
# 'Tomatometer de Okay del año 2019.0'
# No tiene datos
# 'Tomatometer de Hanna Wins del año 2019.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Cafèsigaret del año 2019.0'
# No tiene datos
# 'Tomatometer de Witness to Murder del año 2019.0'
# Witness to Murder: A Darrow Mystery
#
# 54
# 'Tomatometer de Good Friends del año 2019.0'
# No tiene datos
# 'Tomatometer de Voiceless del año 2019.0'
# Voiceless
#
# 46
# 'Tomatometer de Ludere del año 2019.0'
# No tiene datos
# 'Tomatometer de Melodrama del año 2019.0'
# The Farewell
#
# No tiene datos
# 'Tomatometer de The Coven del año 2019.0'
# The Coven
#
# 11
# 'Tomatometer de Candle Light del año 2019.0'
# Candlelight Revolution
#
# No tiene datos
# 'Tomatometer de Erewhile del año 2019.0'
# The Farewell
#
# No tiene datos
# 'Tomatometer de Atonement del año 2019.0'
# Atonement
#
# 83
# 'Tomatometer de Facing Life del año 2019.0'
# Facing Life
#
# No tiene datos
# 'Tomatometer de For Ellis del año 2019.0'
# No tiene datos
# 'Tomatometer de The Veil Removed del año 2019.0'
# The Veil
#
# No tiene datos
# 'Tomatometer de Riviera del año 2019.0'
# Riviera
#
# No tiene datos
# 'Tomatometer de Destiny del año 2019.0'
# Past Lives
#
# 80
# 'Tomatometer de Along The Line del año 2019.0'
# On the Line
#
# No tiene datos
# 'Tomatometer de Chadwick Manor del año 2019.0'
# The Best Movies of 2020, Ranked by Tomatometer
#
# No tiene datos
# 'Tomatometer de Controlling Intentions del año 2019.0'
# No tiene datos
# 'Tomatometer de The Chair del año 2019.0'
# The Chair
#
# 86
# 'Tomatometer de FantasyLand del año 2019.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2019.0'
# No tiene datos
# 'Tomatometer de Shakira del año 2019.0'
# Shakira
#
# No tiene datos
# 'Tomatometer de Confession del año 2019.0'
# Confession
#
# 30
# 'Tomatometer de Motel del año 2019.0'
# No tiene datos
# 'Tomatometer de Tender del año 2019.0'
# Rotten Tomatoes
#
# No tiene datos
# 'Tomatometer de Partir de Cero del año 2019.0'
# No tiene datos
# 'Tomatometer de Cheyenne del año 2019.0'
# Cheyenne
#
# 17
# 'Tomatometer de Greta's Bed & Breakfast del año 2019.0'
# No tiene datos
# 'Tomatometer de Stay For The Weak del año 2019.0'
# No tiene datos
# 'Tomatometer de Anxiety del año 2019.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de The Theology of Friendship del año 2019.0'
# Charlie's Angels
#
# No tiene datos
# 'Tomatometer de Memoria del año 2019.0'
# Memoria
#
# 90
# 'Tomatometer de It Could Be Worse del año 2019.0'
# The Worst Person in the World
#
# No tiene datos
# 'Tomatometer de Bellingham del año 2019.0'
# Bellingham
#
# No tiene datos
# 'Tomatometer de NRI Story del año 2019.0'
# Marriage Story
#
# No tiene datos
# 'Tomatometer de Chlorine del año 2019.0'
# Chlorine
#
# 8
# 'Tomatometer de Freaky Forest del año 2019.0'
# No tiene datos
# 'Tomatometer de Winger del año 2019.0'
# No tiene datos
# 'Tomatometer de Viola del año 2019.0'
# Rotten Tomatoes
#
# No tiene datos
# 'Tomatometer de Andros del año 2019.0'
# Trailers & Videos
#
# No tiene datos
# 'Tomatometer de Delicious Poison del año 2019.0'
# No tiene datos
# 'Tomatometer de Leaves del año 2019.0'
# No tiene datos
# 'Tomatometer de He's Mine del año 2019.0'
# He's Mine Not Yours
#
# No tiene datos
# 'Tomatometer de Afganistanii del año 2019.0'
# No tiene datos
# 'Tomatometer de Something del año 2019.0'
# Something
#
# 50
# 'Tomatometer de St. Louis Superman del año 2019.0'
# No tiene datos
# 'Tomatometer de Passage del año 2019.0'
# The Passage
#
# No tiene datos
# 'Tomatometer de The Silver Lining del año 2019.0'
# Silver Linings Playbook
#
# No tiene datos
# 'Tomatometer de Stormy del año 2019.0'
# Stormy
#
# No tiene datos
# 'Tomatometer de Agente Secret del año 2019.0'
# The Secret Agent
#
# No tiene datos
# 'Tomatometer de iParent del año 2019.0'
# No tiene datos
# 'Tomatometer de Lilac del año 2019.0'
# No tiene datos
# 'Tomatometer de Chimes of Love and Death del año 2019.0'
# Love & Death: Limited Series
#
# No tiene datos
# 'Tomatometer de Uncertainship del año 2019.0'
# Uncertain
#
# No tiene datos
# 'Tomatometer de It Happened One Night del año 2019.0'
# It Happened One Night
#
# 98
# 'Tomatometer de Parabola del año 2019.0'
# Parabola
#
# No tiene datos
# 'Tomatometer de 42 del año 2020.0'
# No tiene datos
# 'Tomatometer de Rewind del año 2019.0'
# Rewind
#
# 100
# 'Tomatometer de It's a Small World del año 2019.0'
# No tiene datos
# 'Tomatometer de Heaven del año 2019.0'
# Heaven
#
# 23
# 'Tomatometer de Hanging on a Telephone del año 2019.0'
# Another Round
#
# No tiene datos
# 'Tomatometer de Piercing Stillness del año 2019.0'
# No tiene datos
# 'Tomatometer de Bluefish del año 2019.0'
# No tiene datos
# 'Tomatometer de Don Héctor del año 2019.0'
# Don't Worry Darling
#
# No tiene datos
# 'Tomatometer de La Hora Cero del año 2019.0'
# Old
#
# No tiene datos
# 'Tomatometer de Down the Barrel del año 2019.0'
# Down the Barrel
#
# No tiene datos
# 'Tomatometer de Inhuman del año 2019.0'
# Marvel's Inhumans
#
# No tiene datos
# 'Tomatometer de Pick del año 2019.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Cirque del año 2019.0'
# No tiene datos
# 'Tomatometer de Dear Deer del año 2019.0'
# No tiene datos
# 'Tomatometer de Fragmenter del año 2019.0'
# No tiene datos
# 'Tomatometer de Tesfa del año 2019.0'
# No tiene datos
# 'Tomatometer de Nina del año 2019.0'
# Senior Year
#
# No tiene datos
# 'Tomatometer de Saturday Grace del año 2019.0'
# No tiene datos
# 'Tomatometer de The Present del año 2019.0'
# The Present
#
# No tiene datos
# 'Tomatometer de You Should Be on My Side del año 2019.0'
# No tiene datos
# 'Tomatometer de Waterfrost del año 2019.0'
# Waterfront - Movie Reviews
#
# No tiene datos
# 'Tomatometer de I Stem the Tide del año 2019.0'
# No tiene datos
# 'Tomatometer de You're Just a Kid del año 2019.0'
# No tiene datos
# 'Tomatometer de Like Crazy del año 2019.0'
# Like Crazy
#
# 71
# 'Tomatometer de What Momma Wants del año 2019.0'
# No tiene datos
# 'Tomatometer de Coffee with a Madman del año 2019.0'
# Coffee with a Madman
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2019.0'
# No tiene datos
# 'Tomatometer de Help Me Help You del año 2019.0'
# Help Me Help You Season 1
#
# No tiene datos
# 'Tomatometer de The Strangers We Know del año 2019.0'
# No tiene datos
# 'Tomatometer de Haze del año 2019.0'
# The Dry
#
# No tiene datos
# 'Tomatometer de Brothers del año 2019.0'
# Brothers
#
# 64
# 'Tomatometer de Man Made del año 2019.0'
# Man Made
#
# 100
# 'Tomatometer de Power Out del año 2019.0'
# No tiene datos
# 'Tomatometer de The Darkness del año 2019.0'
# Darkness
#
# 3
# 'Tomatometer de The Circle del año 2019.0'
# The Circle
#
# 16
# 'Tomatometer de This Is Bigger Than Us del año 2019.0'
# Bigger Than Us
#
# No tiene datos
# 'Tomatometer de Osiris III del año 2019.0'
# Hellboy
#
# No tiene datos
# 'Tomatometer de I Have to Fake It del año 2019.0'
# The Farewell
#
# No tiene datos
# 'Tomatometer de Trust Me del año 2019.0'
# Trust Me
#
# 79
# 'Tomatometer de 31st of Decembers del año 2019.0'
# 65
#
# No tiene datos
# 'Tomatometer de Deluge del año 2019.0'
# The Farewell
#
# No tiene datos
# 'Tomatometer de Being Marilyn del año 2019.0'
# Marilyn - Movie Reviews
#
# No tiene datos
# 'Tomatometer de You Need to Get It Together del año 2019.0'
# No tiene datos
# 'Tomatometer de Just Answer One Question del año 2019.0'
# No tiene datos
# 'Tomatometer de The Choice Is Yours del año 2019.0'
# The Choice Is Yours
#
# 91
# 'Tomatometer de From This Day Forward del año 2019.0'
# The Farewell
#
# No tiene datos
# 'Tomatometer de A Labour of Loaf del año 2019.0'
# No tiene datos
# 'Tomatometer de Masterpiece del año 2019.0'
# Movie Reviews - My Masterpiece
#
# No tiene datos
# 'Tomatometer de Witch Trilogy 13+ del año 2019.0'
# No tiene datos
# 'Tomatometer de The Girl In The Cellar del año 2019.0'
# Girl in the Basement
#
# No tiene datos
# 'Tomatometer de I'd Die for This Family del año 2019.0'
# No Time to Die
#
# No tiene datos
# 'Tomatometer de Morning Rain del año 2019.0'
# Never Rarely Sometimes Always
#
# No tiene datos
# 'Tomatometer de Enough Is Enough del año 2019.0'
# Enough
#
# No tiene datos
# 'Tomatometer de The Writer del año 2019.0'
# The Writer
#
# No tiene datos
# 'Tomatometer de It's Stranger Than We Thought del año 2019.0'
# No tiene datos
# 'Tomatometer de Noc v Mariandu del año 2019.0'
# No tiene datos
# 'Tomatometer de Fragile Ghost del año 2019.0'
# Fragile
#
# No tiene datos
# 'Tomatometer de S'échapper vers la Vie del año 2019.0'
# No tiene datos
# 'Tomatometer de Kunst und die Freiheit del año 2019.0'
# No tiene datos
# 'Tomatometer de Uber Oracle del año 2019.0'
# 300
#
# No tiene datos
# 'Tomatometer de Boardwalk del año 2019.0'
# Boardwalk Empire
#
# No tiene datos
# 'Tomatometer de Gifts of the Heart del año 2019.0'
# The Gift
#
# No tiene datos
# 'Tomatometer de Nightmare del año 2019.0'
# Nightmare
#
# 50
# 'Tomatometer de My Home of Thorns del año 2019.0'
# No tiene datos
# 'Tomatometer de Little Bird del año 2019.0'
# Little Bird
#
# 100
# 'Tomatometer de The Turnaround del año 2019.0'
# The Turnaround
#
# No tiene datos
# 'Tomatometer de As Simple As Hello del año 2019.0'
# No tiene datos
# 'Tomatometer de Gaia del año 2019.0'
# Gaia
#
# 84
# 'Tomatometer de Sleep - A Monologue del año 2019.0'
# Doctor Sleep
#
# No tiene datos
# 'Tomatometer de Tóxico del año 2019.0'
# Tóxico
#
# No tiene datos
# 'Tomatometer de Kaveri del año 2019.0'
# No tiene datos
# 'Tomatometer de Following Jamie del año 2019.0'
# No tiene datos
# 'Tomatometer de We'll Go North del año 2019.0'
# Peppermint
#
# No tiene datos
# 'Tomatometer de My Father Belize del año 2019.0'
# My Father Belize
#
# No tiene datos
# 'Tomatometer de Las Alturas del año 2019.0'
# Light of My Life
#
# No tiene datos
# 'Tomatometer de The Rolex del año 2019.0'
# Página Web Oficial de Rolex - Relojes de Lujo Suizos
#
# No tiene datos
# 'Tomatometer de Priest or Painter del año 2019.0'
# No tiene datos
# 'Tomatometer de The Minstrel and the Bard del año 2019.0'
# No tiene datos
# 'Tomatometer de The Camera Loves Kaila del año 2019.0'
# No tiene datos
# 'Tomatometer de Daddy's Girl del año 2019.0'
# Daddy's Girl
#
# 60
# 'Tomatometer de Confessione del año 2019.0'
# No tiene datos
# 'Tomatometer de Desiccation del año 2019.0'
# No tiene datos
# 'Tomatometer de Flying with the Birds del año 2019.0'
# No tiene datos
# 'Tomatometer de Tamarind del año 2019.0'
# No tiene datos
# 'Tomatometer de Caps del año 2019.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2019.0'
# No tiene datos
# 'Tomatometer de Lost Canyon del año 2019.0'
# Lost Canyon
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2019.0'
# No tiene datos
# 'Tomatometer de Parallel Path Trailer del año 2019.0'
# Parallel Path
#
# No tiene datos
# 'Tomatometer de Martha del año 2019.0'
# The Best Movies of 2020, Ranked by Tomatometer
#
# No tiene datos
# 'Tomatometer de Starving (MIFF) del año 2019.0'
# No tiene datos
# 'Tomatometer de Kunststücke del año 2019.0'
# No tiene datos
# 'Tomatometer de The Receipt del año 2019.0'
# The Receipt - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Kurdish Bbq del año 2019.0'
# No tiene datos
# 'Tomatometer de Shadow Animals del año 2019.0'
# No tiene datos
# 'Tomatometer de Tap Tap Tap del año 2019.0'
# Everything Everywhere All at Once
#
# No tiene datos
# 'Tomatometer de Cipher del año 2019.0'
# No tiene datos
# 'Tomatometer de The Red Coat del año 2019.0'
# No tiene datos
# 'Tomatometer de Time has Changed del año 2019.0'
# No tiene datos
# 'Tomatometer de La vicina del año 2019.0'
# No tiene datos
# 'Tomatometer de Mortis del año 2019.0'
# No tiene datos
# 'Tomatometer de The Burial Consequence del año 2019.0'
# The Burial
#
# No tiene datos
# 'Tomatometer de Come What May del año 2019.0'
# Come What May
#
# 41
# 'Tomatometer de Loveless del año 2019.0'
# Loveless
#
# 95
# 'Tomatometer de Le lait magique del año 2019.0'
# No tiene datos
# 'Tomatometer de Plutus del año 2019.0'
# No tiene datos
# 'Tomatometer de X27 del año 2019.0'
# 2024 The ark rotten tomatoes definitive Rotten - hurtyi.wiki
#
# No tiene datos
# 'Tomatometer de Marinai di foresta del año 2019.0'
# No tiene datos
# 'Tomatometer de Koncert del año 2019.0'
# No tiene datos
# 'Tomatometer de Desperate del año 2019.0'
# The Desperate Hour
#
# No tiene datos
# 'Tomatometer de 7 Minutes del año 2019.0'
# 7 Minutes
#
# 24
# 'Tomatometer de Safarikova 19 del año 2019.0'
# No tiene datos
# 'Tomatometer de Fallen Dream del año 2019.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Eye of the Beholder del año 2019.0'
# Eye of the Beholder: The Art of Dungeons and Dragons
#
# 9
# 'Tomatometer de Mouths to Feed del año 2019.0'
# 2024 Video de alejandra ico chu agonizando en y
#
# ...
#
# No tiene datos
# 'Tomatometer de Blame Falls del año 2006.0'
# Blame
#
# No tiene datos
# 'Tomatometer de I'm a Big Brother del año 2006.0'
# No tiene datos
# 'Tomatometer de Stealing Home del año 2006.0'
# Stealing Home
#
# 20
# 'Tomatometer de Miramar Street del año 2006.0'
# Miramar Street (C) (2006)
#
# No tiene datos
# 'Tomatometer de The Box del año 2006.0'
# The Box
#
# 43
# 'Tomatometer de Model Man del año 2006.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de If Occurrence del año 2006.0'
# No tiene datos
# 'Tomatometer de Verano del año 2006.0'
# No tiene datos
# 'Tomatometer de The Girl Who Could Run 600 Miles Per Hour del año 2006.0'
# The Girl Who Could Run 600 Miles Per Hour
#
# No tiene datos
# 'Tomatometer de Alla fein del año 2006.0'
# No tiene datos
# 'Tomatometer de Stolen Love del año 2006.0'
# Stolen Love
#
# No tiene datos
# 'Tomatometer de Huellas del año 2006.0'
# No tiene datos
# 'Tomatometer de Tiny Explosions del año 2006.0'
# XXX
#
# No tiene datos
# 'Tomatometer de Wobbegong del año 2006.0'
# No tiene datos
# 'Tomatometer de Windowbreaker del año 2006.0'
# No tiene datos
# 'Tomatometer de Madres del año 2006.0'
# No tiene datos
# 'Tomatometer de All the French Are Whores del año 2006.0'
# No tiene datos
# 'Tomatometer de Time Will Tell del año 2006.0'
# Time Will Tell
#
# No tiene datos
# 'Tomatometer de A Quiet Spot del año 2006.0'
# A Quiet Place
#
# No tiene datos
# 'Tomatometer de All Is Forgiven del año 2006.0'
# All Is Forgiven
#
# 38
# 'Tomatometer de Ashtide del año 2006.0'
# No tiene datos
# 'Tomatometer de You Too Have Walked in My Shoes del año 2006.0'
# No tiene datos
# 'Tomatometer de Real vs. Reel del año 2006.0'
# No tiene datos
# 'Tomatometer de Scorpions & Frogs del año 2006.0'
# No tiene datos
# 'Tomatometer de Held del año 2006.0'
# No tiene datos
# 'Tomatometer de On the Rocks del año 2006.0'
# On the Rocks
#
# 87
# 'Tomatometer de Gelatin Smile del año 2006.0'
# Smile
#
# No tiene datos
# 'Tomatometer de Försvar del año 2006.0'
# No tiene datos
# 'Tomatometer de Puerto Rican Squirrels del año 2006.0'
# No tiene datos
# 'Tomatometer de Rock and a Hard Place del año 2006.0'
# Rock and a Hard Place
#
# 89
# 'Tomatometer de The 100% Perfect Girl del año 2006.0'
# No tiene datos
# 'Tomatometer de No tiene datos del año 2006.0'
# No tiene datos
# 'Tomatometer de Lovesick Blues del año 2006.0'
# No tiene datos
# 'Tomatometer de Ghost Soldier del año 2006.0'
# No tiene datos
# 'Tomatometer de Actors del año 2006.0'
# No tiene datos
# 'Tomatometer de Trasig idol del año 2006.0'
# No tiene datos
# 'Tomatometer de Huevos, besos brujos y mucho amor del año 2006.0'
# No tiene datos
# 'Tomatometer de A Different Light del año 2006.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Authority del año 2006.0'
# No tiene datos
# 'Tomatometer de Revolver del año 2008.0'
# Revolver
#
# 15
# 'Tomatometer de Room Service del año 2007.0'
# Room Service
#
# 64
# 'Tomatometer de Silent Night del año 2007.0'
# Silent Night
#
# 58
# 'Tomatometer de Beas Vorstellung von Glück del año 2007.0'
# No tiene datos
# 'Tomatometer de Saving Angelo del año 2008.0'
# No tiene datos
# 'Tomatometer de Matters of Life and Death del año 2007.0'
# A Matter of Life and Death
#
# No tiene datos
# 'Tomatometer de El sueño de Harvey del año 2007.0'
# No tiene datos
# 'Tomatometer de La Navidad de la gallina del año 2007.0'
# Las 10 mejores películas de terror de Navidad
#
# No tiene datos
# 'Tomatometer de Night Falls Fast del año 2007.0'
# When Night Falls
#
# No tiene datos
# 'Tomatometer de Found Objects del año 2007.0'
# Primer
#
# No tiene datos
# 'Tomatometer de Sanity or Survival del año 2007.0'
# No tiene datos
# 'Tomatometer de Türelem del año 2007.0'
# No tiene datos
# 'Tomatometer de The Shadow Man del año 2007.0'
# Shadow Man
#
# No tiene datos
# 'Tomatometer de 00:01:18 del año 2007.0'
# No tiene datos
# 'Tomatometer de Meeting Helen del año 2007.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Einsame Insel del año 2007.0'
# No tiene datos
# 'Tomatometer de Santa Croce del año 2007.0'
# Santa Croce
#
# No tiene datos
# 'Tomatometer de Raving del año 2007.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Waylaid del año 2007.0'
# No tiene datos
# 'Tomatometer de Az alma del año 2007.0'
# No tiene datos
# 'Tomatometer de Livewire del año 2007.0'
# Live Wire
#
# No tiene datos
# 'Tomatometer de Stutter del año 2007.0'
# The Pursuit of Happyness
#
# No tiene datos
# 'Tomatometer de Crocodile Dreaming del año 2007.0'
# No tiene datos
# 'Tomatometer de Redemption Maddie del año 2007.0'
# No tiene datos
# 'Tomatometer de Blood Brothers del año 2007.0'
# Blood Brothers
#
# No tiene datos
# 'Tomatometer de Seis o siete veranos del año 2007.0'
# Las 20 películas de cine fantástico con mejores críticas en ...
#
# No tiene datos
# 'Tomatometer de Door Out of the Dark del año 2007.0'
# Door Out of the Dark
#
# No tiene datos
# 'Tomatometer de The Violin del año 2007.0'
# The Violin
#
# 94
# 'Tomatometer de Fale. Wyjazd del año 2007.0'
# No tiene datos
# 'Tomatometer de Mummies: Secrets of the Pharaohs del año 2007.0'
# Mummies: Secrets of the Pharaohs
#
# 80
# 'Tomatometer de Trout del año 2007.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de For a Swim with the Fish del año 2007.0'
# No tiene datos
# 'Tomatometer de Aftermath on Meadowlark Lane del año 2007.0'
# No tiene datos
# 'Tomatometer de High Falls del año 2007.0'
# Man of the Year
#
# No tiene datos
# 'Tomatometer de No tiene datos del año 2007.0'
# No tiene datos
# 'Tomatometer de Bomb del año 2007.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de A Nick in Time del año 2007.0'
# Nick of Time
#
# No tiene datos
# 'Tomatometer de Infinite Delay del año 2007.0'
# No tiene datos
# 'Tomatometer de Bobby Bird: The Devil in Denim del año 2007.0'
# No tiene datos
# 'Tomatometer de King del año 2007.0'
# No tiene datos
# 'Tomatometer de The Oates' Valor del año 2007.0'
# No tiene datos
# 'Tomatometer de Black and White Trypps Number Three del año 2007.0'
# Black and White Trypps #3
#
# No tiene datos
# 'Tomatometer de My Eskimo Friend del año 2007.0'
# No tiene datos
# 'Tomatometer de Goliath del año 2007.0'
# Goliath
#
# 32
# 'Tomatometer de Crassus del año 2007.0'
# No tiene datos
# 'Tomatometer de Interview del año 2007.0'
# Interview
#
# 58
# 'Tomatometer de Dentist Visit del año 2007.0'
# No tiene datos
# 'Tomatometer de Lens Love Story del año 2007.0'
# Love Story
#
# No tiene datos
# 'Tomatometer de Anniversary del año 2007.0'
# No tiene datos
# 'Tomatometer de Memoryeffekt del año 2008.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de The Famous Joe Project del año 2007.0'
# The Famous Joe Project
#
# No tiene datos
# 'Tomatometer de Monsieur Borges and I del año 2007.0'
# Borges and I - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Swerve del año 2007.0'
# The Swerve
#
# 37
# 'Tomatometer de Pin Wheel del año 2007.0'
# No tiene datos
# 'Tomatometer de Kleine Annabelle del año 2007.0'
# Annabelle
#
# No tiene datos
# 'Tomatometer de Ab morgen glücklich del año 2007.0'
# No tiene datos
# 'Tomatometer de Amelia and Michael del año 2007.0'
# End of Days
#
# No tiene datos
# 'Tomatometer de Unfinished del año 2007.0'
# An Unfinished Life
#
# No tiene datos
# 'Tomatometer de Lumen del año 2007.0'
# No tiene datos
# 'Tomatometer de Starry Night del año 2007.0'
# Starry Night
#
# 55
# 'Tomatometer de A Soldier's Faith del año 2007.0'
# No tiene datos
# 'Tomatometer de Misfit del año 2007.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Growing Down del año 2007.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Bipolar Order del año 2007.0'
# No tiene datos
# 'Tomatometer de DayDreams of Rudolph Valentino del año 2007.0'
# No tiene datos
# 'Tomatometer de Twilight Angel del año 2007.0'
# No tiene datos
# 'Tomatometer de Left Turn del año 2007.0'
# Left Turn
#
# No tiene datos
# 'Tomatometer de Rendez-vous fatal del año 2007.0'
# No tiene datos
# 'Tomatometer de Sista dagen del año 2007.0'
# Marie Fredriksson
#
# No tiene datos
# 'Tomatometer de Minne utan återvändo del año 2007.0'
# No tiene datos
# 'Tomatometer de Training Wheels del año 2007.0'
# No tiene datos
# 'Tomatometer de Kake del año 2007.0'
# Bee Movie
#
# No tiene datos
# 'Tomatometer de Zoe's Day del año 2007.0'
# 100 Best Computer-Animated Movies, Ranked by ...
#
# No tiene datos
# 'Tomatometer de Rub Out del año 2007.0'
# Rub Out the Past - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Le café des pécheurs del año 2007.0'
# No tiene datos
# 'Tomatometer de Untitled/The Trees del año 2007.0'
# No tiene datos
# 'Tomatometer de Les heures creuses del año 2007.0'
# No tiene datos
# 'Tomatometer de Moi del año 2007.0'
# No tiene datos
# 'Tomatometer de Weddings and Beheadings del año 2007.0'
# No tiene datos
# 'Tomatometer de Contained del año 2007.0'
# No tiene datos
# 'Tomatometer de Muertas del año 2007.0'
# No tiene datos
# 'Tomatometer de Blood Red Sand del año 2007.0'
# Anexo:Películas con un 100% de aprobación en Rotten ...
#
# No tiene datos
# 'Tomatometer de Segundo aniversario del año 2007.0'
# No tiene datos
# 'Tomatometer de Lay Here del año 2007.0'
# No tiene datos
# 'Tomatometer de No se retire del año 2007.0'
# No tiene datos
# 'Tomatometer de Köra runt del año 2007.0'
# No tiene datos
# 'Tomatometer de Aquanauten del año 2007.0'
# No tiene datos
# 'Tomatometer de Last Exit del año 2007.0'
# Last Exit
#
# 48
# 'Tomatometer de No tiene datos del año 2007.0'
# No tiene datos
# 'Tomatometer de Lebenswandel del año 2007.0'
# No tiene datos
# 'Tomatometer de On a Tuesday del año 2007.0'
# Tuesday
#
# No tiene datos
# 'Tomatometer de My Friends, THC & Me! del año 2007.0'
# No tiene datos
# 'Tomatometer de The Kolaborator del año 2007.0'
# No tiene datos
# 'Tomatometer de Greetings from Earth del año 2007.0'
# No tiene datos
# 'Tomatometer de The Red Front del año 2007.0'
# No tiene datos
# 'Tomatometer de Alterego del año 2007.0'
# Alter Ego
#
# No tiene datos
# 'Tomatometer de A Death in the Woods del año 2007.0'
# Dead Wood
#
# No tiene datos
# 'Tomatometer de On a Clear Day del año 2007.0'
# On a Clear Day
#
# 69
# 'Tomatometer de Summer Breeze del año 2007.0'
# No tiene datos
# 'Tomatometer de Den store trollkarlen del año 2007.0'
# No tiene datos
# 'Tomatometer de A Couple of White Chicks at the Hairdresser del año 2007.0'
# A Couple of White Chicks at the Hairdresser
#
# No tiene datos
# 'Tomatometer de Headshot del año 2007.0'
# No tiene datos
# 'Tomatometer de Téli mese del año 2007.0'
# Aglaia Berlutti - Parte del Tomatometer - Rotten Tomatoes
#
# No tiene datos
# 'Tomatometer de Un santo para Telmo del año 2007.0'
# No tiene datos
# 'Tomatometer de Fallout del año 2007.0'
# Fallout
#
# No tiene datos
# 'Tomatometer de She Wore a Yellow Scrunchy del año 2007.0'
# No tiene datos
# 'Tomatometer de Armistice del año 2007.0'
# No tiene datos
# 'Tomatometer de At Last del año 2007.0'
# No tiene datos
# 'Tomatometer de Sleepwalkers del año 2007.0'
# Sleepwalkers
#
# 29
# 'Tomatometer de On the Spot del año 2007.0'
# Season 1 - On the Spot (2003)
#
# No tiene datos
# 'Tomatometer de I Love You Mommy del año 2007.0'
# Mother, I Love You
#
# No tiene datos
# 'Tomatometer de I Am Nick Robinson del año 2007.0'
# Nick Robinson
#
# No tiene datos
# 'Tomatometer de The Faithful del año 2007.0'
# The Faithful
#
# No tiene datos
# 'Tomatometer de Redemption Song del año 2007.0'
# Redemption Song
#
# No tiene datos
# 'Tomatometer de 27,000 Days del año 2007.0'
# No tiene datos
# 'Tomatometer de Suicide Club del año 2007.0'
# Suicide Club
#
# 63
# 'Tomatometer de A Fitting Tribute del año 2007.0'
# 140 Essential Action Movies To Watch Now
#
# No tiene datos
# 'Tomatometer de The Rapture of the Athlete Assumed Into Heaven del año 2007.0'
# No tiene datos
# 'Tomatometer de Last Hand del año 2007.0'
# Critics Pick the Best Movies of the Last 25 Years
#
# No tiene datos
# 'Tomatometer de Forward del año 2007.0'
# Forward
#
# No tiene datos
# 'Tomatometer de Lucky Blue del año 2007.0'
# No tiene datos
# 'Tomatometer de Breaking Up del año 2007.0'
# Breaking Up
#
# 20
# 'Tomatometer de Valériane va en ville del año 2007.0'
# No tiene datos
# 'Tomatometer de My Silent Sadness del año 2007.0'
# No tiene datos
# 'Tomatometer de El camino de Ana del año 2007.0'
# No tiene datos
# 'Tomatometer de Handle with Care del año 2007.0'
# Handle With Care
#
# No tiene datos
# 'Tomatometer de A Perfect Day del año 2007.0'
# A Perfect Day
#
# 71
# 'Tomatometer de Chickenfüt del año 2007.0'
# No tiene datos
# 'Tomatometer de Balance del año 2007.0'
# Evan Almighty
#
# No tiene datos
# 'Tomatometer de Shadowbox del año 2007.0'
# No tiene datos
# 'Tomatometer de Morning del año 2007.0'
# The Morning Show
#
# No tiene datos
# 'Tomatometer de Nameless del año 2007.0'
# The Nameless - Movie Reviews
#
# No tiene datos
# 'Tomatometer de Face Value del año 2007.0'
# Face Value
#
# No tiene datos
# 'Tomatometer de Open Season del año 2007.0'
# Open Season
#
# 49
# 'Tomatometer de Zen läbi prügi del año 2007.0'
# No tiene datos
# 'Tomatometer de Embedded del año 2007.0'
# Embedded - Movie Reviews
#
# No tiene datos
# 'Tomatometer de The Deceiver del año 2007.0'
# The Deceiver
#
# No tiene datos
# 'Tomatometer de Morpheus' Arms del año 2007.0'
# 140 Essential Action Movies To Watch Now
#
# No tiene datos
# 'Tomatometer de My Last Ten Hours with You del año 2007.0'
# The Biggest and Best TV & Streaming Series of the Last 25 ...
#
# No tiene datos
# 'Tomatometer de Cuisine américaine del año 2007.0'
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[81], line 2
#       1 #llamamos a la funcion
# ----> 2 terceracto_drama_tomatoes = datos_tomatoes(terceracto_drama_imdb, terceracto_drama_api)
#
# Cell In[79], line 41, in datos_tomatoes(lista_imdb, lista_API)
#      39 print(peticion)
#      40 #incluimos el string en la barra de busqueda de Google
# ---> 41 driver.find_element("css selector","#APjFqb").send_keys(peticion, Keys.ENTER)
#      43 #puntuación (tomatometer)
#      45 try:
#      46
#      47     #creamos una variable con el nombre de la primera pelicula que aparece en Google
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=122.0.6261.95)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A4BCAD22+56930]
# 	(No symbol) [0x00007FF7A4B3F622]
# 	(No symbol) [0x00007FF7A49F42E5]
# 	(No symbol) [0x00007FF7A49E191F]
# 	(No symbol) [0x00007FF7A49E1490]
# 	(No symbol) [0x00007FF7A49F6411]
# 	(No symbol) [0x00007FF7A4A778B9]
# 	(No symbol) [0x00007FF7A4A5BA43]
# 	(No symbol) [0x00007FF7A4A2D438]
# 	(No symbol) [0x00007FF7A4A2E4D1]
# 	GetHandleVerifier [0x00007FF7A4F46AAD+3709933]
# 	GetHandleVerifier [0x00007FF7A4F9FFED+4075821]
# 	GetHandleVerifier [0x00007FF7A4F9817F+4043455]
# 	GetHandleVerifier [0x00007FF7A4C69756+706710]
# 	(No symbol) [0x00007FF7A4B4B8FF]
# 	(No symbol) [0x00007FF7A4B46AE4]
# 	(No symbol) [0x00007FF7A4B46C3C]
# 	(No symbol) [0x00007FF7A4B368F4]
# 	BaseThreadInitThunk [0x00007FFBAE42257D+29]
# 	RtlUserThreadStart [0x00007FFBAFA4AA58+40]

# %%
#convertimos la lista a dataframe

 # si da error ponemos esta abajo. **

df_dram_tomatoes_tercer = pd.DataFrame(total_puntuacion_tomatoes)

df_dram_tomatoes_tercer
# Out:
#                    0
# 0     No tiene datos
# 1     No tiene datos
# 2     No tiene datos
# 3                 14
# 4     No tiene datos
# ...              ...
# 6634  No tiene datos
# 6635  No tiene datos
# 6636  No tiene datos
# 6637  No tiene datos
# 6638  No tiene datos
#
# [6639 rows x 1 columns]

# %%
#convertimos el dataframe a csv
df_dram_tomatoes_tercer.to_csv("drama_tomatoes_terceracto.csv")
