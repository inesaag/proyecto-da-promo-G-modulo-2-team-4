# %%
import pandas as pd

import requests

pd.set_option('display.max_columns', None)

# %%
#creamos una funcion para sacar una url dinámica con todas la páginas

def url_dinamica (genero, anio, tipo, clave):

    lista_json = []
    
    for pag in range (1,51):

        url = "https://moviesdatabase.p.rapidapi.com/titles"
        querystring = {"genre":genero,"titleType":tipo,"year":anio,"page":pag}
        headers = {
        "X-RapidAPI-Key": clave,
        "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"}

        response = requests.get(url, headers=headers, params=querystring)

        response_json = response.json()

        lista_json.append (response_json)
       

    return lista_json

# %% [markdown]
# MOVIE

# %%
# 17:54
#creamos un bucle para sacar jsons de varios años llamando a la función anterior, como hay límite sacaremos en esta ronda del 2010 al 2023
lista_json_anios = []

for anio in range(2010,2024):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Comedy", anio, "movie","b55329140bmshff79e342d59c07dp1be8c4jsn2e5fdc28a637")
    lista_json_anios.append(url2)

# %%
# 18:54

#repetimos lo que hemos hecho en la celda anterior para sacar los datos del 2000 al 2009
lista_json_anios1 = []

for anio in range(2000,2010):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Comedy", anio, "movie","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios1.append(url2)

# %% [markdown]
# SHORT

# %%
# 19:54

#creamos un bucle para sacar jsons de varios años llamando a la función anterior, como hay límite sacaremos en esta ronda del 2010 al 2023
lista_json_anios2 = []

for anio in range(2010,2024):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Comedy", anio, "short","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios2.append(url2)

# %%
# 20:54

# #repetimos lo que hemos hecho en la celda anterior para sacar los datos del 2000 al 2009
lista_json_anios3 = []

for anio in range(2000,2010):
    #añadimos el tipo y género que queremos buscar 
    #cada una le pone su API KEY
    url2 = url_dinamica("Comedy", anio, "short","54b0a47db5mshf6ed07e25abb30dp19e0edjsn935796beb60a")
    lista_json_anios3.append(url2)

# %%
#comprobamos que las últimas páginas tienen datos
lista_json_anios[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=movie&page=2&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e58c128a5a6a599f43cfef',
#     'id': 'tt10151854',
#     'primaryImage': {'id': 'rm332475393',
#      'width': 675,
#      'height': 1000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjBmMzQ4MDItZGNiMi00OWJmLTg3MDktMTViZmI0ODRhNzJkXkEyXkFqcGdeQXVyNjMxMTE2Mjg@._V1_.jpg',
#      'caption': {'plainText': 'Helen Mirren, Djimon Hounsou, Lucy Liu, Adam Brody, Meagan Good, Rachel Zegler, Zachary Levi, D.J. Cotrona, Grace Caroline Currey, and Ross Butler in Shazam! Fury of the Gods (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shazam! Fury of the Gods',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shazam! Fury of the Gods',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58c3ad8f3c0931e43d82d',
#     'id': 'tt10178004',
#     'primaryImage': {'id': 'rm1419902977',
#      'width': 3333,
#      'height': 4999,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmIyYzY3NTAtZjg3NC00YTgzLTk5ODAtN2JlMmE2OTczYTAxXkEyXkFqcGdeQXVyNzU4NTc2NzQ@._V1_.jpg',
#      'caption': {'plainText': 'Rapture Camp (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rapture Camp', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rapture Camp', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cfd8a5a6a599f4408cf',
#     'id': 'tt10305228',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Creepers 'R Us", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Creepers 'R Us", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d3f78c012aa34441653',
#     'id': 'tt10351180',
#     'primaryImage': {'id': 'rm2857219841',
#      'width': 960,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjcyMDE3YTgtZDQ3Ni00NWRiLWE2NTctZDU4MjE2MzU5YTgyXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Amrin Qureshi and Namashi Chakraborthy in Bad Boy (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bad Boy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bad Boy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d54971a4a15d6441d41',
#     'id': 'tt10364034',
#     'primaryImage': {'id': 'rm1197810177',
#      'width': 1500,
#      'height': 2222,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDBmNmZmNDMtYTI3NC00OWExLWE2NDYtMDA5ZDRhNDhjMjdkXkEyXkFqcGdeQXVyMTEzMTI1Mjk3._V1_.jpg',
#      'caption': {'plainText': 'Bryce Papenbrook and Cristina Valenzuela in Miraculous: Filmen om Ladybug & Cat Noir (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Miraculous: Filmen om Ladybug & Cat Noir',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Miraculous - Le film',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fa8e1a8ddbd9644acd1',
#     'id': 'tt10750578',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Os Perebas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Os Perebas', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fbf95801a78bc44b441',
#     'id': 'tt10767052',
#     'primaryImage': {'id': 'rm245586945',
#      'width': 1334,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDIwNWQwYTktZGQwYS00NzNjLThhNDMtODBlYmI5N2E0NjM0XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Next Goal Wins (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Next Goal Wins', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Next Goal Wins', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2024,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59000a66e59642344c319',
#     'id': 'tt10810852',
#     'primaryImage': {'id': 'rm2770772225',
#      'width': 1081,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTBlZmFkYTYtMmNmOS00Njc0LTg5MTAtYjU3NDJkNDE2MWNjXkEyXkFqcGdeQXVyNDcyMzkyMTQ@._V1_.jpg',
#      'caption': {'plainText': 'Angelique Burgos in Al Reves (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Al Reves', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Al Reves', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590d98a5a6a599f44f9ab',
#     'id': 'tt10954600',
#     'primaryImage': {'id': 'rm2537959681',
#      'width': 810,
#      'height': 1200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODZhNzlmOGItMWUyYS00Y2Q5LWFlNzMtM2I2NDFkM2ZkYmE1XkEyXkFqcGdeQXVyMTU5OTA4NTIz._V1_.jpg',
#      'caption': {'plainText': 'Michael Douglas, Michelle Pfeiffer, Paul Rudd, Kathryn Newton, Evangeline Lilly, Jonathan Majors, and Jamie Andrew Cutler in Ant-Man and the Wasp: Quantumania (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ant-Man and the Wasp: Quantumania',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ant-Man and the Wasp: Quantumania',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59220a66e5964234548b1',
#     'id': 'tt11170966',
#     'primaryImage': {'id': 'rm3460352257',
#      'width': 540,
#      'height': 800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNWNlZWI1YzUtOGQzZi00MjI1LWFlMWUtZmViZTkwNmM4MjVmXkEyXkFqcGdeQXVyMTI1OTUwNzY2._V1_.jpg',
#      'caption': {'plainText': 'Reception (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Reception', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Reception', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=movie&page=3&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5928a909c2ca7814561cf',
#     'id': 'tt11241232',
#     'primaryImage': {'id': 'rm2580036097',
#      'width': 2500,
#      'height': 4224,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODlhMTFlYjUtYjU3Ny00YWI0LWFlMDktM2QzNDUwYThmMGNmXkEyXkFqcGdeQXVyODgwNTU5Nzg@._V1_.jpg',
#      'caption': {'plainText': 'Denise Depauli, Ariel Li Gotti, and Juanjo Martínez in De Vuelta Al Mundo (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'De Vuelta Al Mundo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'De Vuelta Al Mundo',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e592b98a5a6a599f457045',
#     'id': 'tt11274492',
#     'primaryImage': {'id': 'rm440346369',
#      'width': 729,
#      'height': 1080,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2JmMmE0NjYtODUzNS00ZDg2LTk2ZjMtNDBiNjhlMGU2NjJlXkEyXkFqcGdeQXVyMTQ4NTgxNzYx._V1_.jpg',
#      'caption': {'plainText': 'Pierce Brosnan, Ellen Barkin, Nina Dobrev, and Adam Devine in The Out-Laws (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Out-Laws', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Out-Laws', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e592ecd8f3c0931e457957',
#     'id': 'tt11304740',
#     'primaryImage': {'id': 'rm104419841',
#      'width': 1086,
#      'height': 1609,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWQ4M2ZmODItNzZhYi00MzY1LTk2ZmItYTUwODI2NzJmN2JiXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Alan Tudyk, Chris Pine, and Ariana DeBose in Wish (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Wish', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Wish', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5939e95801a78bc45a67b',
#     'id': 'tt11425114',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'El Quinceañero De Mi Abuela',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'El Quinceañero De Mi Abuela',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e594b678c012aa3445e843',
#     'id': 'tt11608090',
#     'primaryImage': {'id': 'rm291045121',
#      'width': 3840,
#      'height': 2160,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjhkZTdmN2MtYzg2MC00MWQyLWIwYjYtNTQ3NGU2NTA3ZjViXkEyXkFqcGdeQXVyMzQxOTczNg@@._V1_.jpg',
#      'caption': {'plainText': 'Nick Peterson and Alex Altman in The Idiots (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Idiots', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Idiots', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e595dca66e596423463245',
#     'id': 'tt11804530',
#     'primaryImage': {'id': 'rm2532621057',
#      'width': 720,
#      'height': 698,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDUxYTk1M2MtMGEwYS00OGVjLThlMDEtMTZmNGMyM2I2Y2U5XkEyXkFqcGdeQXVyMTUzNTAwNDM@._V1_.jpg',
#      'caption': {'plainText': 'The Loverdoses (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Loverdoses', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Loverdoses', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 8,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e596bcb597b91eb94668b9',
#     'id': 'tt11950404',
#     'primaryImage': {'id': 'rm597186817',
#      'width': 1575,
#      'height': 2100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzQyYzIxNmEtMjYzNC00OTU5LTgwMjQtNWMxMWE0ZDZiNTdjXkEyXkFqcGdeQXVyMTE5NTI1Ng@@._V1_.jpg',
#      'caption': {'plainText': "Saraphina Joachim, Phil Trasolini, Lumen Beltran, Keerthi Paikera, Maritza Brikisak, Dan Zachary, and Marcio Moreno in Sophie's Rules (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Sophie's Rules", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Sophie's Rules", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59880971a4a15d646d9ef',
#     'id': 'tt12254818',
#     'primaryImage': {'id': 'rm1726036737',
#      'width': 1090,
#      'height': 1426,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2RjMzM4NjEtYTBlYy00ODBmLWJjOTQtMzUwNjhkNzJhZmUwXkEyXkFqcGdeQXVyMjE4MzYwNjY@._V1_.jpg',
#      'caption': {'plainText': 'Vernissage hos Gud (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Vernissage hos Gud', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Vernissage hos Gud',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599fccffb8f2faa47380b',
#     'id': 'tt12515422',
#     'primaryImage': {'id': 'rm4254378497',
#      'width': 2000,
#      'height': 2667,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2FjMzRiMzMtODk5Yy00M2MwLWIxMGMtZTYxYzNhNjhiNDY0XkEyXkFqcGdeQXVyNjAyMTY4MDc@._V1_.jpg',
#      'caption': {'plainText': 'Common People (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Common People', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Common People', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59b8478c012aa34479777',
#     'id': 'tt12781876',
#     'primaryImage': {'id': 'rm4230360577',
#      'width': 8100,
#      'height': 12300,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjRiNTE0MTQtZTRjYy00OWNjLWJmNjUtZTA4ZTg2MTdjMmFjXkEyXkFqcGdeQXVyMTE4NTEwNTky._V1_.jpg',
#      'caption': {'plainText': 'Jerry Jensen, Jerry Schultz, and Jay Karales in Mass State Lottery (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mass State Lottery', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mass State Lottery',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=movie&page=4&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e59ba7e1a8ddbd9647a465',
#     'id': 'tt12802346',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Luda godina - Povratak Zikine dinastije',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Luda godina - Povratak Zikine dinastije',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59bc5ef99b1c54347ab1d',
#     'id': 'tt12823454',
#     'primaryImage': {'id': 'rm1722301697',
#      'width': 1383,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjcxY2QwZmMtNjE1MS00OGU2LWJiMjYtOTc3ZTk5NmI2ODc1XkEyXkFqcGdeQXVyMTAyMjQ3NzQ1._V1_.jpg',
#      'caption': {'plainText': 'Reese Witherspoon and Ashton Kutcher in Your Place or Mine (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Your Place or Mine', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Your Place or Mine',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59cf8e1a8ddbd9647f8cb',
#     'id': 'tt7985704',
#     'primaryImage': {'id': 'rm576532737',
#      'width': 1945,
#      'height': 2880,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjcxOTJhZTEtMWFiYi00NTkwLTlkMzktZDQwMGQ0ZjM3YWU2XkEyXkFqcGdeQXVyMTAxNzQ1NzI@._V1_.jpg',
#      'caption': {'plainText': 'Cary Elwes, Hugh Grant, Josh Hartnett, Jason Statham, Bugzy Malone, and Aubrey Plaza in Operation Fortune (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Operation Fortune', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Operation Fortune: Ruse de Guerre',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59d8b8a5a6a599f481f3d',
#     'id': 'tt13130948',
#     'primaryImage': {'id': 'rm4283248897',
#      'width': 1638,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjQzYjE0NGEtZjBkOS00NjUzLWIwOWQtOWYyYjZjNjI1MzQyXkEyXkFqcGdeQXVyMTA1OTk1MjY3._V1_.jpg',
#      'caption': {'plainText': 'Sachin Khedekar, Manisha Koirala, Paresh Rawal, Ronit Roy, Rajpal Naurang Yadav, and Kartik Aaryan in Shehzada (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shehzada', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shehzada', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59e79d8f3c0931e4859ab',
#     'id': 'tt13290130',
#     'primaryImage': {'id': 'rm2382181633',
#      'width': 768,
#      'height': 1086,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOWM0ODQxN2MtNWQzMS00ZWM2LWExN2YtZWM3ZjQyYmYzZDI5XkEyXkFqcGdeQXVyMTYzMDUzNjEw._V1_.jpg',
#      'caption': {'plainText': 'Los buenos modales (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Los buenos modales', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Los buenos modales',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59ea495801a78bc4865f1',
#     'id': 'tt13321744',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'High Weirdness', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'High Weirdness', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 9,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a23f78c012aa344948ab',
#     'id': 'tt13950336',
#     'primaryImage': {'id': 'rm3335600897',
#      'width': 1080,
#      'height': 1490,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTIzMzIyZDUtZWQ5Zi00NjcyLTgxZDMtMjI1NGUyYTRjN2NjXkEyXkFqcGdeQXVyMzE2NDY2NDU@._V1_.jpg',
#      'caption': {'plainText': "Hemanth Prince, Anand Andy, Harsha Naidu, Archana Nair, Isaac D'Souza, Claire D'Souza, Annapoorna Lokesh, Shruthi Anup Kumar, Divya Shree, Rakshitha Venkatesh, Gotra Menon, Princy D'Souza, Sumanth Dachu, Samanvita Shetty, Anurag Shetty, Jayachandran Chandrasekhar, and Divya Sundar in Pros and Cons of Being Single (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pros and Cons of Being Single',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pros and Cons of Being Single',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a3c278c012aa3449a939',
#     'id': 'tt14211906',
#     'primaryImage': {'id': 'rm153631489',
#      'width': 1448,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjdiNGEyY2QtYWM0NC00NTA2LThjNDQtY2ZmMmE1NTIyMTNkXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg',
#      'caption': {'plainText': 'La novia de América (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'La novia de América', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'La novia de América',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a408d8f3c0931e49c0e7',
#     'id': 'tt14259918',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Big Syrup and The Maple Men',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Big Syrup and The Maple Men',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a46978c012aa3449d2c9',
#     'id': 'tt14326000',
#     'primaryImage': {'id': 'rm827009025',
#      'width': 1641,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTEwNThiMDEtZGQ2Mi00NmFmLThjNmYtNzBiMDBkZWEwYjJmXkEyXkFqcGdeQXVyMzcyMDg3ODE@._V1_.jpg',
#      'caption': {'plainText': 'Benyapa Jeenprasom, Rachanun Mahawan, Thanaset Suriyapornchaikul, Trai Nimtawat, Wachirawit Ruangwiwat, Pawat Chittsawangdee, and Korapat Kirdpan in My Precious (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'My Precious', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'My Precious', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=movie&page=5&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5a4a4ef99b1c54349e4ed',
#     'id': 'tt14362112',
#     'primaryImage': {'id': 'rm1287858177',
#      'width': 1895,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY4MDk2YWUtNWY1My00YjAxLWI4ZGQtMmRhN2FiNDI4NDRjXkEyXkFqcGdeQXVyMTUzMTg2ODkz._V1_.jpg',
#      'caption': {'plainText': 'Trolls Band Together (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Trolls Band Together', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Trolls Band Together',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a527b597b91eb94a0299',
#     'id': 'tt14451444',
#     'primaryImage': {'id': 'rm660027649',
#      'width': 840,
#      'height': 1200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTFiN2VhY2QtMDlmZC00NmY0LThmNGEtM2RhNjE0MGIxNTEzXkEyXkFqcGdeQXVyMTI1NDEyNTM5._V1_.jpg',
#      'caption': {'plainText': 'Rafadan Tayfa Galaktik Tayfa (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rafadan Tayfa Galaktik Tayfa',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rafadan Tayfa Galaktik Tayfa',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a54aa66e5964234a0d4d',
#     'id': 'tt14472156',
#     'primaryImage': {'id': 'rm155464705',
#      'width': 4050,
#      'height': 6000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMWFmOTU2ZjctN2VhMS00Yzg4LWIyOGEtMTgwZTdjYTMyZjNkXkEyXkFqcGdeQXVyMzQwMTY2Nzk@._V1_.jpg',
#      'caption': {'plainText': 'Owen Wilson in Paint (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Paint', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Paint', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a5ea971a4a15d64a36b7',
#     'id': 'tt1458167',
#     'primaryImage': {'id': 'rm129127937',
#      'width': 948,
#      'height': 533,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZmVmNWE1ZjktZmI5NS00ZGQwLWIyYjMtN2U3YzY5ZmViNDg1XkEyXkFqcGdeQXVyNTM3ODU5NTA@._V1_.jpg',
#      'caption': {'plainText': 'High in the Clouds (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'High in the Clouds', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'High in the Clouds',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a6accffb8f2faa4a6681',
#     'id': 'tt14709996',
#     'primaryImage': {'id': 'rm4256155393',
#      'width': 3300,
#      'height': 5100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzdlZWQ0MzgtODZmYS00OGFmLTgzNDgtZTQ1NzY2ZWI3YzBlXkEyXkFqcGdeQXVyOTI2MDIwOTc@._V1_.jpg',
#      'caption': {'plainText': 'Burning Love (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Burning Love', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Burning Love', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a755d8f3c0931e4a935f',
#     'id': 'tt14826022',
#     'primaryImage': {'id': 'rm1421947393',
#      'width': 1044,
#      'height': 1566,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGM2NTQ2MGUtYmVjZS00YTNjLTkxMjUtOWQ2ZjRiMDQyNmVlXkEyXkFqcGdeQXVyMTE5MTg5NDIw._V1_.jpg',
#      'caption': {'plainText': 'David Duchovny, Nia Long, Julia Louis-Dreyfus, Eddie Murphy, Jonah Hill, and Lauren London in You People (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'You People', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'You People', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a78fe1a8ddbd964aa221',
#     'id': 'tt14864476',
#     'primaryImage': {'id': 'rm1118823169',
#      'width': 1024,
#      'height': 680,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjFkOTEyMTQtNGI4Yy00ZmY3LTljYzYtMzFhOTg3YWQzZWZiXkEyXkFqcGdeQXVyNTgwNzg3MzY@._V1_.jpg',
#      'caption': {'plainText': 'Tramonto a Nord Ovest (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tramonto a Nord Ovest', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tramonto a Nord Ovest',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a7da8a5a6a599f4ab541',
#     'id': 'tt14914988',
#     'primaryImage': {'id': 'rm972628737',
#      'width': 722,
#      'height': 904,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTJiM2U3NTctNTAwNi00ZmQ5LThmNDUtYjI4MDdhYzQ5ZmExXkEyXkFqcGdeQXVyMTU0ODI1NTA2._V1_.jpg',
#      'caption': {'plainText': 'Satyaprem Ki Katha (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Satyaprem Ki Katha', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Satyaprem Ki Katha',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 6,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a839cffb8f2faa4ac95f',
#     'id': 'tt14979412',
#     'primaryImage': {'id': 'rm2616850433',
#      'width': 1280,
#      'height': 998,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmQ1YTVlNzctMmQ5MS00MzI0LTg4ZjctNmE0ZDNlZWM2ZDdkXkEyXkFqcGdeQXVyNTE0NDY4NTA@._V1_.jpg',
#      'caption': {'plainText': 'First Nights (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'First Nights', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'First Nights', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a84ccffb8f2faa4ace21',
#     'id': 'tt14993250',
#     'primaryImage': {'id': 'rm3798147841',
#      'width': 1148,
#      'height': 1530,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2FlZTE5ZjgtZGY5Ny00ZjIzLWFmZjktNjc1OWIwZjIwN2IzXkEyXkFqcGdeQXVyMTUyNjIwMDEw._V1_.jpg',
#      'caption': {'plainText': 'Alia Bhatt and Ranveer Singh in Rocky Aur Rani Ki Prem Kahani (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rocky Aur Rani Ki Prem Kahani',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rocky Aur Rani Kii Prem Kahaani',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=movie&page=6&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5a851a66e5964234acefd',
#     'id': 'tt14996762',
#     'primaryImage': {'id': 'rm1550317569',
#      'width': 828,
#      'height': 1459,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNWZkZTY0ZTctOGExNS00MzI2LTljMzEtZTUzNWU3NWMyMDI2XkEyXkFqcGdeQXVyNjMyODkwNzI@._V1_.jpg',
#      'caption': {'plainText': 'Not Funny: The Movie (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Not Funny: The Movie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Not Funny: The Movie',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a8988a5a6a599f4ae4eb',
#     'id': 'tt15043302',
#     'primaryImage': {'id': 'rm2037186305',
#      'width': 8100,
#      'height': 12000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTI3Y2FmN2YtMDQzYi00YWVlLTk4ZjMtMWVjZTRiNDEzZjhjXkEyXkFqcGdeQXVyOTAzMDgwODU@._V1_.jpg',
#      'caption': {'plainText': 'Crystal Chu, Phillip Smith, Harry Pang, Kurt Longjohn, Eddie Addams, Richie Fowler, Joanne Leung, Melody Smith, Low Light, Kuromoto Hitomi, Christopher Price, and Thomas Elliott in Love in Isolation (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Love in Isolation', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Love in Isolation',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a93bef99b1c5434b093b',
#     'id': 'tt15153532',
#     'primaryImage': {'id': 'rm2273125121',
#      'width': 500,
#      'height': 792,
# ...
#      'caption': {'plainText': 'The Gortach of Missouri (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Gortach of Missouri',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Gortach of Missouri',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f11d8904ab805b40d9da16',
#     'id': 'tt26747565',
#     'primaryImage': {'id': 'rm768554497',
#      'width': 1280,
#      'height': 1896,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmRkNThjYjMtM2E3OC00YTE5LWJjNGItNGM5OGZjZjg3ZTA1XkEyXkFqcGdeQXVyNTc3NDM4Njc@._V1_.jpg',
#      'caption': {'plainText': 'Jorge Luis Villacorta Santamato in ParlaNchíno Ateo: Errorista Comunista 54 (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'ParlaNchíno Ateo: Errorista Comunista 54',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'ParlaNchíno Ateo: Errorista Comunista 54',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f26e5c90b059a16ecd4242',
#     'id': 'tt26746429',
#     'primaryImage': {'id': 'rm1789146625',
#      'width': 687,
#      'height': 1017,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzY2ODViMTctMDVkMy00OWViLTkxYTAtZDNmOTE2NTFmODc2XkEyXkFqcGdeQXVyMTI1NDE5NjA3._V1_.jpg',
#      'caption': {'plainText': 'Beware the Groove: The Making of A Cult Classic (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Beware the Groove: The Making of A Cult Classic',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Beware the Groove: The Making of A Cult Classic',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f26e7490b059a16ecd4294',
#     'id': 'tt26749243',
#     'primaryImage': {'id': 'rm4085331457',
#      'width': 1920,
#      'height': 1080,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzE4MzBjOTgtODkzYy00ZTdjLWE3OTctZjI1ZjFlZjM3MzgxXkEyXkFqcGdeQXVyMTQ4NzA0NDgy._V1_.jpg',
#      'caption': {'plainText': 'Des hommes, la nuit (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Des hommes, la nuit', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Des hommes, la nuit',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=movie&page=63f7b457e8951abba30e82df&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '63f26e8d314a8ef5afcd4386',
#     'id': 'tt26749976',
#     'primaryImage': {'id': 'rm2379429377',
#      'width': 500,
#      'height': 716,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzBiYWE4ZTYtZWEyMi00NzA2LWEzODktM2M2MDM3NDZiZWIzXkEyXkFqcGdeQXVyOTgzMTMzNDE@._V1_.jpg',
#      'caption': {'plainText': 'Iveta Mukuchyan in Agent 044: Operation Garni (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Agent 044: Operation Garni',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Agent 044: Operation Garni',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f26e9d314a8ef5afcd43f6',
#     'id': 'tt26750250',
#     'primaryImage': {'id': 'rm1560227329',
#      'width': 1080,
#      'height': 1920,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMWRiNDZlMjAtZjdjNC00YWZlLWEwMDgtNTMzMTc2YzY2ZmE0XkEyXkFqcGdeQXVyMTIyNzY0NTMx._V1_.jpg',
#      'caption': {'plainText': 'Tania, Raj Shoker, Renu Kaushal, and Gippy Grewal in Mitran Da Naa Chalda (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mitran Da Naa Chalda', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mitran Da Naa Chalda',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f26f45314a8ef5afcd4aea',
#     'id': 'tt26753343',
#     'primaryImage': {'id': 'rm3799660033',
#      'width': 2025,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzY5MGFmYzgtMjkwMi00YmJjLWE3NGQtNWI1NjNmNjBlZTJhXkEyXkFqcGdeQXVyMTM2MTUyOTc@._V1_.jpg',
#      'caption': {'plainText': 'Brian Ward, Akku Kulhari, Manik Bahl, and Gautam Gurnani in Paraagan (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Paraagan', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Paraagan', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '63f3bfe1197a991530a0daa0',
#     'id': 'tt26751988',
#     'primaryImage': {'id': 'rm766916097',
#      'width': 886,
#      'height': 1036,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjhmMzI0ZmYtNmE3Zi00NDU0LTkxYWEtNjI1OTQ2NjM1MmYyXkEyXkFqcGdeQXVyOTk1NDYwOTA@._V1_.jpg',
#      'caption': {'plainText': 'Non aprite quella sporta (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Non aprite quella sporta',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Non aprite quella sporta',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f3bff2197a991530a0db08',
#     'id': 'tt26754212',
#     'primaryImage': {'id': 'rm3887150593',
#      'width': 1280,
#      'height': 1896,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2U3MjIwZmYtZjNjYS00MzYxLWE1MWQtY2NiMmYyMDMwZWQ5XkEyXkFqcGdeQXVyNTc3NDM4Njc@._V1_.jpg',
#      'caption': {'plainText': 'Jorge Luis Villacorta Santamato in ParlaNchíno Ateo: Errorista Comunista 55 (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'ParlaNchíno Ateo: Errorista Comunista 55',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'ParlaNchíno Ateo: Errorista Comunista 55',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f3c0ab197a991530a0e39a',
#     'id': 'tt26757150',
#     'primaryImage': {'id': 'rm3376953089',
#      'width': 900,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGJiNzk4OGEtZTI1Ni00ZTRlLWEwMGQtMzcwNjcxZjBmZjQ3XkEyXkFqcGdeQXVyMTYyMTQzMjM1._V1_.jpg',
#      'caption': {'plainText': 'Nassar, Nisha Sarangh, and Biju Sopanam in Laika (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Laika', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Laika', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f511599bb4f7f736a8b63f',
#     'id': 'tt26757027',
#     'primaryImage': {'id': 'rm2552575745',
#      'width': 2480,
#      'height': 3543,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMmIzZWJiYWItYjJhOC00NDE2LTg5YjItMTVlYjU5MzE2YTE1XkEyXkFqcGdeQXVyMjA5MTUzOTM@._V1_.jpg',
#      'caption': {'plainText': 'Fratelli Ferretti contro Real Madrid (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fratelli Ferretti contro Real Madrid',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fratelli Ferretti contro Real Madrid',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f5115c8ccd9fec91a8b657',
#     'id': 'tt26756609',
#     'primaryImage': {'id': 'rm1462970625',
#      'width': 2646,
#      'height': 3780,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWFlYzkyZjAtYWRkYy00NjJlLWFkMDEtZDQyYzExMjI1ZDkxXkEyXkFqcGdeQXVyMTkyOTE2Mjk@._V1_.jpg',
#      'caption': {'plainText': 'Vacaciones de verano (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Vacaciones de verano', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Vacaciones de verano',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f5121a9bb4f7f736a8be75',
#     'id': 'tt26761095',
#     'primaryImage': {'id': 'rm1281701377',
#      'width': 400,
#      'height': 600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTIyNmUyMGQtNzVmNi00NTQ1LWIxYzYtNzc2OWUwY2MwZTNlXkEyXkFqcGdeQXVyNDM1ODc2NzE@._V1_.jpg',
#      'caption': {'plainText': 'Bugun-bylyr 2 (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bugun-bylyr 2', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bugun-bylyr 2', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63f7b457e8951abba30e82df',
#     'id': 'tt26761873',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': '',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Bet', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Bet', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]}]

# %%
# comprobamos que las últimas páginas tienen datos
lista_json_anios1[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=movie&page=2&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e581f5cffb8f2faa41808d',
#     'id': 'tt0153140',
#     'primaryImage': {'id': 'rm3937200640',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE2NDAxNDE0Nl5BMl5BanBnXkFtZTgwMTU1MjQwNjE@._V1_.jpg',
#      'caption': {'plainText': 'Rózsaszín sajt (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rózsaszín sajt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rózsaszín sajt', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58364d735dff3f941d345',
#     'id': 'tt0288190',
#     'primaryImage': {'id': 'rm2837450752',
#      'width': 228,
#      'height': 320,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTEyYmNiOWQtNTM4OS00NTQ2LTgwNWItYjY3Y2RkYTY0Y2E3XkEyXkFqcGdeQXVyMDcwNzg1MQ@@._V1_.jpg',
#      'caption': {'plainText': 'El reino de los cielos (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'El reino de los cielos', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'El reino de los cielos',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58394b597b91eb941ddf3',
#     'id': 'tt0304876',
#     'primaryImage': {'id': 'rm713132289',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDgzNTM0NTgtYTQ1ZC00NDJlLTk5YzAtOTFmM2Y1ZmI2YTIzXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#      'caption': {'plainText': 'Unter Strom (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Unter Strom', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Unter Strom', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e583a9b597b91eb941e329',
#     'id': 'tt0311698',
#     'primaryImage': {'id': 'rm3357524224',
#      'width': 800,
#      'height': 1185,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTkyMzIzNjUwOF5BMl5BanBnXkFtZTgwMzgwNzE1MjE@._V1_.jpg',
#      'caption': {'plainText': 'Railed (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Railed', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Railed', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e583acd735dff3f941e361',
#     'id': 'tt0312958',
#     'primaryImage': {'id': 'rm2705494528',
#      'width': 350,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTk3NTYwNTc3MF5BMl5BanBnXkFtZTcwODk4MTkzMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Chinango (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Chinango', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Chinango', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2003,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58417d735dff3f941fc8d',
#     'id': 'tt0353765',
#     'primaryImage': {'id': 'rm3524329984',
#      'width': 720,
#      'height': 1034,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDIwMDFkZmYtMTc0MS00MzAyLWFkNDAtYmRmMmMyNjdiMWY5XkEyXkFqcGdeQXVyMTM2Mzg4MA@@._V1_.jpg',
#      'caption': {'plainText': 'Los muertos van deprisa (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Los muertos van deprisa',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Los muertos van deprisa',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58438e1a8ddbd96420385',
#     'id': 'tt0365873',
#     'primaryImage': {'id': 'rm1970328064',
#      'width': 388,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTcyOTc0ODA0M15BMl5BanBnXkFtZTgwMzU5OTk1MDE@._V1_.jpg',
#      'caption': {'plainText': 'Two-Minute Heist (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Two-Minute Heist', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Two-Minute Heist',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58456e1a8ddbd96420a25',
#     'id': 'tt0375568',
#     'primaryImage': {'id': 'rm3129051392',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI5NTEwNTcxMl5BMl5BanBnXkFtZTcwMDEyMTE4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Nicolas Cage, Donald Sutherland, Newell Alexander, Kristen Bell, Freddie Highmore, Eugene Levy, Bob Logan, and Ryan Stiles in Astro Boy (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Astro Boy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Astro Boy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5846aef99b1c543420eb9',
#     'id': 'tt0382579',
#     'primaryImage': {'id': 'rm3580940800',
#      'width': 343,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTQyOTExOTcyOV5BMl5BanBnXkFtZTgwMTMxMDA2MDE@._V1_.jpg',
#      'caption': {'plainText': "Boppin' at the Glue Factory (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Boppin' at the Glue Factory",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Boppin' at the Glue Factory",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584a8b597b91eb9421dc5',
#     'id': 'tt0403702',
#     'primaryImage': {'id': 'rm1877642752',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE3NTkxODUwOV5BMl5BanBnXkFtZTcwMjE4NjI5Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Michael Cera and Portia Doubleday in Youth in Revolt (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Youth in Revolt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Youth in Revolt',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 1,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=movie&page=3&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e584b995801a78bc42215f',
#     'id': 'tt0411670',
#     'primaryImage': {'id': 'rm710909184',
#      'width': 300,
#      'height': 480,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTE5OTMzMjc2OV5BMl5BanBnXkFtZTcwMDMzOTkyMQ@@._V1_.jpg',
#      'caption': {'plainText': 'Mixing Karma (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mixing Karma', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mixing Karma', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584c9ef99b1c54342243b',
#     'id': 'tt0417205',
#     'primaryImage': {'id': 'rm2944079872',
#      'width': 234,
#      'height': 360,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTJjZTg3OTgtNGIxNC00NzgxLTkzMzItZTBiZTgwYWYzNjllXkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_.jpg',
#      'caption': {'plainText': 'Mila Kunis in Tom Cool (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tom Cool', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tom Cool', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584f28a5a6a599f422e3b',
#     'id': 'tt0432283',
#     'primaryImage': {'id': 'rm329928960',
#      'width': 2359,
#      'height': 3495,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGUwYTU4NGEtNDM4MS00NDRjLTkwNmQtOTkwMWMyMjhmMjdlXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg',
#      'caption': {'plainText': 'George Clooney, Bill Murray, Meryl Streep, Jason Schwartzman, Owen Wilson, Eric Chase Anderson, and Wallace Wolodarsky in Fantastic Mr. Fox (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fantastic Mr. Fox', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fantastic Mr. Fox',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e584fea66e5964234230c1',
#     'id': 'tt0436339',
#     'primaryImage': {'id': 'rm1116768256',
#      'width': 500,
#      'height': 747,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTM4NTY3MzY2MV5BMl5BanBnXkFtZTcwMDQ1NTM2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Nicolas Cage, Penélope Cruz, Jon Favreau, and Tracy Morgan in G-Force (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'G-Force', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'G-Force', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5850195801a78bc4231cd',
#     'id': 'tt0437405',
#     'primaryImage': {'id': 'rm2024049920',
#      'width': 1383,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTExODM1MDI4MDVeQTJeQWpwZ15BbWU3MDQzMjc1MzM@._V1_.jpg',
#      'caption': {'plainText': 'Jeff Daniels and Ryan Reynolds in Paper Man (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Paper Man', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Paper Man', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 5,
#      'year': 2014,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58503e1a8ddbd96423125',
#     'id': 'tt0438894',
#     'primaryImage': {'id': 'rm2995410176',
#      'width': 1090,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODU3NGRjYjEtZTViNS00NmE0LWFlOGUtYmJkODhhYmJiNzRjXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Kisse Pyaar Karoon? (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Kisse Pyaar Karoon?', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Kisse Pyaar Karoon?',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5852bcffb8f2faa423a33',
#     'id': 'tt0453501',
#     'primaryImage': {'id': 'rm4199998976',
#      'width': 290,
#      'height': 431,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGIwM2M5ZGEtNzAyOS00MmNiLTkxYTktNzUzYmQwMjA0MjYwXkEyXkFqcGdeQXVyNTIwODMzNjc@._V1_.jpg',
#      'caption': {'plainText': "It's a Mismatch (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "It's a Mismatch", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "It's a Mismatch",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5852e8a5a6a599f423bed',
#     'id': 'tt0452935',
#     'primaryImage': {'id': 'rm1258391809',
#      'width': 399,
#      'height': 595,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzM1MWZlZjMtMDI2Yy00NTZkLWJiMmUtMDFmNGRiNWNmYTRlXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg',
#      'caption': {'plainText': 'Un ajuste de cuentas (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Un ajuste de cuentas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Un ajuste de cuentas',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58530cffb8f2faa423b5d',
#     'id': 'tt0452694',
#     'primaryImage': {'id': 'rm3885367808',
#      'width': 1000,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWNlN2RmZDktNzllNC00NDVlLTllMzgtZGQ1YmRmZThmZjZmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#      'caption': {'plainText': "The Time Traveler's Wife (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "The Time Traveler's Wife",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "The Time Traveler's Wife",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5853a78c012aa34423d55',
#     'id': 'tt0457400',
#     'primaryImage': {'id': 'rm2240514048',
#      'width': 1013,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTkzNDg2OTc1NF5BMl5BanBnXkFtZTcwNDcxODE2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Land of the Lost (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Land of the Lost', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Land of the Lost',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=movie&page=4&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e58547ef99b1c543424121',
#     'id': 'tt0462479',
#     'primaryImage': {'id': 'rm3195407360',
#      'width': 5320,
#      'height': 7600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzU5NGRmMzctNTg2OS00MTVjLTk3MWItZGFhMjU5MmM3NGQ0XkEyXkFqcGdeQXVyMDYyMjU1NQ@@._V1_.jpg',
#      'caption': {'plainText': 'Naco es chido (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Naco es chido', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Naco es chido', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5854895801a78bc424221',
#     'id': 'tt0462559',
#     'primaryImage': {'id': 'rm2083558913',
#      'width': 8100,
#      'height': 12300,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjJkY2RjYzYtMDQ4Zi00NDM4LWI0OGEtYjgyYjMxMmZhNmEzXkEyXkFqcGdeQXVyMTczODU2Ng@@._V1_.jpg',
#      'caption': {'plainText': 'Summer of the Eagle (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Summer of the Eagle', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Summer of the Eagle',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5854d78c012aa34424197',
#     'id': 'tt0464137',
#     'primaryImage': {'id': 'rm3586689024',
#      'width': 500,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjIwMzUwMTYzMF5BMl5BanBnXkFtZTcwODM5NjU1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Baja Beach Bums (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Baja Beach Bums', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Baja Beach Bums',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e58550e1a8ddbd964242e3',
#     'id': 'tt0464077',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Labor Day', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Labor Day', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5855aef99b1c54342456b',
#     'id': 'tt0469251',
#     'primaryImage': {'id': 'rm2306574336',
#      'width': 1944,
#      'height': 2880,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc3MTM1OTExMl5BMl5BanBnXkFtZTcwODA3NTU2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Tripping Forward (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Tripping Forward', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Tripping Forward',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5855f909c2ca781424629',
#     'id': 'tt0473102',
#     'primaryImage': {'id': 'rm1782224640',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI1MTgzMTk1OF5BMl5BanBnXkFtZTcwNDY3Nzk3MQ@@._V1_.jpg',
#      'caption': {'plainText': 'The Perfect Game (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Perfect Game', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Perfect Game',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5855fd735dff3f94246e7',
#     'id': 'tt0473001',
#     'primaryImage': {'id': 'rm641041409',
#      'width': 1200,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2E4Y2E0MzYtZTRlYS00YzYwLTk0N2ItMjI0ZWI1YTk5OTA5XkEyXkFqcGdeQXVyMTY5Nzc4MDY@._V1_.jpg',
#      'caption': {'plainText': 'David Lengel in Bald (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bald', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bald', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58571909c2ca781424a49',
#     'id': 'tt0476009',
#     'primaryImage': {'id': 'rm1177468672',
#      'width': 1575,
#      'height': 2328,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTAxMDkxODQ0OV5BMl5BanBnXkFtZTcwNzQxNTMxNg@@._V1_.jpg',
#      'caption': {'plainText': 'RiffRaff (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'RiffRaff', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'RiffRaff', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 7,
#      'year': 2012,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5857278c012aa34424a47',
#     'id': 'tt0478860',
#     'primaryImage': {'id': 'rm323293696',
#      'width': 500,
#      'height': 669,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTllYzM3YTctNWJkMy00ZTg4LTk0OWMtOGIxZjcwNDc0ZTZjXkEyXkFqcGdeQXVyOTU3ODk4MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Marília Pêra and José Wilker in Embarque Imediato (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Embarque Imediato', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Embarque Imediato',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5858fb597b91eb942524b',
#     'id': 'tt0489049',
#     'primaryImage': {'id': 'rm2450822144',
#      'width': 1316,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI2MDM0NTY5OF5BMl5BanBnXkFtZTcwODMxMzIwMg@@._V1_.jpg',
#      'caption': {'plainText': 'Fanboys (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fanboys', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fanboys', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=movie&page=5&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5859a8a5a6a599f425531',
#     'id': 'tt0492896',
#     'primaryImage': {'id': 'rm3390357248',
#      'width': 436,
#      'height': 640,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTA1NzEzMTYxODZeQTJeQWpwZ15BbWU3MDcyMTYxMjY@._V1_.jpg',
#      'caption': {'plainText': 'My Suicide (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'My Suicide', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'My Suicide', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 9,
#      'year': 2011,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5859de1a8ddbd964254a3',
#     'id': 'tt0494252',
#     'primaryImage': {'id': 'rm3834361088',
#      'width': 1571,
#      'height': 2250,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTg1MzI0Njk1NV5BMl5BanBnXkFtZTcwMDYzMjQ4Nw@@._V1_.jpg',
#      'caption': {'plainText': 'A Little Party (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Little Party', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Little Party', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e585a3909c2ca781425613',
#     'id': 'tt0496673',
#     'primaryImage': {'id': 'rm1858502656',
#      'width': 396,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjExODkwMzg4N15BMl5BanBnXkFtZTcwMDMxNTg2Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Calvin Marshall (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Calvin Marshall', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Calvin Marshall',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 9,
#      'year': 2011,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e585abef99b1c54342583b',
#     'id': 'tt0499493',
#     'primaryImage': {'id': 'rm93097728',
#      'width': 550,
#      'height': 813,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzc1MzgxNjAzM15BMl5BanBnXkFtZTcwMjEyNDYxMw@@._V1_.jpg',
#      'caption': {'plainText': "He's Such a Girl (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "He's Such a Girl", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "He's Such a Girl",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5889fef99b1c54342ff8b',
#     'id': 'tt0762125',
#     'primaryImage': {'id': 'rm1181031680',
#      'width': 1050,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzA3NDEwMGYtZWVmNi00MDRiLWExYWItM2I1ZTQ5NDI4NTQyXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_.jpg',
#      'caption': {'plainText': 'Planet 51 (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Planet 51', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Planet 51', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 4,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588a3d8f3c0931e4300cf',
#     'id': 'tt0762072',
#     'primaryImage': {'id': 'rm3806038272',
#      'width': 2025,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjEyODYwODk5OV5BMl5BanBnXkFtZTcwODAwNTc3Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Baghdad Texas (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Baghdad Texas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Baghdad Texas', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588a4cffb8f2faa42ffcd',
#     'id': 'tt0762105',
#     'primaryImage': {'id': 'rm3712649216',
#      'width': 1350,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI3NjE0OTE0MV5BMl5BanBnXkFtZTcwNTc4NzY2Mg@@._V1_.jpg',
#      'caption': {'plainText': "I Hate Valentine's Day (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "I Hate Valentine's Day", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "I Hate Valentine's Day",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588bcef99b1c543430633',
#     'id': 'tt0770790',
#     'primaryImage': {'id': 'rm1132475904',
#      'width': 324,
#      'height': 468,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDRkNDYyNjEtOWM5My00MzU4LTk0MzgtMDI5MWI0Zjc0NzQzXkEyXkFqcGdeQXVyODk4NjI3Ng@@._V1_.jpg',
#      'caption': {'plainText': 'My Sweet Misery (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'My Sweet Misery', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'My Sweet Misery',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588c6b597b91eb943092f',
#     'id': 'tt0775418',
#     'primaryImage': {'id': 'rm4229338880',
#      'width': 852,
#      'height': 1284,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTgxNDEzMjQxNl5BMl5BanBnXkFtZTcwNDgwMzM4MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Angels, Devils and Men (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Angels, Devils and Men', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Angels, Devils and Men',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588c9971a4a15d64309f5',
#     'id': 'tt0775552',
#     'primaryImage': {'id': 'rm248219648',
#      'width': 1383,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTk3NTMzNTIxNV5BMl5BanBnXkFtZTcwOTI4ODU1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Thomas Haden Church, Josh Peck, J.K. Simmons, Ashley Tisdale, Kari Wahlgren, Carter Jenkins, Ashley Boettcher, Austin Butler, Henri Young, and Regan Young in Aliens in the Attic (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Aliens in the Attic', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Aliens in the Attic',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=movie&page=6&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e588d478c012aa34430ad7',
#     'id': 'tt0780002',
#     'primaryImage': {'id': 'rm4259022848',
#      'width': 2480,
#      'height': 3508,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzc0OTAyMDM1NF5BMl5BanBnXkFtZTcwOTM2Mjc1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Contact High (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Contact High', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Contact High', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588d6a66e596423430c0f',
#     'id': 'tt0780567',
#     'primaryImage': {'id': 'rm3398273792',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjIwMjgwMjg4M15BMl5BanBnXkFtZTcwNTU2ODkzMg@@._V1_.jpg',
#      'caption': {'plainText': 'Eddie Murphy and Yara Shahidi in Imagine That (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Imagine That', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Imagine That', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588d8a66e596423430c91',
#     'id': 'tt0780521',
#     'primaryImage': {'id': 'rm3488974848',
#      'width': 484,
#      'height': 755,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjEyOTQ5NzAzNl5BMl5BanBnXkFtZTcwMTcyNTU1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Bruno Campos, Jim Cummings, Keith David, Jenifer Lewis, Anika Noni Rose, and Michael-Leon Wooley in The Princess and the Frog (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Princess and the Frog',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Princess and the Frog',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588e5b597b91eb943107d',
#     'id': 'tt0787470',
#     'primaryImage': {'id': 'rm1190539264',
#      'width': 800,
#      'height': 1200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmY3YmUxZDctMGE2MC00Nzk1LWFjOWMtYjM5ZTI0MTYyMjUxXkEyXkFqcGdeQXVyNTYyNDI4MzY@._V1_.jpg',
#      'caption': {'plainText': 'Seann William Scott in Balls Out: Gary the Tennis Coach (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Balls Out: Gary the Tennis Coach',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Balls Out: Gary the Tennis Coach',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588e5d735dff3f9431017',
#     'id': 'tt0785006',
#     'primaryImage': {'id': 'rm2486539264',
#      'width': 510,
#      'height': 755,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI5NjkxOTE5MF5BMl5BanBnXkFtZTcwMTcxNTAwMg@@._V1_.jpg',
#      'caption': {'plainText': 'Emma Roberts, Jake T. Austin, and Cosmo in Hotel for Dogs (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Hotel for Dogs', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Hotel for Dogs', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588eca66e596423431149',
#     'id': 'tt0790627',
#     'primaryImage': {'id': 'rm2338359552',
#      'width': 261,
#      'height': 385,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTQyNzYxMTk4NF5BMl5BanBnXkFtZTcwMDY1MTM4Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Brief Interviews with Hideous Men (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Brief Interviews with Hideous Men',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Brief Interviews with Hideous Men',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588ecd735dff3f94311bb',
#     'id': 'tt0790633',
#     'primaryImage': {'id': 'rm1920258560',
#      'width': 90,
#      'height': 150,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjMzMjcxMDQ3N15BMl5BanBnXkFtZTgwMTMxMTA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'The Cops Did It (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Cops Did It', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Cops Did It',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588f495801a78bc431433',
#     'id': 'tt0791488',
#     'primaryImage': {'id': 'rm3807676416',
#      'width': 583,
#      'height': 864,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI2MDI4NTc5NV5BMl5BanBnXkFtZTcwNzc5MzU1Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Saddle Up with Dick Wrangler & Injun Joe (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Saddle Up with Dick Wrangler & Injun Joe',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Saddle Up with Dick Wrangler & Injun Joe',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58913d8f3c0931e431ad9',
#     'id': 'tt0804469',
#     'primaryImage': {'id': 'rm2809451008',
#      'width': 417,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc1OTQ3MzA0OV5BMl5BanBnXkFtZTgwNTcxMTA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'Dream State (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dream State', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dream State', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5891ea66e596423431cb3',
#     'id': 'tt0807028',
#     'primaryImage': {'id': 'rm2404498688',
#      'width': 572,
#      'height': 844,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjA5MTQ3NjQ5Ml5BMl5BanBnXkFtZTcwMDA5ODY4Ng@@._V1_.jpg',
#      'caption': {'plainText': 'Matthew Lillard, Rachelle Lefevre, Efren Ramirez, and Brett Davern in The Pool Boys (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Pool Boys', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Pool Boys', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '6',
#   'next': '/titles?titleType=movie&page=7&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e58920ef99b1c543431dc7',
#     'id': 'tt0808285',
#     'primaryImage': {'id': 'rm2889060096',
#      'width': 1381,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE1MzgyNDM1OF5BMl5BanBnXkFtZTcwNDIzODIyMw@@._V1_.jpg',
#      'caption': {'plainText': 'The Good Heart (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Good Heart', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Good Heart', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 7,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58923b597b91eb9431f11',
#     'id': 'tt0808232',
#     'primaryImage': {'id': 'rm4268772864',
#      'width': 538,
#      'height': 806,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNThmNDA4NjAtYmM3Zi00MTc0LWE2MDAtYWJiZDYzMGE3YTNmXkEyXkFqcGdeQXVyMTQ3Njg3MQ@@._V1_.jpg',
#      'caption': {'plainText': 'A Dog Year (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Dog Year', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Dog Year', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 2,
#      'year': 2012,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e589248a5a6a599f431fa3',
#     'id': 'tt0808526',
#     'primaryImage': {'id': 'rm2807857920',
#      'width': 1381,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTYyNzg2NzUyNl5BMl5BanBnXkFtZTcwNjEzOTM2Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Life During Wartime (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Life During Wartime', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Life During Wartime',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 5,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58932d735dff3f94321bf',
#     'id': 'tt0814331',
#     'primaryImage': {'id': 'rm399444736',
#      'width': 1400,
#      'height': 2100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTU1ZjVlMDAtNmIxNi00YTRkLWE0ZWMtYjE2YzA1ODVmZjFkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#      'caption': {'plainText': 'Parker Posey, Rachel Dratch, and Amy Poehler in Spring Breakdown (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Spring Breakdown', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Spring Breakdown',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58932d8f3c0931e4321d9',
#     'id': 'tt0815182',
#     'primaryImage': {'id': 'rm2994898944',
#      'width': 1275,
#      'height': 1650,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAyOTEyMjc3NV5BMl5BanBnXkFtZTcwNzc4MzI2Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Irene in Time (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
# ...
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Assistants', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Assistants', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 12,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599c3971a4a15d6472afb',
#     'id': 'tt1247704',
#     'primaryImage': {'id': 'rm2651818240',
#      'width': 829,
#      'height': 1200,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTkyOTEwNjg0M15BMl5BanBnXkFtZTcwNDI4NDA5Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Carla Gugino, Emmanuelle Chriqui, Marley Shelton, Connie Britton, Cameron Richardson, and Adrianne Palicki in Women in Trouble (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Women in Trouble', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Women in Trouble',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 7,
#      'year': 2011,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599c3a66e596423472acf',
#     'id': 'tt1247662',
#     'primaryImage': {'id': 'rm481857280',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTc3MTExMzIzMV5BMl5BanBnXkFtZTcwMjI1MzUxMw@@._V1_.jpg',
#      'caption': {'plainText': 'Alexis Bledel, Bryan Greenberg, and Scott Porter in The Good Guy (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Good Guy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Good Guy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 2,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599c5b597b91eb947289d',
#     'id': 'tt1247685',
#     'primaryImage': {'id': 'rm387455744',
#      'width': 512,
#      'height': 800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzRiYmU1MjQtNGQ4YS00OGRkLTk1NTUtZjIzNmNiYTllNGUwXkEyXkFqcGdeQXVyMTU1NTI2MA@@._V1_.jpg',
#      'caption': {'plainText': 'Zoltán Mucsi and Péter Scherer in Papírkutyák (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Papírkutyák', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Papírkutyák', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599cc971a4a15d6472d3f',
#     'id': 'tt1248128',
#     'primaryImage': {'id': 'rm66264832',
#      'width': 300,
#      'height': 442,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTBhMzY3NDUtMjIwMy00ZTY1LWExZjYtZTMyNTlkYmZjNmY0XkEyXkFqcGdeQXVyNTI5NjIyMw@@._V1_.jpg',
#      'caption': {'plainText': 'Robert Arevalo, Eddie Garcia, Gloria Romero, and Armida Siguion-Reyna in Fuschia (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fuschia', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fuschia', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599d3ef99b1c543472e21',
#     'id': 'tt1248957',
#     'primaryImage': {'id': 'rm3378676224',
#      'width': 2625,
#      'height': 3375,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTg5NDczODMwM15BMl5BanBnXkFtZTcwMTM2MTE1Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Dumping Lisa (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dumping Lisa', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dumping Lisa', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e599db971a4a15d647310b',
#     'id': 'tt1249431',
#     'primaryImage': None,
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "The People's Agency", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "The People's Agency",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599dccffb8f2faa473043',
#     'id': 'tt1249307',
#     'primaryImage': {'id': 'rm3259617792',
#      'width': 375,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjI1ODY1NjQ2Nl5BMl5BanBnXkFtZTgwMzU2MjA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'Puck Hogs (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Puck Hogs', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Puck Hogs', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599de971a4a15d64731d7',
#     'id': 'tt1249443',
#     'primaryImage': {'id': 'rm2154596096',
#      'width': 500,
#      'height': 808,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU5Mjk3ODIyOV5BMl5BanBnXkFtZTcwODU0NjcwNA@@._V1_.jpg',
#      'caption': {'plainText': 'You Wont Miss Me (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'You Wont Miss Me', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'You Wont Miss Me',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=movie&page=61e59a12a66e596423473e59&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e599fcb597b91eb9473665',
#     'id': 'tt1251495',
#     'primaryImage': {'id': 'rm1299745536',
#      'width': 1382,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTM0OTgyMzQyN15BMl5BanBnXkFtZTcwNjMxOTI0Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Spicy Mac Project (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Spicy Mac Project', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Spicy Mac Project',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599fed735dff3f94739b9',
#     'id': 'tt1251725',
#     'primaryImage': {'id': 'rm3599958784',
#      'width': 1062,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDM0ODVhNTItNDYyZC00ZjU5LTgxNTMtZmY2MjJkOTU2MTcxXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_.jpg',
#      'caption': {'plainText': 'Bunny and the Bull (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bunny and the Bull', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bunny and the Bull',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e599ff909c2ca781473873',
#     'id': 'tt1251757',
#     'primaryImage': {'id': 'rm2264272640',
#      'width': 1391,
#      'height': 2061,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDYyZDAxMzMtM2I5Ni00Y2U1LTgwZDQtZmNlYzc4YzI2NGVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#      'caption': {'plainText': 'Giovanni Ribisi, James Caan, and Luke Wilson in Middle Men (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Middle Men', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Middle Men', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 8,
#      'year': 2010,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a0695801a78bc473e2d',
#     'id': 'tt1252400',
#     'primaryImage': {'id': 'rm2990053120',
#      'width': 807,
#      'height': 454,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU4NDgwNDAyM15BMl5BanBnXkFtZTcwOTU2Njk3MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Pajamas (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pajamas', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pajamas', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e59a09e1a8ddbd96473cfd',
#     'id': 'tt1252289',
#     'primaryImage': {'id': 'rm3444167168',
#      'width': 357,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjI1Mjc2MzkwN15BMl5BanBnXkFtZTgwOTU2MjA2MDE@._V1_.jpg',
#      'caption': {'plainText': 'Four Single Fathers (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Four Single Fathers', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Four Single Fathers',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a0ae1a8ddbd96473d25',
#     'id': 'tt1252385',
#     'primaryImage': {'id': 'rm2852227328',
#      'width': 573,
#      'height': 767,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTQxMDYzOTUyNF5BMl5BanBnXkFtZTcwNzE5NTA5Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Drama Kings (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Drama Kings', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Drama Kings', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 11,
#      'year': 2013,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a0d78c012aa34473a21',
#     'id': 'tt1252596',
#     'primaryImage': {'id': 'rm430656000',
#      'width': 1280,
#      'height': 1811,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmZhNjhkN2UtN2I3NS00MzUyLTg3M2YtNjRjN2Y2NmNhNzUxXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Katrina Kaif and Ranbir Kapoor in Ajab Prem Ki Ghazab Kahani (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ajab Prem Ki Ghazab Kahani',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ajab Prem Ki Ghazab Kahani',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a0d95801a78bc473fd1',
#     'id': 'tt1252610',
#     'primaryImage': {'id': 'rm150850048',
#      'width': 354,
#      'height': 500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTUxMTYzMTY0MF5BMl5BanBnXkFtZTgwMTc5NTAzMTE@._V1_.jpg',
#      'caption': {'plainText': 'Nord (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nord', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nord', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 11,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a0def99b1c543473cc1',
#     'id': 'tt1252602',
#     'primaryImage': {'id': 'rm2091715584',
#      'width': 600,
#      'height': 800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTkzNGUxYTUtZGVmOS00OTZiLWI4YzEtOTcwYTM1Zjc1NzYzXkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_.jpg',
#      'caption': {'plainText': "Julie Depardieu in La femme invisible (d'après une histoire vraie) (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "La femme invisible (d'après une histoire vraie)",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "La femme invisible (d'après une histoire vraie)",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59a12a66e596423473e59',
#     'id': 'tt1252614',
#     'primaryImage': {'id': 'rm2496436737',
#      'width': 1150,
#      'height': 1500,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWIxOWJhZTktMWQxYS00NzJhLWFmZDMtYzNiZDNlMjVkYzY4XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_.jpg',
#      'caption': {'plainText': 'Sankat City (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Movie',
#      'id': 'movie',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sankat City', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sankat City', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]}]

# %%
lista_json_anios2[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=short&page=2&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e59d97e1a8ddbd96482061',
#     'id': 'tt13135936',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Sexorcism', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Sexorcism', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5cd93e1a8ddbd9653b797',
#     'id': 'tt15745324',
#     'primaryImage': {'id': 'rm1655379457',
#      'width': 3600,
#      'height': 5400,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzg5ZjYzODQtNDk2Mi00MDNhLTg0NGUtODUxMDYzMDQ0NTNhXkEyXkFqcGdeQXVyNjQ4MzcyNDA@._V1_.jpg',
#      'caption': {'plainText': 'Bear Trap (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bear Trap', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bear Trap', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5dbbdcffb8f2faa572987',
#     'id': 'tt15770114',
#     'primaryImage': {'id': 'rm1632367873',
#      'width': 779,
#      'height': 1008,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzlmZjQ0ZWMtZDFlNy00ODQ4LWE2MWUtMmMzMWY0NGMzMjZkXkEyXkFqcGdeQXVyMzQ5MjE5Nzc@._V1_.jpg',
#      'caption': {'plainText': 'Kumud Pant in Facebook (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Facebook', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Facebook', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f011f1399aff92263d4af0',
#     'id': 'tt16969998',
#     'primaryImage': {'id': 'rm1912018433',
#      'width': 1728,
#      'height': 2304,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzlmNzI4ZTYtYzFiOS00YTQyLTg0ODctMDQ3Yjg0NmRlZTRjXkEyXkFqcGdeQXVyMTM0MzE1ODU4._V1_.jpg',
#      'caption': {'plainText': 'Bilan de santé (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bilan de santé', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bilan de santé', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f01b0b8f746489a60492b3',
#     'id': 'tt17009170',
#     'primaryImage': {'id': 'rm1911545857',
#      'width': 5475,
#      'height': 8157,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzg3ZTNlODgtNzYzMS00ZGIwLTg0NDgtZmFmN2JhMjkxM2Q2XkEyXkFqcGdeQXVyNTc4OTc4OTI@._V1_.jpg',
#      'caption': {'plainText': 'Bloodbowl I (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bloodbowl I', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bloodbowl I', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f01c778f746489a604a44b',
#     'id': 'tt17066254',
#     'primaryImage': {'id': 'rm3243369729',
#      'width': 1414,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOWI0OTJiZDUtODgwMy00MWNmLWE2NGUtZjEzODNjOGIyNWMwXkEyXkFqcGdeQXVyNTMyODg1MzE@._V1_.jpg',
#      'caption': {'plainText': 'Deli Meat (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Deli Meat', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Deli Meat', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61f527571fa73b252f79638f',
#     'id': 'tt17422822',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Troll', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Troll', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '620000cba431ddc72befd6e2',
#     'id': 'tt17720464',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sexy Nails by Aunt Tootsie',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sexy Nails by Aunt Tootsie',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': None,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62027e97ff449bd5995bdfab',
#     'id': 'tt17889486',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Only in Springfield', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Only in Springfield',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6209618ebec57314a888e8fb',
#     'id': 'tt18226288',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Shadows Fall Behind You',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Shadows Fall Behind You',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '2',
#   'next': '/titles?titleType=short&page=3&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '622382bb0b33d3a3af69a93a',
#     'id': 'tt18394068',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Flatmates', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Flatmates', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 11,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62650e2f146b8befb812c9b4',
#     'id': 'tt19797782',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'I Care', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'I Care', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '626902940f16c046fcae782f',
#     'id': 'tt19816152',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': '3', '__typename': 'TitleText'},
#     'originalTitleText': {'text': '3', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6270e845bc1317180030e90d',
#     'id': 'tt19880066',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Liga dos Carecas Maguire'S Cut",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Liga dos Carecas Maguire'S Cut",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6274dc9d4eb96cb76d87f062',
#     'id': 'tt19896388',
#     'primaryImage': {'id': 'rm1891635713',
#      'width': 1200,
#      'height': 1700,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzU3MGQ3MzktNjZlZi00NzY0LTg2NTUtY2Q3NzI0NjFjNjIyXkEyXkFqcGdeQXVyMTA3ODAzOTI5._V1_.jpg',
#      'caption': {'plainText': 'Corentin Pilarczyk in Bardache (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bardache', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bardache', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62777f7de484ec36c34ec13c',
#     'id': 'tt20113664',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Stuck with Friends', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Stuck with Friends',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '627b740d347d0d7367d33cd0',
#     'id': 'tt20191770',
#     'primaryImage': {'id': 'rm4146270721',
#      'width': 1587,
#      'height': 2245,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTBkZTIxMDMtNDNjYy00MDM1LTlhZDctZDNhZjZhZDBiNjRkXkEyXkFqcGdeQXVyNjA5ODQyNzQ@._V1_.jpg',
#      'caption': {'plainText': 'Catfish (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Catfish', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Catfish', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62a4535d6bfccda70116b75a',
#     'id': 'tt20916548',
#     'primaryImage': {'id': 'rm1095439361',
#      'width': 2000,
#      'height': 2829,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjRhMTRhZjAtMzUyOS00Y2NmLWJhMjctYjQ5Y2MwOWY1ZTcwXkEyXkFqcGdeQXVyMTM2MjUzMzY@._V1_.jpg',
#      'caption': {'plainText': 'Nesten død (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nesten død', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nesten død', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 10,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62a6f65cb34a8ef4756f8fce',
#     'id': 'tt21033356',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Absent Jack', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Absent Jack', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62a84888dc3116c2d853f6ca',
#     'id': 'tt21030528',
#     'primaryImage': {'id': 'rm1427314177',
#      'width': 1587,
#      'height': 2245,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjhiNzY2OWEtYTYwMC00ZDRhLTgyODYtZGE5ZDkwZTE5NTc4XkEyXkFqcGdeQXVyMTUzMzM4NTk3._V1_.jpg',
#      'caption': {'plainText': 'George K., Baby A. Francois, Ratana Puttarattanamane, Pattarapol Puangpachang, Pann, and Sauro in Food Dating (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Food Dating', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Food Dating', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=short&page=4&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '62d51cc8bf57b5be550500a2',
#     'id': 'tt21294520',
#     'primaryImage': {'id': 'rm4104129281',
#      'width': 1356,
#      'height': 2410,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2UxM2Y5YmItNjhiZC00YTJmLWFiYzktZmY0ZGFmZmJiODZjXkEyXkFqcGdeQXVyMTQ3MzQ2NDgy._V1_.jpg',
#      'caption': {'plainText': 'Spider-Man 2: Electro Boogaloo (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Spider-Man 2: Electro Boogaloo',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Spider-Man 2: Electro Boogaloo',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 12,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '62da609c19680bf8488b6b31',
#     'id': 'tt21336722',
#     'primaryImage': {'id': 'rm960105217',
#      'width': 1587,
#      'height': 2245,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjI4M2EwMTMtMTk4ZC00MzcyLTliYjEtYmJjODY1MjVhNmQ2XkEyXkFqcGdeQXVyNjY5MzMyMTc@._V1_.jpg',
#      'caption': {'plainText': 'Briefcase (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Briefcase', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Briefcase', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 27,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63009c62096e63000b7784db',
#     'id': 'tt21825490',
#     'primaryImage': {'id': 'rm3645127937',
#      'width': 1728,
#      'height': 2168,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2Q4ZjExYTAtZGI2MS00ZGNiLTlmM2ItYWY0ZTc3ZGYzYTA3XkEyXkFqcGdeQXVyMTIwNjc1NTA4._V1_.jpg',
#      'caption': {'plainText': 'Delaney Wenner, Nick Savino, and Avery Widener in Bugbear II (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bugbear II', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bugbear II', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6308853d0e3eb5158ef256ac',
#     'id': 'tt21869080',
#     'primaryImage': {'id': 'rm1076170497',
#      'width': 1222,
#      'height': 1686,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmQxOTkzZDMtMTY3MC00NTdmLTgzODQtY2ZmZTc3YWM2YTcxXkEyXkFqcGdeQXVyMTQ5MDQyODU4._V1_.jpg',
#      'caption': {'plainText': 'Colin Wasmund in Simpleman (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Simpleman', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Simpleman', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 8,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6309d74c44a16fd075ca9aad',
#     'id': 'tt21876336',
#     'primaryImage': {'id': 'rm2533625601',
#      'width': 1945,
#      'height': 2881,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzgyNTVmN2EtNWFkZi00MTI1LWJhMWEtYzMwZTUyNWYyOWJhXkEyXkFqcGdeQXVyMTA2OTQ0Mjc1._V1_.jpg',
#      'caption': {'plainText': 'Oh, Marie (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Oh, Marie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Oh, Marie', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6311bfd694565d6dd006be26',
#     'id': 'tt21934702',
#     'primaryImage': {'id': 'rm727528193',
#      'width': 1728,
#      'height': 2592,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2MxOTVjODktODlhMy00OWQxLThlYjMtN2E4Zjk2MmE1YTY4XkEyXkFqcGdeQXVyOTg1MDAyMDM@._V1_.jpg',
#      'caption': {'plainText': 'Gold and Mud (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Gold and Mud', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Gold and Mud', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '631857165a5e57bfb4d4a805',
#     'id': 'tt21983840',
#     'primaryImage': {'id': 'rm834014465',
#      'width': 1080,
#      'height': 1529,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGQ1ZmZkMWUtNWEzYS00MzUzLWI1YmMtYjkzMDI4YjZmOWJkXkEyXkFqcGdeQXVyMTMwMTk5MjM2._V1_.jpg',
#      'caption': {'plainText': 'Sam Hume in The Phoney (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Phoney', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Phoney', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '632d6ee82484ae4a2a043230',
#     'id': 'tt22178830',
#     'primaryImage': {'id': 'rm2501640193',
#      'width': 4050,
#      'height': 6000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTg1YWMzNjUtMGFhMy00NzliLWE0MGMtZmIzNjRlNGU0MTM2XkEyXkFqcGdeQXVyMTU3NDUzMzk3._V1_.jpg',
#      'caption': {'plainText': 'Flags and Emblems (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Flags and Emblems', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Flags and Emblems',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '632ec0b3a9e37aa4715bec69',
#     'id': 'tt22207302',
#     'primaryImage': {'id': 'rm3316797953',
#      'width': 531,
#      'height': 800,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZGEyZTFkYjUtNTRlNy00NmIwLTliZTQtZmFhNGE4NDgzNDRlXkEyXkFqcGdeQXVyMTcwNzQ1MDE4._V1_.jpg',
#      'caption': {'plainText': 'European Man... American Beach (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'European Man... American Beach',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'European Man... American Beach',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6332b4f0e49f421c37920702',
#     'id': 'tt22248028',
#     'primaryImage': {'id': 'rm4036362497',
#      'width': 1015,
#      'height': 1638,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTUwYTZkNDMtYzhlNS00ZDAyLWIxZWItZjc1OWM3OWU5ZjkzXkEyXkFqcGdeQXVyNDg4OTI5NDQ@._V1_.jpg',
#      'caption': {'plainText': "Kevin Day, Christi Day, Julie Zimmermann, Matthew Ham, Robert Babcock, Victoria Fox, and Dene'a Hardin in Dinner with the Inlaws (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dinner with the Inlaws', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dinner with the Inlaws',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=short&page=5&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '6335583f5f58aa192f1da899',
#     'id': 'tt22334270',
#     'primaryImage': {'id': 'rm3473343233',
#      'width': 1511,
#      'height': 2173,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmQyZWU5YWMtM2NlNi00MDAzLWFhYjItOWUxZjAyZTY0MzY5XkEyXkFqcGdeQXVyNDA2NjkwOTQ@._V1_.jpg',
#      'caption': {'plainText': 'Love on Lock (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Love on Lock', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Love on Lock', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63491eafcfd2662a5cc6f366',
#     'id': 'tt22752752',
#     'primaryImage': {'id': 'rm3443196161',
#      'width': 794,
#      'height': 1124,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjYwOTRhYjYtNjdiZC00ODFmLTg5YTgtNzFiY2JjYjY2ZmI0XkEyXkFqcGdeQXVyMTMxMTE5NDQx._V1_.jpg',
#      'caption': {'plainText': 'Gotcha! (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Gotcha!', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Gotcha!', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6354fbfc63dd397807a669d1',
#     'id': 'tt22888940',
#     'primaryImage': {'id': 'rm2746287873',
#      'width': 1417,
#      'height': 1984,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWU3Mzk0NDItYmVjZi00YzQ0LTk4ZTMtYzhlNDVhNTAzZDIxXkEyXkFqcGdeQXVyOTczMzQ4NDM@._V1_.jpg',
#      'caption': {'plainText': 'Loading Love (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Loading Love', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Loading Love', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63564d7cce3a2ee6505eb362',
#     'id': 'tt22896014',
#     'primaryImage': {'id': 'rm3125500161',
#      'width': 3584,
#      'height': 2012,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNDFiMGNkYzctZGEyMy00MGRmLWE1NjUtMDIyMDAyMTA3MDVkXkEyXkFqcGdeQXVyMTU3NTY0Mjgz._V1_.jpg',
#      'caption': {'plainText': 'Always Tomorrow (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Always Tomorrow', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Always Tomorrow',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 7,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6358f0c8fd39c812470ece5e',
#     'id': 'tt23014970',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Concerned Citizen', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Concerned Citizen',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6358f0cae3b640b3fd0ece6a',
#     'id': 'tt23016192',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'House Haunting', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'House Haunting', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63822fa9f641fb6e13054833',
#     'id': 'tt23329694',
#     'primaryImage': {'id': 'rm3498006785',
#      'width': 1200,
#      'height': 719,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDQxY2EzMDYtN2FmZC00ODgzLWI1Y2MtNTU0M2IwMjEzZTIwXkEyXkFqcGdeQXVyMDYxMTUwNg@@._V1_.jpg',
#      'caption': {'plainText': 'The Curse of Room 102 (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Curse of Room 102', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Curse of Room 102',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 13,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63822fc0f641fb6e130548fd',
#     'id': 'tt23330510',
#     'primaryImage': {'id': 'rm409207809',
#      'width': 1166,
#      'height': 1420,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzk5YTlhNjYtNTIzZC00NTUzLTk4MzUtOTY5ZmMwNzU4N2I2XkEyXkFqcGdeQXVyNTAzNjgyMTY@._V1_.jpg',
#      'caption': {'plainText': 'Faulty Newsroom (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Faulty Newsroom', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Faulty Newsroom',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6382313ff641fb6e13055631',
#     'id': 'tt23395496',
#     'primaryImage': {'id': 'rm3863086081',
#      'width': 2908,
#      'height': 1628,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMWM4YzJlZjgtMGMzNi00ZTZhLWI4MDQtZTMwYzEwMGJmOGY5XkEyXkFqcGdeQXVyNTAzNjgyMTY@._V1_.jpg',
#      'caption': {'plainText': 'Afton Alivia-McKeith and Skylar McKeith in The London Gals (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The London Gals', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The London Gals',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63823384f641fb6e130569e7',
#     'id': 'tt23463934',
#     'primaryImage': {'id': 'rm636749057',
#      'width': 1944,
#      'height': 2880,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzNhMzQxOWEtODc3Ny00Y2RjLWI2OWItNGIyZmUzNzVlNjZhXkEyXkFqcGdeQXVyMjg3NzE3NjQ@._V1_.jpg',
#      'caption': {'plainText': 'Leigh Quinn and Mark Rowley in Write Off (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Write Off', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Write Off', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=short&page=6&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '638237c743254a6477058f54',
#     'id': 'tt23617442',
#     'primaryImage': {'id': 'rm84423169',
#      'width': 1545,
#      'height': 2000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDZjMDM0ZDUtNTZkZC00NWQ5LThmNjctYTdjM2VmZDEzNGVhXkEyXkFqcGdeQXVyODcyOTAzNTU@._V1_.jpg',
#      'caption': {'plainText': 'A Meeting of the Henry Chapel Fan Club (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Meeting of the Henry Chapel Fan Club',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Meeting of the Henry Chapel Fan Club',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63823c3643254a647705b590',
#     'id': 'tt23667626',
#     'primaryImage': {'id': 'rm2482715137',
#      'width': 3024,
#      'height': 4032,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjFiZGM3MDUtYjEzNS00MDdkLTk4NWItYWIwMWU2YjU4N2EyXkEyXkFqcGdeQXVyODU1NDA2OTI@._V1_.jpg',
#      'caption': {'plainText': 'Nostalgia (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nostalgia', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nostalgia', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 12,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '63823ef8f641fb6e1305ccd6',
#     'id': 'tt23739900',
#     'primaryImage': {'id': 'rm614021633',
#      'width': 1999,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDM1NWRkOWItZGI3Yy00ZjJmLTgzMzMtZTAxYTJlMjk2YmNkXkEyXkFqcGdeQXVyMTI3NDI3NDc1._V1_.jpg',
#      'caption': {'plainText': 'The Menu (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Menu', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Menu', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '638244e843254a64770601b0',
#     'id': 'tt23803320',
#     'primaryImage': {'id': 'rm3788061441',
#      'width': 842,
#      'height': 1191,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGMwZGZlYzQtMmEzOS00MGM5LWE4YjYtNWJiODI0OGJjMjgzXkEyXkFqcGdeQXVyMTUzODY2MTg0._V1_.jpg',
#      'caption': {'plainText': 'Patrícia Inverneiro and William Dell-Price in Spellbound (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Spellbound', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Spellbound', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '638244f7f641fb6e1306013b',
#     'id': 'tt23803936',
#     'primaryImage': {'id': 'rm2450864641',
#      'width': 3375,
#      'height': 5000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDg3N2QxMTItNDM0Mi00ZTA5LTg3ODQtMDhmMzRhN2U0OTg4XkEyXkFqcGdeQXVyODQ1MTIzNDQ@._V1_.jpg',
#      'caption': {'plainText': 'Alisha Erozer in Check (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Check', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Check', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6383b07bfaa99c3b7130aac2',
#     'id': 'tt23180434',
#     'primaryImage': {'id': 'rm3600417793',
#      'width': 828,
#      'height': 1242,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjE3YzY2NmItNDAwNy00NDM3LWI2NWYtMGUwMWU0Yjc1MWJkXkEyXkFqcGdeQXVyMTU3NjE3NDI2._V1_.jpg',
#      'caption': {'plainText': "Rafael Sanchez in Death's Day Off (2023)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Death's Day Off", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Death's Day Off",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
# ...
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Guilt Actually', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Guilt Actually', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6400efbba7c3afbf3b0797aa',
#     'id': 'tt26929275',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Judy and family', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Judy and family',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '64024077d1f4a003eebc1eac',
#     'id': 'tt26929871',
#     'primaryImage': {'id': 'rm3273537281',
#      'width': 3301,
#      'height': 5100,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGJmYzg3ZGItOGY3OC00YWQ0LTk2NzYtYmFjZDY5MjA1NmRlXkEyXkFqcGdeQXVyNDk5ODg2Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Stalk (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Stalk', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Stalk', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 28,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6402407ed1f4a003eebc1ec8',
#     'id': 'tt26929968',
#     'primaryImage': {'id': 'rm4031930113',
#      'width': 1224,
#      'height': 1584,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2MyNDhjMWMtM2U4NS00OGJhLTlmZjktZTJmOWQwMGY0N2RkXkEyXkFqcGdeQXVyMTE5ODUzMzM4._V1_.jpg',
#      'caption': {'plainText': 'Snuggledown (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Snuggledown', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Snuggledown', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6402407f6bc4e3cebebc1eca',
#     'id': 'tt26930067',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Channels', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Channels', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6402407f6bc4e3cebebc1ecc',
#     'id': 'tt26929971',
#     'primaryImage': {'id': 'rm3277137921',
#      'width': 4320,
#      'height': 6840,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDQyOGZkZGEtMDMyYS00ZTg0LTk5Y2ItZGJkZTExYjllNmZmXkEyXkFqcGdeQXVyMTQ4Mjg5MzIy._V1_.jpg',
#      'caption': {'plainText': 'Welcome to Celibacy Club (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Welcome to Celibacy Club',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Welcome to Celibacy Club',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=short&page=640391e548c186f77c67e8d1&year=2023&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '64024088d1f4a003eebc1f14',
#     'id': 'tt26930255',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'BreakAway', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'BreakAway', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640240a36bc4e3cebebc2026',
#     'id': 'tt26931228',
#     'primaryImage': {'id': 'rm2963809025',
#      'width': 2000,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzA1MmYyYjctOTRmYy00NzAxLWFhM2EtY2ZjZDkzMjVhNTFiXkEyXkFqcGdeQXVyMTMyNDI1Njg5._V1_.jpg',
#      'caption': {'plainText': 'The Englishman (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Englishman', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Englishman', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640240dbd1f4a003eebc22d6',
#     'id': 'tt26932499',
#     'primaryImage': {'id': 'rm252720897',
#      'width': 2844,
#      'height': 4087,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTc0NzU3ZjYtMDBiOC00YTdjLTljZDItYzQ1YmQ4MjZjZWUyXkEyXkFqcGdeQXVyMTA4NDQyNjY3._V1_.jpg',
#      'caption': {'plainText': 'Unsere Problemzone (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Unsere Problemzone', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Unsere Problemzone',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '64024107d1f4a003eebc2514',
#     'id': 'tt26933528',
#     'primaryImage': {'id': 'rm4277548033',
#      'width': 2025,
#      'height': 3075,
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2FhZTUwMDYtZjFhNy00YWRmLTg5MDgtMGI1YTBkMGM4Y2JkXkEyXkFqcGdeQXVyMTQ4NzE1MzQy._V1_.jpg',
#      'caption': {'plainText': 'Les 13 Cyclistes (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Les 13 Cyclistes', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Les 13 Cyclistes',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 1,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '6402410c6bc4e3cebebc2556',
#     'id': 'tt26933846',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Despondency 2', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Despondency 2', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640241176bc4e3cebebc25f8',
#     'id': 'tt26934259',
#     'primaryImage': {'id': 'rm2747474689',
#      'width': 1454,
#      'height': 2034,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTcyMzM2OTctMmY0ZS00NzMzLWIxZGQtMzQ2ZTZlYmI0ZWU3XkEyXkFqcGdeQXVyMTMzMjMwMzM4._V1_.jpg',
#      'caption': {'plainText': 'Brian Ruthruff in More! (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'More!', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'More!', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 5,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640241326bc4e3cebebc277c',
#     'id': 'tt26934991',
#     'primaryImage': {'id': 'rm1510497793',
#      'width': 1296,
#      'height': 1728,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmVjYjExZTUtYzIxOS00OTE2LWFjYmYtNWRlOWM0OTE0MzIzXkEyXkFqcGdeQXVyMTA5ODk0ODkz._V1_.jpg',
#      'caption': {'plainText': 'Crimson Wave (2023)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Crimson Wave', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Crimson Wave', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 15,
#      'month': 4,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '64024135d1f4a003eebc27aa',
#     'id': 'tt26935046',
#     'primaryImage': {'id': 'rm199175169',
#      'width': 725,
#      'height': 1024,
#      'url': 'https://m.media-amazon.com/images/M/MV5BM2I2ZDY3ZGQtYWQ2ZC00MTFmLWIyZDgtNTZkODdjNzk0YWIwXkEyXkFqcGdeQXVyNTg4NzY3NzA@._V1_.jpg',
#      'caption': {'plainText': 'Martin Klempnow, Alexander Wipprecht, Taisiya Schumacher, Ingo van Gulijk, and Jana Rahma in Walküren (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Walküren', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Walküren', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640391e441e65f322d67e8c5',
#     'id': 'tt26933494',
#     'primaryImage': {'id': 'rm3489936385',
#      'width': 2732,
#      'height': 2048,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTIzY2U2Y2ItZTUwYS00N2Y2LWEzM2QtZjFkMzBjNWQwMTA2XkEyXkFqcGdeQXVyODQ2MjQwMA@@._V1_.jpg',
#      'caption': {'plainText': 'Travis Zariwny in Monster P.O.V. (2023)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Monster P.O.V.', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Monster P.O.V.', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 3,
#      'year': 2023,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '640391e548c186f77c67e8d1',
#     'id': 'tt26934255',
#     'primaryImage': None,
#     'titleType': {'displayableProperty': {'value': {'plainText': 'Short',
#        '__typename': 'Markdown'},
#       '__typename': 'DisplayableTitleTypeProperty'},
#      'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#      'canHaveEpisodes': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Paul Delvaux', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Paul Delvaux', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None}]}]

# %%
lista_json_anios3[-1]
# Out:
# [{'page': '1',
#   'next': '/titles?titleType=short&page=2&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e580e7971a4a15d6414bbf',
#     'id': 'tt0067230',
#     'primaryImage': {'id': 'rm3864507393',
#      'width': 859,
#      'height': 1229,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGUwZmQ0ZGYtNTk5OS00NWMyLTlkYWQtZjBjOGI5MWY3N2UzXkEyXkFqcGdeQXVyMDY4MzkyNw@@._V1_.jpg',
#      'caption': {'plainText': 'I Miss Sonia Henie (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'I Miss Sonia Henie', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'I Miss Sonia Henie',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 1971,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e588bae1a8ddbd964305cd',
#     'id': 'tt0770731',
#     'primaryImage': {'id': 'rm4269652480',
#      'width': 682,
#      'height': 954,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTUxMTkyOTEwM15BMl5BanBnXkFtZTcwNDQ5OTk0NA@@._V1_.jpg',
#      'caption': {'plainText': 'Chubby Killer (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Chubby Killer', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Chubby Killer', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 10,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e589318a5a6a599f4322b3',
#     'id': 'tt0814265',
#     'primaryImage': {'id': 'rm1380422656',
#      'width': 2025,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjA2MjU0ODQwNl5BMl5BanBnXkFtZTcwMzMyNzc5MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Pink Eye (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pink Eye', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pink Eye', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58a4f95801a78bc436319',
#     'id': 'tt0918541',
#     'primaryImage': {'id': 'rm3718246912',
#      'width': 350,
#      'height': 494,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTA4MTIyODgwMjheQTJeQWpwZ15BbWU4MDUwMDg3NDQx._V1_.jpg',
#      'caption': {'plainText': 'Laundry (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Laundry', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Laundry', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ae0ef99b1c543438421',
#     'id': 'tt0969649',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sex, Lies, and Myspace', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sex, Lies, and Myspace',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58b77a66e59642343a7a5',
#     'id': 'tt10048394',
#     'primaryImage': {'id': 'rm633627392',
#      'width': 960,
#      'height': 642,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGVlMGQ4N2ItNDM4My00OTZhLWFkYjYtZTI0MmIzNTNmNmI2XkEyXkFqcGdeQXVyNjk1NzQxMTc@._V1_.jpg',
#      'caption': {'plainText': 'Veux-Tu (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Veux-Tu', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Veux-Tu', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58b81ef99b1c54343a9ff',
#     'id': 'tt10055682',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "It's Christmas Time", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "It's Christmas Time",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ba5b597b91eb943b38f',
#     'id': 'tt10080030',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Cry of the Sasquatch',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Cry of the Sasquatch',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58bb8971a4a15d643b89f',
#     'id': 'tt10091374',
#     'primaryImage': {'id': 'rm2298109952',
#      'width': 986,
#      'height': 660,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2ZmMDU3MWEtZDRjOS00ZTRlLWI5YmQtODk3YWFlZmZlYWE3XkEyXkFqcGdeQXVyMjYzMzY4ODU@._V1_.jpg',
#      'caption': {'plainText': 'O Desaparecimento de Scott Baio (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'O Desaparecimento de Scott Baio',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'O Desaparecimento de Scott Baio',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58c1d909c2ca78143d0c9',
#     'id': 'tt10160606',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Making It', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Making It', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None}]},
#  {'page': '2',
#   'next': '/titles?titleType=short&page=3&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e58c758a5a6a599f43e835',
#     'id': 'tt10217800',
#     'primaryImage': {'id': 'rm620390144',
#      'width': 505,
#      'height': 578,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTA4M2M5M2YtZmY4ZC00MGRjLTkyZDItZDQxYjdjNDIzMWYxXkEyXkFqcGdeQXVyNjU4MTIwMDQ@._V1_.jpg',
#      'caption': {'plainText': 'Devil My Cry (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Devil My Cry', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Devil My Cry', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 7,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cbda66e59642343f7db',
#     'id': 'tt10261122',
#     'primaryImage': {'id': 'rm720069632',
#      'width': 1142,
#      'height': 1600,
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2YzMWZkNWUtZDAxZi00M2M0LWEzZTItNWE0YTQ3NWRlMjlmXkEyXkFqcGdeQXVyOTk1NTEzOQ@@._V1_.jpg',
#      'caption': {'plainText': 'Mabbi (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Mabbi', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Mabbi', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cc978c012aa3443f961',
#     'id': 'tt10271174',
#     'primaryImage': {'id': 'rm4218119168',
#      'width': 1240,
#      'height': 1754,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTY3OTkxNTUtMTdkZS00MTM1LTliODctZjNhZTA2NzdkMDViXkEyXkFqcGdeQXVyMjIzNzIwOTA@._V1_.jpg',
#      'caption': {'plainText': "Cihangir'de Bi Ev (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Cihangir'de Bi Ev", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Cihangir'de Bi Ev",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 7,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cd378c012aa3443fbb5',
#     'id': 'tt10276570',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Honibloom Dreams', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Honibloom Dreams',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58ce58a5a6a599f440305',
#     'id': 'tt10287494',
#     'primaryImage': {'id': 'rm675374080',
#      'width': 666,
#      'height': 999,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjMwMWQ1MzktYjEzMy00ODE3LWJhNGEtNTg5MGMyM2ZkMTdlXkEyXkFqcGdeQXVyNTE1MDE2MzY@._V1_.jpg',
#      'caption': {'plainText': 'Provincial (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Provincial', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Provincial', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 3,
#      'year': 2012,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58cfd8a5a6a599f4408bb',
#     'id': 'tt10304504',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pants on Fire', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pants on Fire', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d1b8a5a6a599f441033',
#     'id': 'tt10326940',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Pretender', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Pretender', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d1dcffb8f2faa440e37',
#     'id': 'tt10326894',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Me Siento Rara', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Me Siento Rara', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d23b597b91eb9441105',
#     'id': 'tt10329140',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'No Pienso Ir', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'No Pienso Ir', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58d2595801a78bc4412e9',
#     'id': 'tt10333456',
#     'primaryImage': {'id': 'rm1881761024',
#      'width': 905,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDVkZDhjMDItMWE1Yi00MTEwLTkzMzAtNGQyODQ2ZmU1YjU0XkEyXkFqcGdeQXVyOTk1NTEzOQ@@._V1_.jpg',
#      'caption': {'plainText': 'Three Men And A Woman (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Three Men And A Woman', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Three Men And A Woman',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '3',
#   'next': '/titles?titleType=short&page=4&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e58e46971a4a15d64457d3',
#     'id': 'tt10522772',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Elevation', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Elevation', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e58effd735dff3f94483e9',
#     'id': 'tt10640186',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Flirt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Flirt', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 11,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58f1ccffb8f2faa4489ff',
#     'id': 'tt10660452',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Keynote', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Keynote', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e58fd2ef99b1c54344b6b3',
#     'id': 'tt10778776',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dt.Narubleachballimon-oh',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dt.Narubleachballimon-oh',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 22,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59002a66e59642344c393',
#     'id': 'tt10812150',
#     'primaryImage': {'id': 'rm572887041',
#      'width': 2000,
#      'height': 3000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjI0NjcxNTUtMTVjMy00ZTUxLWFkZGQtNjA0MmFkZDFkOTkxXkEyXkFqcGdeQXVyMjUxOTU0NTY@._V1_.jpg',
#      'caption': {'plainText': 'Was geschah - Man weiß es nicht (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Was geschah - Man weiß es nicht',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Was geschah - Man weiß es nicht',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59010cffb8f2faa44c657',
#     'id': 'tt10821254',
#     'primaryImage': {'id': 'rm2683277569',
#      'width': 450,
#      'height': 675,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTc3NzNhYTQtOGYyYy00ZDc1LTk2NzAtZWU0ZThhY2RmODRjXkEyXkFqcGdeQXVyMTAzMTQ3MTk@._V1_.jpg',
#      'caption': {'plainText': 'The Game Boys (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Game Boys', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Game Boys', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5903fb597b91eb944d177',
#     'id': 'tt10855024',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Escoffier', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Escoffier', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590898a5a6a599f44e627',
#     'id': 'tt10901258',
#     'primaryImage': {'id': 'rm994088449',
#      'width': 1080,
#      'height': 607,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOWRhMTBhNjktMDg4MS00MjEwLThhNGEtYmVkODM4YjY3Njg4XkEyXkFqcGdeQXVyMTY3NjcxMTA@._V1_.jpg',
#      'caption': {'plainText': 'Don Striano, Lori Hammel, and Kate Katcher in Planning Ahead (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Planning Ahead', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Planning Ahead', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 21,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5909b95801a78bc44ea47',
#     'id': 'tt10912134',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'A Good Day for Turkey', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'A Good Day for Turkey',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 14,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590a0e1a8ddbd9644ea75',
#     'id': 'tt10917278',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Go Go Cowboy Rangers', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Go Go Cowboy Rangers',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 31,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '4',
#   'next': '/titles?titleType=short&page=5&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e590a4d735dff3f944eb0d',
#     'id': 'tt10917444',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Breakfast in Bedlam', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Breakfast in Bedlam',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 5,
#      'month': 9,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590e8e1a8ddbd9644fc2d',
#     'id': 'tt10963232',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Invented Less', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Invented Less', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e590fe78c012aa3444fedd',
#     'id': 'tt10975444',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Librarians', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Librarians', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 30,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5910ad735dff3f9450405',
#     'id': 'tt10984518',
#     'primaryImage': {'id': 'rm2828188161',
#      'width': 2430,
#      'height': 1280,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDM5Y2NhNWItY2ViMy00YjQ3LTg3MWItMjMyYmJlNTU1ZDZmXkEyXkFqcGdeQXVyNjc5MDI5MDc@._V1_.jpg',
#      'caption': {'plainText': 'Attic (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Attic', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Attic', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59114909c2ca781450581',
#     'id': 'tt10990990',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Strange People Strange Times',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Strange People Strange Times',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59139cffb8f2faa450f3d',
#     'id': 'tt11016412',
#     'primaryImage': {'id': 'rm1045072897',
#      'width': 586,
#      'height': 780,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZWY5NWY4ZmItODUwYy00ZDkwLThlM2MtMzFhODg0Njg2ZWMwXkEyXkFqcGdeQXVyMjAwMTQ0NDM@._V1_.jpg',
#      'caption': {'plainText': 'Vit Fic in Silver Rainbow (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Silver Rainbow', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Silver Rainbow', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e592178a5a6a599f454845',
#     'id': 'tt11166332',
#     'primaryImage': {'id': 'rm1338542337',
#      'width': 1307,
#      'height': 729,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTEzOTNlNzQtNTA2OS00OTE4LThmZjUtM2Y0NTRlOTZiOGZjXkEyXkFqcGdeQXVyMzg1OTcwNjg@._V1_.jpg',
#      'caption': {'plainText': 'Racine Cubique (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Racine Cubique', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Racine Cubique', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 8,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e592458a5a6a599f4553ff',
#     'id': 'tt11193828',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'New Fish', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'New Fish', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59247cffb8f2faa45525d',
#     'id': 'tt11199398',
#     'primaryImage': {'id': 'rm1779140865',
#      'width': 482,
#      'height': 720,
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjI0MTcwZTAtM2M1Ny00NDVkLTg1NjYtNDU4MDk0ZDQ1NDAwXkEyXkFqcGdeQXVyNjc5MDI5MDc@._V1_.jpg',
#      'caption': {'plainText': 'The Suitors (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Suitors', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Suitors', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 24,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5932fa66e596423458973',
#     'id': 'tt11349126',
#     'primaryImage': {'id': 'rm1522502913',
#      'width': 545,
#      'height': 482,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOTdmYzY3MzYtYTQ3Mi00NjA4LWFjMzAtMDUxNWUwMTcyOGRkXkEyXkFqcGdeQXVyMTM3NzI3NjQ@._V1_.jpg',
#      'caption': {'plainText': "One Day Mario Woke Up and Decided to Take a Shit because hey he's Mario (2009)",
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "One Day Mario Woke Up and Decided to Take a Shit because hey he's Mario",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "One Day Mario Woke Up and Decided to Take a Shit because hey he's Mario",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '5',
#   'next': '/titles?titleType=short&page=6&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e59343ef99b1c543458dc1',
#     'id': 'tt11363598',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Pas de Quatre', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Pas de Quatre', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59365ef99b1c5434595bb',
#     'id': 'tt11384378',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fantasy Hole', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fantasy Hole', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59366d735dff3f9459791',
#     'id': 'tt11384466',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Christmas Greeting from Skinny Bitch Jesus Meeting!',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Christmas Greeting from Skinny Bitch Jesus Meeting!',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5939f909c2ca78145a487',
#     'id': 'tt11422910',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Great Hatsby Stakeout',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Great Hatsby Stakeout',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593ad8a5a6a599f45ab7f',
#     'id': 'tt11432582',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Nic se nestalo', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Nic se nestalo', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e593dad735dff3f945b441',
#     'id': 'tt11460056',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Prestige', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Prestige', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e59401d735dff3f945bda5',
#     'id': 'tt11488458',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Secret', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Secret', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5944f78c012aa3445cef7',
#     'id': 'tt11541134',
#     'primaryImage': {'id': 'rm3467870465',
#      'width': 675,
#      'height': 1000,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTZhZjIwMDctMWI5OC00YmM5LTk4YzItMGU4YmQxMjk4NTM5XkEyXkFqcGdeQXVyNDAxNzk0OQ@@._V1_.jpg',
#      'caption': {'plainText': 'Never Been Roofied (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Never Been Roofied', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Never Been Roofied',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 4,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e594b0e1a8ddbd9645e921',
#     'id': 'tt11608510',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Fiesshta', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Fiesshta', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e594e5ef99b1c54345f4f5',
#     'id': 'tt11640404',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Neighbours', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Neighbours', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '6',
#   'next': '/titles?titleType=short&page=7&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e594f978c012aa3445f911',
#     'id': 'tt11653902',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Flying Circus', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Flying Circus', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59583d735dff3f9461cb7',
#     'id': 'tt11744416',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "Life's a Bitch", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "Life's a Bitch", '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5958e8a5a6a599f46224b',
#     'id': 'tt11754058',
#     'primaryImage': {'id': 'rm269583617',
#      'width': 1116,
#      'height': 968,
#      'url': 'https://m.media-amazon.com/images/M/MV5BOWMxNTNlM2YtZGZkZi00MWEzLWExYzYtMTNmY2Q2M2M0OTI3XkEyXkFqcGdeQXVyMTEzNDUxNDQ4._V1_.jpg',
#      'caption': {'plainText': 'O Comprador de Promessas (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'O Comprador de Promessas',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'O Comprador de Promessas',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5959595801a78bc4622cf',
#     'id': 'tt11757022',
#     'primaryImage': {'id': 'rm3790518785',
#      'width': 993,
#      'height': 750,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDAyMWIxNzMtMjRhNC00ODc0LWIzZmUtYTZiOGYxODcxNDdiXkEyXkFqcGdeQXVyMTExNzc3OTU1._V1_.jpg',
#      'caption': {'plainText': 'Sara Iuretig in Missione Natale (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Missione Natale', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Missione Natale',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 25,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59596d8f3c0931e462107',
#     'id': 'tt11758696',
#     'primaryImage': {'id': 'rm4290425857',
#      'width': 366,
#      'height': 521,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGViNDRiYTAtYzU5NS00YmYxLTk2OGEtMDQ2NzNlMjliNGZjXkEyXkFqcGdeQXVyMzg0NzY4Mzc@._V1_.jpg',
#      'caption': {'plainText': 'Sofia Brattwall in Trångt & Jobbigt (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Trångt & Jobbigt', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Trångt & Jobbigt',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e595be95801a78bc462d01',
#     'id': 'tt11784286',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The CaramelDansen', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The CaramelDansen',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 3,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e595be971a4a15d6462b9d',
#     'id': 'tt11784298',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Destroying a Clock Radio',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Destroying a Clock Radio',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 9,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e595bf8a5a6a599f462e73',
#     'id': 'tt11785426',
#     'primaryImage': {'id': 'rm2498673409',
#      'width': 940,
#      'height': 940,
#      'url': 'https://m.media-amazon.com/images/M/MV5BODc2MmU4MTQtN2NkYS00NzhkLTlkOTAtNjE2YWJiNjMyODUwXkEyXkFqcGdeQXVyOTE4ODkxMzI@._V1_.jpg',
#      'caption': {'plainText': 'Survivor Boy (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Survivor Boy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Survivor Boy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 6,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59606d735dff3f9463cfd',
#     'id': 'tt11832636',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Word Choice', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Word Choice', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5960db597b91eb9463d07',
#     'id': 'tt1183935',
#     'primaryImage': {'id': 'rm3785982208',
#      'width': 1750,
#      'height': 2484,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTI5NDUwMzM2M15BMl5BanBnXkFtZTcwNTQxMzk3Mw@@._V1_.jpg',
#      'caption': {'plainText': 'Hit the Big Time (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Hit the Big Time', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Hit the Big Time',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '7',
#   'next': '/titles?titleType=short&page=8&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e59625e1a8ddbd9646452f',
#     'id': 'tt11853448',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Ultimate Challenge', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Ultimate Challenge',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5962a971a4a15d6464643',
#     'id': 'tt11855252',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Hotel', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Hotel', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5962b78c012aa34464411',
#     'id': 'tt11857356',
#     'primaryImage': {'id': 'rm298760193',
#      'width': 1204,
#      'height': 1695,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMmIxMjkzYTUtY2Y2Zi00YWMwLWI2MzktYThkZjE1YzQ5OGNlXkEyXkFqcGdeQXVyMjE1Mzg1NTU@._V1_.jpg',
#      'caption': {'plainText': 'Das Winter Garden (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Das Winter Garden', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Das Winter Garden',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5969495801a78bc46622d',
#     'id': 'tt11926930',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "This Girl's Life", '__typename': 'TitleText'},
#     'originalTitleText': {'text': "This Girl's Life",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 5,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e596c28a5a6a599f466ebf',
#     'id': 'tt11957652',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Performer. Audience. Fuck Off.',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Performer. Audience. Fuck Off.',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 26,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e597e778c012aa3446b19b',
#     'id': 'tt12153174',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Rockton Manor Studios', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Rockton Manor Studios',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59860cffb8f2faa46d0fd',
#     'id': 'tt12236306',
#     'primaryImage': {'id': 'rm2689183745',
#      'width': 1046,
#      'height': 887,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTI0NTkwYmEtODQwMi00M2U0LTg2M2MtM2NiZTY0MTU3NzE0XkEyXkFqcGdeQXVyMjI3NDU1NTQ@._V1_.jpg',
#      'caption': {'plainText': 'Valérie Fortin in Roule ta boule (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Roule ta boule', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Roule ta boule', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 17,
#      'month': 12,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e59863d8f3c0931e46d2df',
#     'id': 'tt1224141',
#     'primaryImage': {'id': 'rm1971358464',
#      'width': 2770,
#      'height': 2163,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjAzNDAyODI4OV5BMl5BanBnXkFtZTcwMzAxMDA0Mg@@._V1_.jpg',
#      'caption': {'plainText': 'The Figure of Authority (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Figure of Authority',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Figure of Authority',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5987ccffb8f2faa46d819',
#     'id': 'tt12257166',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
# ...
#     'id': 'tt1377671',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Clumsy', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Clumsy', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 29,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13a971a4a15d6490ad3',
#     'id': 'tt1377515',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Love Connection', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Love Connection',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 23,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13aa66e5964234909b9',
#     'id': 'tt1377686',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Equal Rights', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Equal Rights', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13acffb8f2faa490adb',
#     'id': 'tt1377487',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Hangman', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Hangman', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13b95801a78bc490dbf',
#     'id': 'tt1377494',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Immaculate Reception', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Immaculate Reception',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13b95801a78bc490e05',
#     'id': 'tt1377664',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Broken Ring', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Broken Ring', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13bd8f3c0931e490d0f',
#     'id': 'tt1377438',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'El bluff', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'El bluff', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 20,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '49',
#   'next': '/titles?titleType=short&page=50&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5a13be1a8ddbd96490d2f',
#     'id': 'tt1377587',
#     'primaryImage': {'id': 'rm4122035968',
#      'width': 4959,
#      'height': 7012,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzY1YzY0MDMtNzA0NC00ZDM0LWJiNmQtMDg2ZDkyNTEyOWY0XkEyXkFqcGdeQXVyMjA1NTU2OTc@._V1_.jpg',
#      'caption': {'plainText': 'Jade Goe and Mark Ammann in Sweet Tooth (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sweet Tooth', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sweet Tooth', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13bef99b1c543490aeb',
#     'id': 'tt1377673',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Cooties', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Cooties', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13c971a4a15d6490b75',
#     'id': 'tt1377771',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Red State Blues', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Red State Blues',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13cb597b91eb9490849',
#     'id': 'tt1377768',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Quiet', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Quiet', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13d95801a78bc490e61',
#     'id': 'tt1377799',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sunshine', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sunshine', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13d971a4a15d6490bd3',
#     'id': 'tt1377705',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Guitar', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Guitar', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13dd8f3c0931e490d79',
#     'id': 'tt1377742',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Milk', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Milk', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13dd8f3c0931e490da1',
#     'id': 'tt1377609',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': "What's Your Neighbor Cooking?",
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': "What's Your Neighbor Cooking?",
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13eb597b91eb94908db',
#     'id': 'tt1377417',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Acting for the Greenscreen',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Acting for the Greenscreen',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': None,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13ecffb8f2faa490bf3',
#     'id': 'tt1377654',
#     'primaryImage': {'id': 'rm309123841',
#      'width': 862,
#      'height': 489,
#      'url': 'https://m.media-amazon.com/images/M/MV5BMmZkNDVlYjUtYmQwMC00NDc4LWIxODgtNDAwZmNiNDExNDMwXkEyXkFqcGdeQXVyMTA5NzI2MQ@@._V1_.jpg',
#      'caption': {'plainText': 'Sally Jackson, Allison Allen, Kelly Jackson, Pam Henderson, Anita Tschurr, and Barbara Ann Kelso in Bad Hair Day: A Murder Mystery (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Bad Hair Day: A Murder Mystery',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Bad Hair Day: A Murder Mystery',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 16,
#      'month': 1,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]},
#  {'page': '50',
#   'next': '/titles?titleType=short&page=61e5a143d8f3c0931e490f0f&year=2009&genre=Comedy',
#   'entries': 10,
#   'results': [{'_id': '61e5a13ee1a8ddbd96490dc7',
#     'id': 'tt1377657',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'The Big Hang-Up', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'The Big Hang-Up',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 1,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13f971a4a15d6490c4d',
#     'id': 'tt1377678',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Deadline: Meet the Staff',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Deadline: Meet the Staff',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': None,
#      'month': 4,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13f971a4a15d6490c4f',
#     'id': 'tt1377722',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Ladies Who Lunch', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Ladies Who Lunch',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13fa66e596423490b27',
#     'id': 'tt1377770',
#     'primaryImage': {'id': 'rm3308884481',
#      'width': 3892,
#      'height': 2586,
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjg0OTQwMTAtOWU2Ny00NjU4LWE3MGQtMjIxYzA5OTI3OTI4XkEyXkFqcGdeQXVyMjA2MjE4OTE@._V1_.jpg',
#      'caption': {'plainText': 'Reality Survivor (2009)',
#       '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Reality Survivor', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Reality Survivor',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a13fb597b91eb9490927',
#     'id': 'tt1377790',
#     'primaryImage': {'id': 'rm2120452864',
#      'width': 1583,
#      'height': 2185,
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzYyMjk5MjE2OV5BMl5BanBnXkFtZTcwNTU5NTI0Mg@@._V1_.jpg',
#      'caption': {'plainText': 'Sperfect (2009)', '__typename': 'Markdown'},
#      '__typename': 'Image'},
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Sperfect', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Sperfect', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 19,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a13fef99b1c543490bf7',
#     'id': 'tt1377681',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Dirty Laundry', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Dirty Laundry', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 18,
#      'month': 6,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a143909c2ca781490b8b',
#     'id': 'tt1378178',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'All Broken Up', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'All Broken Up', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 8,
#      'month': 3,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a143971a4a15d6490d6f',
#     'id': 'tt1378267',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'In Dreams', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'In Dreams', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': None},
#    {'_id': '61e5a143cffb8f2faa490d53',
#     'id': 'tt1378214',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Chlamydia Is Not a Flower',
#      '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Chlamydia Is Not a Flower',
#      '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 10,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}},
#    {'_id': '61e5a143d8f3c0931e490f0f',
#     'id': 'tt1378200',
#     'primaryImage': None,
#     'titleType': {'text': 'Short',
#      'id': 'short',
#      'isSeries': False,
#      'isEpisode': False,
#      '__typename': 'TitleType'},
#     'titleText': {'text': 'Brain Freeze', '__typename': 'TitleText'},
#     'originalTitleText': {'text': 'Brain Freeze', '__typename': 'TitleText'},
#     'releaseYear': {'year': 2009, 'endYear': None, '__typename': 'YearRange'},
#     'releaseDate': {'day': 2,
#      'month': 2,
#      'year': 2009,
#      '__typename': 'ReleaseDate'}}]}]

# %%
#unificamos ambas listas con lo sacado de la API
lista_json_anios = lista_json_anios + lista_json_anios1 + lista_json_anios2 + lista_json_anios3

# %%
#creamos una función para sacar los datos que queremos de los json

def busqueda_info (lista):
    datos = []
    #un primer bucle para iterar por cada año
    for num in range (0,len(lista)):
        #iteramos por cada película
        for pelicula in lista[num]["results"]:
            lista_para_tupla = []
            lista_para_tupla.append(pelicula["titleType"]["text"])
            lista_para_tupla.append(pelicula['originalTitleText']['text'])
            
            try: #si el valor de año es nulo cogemos el otro dato de año que tiene el json
                lista_para_tupla.append(pelicula["releaseDate"]["year"])
            except:
                lista_para_tupla.append(pelicula["releaseYear"]["year"])

            try:#si el valor de mes es nulo, appendeamos 0
                lista_para_tupla.append(pelicula['releaseDate']['month'])
            except:
                lista_para_tupla.append(0)

            lista_para_tupla.append(pelicula['id'])

            #convertimos en tupla
            tupla = tuple(lista_para_tupla)
            
            #añadimos la tupla a la lista 
            datos.append(tupla)
            
                
    return datos

# %%
#llamamos a la funcion anterior

datos_final = []

fin =len(lista_json_anios)

for num in range(0,fin):
    lista3 = busqueda_info(lista_json_anios[num])
    datos_final = datos_final + lista3

datos_final
# Out:
# [('Movie', 'This Wretched Life', 2010, 7, 'tt0331312'),
#  ('Movie', 'Blind Sided', 2010, 0, 'tt0337882'),
#  ('Movie', "Anderson's Cross", 2010, 5, 'tt0393049'),
#  ('Movie', 'Tangled', 2010, 12, 'tt0398286'),
#  ('Movie', 'Venus & Vegas', 2010, 11, 'tt0423474'),
#  ('Movie', 'Dinner for Schmucks', 2010, 8, 'tt0427152'),
#  ('Movie', 'Toy Story 3', 2010, 6, 'tt0435761'),
#  ('Movie', 'Diary of a Bad Lad', 2010, 2, 'tt0449005'),
#  ('Movie', 'Scott Pilgrim vs. the World', 2010, 11, 'tt0446029'),
#  ('Movie', 'El hada buena - Una fábula peronista', 2010, 4, 'tt0454155'),
#  ('Movie', 'Guns, Drugs and Dirty Money', 2011, None, 'tt0464032'),
#  ('Movie', 'Piranha 3D', 2010, 9, 'tt0464154'),
#  ('Movie', 'Harlem Hostel', 2010, 2, 'tt0469094'),
#  ('Movie', 'Stiffs', 2010, None, 'tt0476023'),
#  ('Movie', 'Barry Munday', 2010, 3, 'tt0482461'),
#  ('Movie', 'A Woman Is a Woman', 2010, None, 'tt0483839'),
#  ('Movie', 'PrimeMates', 2010, 1, 'tt0490199'),
#  ('Movie', 'Ramona and Beezus', 2010, 7, 'tt0493949'),
#  ('Movie', 'Furry Vengeance', 2010, 7, 'tt0492389'),
#  ('Movie', 'Love & Other Drugs', 2011, 1, 'tt0758752'),
#  ('Movie', 'Waste of Space', 2010, 4, 'tt0765485'),
#  ('Movie', 'The Guardians', 2010, None, 'tt0800054'),
#  ('Movie', "It's Kind of a Funny Story", 2010, 10, 'tt0804497'),
#  ('Movie', 'Tooth Fairy', 2010, 1, 'tt0808510'),
#  ('Movie', 'Plumíferos - Aventuras voladoras', 2010, 2, 'tt0811021'),
#  ('Movie', "She's Out of My League", 2010, 6, 'tt0815236'),
#  ('Movie', "Valentine's Day", 2010, 2, 'tt0817230'),
#  ('Movie', 'Flipped', 2010, 9, 'tt0817177'),
#  ('Movie', 'Return to Yucca Flats: Desert Man-Beast', 2010, 1, 'tt0826532'),
#  ('Movie', 'The Kids Are All Right', 2010, 12, 'tt0842926'),
#  ('Movie', 'Gangster Exchange', 2010, 2, 'tt0846004'),
#  ('Movie', 'Fauj Mein Mauj', 2010, None, 'tt0847735'),
#  ('Movie', '2001 Maniacs: Field of Screams', 2010, 2, 'tt0858411'),
#  ('Movie', 'Wide Blue Yonder', 2012, 5, 'tt0858500'),
#  ('Movie', 'Zenitram', 2010, 5, 'tt0861747'),
#  ('Movie', 'Touch Wood', 2010, 0, 'tt0870208'),
#  ('Movie', 'Please Give', 2010, 7, 'tt0878835'),
#  ('Movie', 'AIR: The Musical', 2010, 4, 'tt0882741'),
#  ('Movie', 'Repo', 2010, None, 'tt0887161'),
#  ('Movie', 'The Switch', 2010, 10, 'tt0889573'),
#  ('Movie', 'Letters to Juliet', 2010, 6, 'tt0892318'),
#  ('Movie', 'Shrek Forever After', 2010, 7, 'tt0892791'),
#  ('Movie', 'How to Train Your Dragon', 2010, 3, 'tt0892769'),
#  ('Movie', "Movin' In", 2010, 8, 'tt0910926'),
#  ('Movie', 'Jackboots on Whitehall', 2010, 10, 'tt0915463'),
#  ('Movie', 'De gelukkige huisvrouw', 2010, 4, 'tt0920459'),
#  ('Movie', 'Pizza with Bullets', 2021, None, 'tt0924266'),
#  ('Movie', 'The Penthouse', 2010, 3, 'tt0929618'),
#  ('Movie', 'Private Security Officer: Los Angeles', 2010, 12, 'tt0960827'),
#  ('Movie', 'Made in Romania', 2010, None, 'tt0963177'),
#  ('Movie', "Pushin' Up Daisies", 2010, 6, 'tt0964544'),
#  ('Movie', "L'imbroglio nel lenzuolo", 2010, 6, 'tt0965429'),
#  ('Movie', 'The Chosen One', 2010, 9, 'tt0970926'),
#  ('Movie', 'Little Fockers', 2010, 12, 'tt0970866'),
#  ('Movie', 'Lottery Ticket', 2010, 8, 'tt0979434'),
#  ('Movie', 'Multiple Sarcasms', 2010, 4, 'tt0984210'),
#  ('Movie', 'Adventure Scouts', 2010, 10, 'tt0994917'),
#  ('Movie', 'Megamind', 2010, 12, 'tt1001526'),
#  ('Movie', 'The Steamroom', 2010, None, 'tt1008046'),
#  ('Movie', 'Knight and Day', 2010, 7, 'tt1013743'),
#  ('Movie', 'Dylan Dog: Dead of Night', 2011, 4, 'tt1013860'),
#  ('Movie', 'Prime of Your Life', 2010, None, 'tt1016226'),
#  ('Movie', 'Jeffie Was Here', 2010, None, 'tt1019442'),
#  ('Movie', 'Piel de Lija', 2010, 5, 'tt10229082'),
#  ('Movie', 'RiffTrax: High School Musical', 2010, None, 'tt10263222'),
#  ('Movie', 'The Bounty Hunter', 2010, 4, 'tt1038919'),
#  ('Movie', 'Let the Game Begin', 2010, 1, 'tt1041778'),
#  ('Movie', 'Not Another B Movie', 2015, None, 'tt1043757'),
#  ('Movie', 'Aaj Kal', 2010, 2, 'tt1047439'),
#  ('Movie', 'House Broken', 2011, 7, 'tt1054631'),
#  ('Movie', 'As Melhores Coisas do Mundo', 2010, 4, 'tt1054677'),
#  ('Movie', 'Life as We Know It', 2010, 10, 'tt1055292'),
#  ('Movie', 'Spud', 2010, 12, 'tt1059969'),
#  ('Movie', "For Christ's Sake", 2011, 12, 'tt1067107'),
#  ('Movie', 'The Vampires of Zanzibar', 2010, 1, 'tt1067090'),
#  ('Movie', "Quincas Berro d'Água", 2010, 5, 'tt1068962'),
#  ('Movie', 'Habana Eva', 2010, 5, 'tt1069246'),
#  ('Movie', 'Good Intentions', 2010, 3, 'tt1070781'),
#  ('Movie', 'Elvis & Madona', 2011, 9, 'tt1071211'),
#  ('Movie', 'Jelly', 2010, None, 'tt1071877'),
#  ('Movie', 'See You in September', 2010, 4, 'tt1073246'),
#  ('Movie', 'Psychosomatika', 2011, 12, 'tt1078591'),
#  ('Movie', '10 Years Later', 2010, 3, 'tt1079974'),
#  ('Movie', 'Jerry Cotton', 2010, 3, 'tt1080019'),
#  ('Movie', 'The University Days of a Dog', 2010, 9, 'tt10912908'),
#  ('Movie', 'Oru Avadhikaalam', 2010, None, 'tt10940482'),
#  ('Movie', 'Amor en tránsito', 2010, 12, 'tt1095399'),
#  ('Movie', 'Trevor Boris: Over Easy', 2010, None, 'tt10966982'),
#  ('Movie', 'Les princes de la nuit', 2010, 0, 'tt1101041'),
#  ('Movie', 'Peep World', 2011, 3, 'tt1103273'),
#  ('Movie', 'Killers', 2010, 6, 'tt1103153'),
#  ('Movie', 'Cornhole: The Movie', 2010, 5, 'tt1103269'),
#  ('Movie', 'Something Like a Business', 2010, None, 'tt1103255'),
#  ('Movie', 'Dirty Girl', 2011, 7, 'tt1107319'),
#  ('Movie', 'Mars', 2010, 12, 'tt1109488'),
#  ('Movie', 'Prigode kmeta Pajota', 2010, 3, 'tt11157618'),
#  ('Movie', 'Jackass 3D', 2010, 10, 'tt1116184'),
#  ('Movie', 'A Fork in the Road', 2010, 4, 'tt1117386'),
#  ('Movie', 'Love Ranch', 2011, 1, 'tt1125929'),
#  ('Movie', 'Morning Glory', 2011, 1, 'tt1126618'),
#  ('Movie', 'Mission London', 2010, 4, 'tt1127702'),
#  ('Movie', 'Miss Nobody', 2011, 6, 'tt1129427'),
#  ('Movie', 'Swishbucklers', 2010, 5, 'tt1130092'),
#  ('Movie',
#   "Maria Costa's Macho Men and the Women Who Love Them",
#   2010,
#   1,
#   'tt1131737'),
#  ('Movie', 'Donkeys', 2010, 10, 'tt1134846'),
#  ('Movie', 'Undercover Rascals', 2010, 10, 'tt11361770'),
#  ('Movie', 'The Story of F***', 2010, 10, 'tt1137482'),
#  ('Movie', 'Holyman Undercover', 2010, 4, 'tt1144546'),
#  ('Movie', 'Rudolfa mantojums', 2010, 1, 'tt1149607'),
#  ('Movie', 'El kaserón', 2010, 4, 'tt1149619'),
#  ('Movie', 'Heels', 2012, 2, 'tt1160371'),
#  ('Movie', 'Una hora más en Canarias', 2010, 7, 'tt1161411'),
#  ('Movie', 'Harvey Putter and the Ridiculous Premise', 2010, 7, 'tt1161421'),
#  ('Movie', 'Sint', 2010, 11, 'tt1167675'),
#  ('Movie', 'Boston Girls', 2010, None, 'tt1168696'),
#  ('Movie', 'Qué Sera, Sera', 2010, 9, 'tt11704124'),
#  ('Movie', 'The Myth of the American Sleepover', 2011, 4, 'tt1174042'),
#  ('Movie', 'The Four-Faced Liar', 2010, 1, 'tt1174693'),
#  ('Movie', 'Acorazado', 2012, 6, 'tt1174933'),
#  ('Movie', 'Failing Better Now', 2010, 5, 'tt1176728'),
#  ('Movie',
#   "Les aventures extraordinaires d'Adèle Blanc-Sec",
#   2010,
#   4,
#   'tt1179025'),
#  ('Movie', 'Todas las canciones hablan de mí', 2010, 12, 'tt1179927'),
#  ('Movie', 'You Will Meet a Tall Dark Stranger', 2010, 12, 'tt1182350'),
#  ('Movie', 'Dulha Mil Gaya', 2010, 1, 'tt1182884'),
#  ('Movie', 'Stag Night of the Dead', 2010, 10, 'tt1183489'),
#  ('Movie', 'Mr. Nice', 2011, 9, 'tt1183911'),
#  ('Movie', 'At Best Derivative', 2010, 1, 'tt1185040'),
#  ('Movie', 'When in Rome', 2010, 6, 'tt1185416'),
#  ('Movie', 'Kung Fu Magoo', 2010, 5, 'tt1186365'),
#  ('Movie', 'Prince of Swine', 2011, 9, 'tt1186665'),
#  ('Movie', 'Toonpur Ka Superrhero', 2010, 12, 'tt1189006'),
#  ('Movie', 'Woodshop', 2010, 9, 'tt1189267'),
#  ('Movie', 'Hello Darling', 2010, 8, 'tt1191118'),
#  ('Movie', 'My Own Love Song', 2010, 4, 'tt1193507'),
#  ('Movie', 'Casino Jack', 2010, 12, 'tt1194417'),
#  ('Movie', 'Jaane Kahan Se Aayi Hai', 2010, 4, 'tt1194232'),
#  ('Movie', 'Crazy on the Outside', 2010, 1, 'tt1196134'),
#  ('Movie', 'Diary of a Wimpy Kid', 2010, 3, 'tt1196141'),
#  ('Movie', 'Cemetery Junction', 2021, 9, 'tt1196204'),
#  ('Movie', 'You, Only Better...', 2010, None, 'tt1197633'),
#  ('Movie', 'One Too Many Mornings', 2010, 1, 'tt1200274'),
#  ('Movie', 'Why Am I in a Box?', 2010, 12, 'tt1204984'),
#  ('Movie',
#   "Maverick and Ariel's First Ever Ever Movie Hollywood or Else... (Ang pinakamahabang title ng movie sa balat ng lupa)",
#   2010,
#   4,
#   'tt1204784'),
#  ('Movie', 'Las Angeles', 2010, 0, 'tt1206083'),
#  ('Movie', 'Next Time Ned', 2010, 5, 'tt1207009'),
#  ('Movie', 'Van Von Hunter', 2010, 7, 'tt1209368'),
#  ('Movie', 'Snatched!', 2010, 7, 'tt1210047'),
#  ('Movie', 'Creative Differences', 2012, 4, 'tt1212077'),
#  ('Movie', 'One Wish', 2010, 11, 'tt1212434'),
#  ('Movie', 'The Back-up Plan', 2010, 6, 'tt1212436'),
#  ('Movie', 'An Invisible Sign', 2011, 4, 'tt1212454'),
#  ('Movie', 'Alpha and Omega', 2011, 2, 'tt1213012'),
#  ('Movie', 'Gerald', 2010, None, 'tt1213900'),
#  ('Movie', 'The Wrong Hands', 2010, 11, 'tt1214993'),
#  ('Movie', 'Tug', 2013, 2, 'tt1215486'),
#  ('Movie', 'Leap Year', 2010, 7, 'tt1216492'),
#  ('Movie', 'Yeah, I Blew Up the Internet', 2010, None, 'tt12169534'),
#  ('Movie', 'Dou Khahar', 2010, 9, 'tt12171216'),
#  ('Movie', "Stacy's Mom", 2010, 7, 'tt1220227'),
#  ('Movie', "Henry's Crime", 2011, 4, 'tt1220888'),
#  ('Movie', "Cupid's Arrow", 2010, None, 'tt1220625'),
#  ('Movie', 'Hard Breakers', 2011, 1, 'tt1220627'),
#  ('Movie', 'Get Him to the Greek', 2010, 7, 'tt1226229'),
#  ('Movie', 'Alphonso Bow', 2010, 2, 'tt1226737'),
#  ('Movie', "Three Chris's", 2010, None, 'tt1227566'),
#  ('Movie', 'Puss', 2010, 8, 'tt1230196'),
#  ('Movie', 'Mad Mad Wagon Party', 2010, 8, 'tt1231289'),
#  ('Movie', 'Hot Tub Time Machine', 2010, 3, 'tt1231587'),
#  ('Movie', 'Due Date', 2010, 11, 'tt1231583'),
#  ('Movie', 'Drones', 2011, 4, 'tt1232775'),
#  ('Movie', "My Girlfriend's Back", 2010, None, 'tt1233328'),
#  ('Movie', 'Greenberg', 2010, 7, 'tt1234654'),
#  ('Movie', 'Heterosexuals', 2010, None, 'tt1235430'),
#  ('Movie', 'Wild Target', 2010, 6, 'tt1235189'),
#  ('Movie', 'How to Make Love to a Woman', 2010, None, 'tt1241017'),
#  ('Movie', 'Khurchi Samrat', 2010, 10, 'tt12415570'),
#  ('Movie', 'Les nuits de Sister Welsh', 2010, 10, 'tt1242520'),
#  ('Movie', 'The Mikado Project', 2010, 5, 'tt1243631'),
#  ('Movie', 'Hisss', 2010, 10, 'tt1244093'),
#  ('Movie', 'RED', 2010, 10, 'tt1245526'),
#  ('Movie', 'High School', 2012, 11, 'tt1247667'),
#  ('Movie', 'Friendship!', 2010, 1, 'tt1247657'),
#  ('Movie', 'Norman', 2010, 6, 'tt1247683'),
#  ('Movie', 'Kick-Ass', 2010, 4, 'tt1250777'),
#  ('Movie', 'Malta Force', 2010, 0, 'tt12506072'),
#  ('Movie', 'The Making of Plus One', 2010, None, 'tt1251756'),
#  ('Movie', 'Czukor Show', 2010, 4, 'tt1254724'),
#  ('Movie', 'Hello Lonesome', 2010, None, 'tt1258201'),
#  ('Movie', 'SoulBoy', 2010, 9, 'tt1259227'),
#  ('Movie', "L'autre Dumas", 2010, 2, 'tt1259591'),
#  ('Movie', 'Carne de neón', 2011, 1, 'tt1259570'),
#  ('Movie', 'Sex and the City 2', 2010, 5, 'tt1261945'),
#  ('Movie', 'Coasting', 2010, 3, 'tt1262876'),
#  ('Movie', "Pickin' & Grinnin'", 2010, 4, 'tt1262941'),
#  ('Movie', 'Dead in the Head', 2010, None, 'tt1262983'),
#  ('Movie', 'Screwball: The Ted Whitfield Story', 2010, 10, 'tt1262978'),
#  ('Movie', 'Kao rani mraz', 2010, 4, 'tt1264889'),
#  ('Movie', 'Quartier lointain', 2011, 7, 'tt1266037'),
#  ('Movie', 'Boxhagener Platz', 2010, 3, 'tt1266025'),
#  ('Movie', 'BoyBand', 2010, 6, 'tt1266615'),
#  ('Movie', 'Lunatics, Lovers & Poets', 2010, 4, 'tt1268241'),
#  ('Movie', 'The Prankster', 2010, 0, 'tt1268981'),
#  ('Movie', 'Rogues Gallery', 2012, 5, 'tt1268987'),
#  ('Movie', 'Ditching Party', 2010, None, 'tt1270283'),
#  ('Movie', "Ashley's Ashes", 2010, None, 'tt1270288'),
#  ('Movie', 'Hatchet II', 2013, 7, 'tt1270835'),
#  ('Movie', 'Starlight & Superfish', 2010, 6, 'tt1270791'),
#  ('Movie', 'Belka i Strelka. Zvyozdnye sobaki', 2010, 3, 'tt1272051'),
#  ('Movie', 'Art House', 2010, 4, 'tt1273194'),
#  ('Movie', 'The Spy Next Door', 2010, 2, 'tt1273678'),
#  ('Movie', 'Kill the Habit', 2010, 2, 'tt1274285'),
#  ('Movie', 'Matrimoni e altri disastri', 2010, 4, 'tt1274297'),
#  ('Movie', 'The Tempest', 2011, 1, 'tt1274300'),
#  ('Movie', 'Olsen-banden på de bonede gulve', 2010, 10, 'tt1274275'),
#  ('Movie', 'La mosquitera', 2010, 11, 'tt1274645'),
#  ('Movie', 'Breast Picture', 2010, 6, 'tt1274639'),
#  ('Movie', 'References', 2010, 1, 'tt1277144'),
#  ('Movie', 'California Tango', 2010, 4, 'tt1277398'),
#  ('Movie', 'Basile: Growing Up Greek in America II', 2010, None, 'tt12776826'),
#  ('Movie', 'Sound of Noise', 2011, 3, 'tt1278449'),
#  ('Movie', 'Banglar King Kong', 2010, 6, 'tt12798342'),
#  ('Movie', 'Date Night', 2010, 5, 'tt1279935'),
#  ('Movie', 'Easy A', 2011, 2, 'tt1282140'),
#  ('Movie', 'Senior Mandrake', 2010, 1, 'tt12828580'),
#  ('Movie', 'A Numbers Game', 2010, 4, 'tt1283542'),
#  ('Movie', 'The Apology Dance', 2010, 6, 'tt1283881'),
#  ('Movie', 'Burning Palms', 2010, 4, 'tt1283887'),
#  ('Movie', 'The Symmetry of Love', 2011, 4, 'tt1283959'),
#  ('Movie', 'The Awkward Comedy Show', 2010, 4, 'tt1285212'),
#  ('Movie', 'La liga del arte criminal', 2010, 1, 'tt12866138'),
#  ('Movie', 'Weakness', 2010, 10, 'tt1286753'),
#  ('Movie', 'Cats & Dogs: The Revenge of Kitty Galore', 2010, 7, 'tt1287468'),
#  ('Movie', 'Left for Dead', 2010, None, 'tt1288472'),
#  ('Movie', 'Meant to Be', 2010, 9, 'tt1290140'),
#  ('Movie', 'Yi ye Taibei', 2010, 4, 'tt1291125'),
#  ('Movie', 'Meet Monica Velour', 2010, 4, 'tt1291549'),
#  ('Movie', 'Dancing Ninja', 2010, None, 'tt1294141'),
#  ('Movie', 'La vida empieza hoy', 2010, 6, 'tt1295075'),
#  ('Movie', 'Waiting for Forever', 2011, 2, 'tt1296898'),
#  ('Movie', 'Most Wanted', 2010, None, 'tt12969926'),
#  ('Movie', 'Devolved', 2010, None, 'tt1297925'),
#  ('Movie', 'Every Day', 2012, 10, 'tt1301990'),
#  ('Movie', 'Yogi Bear', 2011, 2, 'tt1302067'),
#  ('Movie', 'In the Drink', 2010, 6, 'tt1303743'),
#  ('Movie', 'The Bill Collector', 2010, 9, 'tt1305008'),
#  ('Movie', 'Our Family Wedding', 2010, 3, 'tt1305583'),
#  ('Movie', 'All About Evil', 2014, 6, 'tt1307858'),
#  ('Movie', 'The Cost of Living', 2010, 2, 'tt1307887'),
#  ('Movie', 'American Grindhouse', 2010, 3, 'tt1307861'),
#  ('Movie', 'Rebels Without a Clue', 2014, 2, 'tt1308012'),
#  ('Movie', 'Muzh moey vdovy', 2010, 4, 'tt1307976'),
#  ('Movie', 'Father vs. Son', 2010, 4, 'tt1308112'),
#  ('Movie', 'Kissing Strangers', 2010, 8, 'tt1308758'),
#  ('Movie', 'Zwerge sprengen', 2010, 1, 'tt1309601'),
#  ('Movie', 'The Human Resources Manager', 2010, 10, 'tt1311075'),
#  ('Movie', 'Audrey the Trainwreck', 2010, None, 'tt1314161'),
#  ('Movie', 'American Scream King', 2012, 1, 'tt1314222'),
#  ('Movie', 'Cherry', 2011, 6, 'tt1315350'),
#  ('Movie', 'Black Mail', 2010, 0, 'tt1316077'),
#  ('Movie', 'Neka ostane medju nama', 2010, 3, 'tt1318029'),
#  ('Movie', 'Da bing xiao jiang', 2010, 2, 'tt1319718'),
#  ('Movie', "It's a Wonderful Afterlife", 2010, 4, 'tt1319716'),
#  ('Movie', 'A Little Help', 2011, 7, 'tt1319722'),
#  ('Movie', 'Shank', 2010, 3, 'tt1320296'),
#  ('Movie', 'Burke and Hare', 2010, 10, 'tt1320239'),
#  ('Movie', "Gulliver's Travels", 2011, 2, 'tt1320261'),
#  ('Movie', 'GravyTrain', 2010, None, 'tt1320334'),
#  ('Movie', 'Death at a Funeral', 2010, 7, 'tt1321509'),
#  ('Movie', 'América', 2011, 5, 'tt1322266'),
#  ('Movie', 'Jhootha Hi Sahi', 2010, 10, 'tt1322257'),
#  ('Movie', 'Going the Distance', 2010, 9, 'tt1322312'),
#  ('Movie', 'Protéger & servir', 2010, 2, 'tt1322354'),
#  ('Movie',
#   'The Triumph of Dingus McGraw: Village Idiot',
#   2014,
#   12,
#   'tt1323004'),
#  ('Movie', 'Hey Watch This', 2010, 4, 'tt1323598'),
#  ('Movie', 'Despicable Me', 2010, 10, 'tt1323594'),
#  ('Movie', 'Zena sa slomljenim nosem', 2011, 7, 'tt1324061'),
#  ('Movie', 'The People vs. George Lucas', 2011, 8, 'tt1325014'),
#  ('Movie', 'Beautysleep Symphony', 2010, None, 'tt1326193'),
#  ('Movie', 'Opération Casablanca', 2010, 10, 'tt1327808'),
#  ('Movie', 'Limbo Lounge', 2010, 4, 'tt1328911'),
#  ('Movie', 'Bold Native', 2010, None, 'tt1328908'),
#  ('Movie', 'The Battle of Pussy Willow Creek', 2013, 3, 'tt1329309'),
#  ('Movie', 'Girl Clock!', 2010, None, 'tt1329354'),
#  ('Movie', 'Everything Nice', 2010, None, 'tt1330022'),
#  ('Movie', 'The Grover Complex', 2016, 1, 'tt1330026'),
#  ('Movie', 'Shoot the Hero', 2010, 1, 'tt1332119'),
#  ('Movie', 'Night Terrors', 2010, 12, 'tt1332570'),
#  ('Movie', 'The Perfect Host', 2011, 10, 'tt1334553'),
#  ('Movie', 'Bronx Paradise', 2010, None, 'tt1335980'),
#  ('Movie', 'Dahmer vs. Gacy', 2010, 4, 'tt1335986'),
#  ('Movie', 'Cyrus', 2010, 7, 'tt1336617'),
#  ('Movie', 'Jucy', 2011, 11, 'tt1336999'),
#  ('Movie',
#   'Nodame Kantâbire: Saishuu-gakushou - Kouhen',
#   2010,
#   4,
#   'tt1337673'),
#  ('Movie', 'Raspberry Magic', 2010, 7, 'tt1339488'),
#  ('Movie', 'Ta oporofora tis Athinas', 2010, 10, 'tt1339340'),
#  ('Movie', 'Russian Snark', 2010, 7, 'tt1340119'),
#  ('Movie',
#   "The Rock 'n' Roll Dreams of Duncan Christopher",
#   2012,
#   5,
#   'tt1340793'),
#  ('Movie', 'Regresa', 2010, 1, 'tt1340791'),
#  ('Movie', 'Elektra Luxx', 2010, 3, 'tt1340773'),
#  ('Movie', 'Six Semesters', 2010, 4, 'tt1340737'),
#  ('Movie', 'I Am 24', 2012, 8, 'tt1340778'),
#  ('Movie', 'Four Lions', 2010, 9, 'tt1341167'),
#  ('Movie', 'How Do You Know', 2011, 2, 'tt1341188'),
#  ('Movie', 'Ceremony', 2011, 2, 'tt1341341'),
#  ('Movie', 'Queen of the Lot', 2010, 11, 'tt1342122'),
#  ('Movie', 'Speed-Dating', 2010, 6, 'tt1343110'),
#  ('Movie', 'Reuniting the Rubins', 2011, 10, 'tt1344337'),
#  ('Movie', 'Angels Love Donuts', 2010, 0, 'tt1344699'),
#  ('Movie', 'From Hollywood to Hollywood', 2010, 2, 'tt1344836'),
#  ('Movie', 'Darren & Abbey', 2010, 3, 'tt1345719'),
#  ('Movie', 'Ishqiya', 2010, 1, 'tt1345777'),
#  ('Movie', 'The Loneliest Road in America', 2010, 3, 'tt1349629'),
#  ('Movie', 'How to Be a SexStar', 2010, 5, 'tt1351235'),
#  ('Movie', 'Everything Will Happen Before You Die', 2010, 5, 'tt1351141'),
#  ('Movie', 'Pyaar Impossible!', 2010, 1, 'tt1351224'),
#  ('Movie', 'Nude Nuns with Big Guns', 2010, 9, 'tt1352388'),
#  ('Movie', 'Prezít svuj zivot (teorie a praxe)', 2010, 9, 'tt1352765'),
#  ('Movie', 'Feed the Fish', 2011, 1, 'tt1354687'),
#  ('Movie', 'Rifftrax: Santa and the Ice Cream Bunny', 2010, 12, 'tt13560816'),
#  ('Movie', 'Exporting Raymond', 2010, 10, 'tt1356763'),
#  ('Movie', 'Disowning Claire', 2010, 2, 'tt1357120'),
#  ('Movie', "I'm Still Here", 2010, 9, 'tt1356864'),
#  ('Movie', 'Pájaros de papel', 2010, 3, 'tt1360822'),
#  ('Movie', 'The Shouting Men', 2010, 3, 'tt1360829'),
#  ('Movie', 'The Extra Man', 2011, 1, 'tt1361313'),
#  ('Movie', 'Dynamite Swine', 2010, 8, 'tt1362210'),
#  ('Movie', 'Foodland', 2010, 12, 'tt1363368'),
#  ('Movie', 'The Platinum Peacemaker', 2010, 12, 'tt1364277'),
#  ('Movie', 'Norberto apenas tarde', 2012, 1, 'tt1365491'),
#  ('Movie', 'Costa Rican Summer', 2010, 5, 'tt1370426'),
#  ('Movie', '180º', 2013, 1, 'tt1370428'),
#  ('Movie', 'Made in Dagenham', 2011, 5, 'tt1371155'),
#  ('Movie', 'I Was a 7th Grade Dragon Slayer', 2010, 4, 'tt1373149'),
#  ('Movie', 'Snowmen', 2010, 11, 'tt1373406'),
#  ('Movie', 'Grown Ups', 2010, 9, 'tt1375670'),
#  ('Movie', 'Gunless', 2010, 4, 'tt1376195'),
#  ('Movie', 'Imogène McCarthery', 2010, 5, 'tt1376421'),
#  ('Movie', 'I Love You Too', 2010, 5, 'tt1376709'),
#  ('Movie', 'Peepers', 2010, 4, 'tt1379234'),
#  ('Movie',
#   'The Gertrude Stein Mystery or Some Like It Art',
#   2010,
#   7,
#   'tt1379651'),
#  ('Movie', 'Cheshmak', 2010, None, 'tt13797198'),
#  ('Movie', 'Risto Räppääjä ja polkupyörävaras', 2010, 2, 'tt1380190'),
#  ('Movie', 'Big Money Rustlas', 2010, 1, 'tt1380784'),
#  ('Movie', 'Attack of the Vegan Zombies!', 2010, 2, 'tt1380852'),
#  ('Movie', 'Die Bielefeld Verschwörung', 2010, 6, 'tt1381403'),
#  ('Movie', 'Baby Jane?', 2010, 6, 'tt1381402'),
#  ('Movie', 'Pete Smalls Is Dead', 2011, 4, 'tt1381413'),
#  ('Movie', 'Father of Invention', 2011, 11, 'tt1381505'),
#  ('Movie', 'Mord på mere end én Måde', 2010, 0, 'tt1383448'),
#  ('Movie', 'The Runway', 2011, 6, 'tt1385633'),
#  ('Movie', 'Cop Out', 2010, 3, 'tt1385867'),
#  ('Movie', 'The Other Guys', 2010, 11, 'tt1386588'),
#  ('Movie', 'En ganske snill mann', 2010, 9, 'tt1386683'),
#  ('Movie', 'Bicycle Bride', 2011, 5, 'tt1388391'),
#  ('Movie', '9 meses', 2012, 10, 'tt1388388'),
#  ('Movie', 'Mirch', 2010, 10, 'tt1388903'),
#  ('Movie', 'Dancing on a Dry Salt Lake', 2013, 12, 'tt1389070'),
#  ('Movie', 'Teufelskicker', 2010, 3, 'tt1390424'),
#  ('Movie', 'Walkaway', 2010, 10, 'tt1390840'),
#  ('Movie', 'Lean Like a Cholo', 2013, 9, 'tt1391087'),
#  ('Movie', 'Why Did I Get Married Too?', 2010, 4, 'tt1391137'),
#  ('Movie', 'Marmaduke', 2010, 8, 'tt1392197'),
#  ('Movie', 'Chance Pe Dance', 2010, 1, 'tt1392744'),
#  ('Movie',
#   'No Limit Kids: Much Ado About Middle School',
#   2010,
#   5,
#   'tt1394240'),
#  ('Movie', 'Helena from the Wedding', 2010, 3, 'tt1394211'),
#  ('Movie', 'Action Replayy', 2010, 11, 'tt1396208'),
#  ('Movie', 'Pièce montée', 2010, 3, 'tt1399677'),
#  ('Movie', 'Paach Naar Ek Bejar', 2010, 4, 'tt13996304'),
#  ('Movie', 'First Dog', 2012, 12, 'tt1400335'),
#  ('Movie', 'The Con Artist', 2010, 11, 'tt1401607'),
#  ('Movie', 'Sedamdeset i dva dana', 2010, 7, 'tt1401672'),
#  ('Movie', 'The Romantics', 2010, 5, 'tt1403988'),
#  ('Movie', 'The Bannen Way', 2010, 1, 'tt1404830'),
#  ('Movie', 'Six Days in Paradise', 2010, None, 'tt1405414'),
#  ('Movie', 'Mine vaganti', 2011, 5, 'tt1405810'),
#  ('Movie', 'Le baltringue', 2010, 1, 'tt1405807'),
#  ('Movie', 'Violet Tendencies', 2010, 4, 'tt1407055'),
#  ('Movie', 'Just Wright', 2010, 5, 'tt1407061'),
#  ('Movie', 'O Bem Amado', 2010, 1, 'tt1410297'),
#  ('Movie', 'Pastor Shepherd', 2010, 4, 'tt1411762'),
#  ('Movie', 'Beware the Gonzo', 2011, 9, 'tt1412442'),
#  ('Movie', 'Eat Me!', 2010, 11, 'tt1412541'),
#  ('Movie', 'Le baiser du barbu', 2010, 6, 'tt1413815'),
#  ('Movie', 'You Again', 2010, 9, 'tt1414382'),
#  ('Movie', 'Nanny McPhee and the Big Bang', 2010, 3, 'tt1415283'),
#  ('Movie', 'Immigration Tango', 2010, 4, 'tt1415269'),
#  ('Movie', 'Bus Palladium', 2010, 3, 'tt1415255'),
#  ('Movie', 'Minor League: A Football Story', 2010, None, 'tt1416341'),
#  ('Movie', 'Texas Frightmare Massacre', 2010, 4, 'tt1416343'),
#  ('Movie', 'Cirkus Columbia', 2011, 7, 'tt1417067'),
#  ('Movie', 'Il figlio più piccolo', 2010, 2, 'tt1417038'),
#  ('Movie', 'Blue Bus', 2010, None, 'tt1419453'),
#  ('Movie', 'No eres tú, soy yo', 2010, 8, 'tt1421046'),
#  ('Movie', 'Somewhere', 2011, 4, 'tt1421051'),
#  ('Movie', 'Goa', 2010, 1, 'tt1421036'),
#  ('Movie', '180° moires', 2010, 3, 'tt1424038'),
#  ('Movie', "Barney's Version", 2011, 3, 'tt1423894'),
#  ('Movie', 'The Infidel', 2010, 6, 'tt1424003'),
#  ('Movie', 'Parterapi', 2010, 2, 'tt1425624'),
#  ('Movie', 'Money to Burn', 2010, None, 'tt1425930'),
#  ('Movie', 'Skeletons', 2010, 7, 'tt1425933'),
#  ('Movie', 'BearCity', 2010, 6, 'tt1426320'),
#  ('Movie', 'Beer Pong Saved My Life', 2010, 0, 'tt1426355'),
#  ('Movie', 'Quitting', 2010, 0, 'tt1427937'),
#  ('Movie', '3faltig', 2010, 10, 'tt1428436'),
#  ('Movie', 'Kottan ermittelt: Rien ne va plus', 2010, 12, 'tt1428448'),
#  ('Movie', 'We Are Family', 2010, 9, 'tt1428459'),
#  ('Movie', 'Madly in Love', 2010, 1, 'tt1429451'),
#  ('Movie', 'Africa United', 2011, 3, 'tt1429313'),
#  ('Movie', 'Coursier', 2010, 2, 'tt1429429'),
#  ('Movie', 'Alien Opponent', 2011, 8, 'tt1429382'),
#  ('Movie', 'Yuzma yuz', 2010, None, 'tt14296082'),
#  ('Movie', 'Rio Sex Comedy', 2011, 2, 'tt1429432'),
#  ('Movie',
#   '1,001 Ways to Enjoy the Missionary Position',
#   2010,
#   10,
#   'tt1430064'),
#  ('Movie', 'Silverlake Video: The Movie', 2010, 12, 'tt1430508'),
#  ('Movie', 'Another Year', 2010, 11, 'tt1431181'),
#  ('Movie', 'No Problem', 2010, 12, 'tt1431122'),
#  ('Movie', 'Perfect Combination', 2010, 5, 'tt1431133'),
#  ('Movie', 'Bakamono', 2010, 12, 'tt1433763'),
#  ('Movie', 'Diciotto anni dopo', 2010, 6, 'tt1433802'),
#  ('Movie', 'Self Helpless', 2010, 3, 'tt1434449'),
#  ('Movie', 'All American Gender Outlaw', 2010, None, 'tt1434942'),
#  ('Movie', 'Splatter: Love, Honor and Paintball', 2010, 4, 'tt1436564'),
#  ('Movie', 'Lovers of Hate', 2011, 2, 'tt1436560'),
#  ('Movie', 'Le mac', 2010, 2, 'tt1437361'),
#  ('Movie', 'The Best and the Brightest', 2010, 10, 'tt1438251'),
#  ('Movie', 'Submarine', 2011, 9, 'tt1440292'),
#  ('Movie', 'Les petits mouchoirs', 2011, 1, 'tt1440232'),
#  ('Movie', 'The Spy Who Kicked Me', 2010, 4, 'tt14404234'),
#  ('Movie', 'Round Ireland with a Fridge', 2010, 0, 'tt1440755'),
#  ('Movie', 'The Way', 2010, 11, 'tt1441912'),
#  ('Movie', 'West Is West', 2011, 2, 'tt1441956'),
#  ('Movie', 'Joo-yoo-so-seup-gyeok-sa-geon-too', 2010, 1, 'tt1442512'),
#  ('Movie', 'Das Sandmännchen - Abenteuer im Traumland', 2010, 9, 'tt1442223'),
#  ('Movie', 'Tum Milo Toh Sahi', 2010, 4, 'tt1442583'),
#  ('Movie', 'Reflexões de um Liquidificador', 2010, 8, 'tt1442578'),
#  ('Movie', "Tutto l'amore del mondo", 2010, 2, 'tt1443521'),
#  ('Movie', 'Gangsterboys', 2010, 2, 'tt1444261'),
#  ('Movie', 'Bass Ackwards', 2010, 1, 'tt1445202'),
#  ('Movie', 'Hubristic', 2010, 0, 'tt1445650'),
#  ('Movie', '8 Dates with Paul', 2010, 5, 'tt1446815'),
#  ('Movie', 'Peepli [Live]', 2010, 8, 'tt1447508'),
#  ('Movie', "My Girlfriend's Boyfriend", 2012, 11, 'tt1447793'),
#  ('Movie', 'Yut mun Hinneisi', 2010, 4, 'tt1447800'),
#  ('Movie', 'Shuarî samudei', 2010, 7, 'tt1450332'),
#  ('Movie', 'Sensation', 2011, 11, 'tt1451632'),
#  ('Movie', 'Tournée', 2011, 1, 'tt1451762'),
#  ('Movie', 'Just for the Record', 2010, 5, 'tt1452294'),
#  ('Movie', 'Hahaha', 2010, 5, 'tt1452626'),
#  ('Movie', 'Below the Beltway', 2010, 4, 'tt1453428'),
#  ('Movie', 'Cheung Gong 7 hou: Oi dei kau', 2010, 7, 'tt1453967'),
#  ('Movie', 'A Bela e o Paparazzo', 2010, 1, 'tt1454603'),
#  ('Movie', 'Napapiirin sankarit', 2010, 10, 'tt1454505'),
#  ('Movie', 'Sci-Fi High: The Movie Musical', 2010, 4, 'tt1454542'),
#  ('Movie', 'Copacabana', 2010, 11, 'tt1454910'),
#  ('Movie', 'La tête en friche', 2010, 7, 'tt1455151'),
#  ('Movie', 'Randka w ciemno', 2010, 2, 'tt1455241'),
#  ('Movie', 'Hijinks and Weiners', 2010, 10, 'tt14549660'),
#  ('Movie', 'How to Boil a Frog', 2010, 9, 'tt1455659'),
#  ('Movie', 'Khatta Meetha', 2010, 7, 'tt1455811'),
#  ('Movie', 'Happy Family', 2010, 3, 'tt1455810'),
#  ('Movie', 'Faa tin hei si 2010', 2010, 2, 'tt1456520'),
#  ('Movie', 'The Kings of Mykonos', 2010, 5, 'tt1457766'),
#  ('Movie', 'Huge', 2011, 7, 'tt1457726'),
#  ('Movie', 'Brooklyn', 2010, None, 'tt1458730'),
#  ('Movie', 'Lose with English', 2011, 2, 'tt1458927'),
#  ('Movie', 'Cabotins', 2010, 7, 'tt1460741'),
#  ('Movie', 'The Putt Putt Syndrome', 2010, 0, 'tt1460661'),
#  ('Movie', 'Bunch of Guys', 2010, 1, 'tt1460774'),
#  ('Movie', 'Änglagård - Tredje gången gillt', 2010, 12, 'tt1461307'),
#  ('Movie', 'Awaremi mumashika', 2010, 7, 'tt1462018'),
#  ('Movie', 'Leading Ladies', 2010, 7, 'tt1462053'),
#  ('Movie', 'The Weathered Underground', 2010, 1, 'tt1464590'),
#  ('Movie', 'Hum Tum Aur Ghost', 2010, 3, 'tt1465493'),
#  ('Movie', 'The Wedding Party', 2012, 9, 'tt1465496'),
#  ('Movie', "L'arnacoeur", 2011, 8, 'tt1465487'),
#  ('Movie', 'Tucker and Dale vs Evil', 2011, 1, 'tt1465522'),
#  ('Movie', 'Fathers & Sons', 2010, 9, 'tt1465481'),
#  ('Movie', 'The Prospects', 2011, 3, 'tt1466069'),
#  ('Movie', 'The Lake Effect', 2010, 10, 'tt1466068'),
#  ('Movie',
#   "Ensemble, nous allons vivre une très, très grande histoire d'amour...",
#   2010,
#   4,
#   'tt1466569'),
#  ('Movie', 'Lang & gelukkig', 2010, 10, 'tt1467385'),
#  ('Movie', 'La prima cosa bella', 2011, 8, 'tt1467273'),
#  ('Movie',
#   'Higashi no Eden Gekijôban II: Paradise Lost',
#   2010,
#   3,
#   'tt1468321'),
#  ('Movie', 'El diario de Carlota', 2010, 7, 'tt1468840'),
#  ('Movie', 'MacGruber', 2010, 5, 'tt1470023'),
#  ('Movie', 'Eddies: The Documentary', 2010, 9, 'tt1470818'),
#  ('Movie', 'Teenager Hamlet', 2010, 10, 'tt1472537'),
#  ('Movie', 'Waiter from Hell', 2010, 12, 'tt1472589'),
#  ('Movie', 'Donnant donnant', 2010, 10, 'tt1473142'),
#  ('Movie', 'Mammuth', 2011, 4, 'tt1473074'),
#  ('Movie', 'Fatal', 2010, 6, 'tt1473357'),
#  ('Movie', 'Ultimate Guide to Flight', 2010, 10, 'tt1473181'),
#  ('Movie', 'May I Be Frank', 2010, 0, 'tt1474792'),
#  ('Movie', 'The Freebie', 2010, 9, 'tt1474889'),
#  ('Movie', 'Open Five', 2010, 4, 'tt1474816'),
#  ('Movie', 'Slimed', 2010, 3, 'tt1474859'),
#  ('Movie', "Baby Mama's Club", 2010, 1, 'tt1475135'),
#  ('Movie', 'Que se mueran los feos', 2010, 4, 'tt1475400'),
#  ('Movie', 'The Dogfather', 2010, 3, 'tt1475549'),
#  ('Movie', 'The Rum Diary', 2011, 12, 'tt0376136'),
#  ('Movie', 'Gnomeo & Juliet', 2011, 2, 'tt0377981'),
#  ('Movie', 'Seven Fallen Objects', 2011, 5, 'tt0407194'),
#  ('Movie', 'Satin', 2011, 3, 'tt0433397'),
#  ('Movie', 'Puss in Boots', 2011, 12, 'tt0448694'),
#  ('Movie', 'Generation P', 2011, 4, 'tt0459748'),
#  ('Movie', 'Salvando al Soldado Pérez', 2011, 3, 'tt0461336'),
#  ('Movie', 'Silent Alarm', 2011, 1, 'tt0462536'),
#  ('Movie', 'Act Your Age', 2011, 4, 'tt0464891'),
#  ('Movie', 'The Smurfs', 2011, 8, 'tt0472181'),
#  ('Movie', 'Stan', 2011, None, 'tt0473088'),
#  ('Movie', 'Tower Heist', 2011, 11, 'tt0471042'),
#  ('Movie', 'Bamboo Shark', 2012, None, 'tt0473122'),
#  ('Movie', 'Hall Pass', 2011, 3, 'tt0480687'),
#  ('Movie', 'Monkey Man', 2011, 1, 'tt0483740'),
#  ('Movie', 'La daga de Rasputín', 2011, 1, 'tt0484828'),
#  ('Movie', 'Something Borrowed', 2011, 6, 'tt0491152'),
#  ('Movie', "What's Your Number?", 2011, 10, 'tt0770703'),
#  ('Movie', 'Till You Get to Baraboo', 2011, 0, 'tt0770819'),
#  ('Movie', 'Kill', 2011, 9, 'tt0772179'),
#  ('Movie', 'Red Dog', 2011, 8, 'tt0803061'),
#  ('Movie', 'Jack and Jill', 2012, 2, 'tt0810913'),
#  ('Movie', 'Take Me Home Tonight', 2011, 3, 'tt0810922'),
#  ('Movie', 'Hoodwinked Too! Hood vs. Evil', 2011, 7, 'tt0844993'),
#  ('Movie', 'Pox', 2011, 4, 'tt0844915'),
#  ('Movie', 'Loot', 2011, 11, 'tt0847180'),
#  ('Movie', 'Naked Run', 2011, 5, 'tt0852986'),
#  ('Movie', '6 Month Rule', 2012, 8, 'tt0865561'),
#  ('Movie', 'From Prada to Nada', 2011, 1, 'tt0893412'),
#  ('Movie', 'Un monstre à Paris', 2012, 6, 'tt0961097'),
#  ('Movie', 'Saxána a Lexikon kouzel', 2011, 9, 'tt0969332'),
#  ('Movie', 'Lives and Deaths of the Poets', 2011, 12, 'tt0972848'),
#  ('Movie', 'Maaginen kristalli', 2011, 11, 'tt0986361'),
#  ('Movie', 'The Green Hornet', 2011, 1, 'tt0990407'),
#  ('Movie', 'Ghost Hustlers', 2011, 1, 'tt10110584'),
#  ('Movie', 'Hip Hip Hurray', 2011, 1, 'tt10147376'),
#  ('Movie', 'Tôi Nay, 8 Gio!', 2011, 12, 'tt10229972'),
#  ('Movie', "Where's My Stuff?", 2011, 8, 'tt1023336'),
#  ('Movie', 'Tied to a Chair', 2011, 5, 'tt1029385'),
#  ('Movie', 'The Descendants', 2012, 2, 'tt1033575'),
#  ('Movie', 'Bad Meat', 2013, 2, 'tt1034010'),
#  ('Movie', 'Somewhere Tonight', 2012, 6, 'tt1034293'),
#  ('Movie', 'Al-Andalus mounamour!', 2011, 0, 'tt10482034'),
#  ('Movie', 'SeeFood', 2011, 10, 'tt1891905'),
#  ('Movie', 'Una favola da raccontare', 2011, None, 'tt10525606'),
#  ('Movie', 'The Big Year', 2011, 10, 'tt1053810'),
#  ('Movie', 'Züri Zoo', 2011, 7, 'tt10587942'),
#  ('Movie', 'The Legend of Awesomest Maximus', 2011, 8, 'tt1059887'),
#  ('Movie', 'Monte Carlo', 2011, 7, 'tt1067774'),
#  ('Movie', 'Footloose', 2011, 10, 'tt1068242'),
#  ('Movie', 'Sunburnt Angels', 2011, None, 'tt1068780'),
#  ('Movie', 'Mardi Gras: Spring Break', 2011, 9, 'tt1083462'),
#  ('Movie', 'Vacanze a Gallipoli', 2011, None, 'tt10851620'),
#  ('Movie', 'Paren s Marsa', 2011, 5, 'tt1087898'),
#  ('Movie', 'Paul', 2011, 4, 'tt1092026'),
#  ('Movie', 'The Usurpers', 2011, 6, 'tt10981510'),
#  ('Movie', 'Dirty Movie', 2011, 2, 'tt1107812'),
#  ('Movie', 'Area Boys', 2011, 5, 'tt11197856'),
#  ('Movie', 'The Debts', 2011, 6, 'tt11374492'),
#  ('Movie', 'Son of Morning', 2011, 2, 'tt1144815'),
#  ('Movie', 'Small Timers', 2011, None, 'tt1152286'),
#  ('Movie', 'The Joneses', 2012, 4, 'tt1152830'),
#  ('Movie', 'Hum Do Bhagode', 2011, None, 'tt11581650'),
#  ('Movie', 'Mark Watson Live', 2011, None, 'tt11705786'),
#  ('Movie', 'Obsessions', 2011, 3, 'tt11723770'),
#  ('Movie', 'Obsessions Part II: The Last Hope', 2011, 9, 'tt11729324'),
#  ('Movie', 'Walking in Your Shoes', 2011, 12, 'tt11742876'),
#  ('Movie', 'The Family Tree', 2011, 12, 'tt1175713'),
#  ('Movie', 'Slacker', 2011, 8, 'tt11761300'),
#  ('Movie', 'Diagnosis Superstar', 2011, None, 'tt1183930'),
#  ('Movie', 'Rango', 2011, 3, 'tt1192628'),
#  ('Movie', "Phil Cobb's Dinner for Four", 2011, None, 'tt1196952'),
#  ('Movie', 'Cougars Inc.', 2012, 9, 'tt1198075'),
#  ('Movie', 'Dance Fu', 2012, None, 'tt1204285'),
#  ('Movie', 'The Muppets', 2012, 2, 'tt1204342'),
#  ('Movie', 'Hick', 2012, 5, 'tt1205558'),
#  ('Movie', 'Labios rojos', 2011, 10, 'tt1206483'),
#  ('Movie', 'We Need to Talk About Kieran', 2011, None, 'tt1215172'),
#  ('Movie', 'Cars 2', 2011, 7, 'tt1216475'),
#  ('Movie', 'Pritchi 2', 2011, None, 'tt12194546'),
#  ('Movie', 'Demoted', 2012, 9, 'tt1221207'),
#  ('Movie', 'Zookeeper', 2011, 7, 'tt1222817'),
#  ('Movie', 'Kalla Malla Sulla', 2011, 9, 'tt12243674'),
#  ('Movie', 'Action News 5', 2013, 12, 'tt1229402'),
#  ('Movie', 'A Good Old Fashioned Orgy', 2012, 1, 'tt1231586'),
#  ('Movie', 'Monsterpiece Theatre Volume 1', 2011, None, 'tt1235154'),
#  ('Movie', 'Medianeras', 2011, 10, 'tt1235841'),
#  ('Movie', 'Silent But Deadly', 2011, 11, 'tt1237961'),
#  ('Movie', 'Writing on the Wall', 2013, 12, 'tt1238847'),
#  ('Movie', 'Your Highness', 2011, 9, 'tt1240982'),
#  ('Movie', "Here's the Kicker", 2011, None, 'tt1241332'),
#  ('Movie', 'Hetjur Valhallar - Þór', 2012, 8, 'tt1241721'),
#  ('Movie', 'Father, Son & Holy Cow', 2012, 2, 'tt1242517'),
#  ('Movie', 'Fancypants', 2011, 9, 'tt1243630'),
#  ('Movie', 'Snatched', 2018, 12, 'tt1245534'),
#  ('Movie', 'Sister Mary', 2011, 7, 'tt1247693'),
#  ('Movie', 'Ragel wa sitt settat Part 8', 2011, 8, 'tt12481816'),
#  ('Movie', 'Almost Perfect', 2013, 9, 'tt1249158'),
#  ('Movie', 'Salvation Boulevard', 2011, 7, 'tt1251743'),
#  ('Movie', 'Learning', 2011, 8, 'tt12568720'),
#  ('Movie', 'Take Me Home', 2013, 10, 'tt1261954'),
#  ('Movie', 'Ghost Phone: Phone Calls from the Dead', 2011, None, 'tt1263779'),
#  ('Movie', 'Memphis Rising: Elvis Returns', 2011, 1, 'tt1265295'),
#  ('Movie', 'Wintertochter', 2011, 10, 'tt1266038'),
#  ('Movie', 'A Very Harold & Kumar 3D Christmas', 2011, 11, 'tt1268799'),
#  ('Movie', 'Deadheads', 2012, 2, 'tt1273207'),
#  ('Movie', 'Apocalypse, CA', 2011, 12, 'tt1273193'),
#  ('Movie', 'Killadi Raman', 2011, 12, 'tt12828476'),
#  ('Movie', 'Bad Teacher', 2011, 6, 'tt1284575'),
#  ('Movie', 'Life at the Resort', 2011, 11, 'tt1288406'),
#  ('Movie', 'Operation Belvis Bash', 2018, 1, 'tt1288367'),
#  ('Movie', 'The Ride of Tom & Valkyrie', 2011, None, 'tt1292650'),
#  ('Movie', 'Gingerdead Man 3: Saturday Night Cleaver', 2011, 9, 'tt1293561'),
#  ('Movie', 'The FP', 2011, 3, 'tt1296373'),
#  ('Movie', 'Pasen', 2011, 10, 'tt12969366'),
#  ('Movie', 'The Lady and the Taxi Driver', 2011, 0, 'tt1297282'),
#  ('Movie', 'Kung Fu Panda 2', 2011, 6, 'tt1302011'),
#  ('Movie', 'Not Another Not Another Movie', 2011, 9, 'tt1302019'),
#  ('Movie', 'Koszmar minionej zimy', 2011, 6, 'tt13026740'),
#  ('Movie', 'Laifu, Laifu', 2011, 8, 'tt13038778'),
#  ('Movie', 'Fred & Vinnie', 2011, 1, 'tt1305586'),
#  ('Movie', '50/50', 2011, 12, 'tt1306980'),
#  ('Movie', 'All Stars 2: Old Stars', 2011, 10, 'tt1307859'),
#  ('Movie', 'Frontman', 2011, 6, 'tt1307920'),
#  ('Movie', 'The Visitor from Elsewhere', 2011, 0, 'tt1308065'),
#  ('Movie', 'The Oranges', 2012, 10, 'tt1313139'),
#  ('Movie', 'Blaxican Brothers', 2021, 1, 'tt1315932'),
#  ('Movie', 'The Year Dolly Parton Was My Mom', 2011, 3, 'tt1316624'),
#  ('Movie', 'The Preening Swan', 2011, 11, 'tt1319730'),
#  ('Movie', 'Empire of Evil', 2011, 10, 'tt13216934'),
#  ('Movie', 'Stags', 2011, 6, 'tt1325020'),
#  ('Movie', 'Bad Actress', 2011, None, 'tt1326188'),
#  ('Movie', 'Convincing Clooney', 2011, None, 'tt1329331'),
#  ('Movie', 'The Life and Death of Steriogram', 2011, 6, 'tt1329389'),
#  ('Movie', 'Arthur', 2011, 5, 'tt1334512'),
#  ('Movie', 'Au Pair, Kansas', 2018, 6, 'tt1334514'),
#  ('Movie', 'Who the F#ck Is Chip Seinfeld?', 2011, 11, 'tt1338705'),
#  ('Movie', 'Hopelessly in June', 2011, 6, 'tt1349616'),
#  ('Movie', 'Butter', 2012, 10, 'tt1349451'),
#  ('Movie', 'Le chat du rabbin', 2011, 9, 'tt1355638'),
#  ('Movie', 'Mamachya Rashila Bhacha', 2011, None, 'tt13582186'),
#  ('Movie', 'Running Mates', 2011, 10, 'tt1360825'),
#  ('Movie', 'The Honey Killer', 2018, 4, 'tt1362141'),
#  ('Movie', 'Naughty @ 40', 2011, 4, 'tt1363125'),
#  ('Movie', 'Proper Villains', 2011, None, 'tt1363132'),
#  ('Movie', 'Chatur Singh Two Star', 2011, 8, 'tt1363363'),
#  ('Movie', 'Dirty Pastor', 2011, 8, 'tt13638530'),
#  ('Movie', 'Qasos', 2011, None, 'tt13641990'),
#  ('Movie', '3D Yuk po tuen: Gik lok bo gam', 2011, 4, 'tt1365048'),
#  ('Movie', 'The Sitter', 2011, 12, 'tt1366344'),
#  ('Movie', 'Ocean Front Property', 2012, 10, 'tt1367248'),
#  ('Movie', '0s & 1s', 2011, None, 'tt1372680'),
#  ('Movie', 'Prairie Love', 2012, 10, 'tt1374996'),
#  ('Movie', 'Beach Bar: The Movie', 2011, 7, 'tt1375742'),
#  ('Movie', 'Rid of Me', 2011, 11, 'tt1376233'),
#  ('Movie', 'Chegoneh Miliarder Shodam', 2011, None, 'tt13799544'),
#  ('Movie', 'Azhans Ezdevaj', 2011, None, 'tt13802190'),
#  ('Movie', 'You May Not Kiss the Bride', 2013, 2, 'tt1381418'),
#  ('Movie', 'American Disciples', 2013, 1, 'tt1383700'),
#  ('Movie', 'Hit List', 2011, 10, 'tt1383705'),
#  ('Movie', 'Is This a Joke?', 2011, 2, 'tt1383706'),
#  ('Movie', 'Rokland', 2011, 1, 'tt1384929'),
#  ('Movie', 'This Is Not a Movie', 2011, 1, 'tt1386492'),
#  ('Movie', 'We Bought a Zoo', 2012, 4, 'tt1389137'),
#  ('Movie', 'Solos en la ciudad', 2011, 10, 'tt1388913'),
#  ('Movie', 'Fully Loaded', 2011, None, 'tt1390536'),
#  ('Movie', 'Jesus Henry Christ', 2012, 5, 'tt1393742'),
#  ('Movie', "Mr. Popper's Penguins", 2011, 8, 'tt1396218'),
#  ('Movie', 'Don Ghadicha Daav', 2011, 3, 'tt13996378'),
#  ('Movie', 'Slip & Fall', 2011, None, 'tt1401700'),
#  ('Movie', 'Uma Professora Muito Maluquinha', 2011, 10, 'tt1401681'),
#  ('Movie', 'Happy Feet Two', 2011, 11, 'tt1402488'),
#  ('Movie', 'The Matador II', 2011, 4, 'tt14041234'),
#  ('Movie', 'A Date with Fear', 2011, 2, 'tt1403990'),
#  ('Movie', 'Charlie Noades R.I.P', 2011, 1, 'tt1409084'),
#  ('Movie', 'Campus Radio', 2011, None, 'tt1409006'),
#  ('Movie',
#   'Swooped: Based on a Real Life Occurrence',
#   2011,
#   None,
#   'tt1409805'),
#  ('Movie', 'No Strings Attached', 2011, 2, 'tt1411238'),
#  ('Movie', 'Bucky Larson: Born to Be a Star', 2011, 9, 'tt1411664'),
#  ('Movie', 'Hop', 2011, 3, 'tt1411704'),
#  ('Movie', 'The Hangover Part II', 2011, 5, 'tt1411697'),
#  ('Movie', 'The Best Exotic Marigold Hotel', 2012, 3, 'tt1412386'),
#  ('Movie', 'Cougar Hunting', 2011, 4, 'tt1413489'),
#  ('Movie', 'Torrente 4', 2011, 3, 'tt1417108'),
#  ('Movie', 'Happy Life', 2011, 1, 'tt1421366'),
#  ('Movie', 'Losers Take All', 2013, 10, 'tt1426748'),
#  ('Movie', 'Wie man leben soll', 2011, 10, 'tt1428464'),
#  ('Movie', 'Mening akam boydoq', 2011, None, 'tt14296152'),
#  ('Movie', 'Valley of the Sun', 2011, 5, 'tt1429411'),
#  ('Movie', 'Floquet de Neu', 2011, 12, 'tt1429433'),
#  ('Movie', 'Act Naturally', 2020, 6, 'tt1430070'),
#  ('Movie', 'Arthur Christmas', 2011, 11, 'tt1430607'),
#  ('Movie', 'Die Relativitätstheorie der Liebe', 2011, 5, 'tt1430631'),
#  ('Movie', 'The Details', 2016, 3, 'tt1433207'),
#  ('Movie', 'Hysteria', 2011, 12, 'tt1435513'),
#  ('Movie', 'UnExpecting', 2011, 4, 'tt1436048'),
#  ('Movie', 'Love, Wedding, Marriage', 2011, 6, 'tt1436559'),
#  ('Movie', 'Rio', 2011, 4, 'tt1436562'),
#  ('Movie', 'Fright Night', 2011, 9, 'tt1438176'),
#  ('Movie', 'A Little Bit of Heaven', 2012, 5, 'tt1440161'),
#  ('Movie', 'This Must Be the Place', 2012, 4, 'tt1440345'),
#  ('Movie', 'Share el-Haram', 2011, 8, 'tt14412286'),
#  ('Movie', 'Salmon Fishing in the Yemen', 2012, 5, 'tt1441952'),
#  ('Movie', 'Politics of Love', 2011, 8, 'tt1444270'),
#  ('Movie', 'Hearat Shulayim', 2012, 4, 'tt1445520'),
#  ('Movie', 'Cat Run', 2011, 4, 'tt1446147'),
#  ('Movie', 'A Kiss for Jed Wood', 2011, 5, 'tt1446672'),
#  ('Movie', 'Winnie the Pooh', 2011, 4, 'tt1449283'),
#  ('Movie', 'Roadie', 2012, 1, 'tt1450330'),
#  ('Movie', 'Kickoff', 2011, 4, 'tt1450326'),
#  ('Movie', 'A Encomenda de Maria Formosa', 2011, None, 'tt14512914'),
#  ('Movie', 'Hexe Lilli: Die Reise nach Mandolan', 2011, 4, 'tt1452293'),
#  ('Movie', 'Oh My Grease!', 2011, 0, 'tt14546104'),
#  ('Movie', 'Habemus Papam', 2011, 10, 'tt1456472'),
#  ('Movie', 'Goon', 2012, 2, 'tt1456635'),
#  ('Movie', 'Trophy Kids', 2011, None, 'tt1457045'),
#  ('Movie', 'Searching for Sonny', 2011, 10, 'tt1456939'),
#  ('Movie', 'Big Mommas: Like Father, Like Son', 2011, 3, 'tt1464174'),
#  ('Movie', 'Odcházení', 2011, 3, 'tt1464251'),
#  ('Movie', 'Lecciones para un Beso', 2011, 4, 'tt1465497'),
#  ('Movie', 'Happy Husbands', 2011, 3, 'tt1465488'),
#  ('Movie', 'The Italian Key', 2011, 12, 'tt1465513'),
#  ('Movie', 'Cloudburst', 2011, 9, 'tt1466054'),
#  ('Movie', 'Monster Mutt', 2011, 1, 'tt1468727'),
#  ('Movie', "One Week to Bill's Thing", 2011, None, 'tt1468842'),
#  ('Movie', 'London Fog', 2011, None, 'tt1469888'),
#  ('Movie', 'Getting That Girl', 2011, 10, 'tt1472082'),
#  ('Movie', 'The Moleman of Belmont Avenue', 2013, 9, 'tt1472192'),
#  ('Movie', 'Lucky', 2011, 7, 'tt1473397'),
#  ('Movie', 'Lizard Boy', 2011, 8, 'tt1474456'),
#  ('Movie', 'Operation Mongoose.', 2011, 4, 'tt1474817'),
#  ('Movie', 'Bite Me: The Movie', 2011, None, 'tt1475205'),
#  ('Movie', 'About Fifty', 2011, 1, 'tt1477118'),
#  ('Movie', 'Cedar Rapids', 2011, 3, 'tt1477837'),
#  ('Movie', 'Bridesmaids', 2011, 7, 'tt1478338'),
#  ('Movie', 'The Funniest Movie Ever... Just Kidding', 2011, 2, 'tt1478448'),
#  ('Movie', 'Attack the Block', 2011, 7, 'tt1478964'),
#  ('Movie', 'Kurteist fólk', 2011, 3, 'tt1479688'),
#  ('Movie', '6 Nonsmokers', 2013, 1, 'tt1482104'),
#  ('Movie', 'The Trouble with Bliss', 2012, 3, 'tt1483756'),
#  ('Movie', 'Padduram', 2011, None, 'tt1484102'),
#  ('Movie', 'Rifftrax: Highlander', 2011, 3, 'tt14843854'),
#  ('Movie', 'Zamonaviy sovchilar', 2011, None, 'tt14852156'),
#  ('Movie', 'Meeting Spencer', 2011, 4, 'tt1486186'),
#  ('Movie', 'Chalet Girl', 2011, 2, 'tt1487118'),
#  ('Movie', 'Answer This!', 2011, 5, 'tt1488164'),
#  ('Movie', 'The Change-Up', 2011, 10, 'tt1488555'),
#  ('Movie', '¿Estás ahí?', 2011, 4, 'tt1490651'),
#  ('Movie', 'Pankot ne e mrtov', 2011, 4, 'tt1493068'),
#  ('Movie', 'Psycho Street', 2011, 7, 'tt1493823'),
#  ('Movie', 'Tim Hawkins: Rockshow Comedy Tour', 2011, 6, 'tt14938440'),
#  ('Movie', 'Naneh Noghli', 2011, None, 'tt14951478'),
#  ('Movie', '(No) Laughing Matter', 2011, 4, 'tt1496374'),
#  ('Movie', 'Mayor Cupcake', 2011, 7, 'tt1496798'),
#  ('Movie', 'Horrible Bosses', 2011, 7, 'tt1499658'),
#  ('Movie', 'Swinging with the Finkels', 2011, 6, 'tt1502420'),
#  ('Movie', 'Damadamm!', 2011, 10, 'tt1503640'),
#  ('Movie', 'Booted', 2011, 0, 'tt1504353'),
#  ('Movie', 'Memoria de mis putas tristes', 2012, 5, 'tt1504019'),
#  ('Movie', 'Fast Romance', 2011, 7, 'tt1504385'),
#  ('Movie', 'Soap on a Rope', 2011, 1, 'tt1505411'),
#  ('Movie', 'Le Havre', 2012, 2, 'tt1508675'),
#  ('Movie', 'Spot Check', 2011, 5, 'tt1508962'),
#  ('Movie', 'A Bag of Hammers', 2011, 3, 'tt1509787'),
#  ('Movie', 'Sweet Little Lies', 2011, 6, 'tt1510987'),
#  ('Movie', 'Losing Control', 2012, 3, 'tt1511425'),
#  ('Movie', 'The Convincer', 2013, 6, 'tt1512240'),
#  ('Movie', 'My Friend Pinto', 2011, 10, 'tt1512220'),
#  ('Movie', 'Playing Warriors', 2011, 10, 'tt15122780'),
#  ('Movie', "Trippin'", 2011, 1, 'tt1516595'),
#  ('Movie', 'Sedona', 2011, 2, 'tt1516577'),
#  ('Movie', 'Spy Kids 4: All the Time in the World', 2011, 10, 'tt1517489'),
#  ('Movie', "Love's Kitchen", 2011, 6, 'tt1519663'),
#  ('Movie', 'Adultolescence', 2011, 4, 'tt1521655'),
#  ('Movie', 'Doortocht', 2011, 5, 'tt15223242'),
#  ('Movie', 'Prometeo Deportado', 2011, 9, 'tt1522250'),
#  ('Movie', 'Apocalypse According to Doris', 2011, None, 'tt1522841'),
#  ('Movie', "Tomorrow's End", 2011, 0, 'tt1523972'),
#  ('Movie', 'Orcs!', 2014, 9, 'tt1524134'),
#  ('Movie', 'Defining Beauty: Ms. Wheelchair America', 2011, 5, 'tt1525571'),
#  ('Movie', "Calvin's Dream", 2013, None, 'tt1528278'),
#  ('Movie', 'Brainwashed Love', 2011, 10, 'tt1528274'),
#  ('Movie', 'Hotel Lux', 2011, 10, 'tt1529559'),
#  ('Movie', 'Julia X', 2013, 7, 'tt1533058'),
#  ('Movie', 'Killing Bono', 2011, 4, 'tt1535101'),
#  ('Movie', 'Head Over Spurs in Love', 2011, 3, 'tt1535100'),
#  ('Movie', 'A Novel Romance', 2011, 11, 'tt1535102'),
#  ('Movie', 'When Harry Tries to Marry', 2011, 4, 'tt1535110'),
#  ('Movie', "C'è chi dice no", 2011, 4, 'tt1535429'),
#  ('Movie', 'Stuck Between Stations', 2011, 4, 'tt1536440'),
#  ('Movie', 'A quién llamarías?', 2011, 12, 'tt1537173'),
#  ('Movie', 'Americatown', 2011, 1, 'tt1537382'),
#  ('Movie', 'The Annual', 2011, 5, 'tt1537909'),
#  ('Movie', 'The South Side Chapter', 2011, None, 'tt1540064'),
#  ('Movie', 'The Return of Joe Rich', 2011, 10, 'tt1540014'),
#  ('Movie', 'The Guard', 2011, 10, 'tt1540133'),
#  ('Movie', 'Hold on Loosely', 2011, None, 'tt1540418'),
#  ('Movie', 'Faith, Fraud, & Minimum Wage', 2011, 11, 'tt1540404'),
#  ('Movie', 'The Cocktail for a Star 2', 2011, 12, 'tt15415654'),
#  ('Movie', 'Flypaper', 2011, 9, 'tt1541160'),
#  ('Movie', 'Yoko/Schmono', 2011, 5, 'tt1542046'),
#  ('Movie', 'Knots', 2019, 3, 'tt1542484'),
#  ('Movie', 'Die Superbullen - Sie kennen keine Gnade', 2011, 1, 'tt1543252'),
#  ('Movie', 'Spoonfed Reality', 2011, None, 'tt1543879'),
#  ('Movie', 'Action Figures', 2011, 11, 'tt15444568'),
#  ('Movie', 'Chop', 2011, 4, 'tt1544578'),
#  ('Movie', 'Desert Rain', 2011, None, 'tt1545056'),
#  ('Movie', 'Orla Frøsnapper', 2011, 6, 'tt1545319'),
#  ('Movie', 'Whole Lotta Sole', 2013, 1, 'tt1545328'),
#  ('Movie', 'Without Men', 2012, 2, 'tt1547090'),
#  ('Movie', 'Judy Moody and the Not Bummer Summer', 2011, 6, 'tt1547230'),
#  ('Movie', 'Shakespeare, You Say?', 2011, None, 'tt1547993'),
#  ('Movie', 'Le fils à Jo', 2011, 1, 'tt1548603'),
#  ('Movie', 'The Selling', 2012, 8, 'tt1552214'),
#  ('Movie', 'The Dish & the Spoon', 2012, 2, 'tt1554414'),
#  ('Movie', 'Blood Effects', 2012, 8, 'tt1554549'),
#  ('Movie', 'Collaborator', 2012, 7, 'tt1555058'),
#  ('Movie', 'Frank & Jerry', 2011, 5, 'tt1554958'),
#  ('Movie', 'Up the Aisle', 2011, 0, 'tt1555153'),
#  ('Movie', 'Do Not Disturb', 2011, 5, 'tt1558249'),
#  ('Movie', 'Reality Check: The Musical', 2011, 0, 'tt1560709'),
#  ('Movie', 'Ova ne e amerikanski film', 2011, 2, 'tt1562401'),
#  ('Movie', 'Zindagi Na Milegi Dobara', 2011, 7, 'tt1562872'),
#  ('Movie', "Division III: Football's Finest", 2011, 10, 'tt1562849'),
#  ('Movie', 'Jensen & Jensen', 2011, 8, 'tt1563776'),
#  ('Movie', 'Just Go with It', 2011, 4, 'tt1564367'),
#  ('Movie', 'Genau', 2011, None, 'tt1566589'),
#  ('Movie', 'Amor Amor Amor: Capitulo Uno', 2011, 9, 'tt15676160'),
#  ('Movie', 'Some Guy Who Kills People', 2012, 10, 'tt1568341'),
#  ('Movie', 'Loosies', 2011, 11, 'tt1568337'),
#  ('Movie', 'Crazy, Stupid, Love.', 2011, 9, 'tt1570728'),
#  ('Movie', 'Mangus!', 2011, 4, 'tt1571406'),
#  ('Movie', 'Textuality', 2011, 4, 'tt1573483'),
#  ('Movie', 'Juntos para siempre', 2011, 6, 'tt1576405'),
#  ('Movie', 'Mijn Opa de Bankrover', 2011, 2, 'tt1576433'),
#  ('Movie', 'Goombah', 2011, None, 'tt1579234'),
#  ('Movie', 'Assalto ao Banco Central', 2011, 7, 'tt1579223'),
#  ('Movie', 'The Dilemma', 2011, 2, 'tt1578275'),
#  ('Movie', "Harold's Going Stiff", 2012, 8, 'tt1579235'),
#  ('Movie', '99 Percent Sure', 2011, 11, 'tt1582358'),
#  ('Movie', 'Sunny Side Up', 2012, 6, 'tt1582268'),
#  ('Movie', 'Larry Crowne', 2011, 8, 'tt1583420'),
#  ('Movie', 'Big Fat Gypsy Gangster', 2011, 9, 'tt1582196'),
#  ('Movie', 'The Night Shift', 2011, 10, 'tt1584937'),
#  ('Movie', 'Wickie auf großer Fahrt', 2012, 5, 'tt1584941'),
#  ('Movie', 'Summertime', 2011, None, 'tt1585660'),
#  ('Movie', 'The Power of Three', 2011, 11, 'tt1588409'),
#  ('Movie', 'The Cost of Love', 2011, None, 'tt1587427'),
#  ('Movie', "Wong Flew Over the Cuckoo's Nest", 2011, 10, 'tt1587387'),
#  ('Movie', 'Love Songs of a Third Grade Teacher', 2011, None, 'tt1587212'),
#  ('Movie', 'Jeff, Who Lives at Home', 2012, 3, 'tt1588334'),
#  ('Movie', 'Bar Room Hero', 2011, 10, 'tt1590808'),
#  ('Movie', "Big Mamma's Boy", 2011, 7, 'tt1590960'),
#  ('Movie', 'Shower Frown', 2013, 10, 'tt1591086'),
#  ('Movie', 'Forgotten Soul', 2011, 10, 'tt1590030'),
#  ('Movie', 'Primos', 2011, 2, 'tt1592521'),
#  ('Movie', 'Take This Waltz', 2012, 8, 'tt1592281'),
#  ('Movie', 'La brújula la lleva el muerto', 2013, 3, 'tt1593714'),
#  ('Movie', 'Manzai gyangu', 2011, 3, 'tt1591638'),
#  ('Movie', 'The Victorville Massacre', 2011, 3, 'tt1595025'),
#  ('Movie', 'The Lutefisk Wars', 2011, 3, 'tt1595379'),
#  ('Movie', "New Year's Eve", 2011, 12, 'tt1598822'),
#  ('Movie', 'Skeem', 2011, 10, 'tt1598609'),
#  ('Movie', 'Going Down in LA-LA Land', 2011, 5, 'tt1599296'),
#  ('Movie', 'Scents and Sensibility', 2011, 5, 'tt1600438'),
#  ('Movie', 'Prom', 2011, 4, 'tt1604171'),
#  ('Movie', 'Midnight in Paris', 2011, 9, 'tt1605783'),
#  ('Movie', 'Ein Tick anders', 2011, 7, 'tt1605735'),
#  ('Movie', 'Pussikaljaelokuva', 2011, 9, 'tt1606657'),
#  ('Movie', 'Roskisprinssi', 2011, 7, 'tt1606385'),
#  ('Movie', 'Avan Ivan', 2011, 6, 'tt1606376'),
#  ('Movie', 'Age Is Just a Word', 2011, 0, 'tt1606351'),
#  ('Movie', 'Showreel', 2012, 10, 'tt1606667'),
#  ('Movie', 'Sommer in Orange', 2011, 8, 'tt1608334'),
#  ('Movie', "That's What I Am", 2011, 4, 'tt1606180'),
#  ('Movie', 'Win Win', 2011, 4, 'tt1606392'),
#  ('Movie', 'Tage die bleiben', 2012, 1, 'tt1609483'),
#  ('Movie', 'A Heaven for Queers', 2011, None, 'tt1608338'),
#  ('Movie', 'Åsa-Nisse - Wälkom to Knohult', 2011, 2, 'tt1609808'),
#  ('Movie', 'Superclásico', 2012, 5, 'tt1609492'),
#  ('Movie', 'Language of a Broken Heart', 2013, 6, 'tt1609488'),
#  ('Movie', 'Calendar Girl', 2010, 9, 'tt1611816'),
#  ('Movie', 'El alma de las moscas', 2012, 7, 'tt1612305'),
#  ('Movie', 'A Heartbeat Away', 2011, 3, 'tt1612793'),
#  ('Movie', 'Potpourri', 2011, 10, 'tt1613874'),
#  ('Movie', 'Cellmates', 2013, 3, 'tt1615480'),
#  ('Movie', 'Alvin and the Chipmunks: Chipwrecked', 2011, 12, 'tt1615918'),
#  ('Movie', 'Los inadaptados', 2011, 3, 'tt1616108'),
#  ('Movie', 'Dealing with Destiny', 2011, 0, 'tt1616084'),
#  ('Movie', 'Desire Street', 2011, 5, 'tt1617083'),
#  ('Movie', 'Single in the ATL', 2011, 2, 'tt1617654'),
#  ('Movie', 'Homecoming', 2011, 8, 'tt1618376'),
#  ('Movie', 'Finding Mr. Wright', 2012, 5, 'tt1619281'),
#  ('Movie', 'Conception', 2014, 11, 'tt1619277'),
#  ('Movie', '30 Minutes or Less', 2011, 8, 'tt1622547'),
#  ('Movie', 'L.A. Paranormal', 2011, 1, 'tt1621445'),
#  ('Movie', 'Natural Selection', 2012, 3, 'tt1621426'),
#  ('Movie', 'Into the Game', 2011, None, 'tt1621805'),
#  ('Movie', 'Night Club', 2011, 4, 'tt1623280'),
#  ('Movie', 'Almost in Love', 2011, 10, 'tt1622563'),
#  ('Movie', 'San kei hap lui', 2011, 2, 'tt1623759'),
#  ('Movie', 'Young Adult', 2012, 3, 'tt1625346'),
#  ('Movie', 'Balls to the Wall', 2011, 4, 'tt1626135'),
#  ('Movie', 'Foster', 2012, 11, 'tt1629443'),
#  ('Movie', 'Ronal Barbaren', 2012, 9, 'tt1629374'),
#  ('Movie', 'Los Marziano', 2011, 4, 'tt1629736'),
#  ('Movie', 'Almanya - Willkommen in Deutschland', 2011, 10, 'tt1630027'),
#  ('Movie', 'Sahi Dhandhe Galat Bande', 2011, 8, 'tt1630282'),
#  ('Movie', 'Immaturi', 2011, 1, 'tt1630637'),
#  ('Movie', 'Maggie Marvel', 2011, 3, 'tt1631359'),
#  ('Movie', 'UFO in Her Eyes', 2012, 4, 'tt1632728'),
#  ('Movie', 'Friends with Benefits', 2011, 9, 'tt1632708'),
#  ('Movie',
#   'Ôki-ke no tanoshii ryokô: Shinkon jigoku-hen',
#   2011,
#   5,
#   'tt1632577'),
#  ('Movie', 'Kill Keith', 2011, 11, 'tt1634141'),
#  ('Movie', 'Johnny English Reborn', 2011, 10, 'tt1634122'),
#  ('Movie', 'Violet & Daisy', 2013, 6, 'tt1634136'),
#  ('Movie', 'Purinsesu Toyotomi', 2011, 5, 'tt1635657'),
#  ('Movie', 'Love Birds', 2011, 2, 'tt1636539'),
#  ('Movie', 'What Happens Next', 2012, 2, 'tt1635659'),
#  ('Movie', 'Our Idiot Brother', 2012, 5, 'tt1637706'),
#  ('Movie', 'Jumping the Broom', 2011, 5, 'tt1640484'),
#  ('Movie', "L'amour dure trois ans", 2012, 1, 'tt1638328'),
#  ('Movie', 'Le Skylab', 2011, 10, 'tt1638350'),
#  ('Movie', 'Do It in Post', 2015, 12, 'tt1640445'),
#  ('Movie', 'Hobo with a Shotgun', 2011, 5, 'tt1640459'),
#  ('Movie', 'A Few Best Men', 2012, 10, 'tt1640711'),
#  ('Movie', 'Christmas with a Capital C', 2011, 12, 'tt1640116'),
#  ('Movie', 'Ma part du gâteau', 2011, 3, 'tt1641624'),
#  ('Movie', 'The Briefcase', 2011, 3, 'tt1641829'),
#  ('Movie', 'Chez Gino', 2011, 3, 'tt1642191'),
#  ('Movie', "And They're Off", 2011, 10, 'tt1644503'),
#  ('Movie', 'Panman', 2015, 4, 'tt1645126'),
#  ('Movie', 'Nintama Rantarô', 2011, 7, 'tt1644655'),
#  ('Movie', 'Scamelot', 2011, None, 'tt1645185'),
#  ('Movie', 'Walk a Mile in My Pradas', 2011, 11, 'tt1645187'),
#  ('Movie', 'Loveless', 2011, 2, 'tt1645769'),
#  ('Movie', 'Get a Job', 2011, 1, 'tt1645754'),
#  ('Movie', 'For Lovers Only', 2011, 5, 'tt1648201'),
#  ('Movie', 'Qwerty', 2016, None, 'tt1648207'),
#  ('Movie', 'Peace, Love & Misunderstanding', 2012, 8, 'tt1649780'),
#  ('Movie', 'Konzen tokkyû', 2011, 4, 'tt1649354'),
#  ('Movie', 'The Perfect Family', 2011, 4, 'tt1650058'),
#  ('Movie', 'Western Confidential', 2011, 10, 'tt1650023'),
#  ('Movie', 'Lobos de Arga', 2012, 7, 'tt1650555'),
#  ('Movie', 'Diary of a Wimpy Kid: Rodrick Rules', 2011, 3, 'tt1650043'),
#  ('Movie', 'Shapito-shou: Lyubov i druzhba', 2012, 1, 'tt1651118'),
#  ('Movie', 'Få meg på, for faen', 2011, 8, 'tt1650407'),
#  ('Movie', 'Resturlaub', 2011, 8, 'tt1650427'),
#  ('Movie', '35 and Ticking', 2011, 5, 'tt1652287'),
#  ('Movie', 'Mil cretins', 2011, 1, 'tt1654054'),
#  ('Movie', 'Amici miei - Come tutto ebbe inizio', 2011, 3, 'tt1656168'),
#  ('Movie', 'The Artist', 2011, 11, 'tt1655442'),
#  ('Movie', 'Bringing Up Bobby', 2011, None, 'tt1656170'),
#  ('Movie', 'Old Goats', 2011, 6, 'tt1656701'),
#  ('Movie', 'The Decoy Bride', 2012, 3, 'tt1657299'),
#  ('Movie', 'Honey 2', 2011, 8, 'tt1657283'),
#  ('Movie', 'Wretches & Jabberers', 2011, 4, 'tt1658501'),
#  ('Movie', 'Anuvahood', 2011, 3, 'tt1658797'),
#  ('Movie', 'Welcome to Gentle Waters', 2011, None, 'tt1659260'),
#  ('Movie', 'Salad Days', 2011, 10, 'tt1659342'),
#  ('Movie', 'Small Pond', 2011, 5, 'tt1659215'),
#  ('Movie', 'Cry of the Eagle', 2011, 7, 'tt1662671'),
#  ('Movie', 'What a Man', 2011, 8, 'tt1661461'),
#  ('Movie', 'The Chaperone', 2011, 3, 'tt1663187'),
#  ('Movie', 'Poulet aux prunes', 2012, 4, 'tt1663321'),
#  ('Movie', 'Hot Hot Hot', 2013, 1, 'tt1665412'),
#  ('Movie', 'Dorfman', 2013, 3, 'tt1665418'),
#  ('Movie', 'S.O.L.', 2011, 1, 'tt1665423'),
#  ('Movie', 'The Taint', 2011, 10, 'tt1667133'),
#  ('Movie', 'Turning 30!!!', 2011, 1, 'tt1666184'),
#  ('Movie', 'Lo contrario al amor', 2011, 8, 'tt1667108'),
#  ('Movie', 'Dadgum, Texas', 2011, 0, 'tt1666822'),
#  ('Movie', 'Up There', 2012, 11, 'tt1667102'),
#  ('Movie', 'F.A.L.T.U', 2011, 4, 'tt1667076'),
#  ('Movie', 'Lyubov-Morkov 3', 2011, 3, 'tt1666169'),
#  ('Movie', 'Virgin Alexander', 2011, 5, 'tt1667145'),
#  ('Movie', 'Wo zhi nv ren xin', 2011, 2, 'tt1667150'),
#  ('Movie', 'Balkan Bazaar', 2011, 4, 'tt1668046'),
#  ('Movie', 'Damsels in Distress', 2012, 4, 'tt1667307'),
#  ('Movie', 'Mozzarella Stories', 2011, None, 'tt1667438'),
#  ('Movie', 'Surrogate Valentine', 2011, 9, 'tt1669277'),
#  ('Movie', 'The A Plate', 2012, 8, 'tt1669779'),
#  ('Movie', 'La vita facile', 2011, 3, 'tt1669625'),
#  ('Movie', 'Senza arte né parte', 2011, 5, 'tt1669687'),
#  ('Movie', 'Une pure affaire', 2011, 3, 'tt1669694'),
#  ('Movie', 'Einer wie Bruno', 2012, 4, 'tt1670388'),
#  ('Movie', 'American Animal', 2011, 3, 'tt1670932'),
#  ('Movie', 'CornerStore', 2021, 7, 'tt1670389'),
#  ('Movie', "You Laugh But It's True", 2013, 12, 'tt1671547'),
#  ('Movie', 'Tomme tønner 2 - Det brune gullet', 2011, 1, 'tt1671492'),
#  ('Movie', 'Tutti al mare', 2011, 3, 'tt1672185'),
#  ('Movie', 'Usagi doroppu', 2011, 8, 'tt1672214'),
#  ('Movie', 'Varasto', 2011, 12, 'tt1672215'),
#  ('Movie', 'You Instead', 2012, 8, 'tt1672845'),
#  ('Movie', 'Et si on vivait tous ensemble?', 2012, 7, 'tt1674057'),
#  ('Movie', 'Exit 101', 2011, 10, 'tt1674185'),
#  ('Movie', 'Little Johnny: The Movie', 2011, 4, 'tt1674086'),
#  ('Movie', 'Intouchables', 2012, 3, 'tt1675434'),
#  ('Movie', 'Lloyd the Conqueror', 2012, 11, 'tt1675439'),
#  ('Movie', 'French Immersion', 2011, 10, 'tt1674692'),
#  ...]

# %%
len(lista_json_anios)
# Out:
# 48

# %%
encabezado = ["Tipo", "Título", "Año", "Mes", "ID"]

# %%
df_comedy_2000_2023 = pd.DataFrame(datos_final, columns = encabezado)

df_comedy_2000_2023
# Out:
#         Tipo                     Título     Año   Mes         ID
# 0      Movie         This Wretched Life  2010.0   7.0  tt0331312
# 1      Movie                Blind Sided  2010.0   0.0  tt0337882
# 2      Movie           Anderson's Cross  2010.0   5.0  tt0393049
# 3      Movie                    Tangled  2010.0  12.0  tt0398286
# 4      Movie              Venus & Vegas  2010.0  11.0  tt0423474
# ...      ...                        ...     ...   ...        ...
# 23995  Short              Dirty Laundry  2009.0   6.0  tt1377681
# 23996  Short              All Broken Up  2009.0   3.0  tt1378178
# 23997  Short                  In Dreams  2009.0   0.0  tt1378267
# 23998  Short  Chlamydia Is Not a Flower  2009.0   2.0  tt1378214
# 23999  Short               Brain Freeze  2009.0   2.0  tt1378200
#
# [24000 rows x 5 columns]

# %%
df_comedy_2000_2023.to_csv("comedy.csv")
