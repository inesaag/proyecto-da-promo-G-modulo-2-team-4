# %%
import mysql.connector
from mysql.connector import errorcode


import pandas as pd
import numpy as np

# %%
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1')
  print("Conexion establecida")

except mysql.connector.Error as err:

  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  else:
    print(err)
# Out:
# Conexion establecida

# %%
df_actor_peli = pd.read_csv("pelis_actores.csv")

# %%
df_actor_peli .head()
# Out:
#       pelicula              actor
# 0  In My Sleep  Philip Winchester
# 1  In My Sleep      Lacey Chabert
# 2  In My Sleep    Abigail Spencer
# 3  In My Sleep      Kelly Overton
# 4  In My Sleep          Tony Hale

# %%
lista_pelis_actores = df_actor_peli .values.tolist()

# %%
lista_pelis_actores
# Out:
# [['In My Sleep', 'Philip Winchester'],
#  ['In My Sleep', 'Lacey Chabert'],
#  ['In My Sleep', 'Abigail Spencer'],
#  ['In My Sleep', 'Kelly Overton'],
#  ['In My Sleep', 'Tony Hale'],
#  ['In My Sleep', 'Michael Badalucco'],
#  ['In My Sleep', 'Amy Aquino'],
#  ['In My Sleep', 'Tim Draxl'],
#  ["Anderson's Cross", 'Jerome Elston Scott'],
#  ["Anderson's Cross", 'Nicholas Downs'],
#  ["Anderson's Cross", 'Heather Bergdahl'],
#  ["Anderson's Cross", 'Michael Warren'],
#  ["Anderson's Cross", 'Joyce Guy'],
#  ["Anderson's Cross", 'Joanna Cassidy'],
#  ["Anderson's Cross", 'Bill Moseley'],
#  ["Anderson's Cross", 'Micah Stuart'],
#  ['Utomlennye solntsem 2', 'Nikita Mijalkov'],
#  ['Utomlennye solntsem 2', 'Nadezhda Mijalkova'],
#  ['Utomlennye solntsem 2', 'Oleg Ménshikov'],
#  ['Utomlennye solntsem 2', 'Yevgeny Mironov'],
#  ['Utomlennye solntsem 2', 'Vladimir Adolfovich Ilyin'],
#  ['Utomlennye solntsem 2', 'Serguéi Makovetski'],
#  ['Utomlennye solntsem 2', 'Dmitri Dyuzhev'],
#  ['Utomlennye solntsem 2', 'Andrey Merzlikin'],
#  ['Tekken', 'Kelly Overton'],
#  ['Tekken', 'Candîce Hillebrand'],
#  ['Tekken', 'Cary-Hiroyuki Tagawa'],
#  ['Tekken', 'Lateef Crowder Dos Santos'],
#  ['Tekken', 'Luke Goss'],
#  ['Tekken', 'Gary Daniels'],
#  ['Tekken', 'Mircea Monroe'],
#  ['Tekken', 'Tamlyn Tomita'],
#  ['Milenge Milenge', 'Shahid Kapoor'],
#  ['Milenge Milenge', 'Kareena Kapoor'],
#  ['Milenge Milenge', 'Satish Kaushik'],
#  ['Milenge Milenge', 'Delnaaz Irani'],
#  ['Milenge Milenge', 'Satish Shah'],
#  ['Milenge Milenge', 'Aarti Chhabria'],
#  ['Milenge Milenge', 'Sarfaraz khan'],
#  ['Milenge Milenge', 'Kirron Kher'],
#  ['Les 7 jours du talion', 'Martin Dubreuil'],
#  ['Les 7 jours du talion', 'Claude Legault'],
#  ['Les 7 jours du talion', 'Rémy Girard'],
#  ['Les 7 jours du talion', 'Rose-Marie Coallier'],
#  ['Les 7 jours du talion', 'Pascale Delhaes'],
#  ['Les 7 jours du talion', 'Fanny Mallette'],
#  ['Les 7 jours du talion', 'Alexandre Goyette'],
#  ['Les 7 jours du talion', 'Dominique Quesnel'],
#  ['Vidas pequeñas', 'Ángela Molina'],
#  ['Vidas pequeñas', 'Roberto Enríquez'],
#  ['Vidas pequeñas', 'Emilio Gutiérrez Caba'],
#  ['Vidas pequeñas', 'Alicia Borrachero'],
#  ['Vidas pequeñas', 'Ana Gracia'],
#  ['Vidas pequeñas', 'Rubén Ochandiano'],
#  ['Vidas pequeñas', 'Yohana Cobo'],
#  ['Vidas pequeñas', 'Asunción Balaguer'],
#  ['Cielito lindo', 'Arturo de Córdova'],
#  ['Cielito lindo', 'Lucha Reyes'],
#  ['Cielito lindo', 'Leonor Gomez'],
#  ['Cielito lindo', 'Carlos López "Chaflán"'],
#  ['Cielito lindo', 'Max Langler'],
#  ['Cielito lindo', 'Miguel Wimer'],
#  ['Cielito lindo', 'Lupita Gallardo'],
#  ['Cielito lindo', 'Alfonso Parra'],
#  ['Barry Munday', 'Judy Greer'],
#  ['Barry Munday', 'Patrick Wilson'],
#  ['Barry Munday', 'Chloë Sevigny'],
#  ['Barry Munday', 'Jean Smart'],
#  ['Barry Munday', 'Malcolm McDowell'],
#  ['Barry Munday', 'Barry Habib'],
#  ['Barry Munday', 'Colin Hanks'],
#  ['Barry Munday', 'Cybill Shepherd'],
#  ['A Woman Is a Woman', 'Anna Karina'],
#  ['A Woman Is a Woman', 'Jean-Paul Belmondo'],
#  ['A Woman Is a Woman', 'Jean-Claude Brialy'],
#  ['A Woman Is a Woman', 'Catherine Demongeot'],
#  ['A Woman Is a Woman', 'Dorothée Blanck'],
#  ['A Woman Is a Woman', 'Gérard Hoffmann'],
#  ['A Woman Is a Woman', 'Noel Pacquin'],
#  ['A Woman Is a Woman', 'György Cserhalmi'],
#  ['Ramona and Beezus', 'Joey King'],
#  ['Ramona and Beezus', 'Selena Gomez'],
#  ['Ramona and Beezus', 'Ginnifer Goodwin'],
#  ['Ramona and Beezus', 'John Corbett'],
#  ['Ramona and Beezus', 'Josh Duhamel'],
#  ['Ramona and Beezus', 'Bridget Moynahan'],
#  ['Ramona and Beezus', 'Sandra Oh'],
#  ['Ramona and Beezus', 'Hutch Dano'],
#  ['Love & Other Drugs', 'Anne Hathaway'],
#  ['Love & Other Drugs', 'Jake Gyllenhaal'],
#  ['Love & Other Drugs', 'Oliver Platt'],
#  ['Love & Other Drugs', 'Gabriel Macht'],
#  ['Love & Other Drugs', 'Judy Greer'],
#  ['Love & Other Drugs', 'Katheryn Winnick'],
#  ['Love & Other Drugs', 'Josh Gad'],
#  ['Love & Other Drugs', 'Hank Azaria'],
#  ['Night Catches Us', 'Anthony Mackie'],
#  ['Night Catches Us', 'Kerry Washington'],
#  ['Night Catches Us', 'Jamie Hector'],
#  ['Night Catches Us', 'Jamara Griffin'],
#  ['Night Catches Us', 'Wendell Pierce'],
#  ['Night Catches Us', 'Amari Cheatom'],
#  ['Night Catches Us', 'Novella Nelson'],
#  ['Night Catches Us', 'Ron Simons'],
#  ['The Wolfman', 'Benicio del Toro'],
#  ['The Wolfman', 'Anthony Hopkins'],
#  ['The Wolfman', 'Emily Blunt'],
#  ['The Wolfman', 'Hugo Weaving'],
#  ['The Wolfman', 'Art Malik'],
#  ['The Wolfman', 'Geraldine Chaplin'],
#  ['The Wolfman', 'Rick Baker'],
#  ['The Wolfman', 'Michael Cronin'],
#  ['Ironmen', 'Robert Downey Jr.'],
#  ['Ironmen', 'Jon Favreau'],
#  ['Ironmen', 'Gwyneth Paltrow'],
#  ['Ironmen', 'Jeff Bridges'],
#  ['Ironmen', 'Terrence Howard'],
#  ['Ironmen', 'Leslie Bibb'],
#  ['Ironmen', 'Stan Lee'],
#  ['Ironmen', 'Paul Bettany'],
#  ["It's Kind of a Funny Story", 'Zach Galifianakis'],
#  ["It's Kind of a Funny Story", 'Keir Gilchrist'],
#  ["It's Kind of a Funny Story", 'Emma Roberts'],
#  ["It's Kind of a Funny Story", 'Dana DeVestern'],
#  ["It's Kind of a Funny Story", 'Viola Davis'],
#  ["It's Kind of a Funny Story", 'Lauren Graham'],
#  ["It's Kind of a Funny Story", 'Ben Folstein'],
#  ["It's Kind of a Funny Story", 'Jim Gaffigan'],
#  ['Flipped', 'Madeline Carroll'],
#  ['Flipped', 'Callan McAuliffe'],
#  ['Flipped', 'Morgan Lily'],
#  ['Flipped', 'Israel Broussard'],
#  ['Flipped', 'Stefanie Scott'],
#  ['Flipped', 'Cody Horn'],
#  ['Flipped', 'Kevin Weisman'],
#  ['Flipped', 'John Mahoney'],
#  ['Soupernatural', 'Jensen Ackles'],
#  ['Soupernatural', 'Jared Padalecki'],
#  ['Soupernatural', 'Misha Collins'],
#  ['Soupernatural', 'Mark Sheppard'],
#  ['Soupernatural', 'Jim Beaver'],
#  ['Soupernatural', 'Jeffrey Dean Morgan'],
#  ['Soupernatural', 'Alexander Calvert'],
#  ['Soupernatural', 'Genevieve Cortese'],
#  ['Waking Madison', 'Elisabeth Shue'],
#  ['Waking Madison', 'Sarah Roemer'],
#  ['Waking Madison', 'Taryn Manning'],
#  ['Waking Madison', 'Imogen Poots'],
#  ['Waking Madison', 'Erin Kelly'],
#  ['Waking Madison', 'Frances Conroy'],
#  ['Waking Madison', 'Will Patton'],
#  ['Waking Madison', 'Conner Ann Waterman'],
#  ['The Town', 'Ben Affleck'],
#  ['The Town', 'Rebecca Hall'],
#  ['The Town', 'Jeremy Renner'],
#  ['The Town', 'Blake Lively'],
#  ['The Town', 'Pete Postlethwaite'],
#  ['The Town', 'Jon Hamm'],
#  ['The Town', 'Titus Welliver'],
#  ['The Town', 'Owen Burke'],
#  ['Risen', 'Joseph Fiennes'],
#  ['Risen', 'Cliff Curtis'],
#  ['Risen', 'Tom Felton'],
#  ['Risen', 'Peter Firth'],
#  ['Risen', 'María Botto'],
#  ['Risen', 'Stephen Hagan'],
#  ['Risen', 'Richard Atwill'],
#  ['Risen', 'James Shilaimon'],
#  ['Please Give', 'Catherine Keener'],
#  ['Please Give', 'Rebecca Hall'],
#  ['Please Give', 'Amanda Peet'],
#  ['Please Give', 'Oliver Platt'],
#  ['Please Give', 'Sarah Steele'],
#  ['Please Give', 'Lois Smith'],
#  ['Please Give', 'Elizabeth Keener'],
#  ['Please Give', 'John Srednicki'],
#  ['Eat Pray Love', 'Julia Roberts'],
#  ['Eat Pray Love', 'Javier Bardem'],
#  ['Eat Pray Love', 'James Franco'],
#  ['Eat Pray Love', 'Richard Jenkins'],
#  ['Eat Pray Love', 'Billy Crudup'],
#  ['Eat Pray Love', 'Hadi Subiyanto'],
#  ['Eat Pray Love', 'Viola Davis'],
#  ['Eat Pray Love', 'I. Gusti Ayu Puspawati'],
#  ['Repo', 'Ben Gourley'],
#  ['Repo', 'Jason Mewes'],
#  ['Repo', 'Izabella Miko'],
#  ['Repo', 'Lindsey McKeon'],
#  ['Repo', 'Sunny Mabrey'],
#  ['Repo', 'Zack Ward'],
#  ['Repo', 'Patrick Muldoon'],
#  ['Repo', 'Rhett Willman'],
#  ['Letters to Juliet', 'Amanda Seyfried'],
#  ['Letters to Juliet', 'Christopher Egan'],
#  ['Letters to Juliet', 'Vanessa Redgrave'],
#  ['Letters to Juliet', 'Gael García Bernal'],
#  ['Letters to Juliet', 'Franco Nero'],
#  ['Letters to Juliet', 'Giordano Formenti'],
#  ['Letters to Juliet', 'Marcia DeBonis'],
#  ['Letters to Juliet', 'Paolo Arvedi'],
#  ['The Whistleblower', 'Rachel Weisz'],
#  ['The Whistleblower', 'Vanessa Redgrave'],
#  ['The Whistleblower', 'Nikolaj Lie Kaas'],
#  ['The Whistleblower', 'Monica Bellucci'],
#  ['The Whistleblower', 'Rosabell Laurenti Sellers'],
#  ['The Whistleblower', 'Danny John-Jules'],
#  ['The Whistleblower', 'Mihai Ghior'],
#  ['The Whistleblower', 'Cristina Cristian'],
#  ['Acts of Violence', 'Bruce Willis'],
#  ['Acts of Violence', 'Cole Hauser'],
#  ['Acts of Violence', 'Sophia Bush'],
#  ['Acts of Violence', 'Mike Epps'],
#  ['Acts of Violence', 'Shawn Ashmore'],
#  ['Acts of Violence', 'Melissa Bolona'],
#  ['Acts of Violence', 'Ashton Holmes'],
#  ['Acts of Violence', 'Sean Brosnan'],
#  ['Proie', 'Albert Dupontel'],
#  ['Proie', 'Stéphane Debac'],
#  ['Proie', 'Alice Taglioni'],
#  ['Proie', 'Caterina Murino'],
#  ['Proie', 'Sergi López'],
#  ['Proie', 'Lucien Jean-Baptiste'],
#  ['Proie', 'Zinedine Soualem'],
#  ['Proie', 'Serge Hazanavicius'],
#  ['De gelukkige huisvrouw', 'Carice van Houten'],
#  ['De gelukkige huisvrouw', 'Waldemar Torenstra'],
#  ['De gelukkige huisvrouw', 'Marcel Hensema'],
#  ['De gelukkige huisvrouw', 'Jaap Spijkers'],
#  ['De gelukkige huisvrouw', 'Maike Meijer'],
#  ['De gelukkige huisvrouw', 'Gijs de Lange'],
#  ['De gelukkige huisvrouw', 'Willem de Wolf'],
#  ['De gelukkige huisvrouw', 'Myranda Jongeling'],
#  ['Truth About Kerry', 'Stana Katić'],
#  ['Truth About Kerry', 'Jessica Dean'],
#  ['Truth About Kerry', 'Darren Reiher'],
#  ['Truth About Kerry', 'Ryan C. King'],
#  ['Truth About Kerry', 'Tommy Fitzgerald'],
#  ['Truth About Kerry', 'Rick Yudt'],
#  ['Truth About Kerry', 'Chris Fitzgerald'],
#  ['Truth About Kerry', 'Teresa Riney'],
#  ['Glenn, the Flying Robot', 'Billy Boyd'],
#  ['Glenn, the Flying Robot', 'Patrick Bauchau'],
#  ['Glenn, the Flying Robot', 'Gérard Depardieu'],
#  ['Glenn, the Flying Robot', 'Smadi Wolfman'],
#  ['Glenn, the Flying Robot', 'Dominic Gould'],
#  ['Glenn, the Flying Robot', 'Geoffrey Carey'],
#  ['Glenn, the Flying Robot', 'Cinsyla Key'],
#  ['Glenn, the Flying Robot', 'George W. Contreras'],
#  ['Rabbit Hole', 'Kiefer Sutherland'],
#  ['Rabbit Hole', 'Meta Golding'],
#  ['Rabbit Hole', 'Charles Dance'],
#  ['Rabbit Hole', 'Jason Butler Harner'],
#  ['Rabbit Hole', 'Enid Graham'],
#  ['Rabbit Hole', 'Walt Klink'],
#  ['Rabbit Hole', 'Rob Yang'],
#  ['Rabbit Hole', 'Peter Weller'],
#  ['Green Zone', 'Matt Damon'],
#  ['Green Zone', 'Greg Kinnear'],
#  ['Green Zone', 'Jason Isaacs'],
#  ['Green Zone', 'Amy Ryan'],
#  ['Green Zone', 'Brendan Gleeson'],
#  ['Green Zone', 'Yigal Naor'],
#  ['Green Zone', 'Khalid Abdalla'],
#  ['Green Zone', 'Raad Rawi'],
#  ['Black Swan', 'Natalie Portman'],
#  ['Black Swan', 'Mila Kunis'],
#  ['Black Swan', 'Vincent Cassel'],
#  ['Black Swan', 'Winona Ryder'],
#  ['Black Swan', 'Barbara Hershey'],
#  ['Black Swan', 'Benjamin Millepied'],
#  ['Black Swan', 'Sebastian Stan'],
#  ['Black Swan', 'Sarah Lane'],
#  ['The Killer Inside Me', 'Casey Affleck'],
#  ['The Killer Inside Me', 'Jessica Alba'],
#  ['The Killer Inside Me', 'Kate Hudson'],
#  ['The Killer Inside Me', 'Simon Baker'],
#  ['The Killer Inside Me', 'Bill Pullman'],
#  ['The Killer Inside Me', 'Ned Beatty'],
#  ['The Killer Inside Me', 'Donna E. Jones'],
#  ['The Killer Inside Me', 'Caitlin Turner'],
#  ['The Fighter', 'Christian Bale'],
#  ['The Fighter', 'Mark Wahlberg'],
#  ['The Fighter', 'Micky Ward'],
#  ['The Fighter', 'Melissa Leo'],
#  ['The Fighter', 'Dicky Eklund'],
#  ['The Fighter', 'Bianca Hunter'],
#  ['The Fighter', 'Jack McGee'],
#  ['The Fighter', 'Frank Renzulli'],
#  ['The Conspirator', 'James McAvoy'],
#  ['The Conspirator', 'Robin Wright'],
#  ['The Conspirator', 'Kevin Kline'],
#  ['The Conspirator', 'Evan Rachel Wood'],
#  ['The Conspirator', 'Alexis Bledel'],
#  ['The Conspirator', 'Justin Long'],
#  ['The Conspirator', 'Tom Wilkinson'],
#  ['The Conspirator', 'Toby Kebbell'],
#  ['Fair Game', 'Naomi Watts'],
#  ['Fair Game', 'Sean Penn'],
#  ['Fair Game', 'Noah Emmerich'],
#  ['Fair Game', 'Sam Shepard'],
#  ['Fair Game', 'Michael Kelly'],
#  ['Fair Game', 'Ty Burrell'],
#  ['Fair Game', 'Bruce McGill'],
#  ['Fair Game', 'Brooke Smith'],
#  ['Multiple Sarcasms', 'Timothy Hutton'],
#  ['Multiple Sarcasms', 'Mira Sorvino'],
#  ['Multiple Sarcasms', 'Mario Van Peebles'],
#  ['Multiple Sarcasms', 'Dana Delany'],
#  ['Multiple Sarcasms', 'Stockard Channing'],
#  ['Multiple Sarcasms', 'India Ennenga'],
#  ['Multiple Sarcasms', 'Aileen Quinn'],
#  ['Multiple Sarcasms', 'Brett Berg'],
#  ['Dear John', 'Channing Tatum'],
#  ['Dear John', 'Amanda Seyfried'],
#  ['Dear John', 'Richard Jenkins'],
#  ['Dear John', 'Scott Porter'],
#  ['Dear John', 'Henry Thomas'],
#  ['Dear John', 'Gavin McCulley'],
#  ['Dear John', 'Luke Benward'],
#  ['Dear John', 'Bryce Hogarth'],
#  ['The Experiment', 'Forest Whitaker'],
#  ['The Experiment', 'Adrien Brody'],
#  ['The Experiment', 'Cam Gigandet'],
#  ['The Experiment', 'Maggie Grace'],
#  ['The Experiment', 'Clifton Collins Jr.'],
#  ['The Experiment', 'Travis Fimmel'],
#  ['The Experiment', 'Fisher Stevens'],
#  ['The Experiment', 'Ethan Cohn'],
#  ['Centurion', 'Michael Fassbender'],
#  ['Centurion', 'Olga Kurylenko'],
#  ['Centurion', 'Imogen Poots'],
#  ['Centurion', 'Dominic West'],
#  ['Centurion', 'Axelle Carolyn'],
#  ['Centurion', 'JJ Feild'],
#  ['Centurion', 'David Morrissey'],
#  ['Centurion', 'Liam Cunningham'],
#  ['Copie conforme', 'Juliette Binoche'],
#  ['Copie conforme', 'William Shimell'],
#  ['Copie conforme', 'Angelo Barbagallo'],
#  ['Copie conforme', 'Filippo Trojano'],
#  ['Copie conforme', 'Andrea Laurenzi'],
#  ['Copie conforme', 'Agathe Natanson'],
#  ['Copie conforme', 'Gianna Giachetti'],
#  ['Copie conforme', 'Jean-Claude Carrière'],
#  ['The Way Back', 'Janina Gavankar'],
#  ['The Way Back', 'Justice Alan'],
#  ['The Way Back', 'Ben Affleck'],
#  ['The Way Back', 'Al Madrigal'],
#  ['The Way Back', 'Michaela Watkins'],
#  ['The Way Back', 'April Adams'],
#  ['The Way Back', 'Calvin Barber'],
#  ['The Way Back', 'Xu Razer'],
#  ['Wall Street: Money Never Sleeps', 'Michael Douglas'],
#  ['Wall Street: Money Never Sleeps', 'Shia LaBeouf'],
#  ['Wall Street: Money Never Sleeps', 'Oliver Stone'],
#  ['Wall Street: Money Never Sleeps', 'Carey Mulligan'],
#  ['Wall Street: Money Never Sleeps', 'Josh Brolin'],
#  ['Wall Street: Money Never Sleeps', 'Frank Langella'],
#  ['Wall Street: Money Never Sleeps', 'Eli Wallach'],
#  ['Wall Street: Money Never Sleeps', 'Susan Sarandon'],
#  ['Secretariat', 'Penny Chenery'],
#  ['Secretariat', 'Margo Martindale'],
#  ['Secretariat', 'John Malkovich'],
#  ['Secretariat', 'Diane Lane'],
#  ['Secretariat', 'Amanda Michalka'],
#  ['Secretariat', 'Kevin Connolly'],
#  ['Secretariat', 'Dylan Walsh'],
#  ['Secretariat', 'James Cromwell'],
#  ['The Book of Eli', 'Denzel Washington'],
#  ['The Book of Eli', 'Gary Oldman'],
#  ['The Book of Eli', 'Mila Kunis'],
#  ['The Book of Eli', 'Jennifer Beals'],
#  ['The Book of Eli', 'Ray Stevenson'],
#  ['The Book of Eli', 'Michael Gambon'],
#  ['The Book of Eli', 'Tom Waits'],
#  ['The Book of Eli', 'Evan Jones'],
#  ['El mal ajeno', 'Eduardo Noriega'],
#  ['El mal ajeno', 'Belén Rueda'],
#  ['El mal ajeno', 'Angie Cepeda'],
#  ['El mal ajeno', 'Carlos Leal'],
#  ['El mal ajeno', 'Clara Lago'],
#  ['El mal ajeno', 'José Ángel Egido'],
#  ['El mal ajeno', 'Sonia Lázaro'],
#  ['El mal ajeno', 'Dritan Biba'],
#  ['Camp Hell', 'Jesse Eisenberg'],
#  ['Camp Hell', 'Dana Delany'],
#  ['Camp Hell', 'Caroline London'],
#  ['Camp Hell', 'Andrew McCarthy'],
#  ['Camp Hell', 'Bruce Davison'],
#  ['Camp Hell', 'Connor Paolo'],
#  ['Camp Hell', 'Will Denton'],
#  ['Camp Hell', 'Spencer Treat Clark'],
#  ['Howl', 'Edward Speleers'],
#  ['Howl', 'Holly Weston'],
#  ['Howl', 'Sam Gittins'],
#  ['Howl', 'Sean Pertwee'],
#  ['Howl', 'Shauna Macdonald'],
#  ['Howl', 'Rosie Day'],
#  ['Howl', 'Elliot Cowan'],
#  ['Howl', 'Calvin Dean'],
#  ['As Melhores Coisas do Mundo', 'Francisco Miguez'],
#  ['As Melhores Coisas do Mundo', 'Denise Fraga'],
#  ['As Melhores Coisas do Mundo', 'Caio Blat'],
#  ['As Melhores Coisas do Mundo', 'Fiuk'],
#  ['As Melhores Coisas do Mundo', 'Gustavo Machado'],
#  ['As Melhores Coisas do Mundo', 'Brenda Lígia'],
#  ['As Melhores Coisas do Mundo', 'Gabriela Rocha'],
#  ['As Melhores Coisas do Mundo', 'Gabriel Illanes'],
#  ['Life as We Know It', 'Katherine Heigl'],
#  ['Life as We Know It', 'Josh Duhamel'],
#  ['Life as We Know It', 'Alexis Clagett'],
#  ['Life as We Know It', 'Josh Lucas'],
#  ['Life as We Know It', 'Brooke Clagett'],
#  ['Life as We Know It', 'Brynn Clagett'],
#  ['Life as We Know It', 'Melissa McCarthy'],
#  ['Life as We Know It', 'Christina Hendricks'],
#  ['Al Nebras', 'Bruce Dern'],
#  ['Al Nebras', 'Will Forte'],
#  ['Al Nebras', 'Bob Odenkirk'],
#  ['Al Nebras', 'June Squibb'],
#  ['Al Nebras', 'Dennis McCoig'],
#  ['Al Nebras', 'Ronald Vosta'],
#  ['Al Nebras', 'Stacy Keach'],
#  ['Al Nebras', 'Devin Ratray'],
#  ['Small Town Saturday Night', 'Chris Pine'],
#  ['Small Town Saturday Night', 'Bre Blair'],
#  ['Small Town Saturday Night', 'Shawn Christian'],
#  ['Small Town Saturday Night', 'Ryan Craig'],
#  ['Small Town Saturday Night', 'John Hawkes'],
#  ['Small Town Saturday Night', 'Lin Shaye'],
#  ['Small Town Saturday Night', 'Robert Pine'],
#  ['Small Town Saturday Night', 'Muse Watson'],
#  ["Quincas Berro d'Água", 'Marieta Severo'],
#  ["Quincas Berro d'Água", 'Paulo José'],
#  ["Quincas Berro d'Água", 'Mariana Ximenes'],
#  ["Quincas Berro d'Água", 'Milton Gonçalves'],
#  ["Quincas Berro d'Água", 'Vladimir Brichta'],
#  ["Quincas Berro d'Água", 'Walderez de Barros'],
#  ["Quincas Berro d'Água", 'Luisa Proserpio'],
#  ["Quincas Berro d'Água", 'Irandhir Santos'],
#  ['Jonah Hex', 'Josh Brolin'],
#  ['Jonah Hex', 'Megan Fox'],
#  ['Jonah Hex', 'Jimmy Hayward'],
#  ['Jonah Hex', 'John Malkovich'],
#  ['Jonah Hex', 'Michael Fassbender'],
#  ['Jonah Hex', 'Will Arnett'],
#  ['Jonah Hex', 'Michael Shannon'],
#  ['Jonah Hex', 'Wes Bentley'],
#  ['Happiness Runs', 'Hanna Hall'],
#  ['Happiness Runs', 'Adam Sherman'],
#  ['Happiness Runs', 'Andie MacDowell'],
#  ['Happiness Runs', 'Jesse Plemons'],
#  ['Happiness Runs', 'Mark L. Young'],
#  ['Happiness Runs', 'Shiloh Fernandez'],
#  ['Happiness Runs', 'Rutger Hauer'],
#  ['Happiness Runs', 'Tyler Steelman'],
#  ['Pusher', 'Nicolas Winding Refn'],
#  ['Pusher', 'Mads Mikkelsen'],
#  ['Pusher', 'Kim Bodnia'],
#  ['Pusher', 'Zlatko Burić'],
#  ['Pusher', 'Laura Drasbaek'],
#  ['Pusher', 'Slavko Labović'],
#  ['Pusher', 'Vanja Bajičić'],
#  ['Pusher', 'Lisbeth Rasmussen'],
#  ['Lights Out', 'Teresa Palmer'],
#  ['Lights Out', 'Gabriel Bateman'],
#  ['Lights Out', 'Maria Bello'],
#  ['Lights Out', 'Lotta Losten'],
#  ['Lights Out', 'Alicia Vela-Bailey'],
#  ['Lights Out', 'Alexander DiPersia'],
#  ['Lights Out', 'Billy Burke'],
#  ['Lights Out', 'Emily Alyn Lind'],
#  ['Shanghai', 'John Cusack'],
#  ['Shanghai', 'Gong Li'],
#  ['Shanghai', 'Chow Yun-Fat'],
#  ['Shanghai', 'Ken Watanabe'],
#  ['Shanghai', 'Jeffrey Dean Morgan'],
#  ['Shanghai', 'Franka Potente'],
#  ['Shanghai', 'Rinko Kikuchi'],
#  ['Shanghai', 'David Morse'],
#  ['The Quiet Ones', 'Jared Harris'],
#  ['The Quiet Ones', 'Sam Claflin'],
#  ['The Quiet Ones', 'Olivia Cooke'],
#  ['The Quiet Ones', 'Erin Richards'],
#  ['The Quiet Ones', 'Tracy Ray'],
#  ['The Quiet Ones', 'Aldo Maland'],
#  ['The Quiet Ones', 'Rory Fleck Byrne'],
#  ['The Quiet Ones', 'Harman Singh'],
#  ['Morning', 'Jennifer Aniston'],
#  ['Morning', 'Reese Witherspoon'],
#  ['Morning', 'Billy Crudup'],
#  ['Morning', 'Julianna Margulies'],
#  ['Morning', 'Steve Carell'],
#  ['Morning', 'Mark Duplass'],
#  ['Morning', 'Greta Lee'],
#  ['Morning', 'Desean K. Terry'],
#  ['Do Elephants Pray?', 'Julie Dray'],
#  ['Do Elephants Pray?', 'Jonnie Hurn'],
#  ['Do Elephants Pray?', 'Marc Warren'],
#  ['Do Elephants Pray?', 'Rosie Fellner'],
#  ['Do Elephants Pray?', 'Dougal Porteous'],
#  ['Do Elephants Pray?', 'John Last'],
#  ['Do Elephants Pray?', 'Grace Vallorani'],
#  ['Do Elephants Pray?', 'Jean-Baptiste Puech'],
#  ['Broken Sun', 'Shingo Usami'],
#  ['Broken Sun', 'Kentaro Hara'],
#  ['Broken Sun', 'Jai Koutrae'],
#  ['Broken Sun', 'James Bishop'],
#  ['Broken Sun', 'Steve Dodd'],
#  ['Broken Sun', 'Rudi Baker'],
#  ['Broken Sun', 'Kuni Hashimoto'],
#  ['Broken Sun', 'Taki Abe'],
#  ['Peep World', 'Rainn Wilson'],
#  ['Peep World', 'Michael C. Hall'],
#  ['Peep World', 'Sarah Silverman'],
#  ['Peep World', 'Ben Schwartz'],
#  ['Peep World', 'Judy Greer'],
#  ['Peep World', 'Kate Mara'],
#  ['Peep World', 'Taraji P. Henson'],
#  ['Peep World', 'Ron Rifkin'],
#  ['Dirty Girl', 'Juno Temple'],
#  ['Dirty Girl', 'Milla JOVOVICH'],
#  ['Dirty Girl', 'Jeremy Dozier'],
#  ['Dirty Girl', 'William H. Macy'],
#  ['Dirty Girl', 'Mary Steenburgen'],
#  ['Dirty Girl', 'Dwight Yoakam'],
#  ['Dirty Girl', 'Tim McGraw'],
#  ['Dirty Girl', 'Elsie Fisher'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Gabriel Batistuta'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'José Wilker'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'José Dumont'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Marcélia Cartaxo'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Zezita Matos'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Ravi Ramos Lacerda'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Fernando Teixeira'],
#  ['O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Gal Cunha Lima'],
#  ['Blue Valentine', 'Michelle Williams'],
#  ['Blue Valentine', 'Ryan Gosling'],
#  ['Blue Valentine', 'Mike Vogel'],
#  ['Blue Valentine', 'Faith Wladyka'],
#  ['Blue Valentine', 'John Doman'],
#  ['Blue Valentine', 'Eileen Rosen'],
#  ['Blue Valentine', 'Ben Shenkman'],
#  ['Blue Valentine', 'Enid Graham'],
#  ['Di renjie: Tong tian di guo', 'Andy Lau'],
#  ['Di renjie: Tong tian di guo', 'Carina Lau'],
#  ['Di renjie: Tong tian di guo', 'Li Bingbing'],
#  ['Di renjie: Tong tian di guo', 'Jean-Michel Casanova'],
#  ['Di renjie: Tong tian di guo', 'Tony Leung Ka-fai'],
#  ['Di renjie: Tong tian di guo', 'Deng Chao'],
#  ['Di renjie: Tong tian di guo', 'Sos Haroyan'],
#  ['Di renjie: Tong tian di guo', 'Chi Wai Yau'],
#  ['Love Ranch', 'Helen Mirren'],
#  ['Love Ranch', 'Joe Pesci'],
#  ['Love Ranch', 'Gina Gershon'],
#  ['Love Ranch', 'Sergio Peris-Mencheta'],
#  ['Love Ranch', 'Bryan Cranston'],
#  ['Love Ranch', 'Taryn Manning'],
#  ['Love Ranch', 'Bai Ling'],
#  ['Love Ranch', 'Scout Taylor-Compton'],
#  ['Burlesque', 'Christina Aguilera'],
#  ['Burlesque', 'Cher'],
#  ['Burlesque', 'Cam Gigandet'],
#  ['Burlesque', 'Stanley Tucci'],
#  ['Burlesque', 'Kristen Bell'],
#  ['Burlesque', 'Julianne Hough'],
#  ['Burlesque', 'Eric Dane'],
#  ['Burlesque', 'Alan Cumming'],
#  ['Morning Glory', 'Harrison Ford'],
#  ['Morning Glory', 'Rachel McAdams'],
#  ['Morning Glory', 'Diane Keaton'],
#  ['Morning Glory', 'Roger Michell'],
#  ['Morning Glory', 'Patrick Wilson'],
#  ['Morning Glory', 'Jeff Goldblum'],
#  ['Morning Glory', 'Alwin H. Küchler'],
#  ['Morning Glory', 'Joseph J. Vargas'],
#  ['Another Harvest Moon', 'Ernest Borgnine'],
#  ['Another Harvest Moon', 'Doris Roberts'],
#  ['Another Harvest Moon', 'Piper Laurie'],
#  ['Another Harvest Moon', 'Sunkrish Bala'],
#  ['Another Harvest Moon', 'Anne Meara'],
#  ['Another Harvest Moon', 'Richard Schiff'],
#  ['Another Harvest Moon', 'Cybill Shepherd'],
#  ['Another Harvest Moon', 'Cameron Monaghan'],
#  ['Sisanje', 'Bojana Novakovic'],
#  ['Sisanje', 'Nikola Rakočević'],
#  ['Sisanje', 'Viktor Savić'],
#  ['Sisanje', 'Nataša Tapušković'],
#  ['Sisanje', 'Nikola Kojo'],
#  ['Sisanje', 'Dragan Mićanović'],
#  ['Sisanje', 'Predrag Ejdus'],
#  ['Sisanje', 'Srђan Miletić'],
#  ['The 5th Quarter', 'Andie MacDowell'],
#  ['The 5th Quarter', 'Aidan Quinn'],
#  ['The 5th Quarter', 'Ryan Merriman'],
#  ['The 5th Quarter', 'Stefan Guy'],
#  ['The 5th Quarter', 'Michael Harding'],
#  ['The 5th Quarter', 'Anessa Ramsey'],
#  ['The 5th Quarter', 'Mandy Manis'],
#  ['The 5th Quarter', 'Jillian Batherson'],
#  ['The Ghost Writer', 'Ewan McGregor'],
#  ['The Ghost Writer', 'Pierce Brosnan'],
#  ['The Ghost Writer', 'Olivia Williams'],
#  ['The Ghost Writer', 'Kim Cattrall'],
#  ['The Ghost Writer', 'Tom Wilkinson'],
#  ['The Ghost Writer', 'Eli Wallach'],
#  ['The Ghost Writer', 'Jim Belushi'],
#  ['The Ghost Writer', 'Jon Bernthal'],
#  ['Holy Rollers', 'Jesse Eisenberg'],
#  ['Holy Rollers', 'Justin Bartha'],
#  ['Holy Rollers', 'Danny A. Abeckaser'],
#  ['Holy Rollers', 'Ari Graynor'],
#  ['Holy Rollers', 'Hallie Kate Eisenberg'],
#  ['Holy Rollers', 'Jason Fuchs'],
#  ['Holy Rollers', 'Elizabeth Marvel'],
#  ['Holy Rollers', 'David Vadim'],
#  ['NY Export: Opus Jazz', 'Tiler Peck'],
#  ['NY Export: Opus Jazz', 'Robert Fairchild'],
#  ['NY Export: Opus Jazz', 'Amar Ramasar'],
#  ['NY Export: Opus Jazz', 'Georgina Pazcoguin'],
#  ['NY Export: Opus Jazz', 'Andrew Veyette'],
#  ['NY Export: Opus Jazz', 'Ashley Laracey'],
#  ['NY Export: Opus Jazz', 'Ellen Bar'],
#  ['NY Export: Opus Jazz', 'Brittany Pollack'],
#  ['The Karate Kid', 'Ralph Macchio'],
#  ['The Karate Kid', 'Pat Morita'],
#  ['The Karate Kid', 'William Zabka'],
#  ['The Karate Kid', 'Jaden Smith'],
#  ['The Karate Kid', 'Elisabeth Shue'],
#  ['The Karate Kid', 'John G. Avildsen'],
#  ['The Karate Kid', 'Martin Kove'],
#  ['The Karate Kid', 'Randee Heller'],
#  ['Biutiful', 'Javier Bardem'],
#  ['Biutiful', 'Alejandro González Iñárritu'],
#  ['Biutiful', 'Diaryatou Daff'],
#  ['Biutiful', 'Maricel Álvarez'],
#  ['Biutiful', 'Hanaa Bouchaib'],
#  ['Biutiful', 'Eduard Fernández'],
#  ['Biutiful', 'Germán Almendros'],
#  ['Biutiful', 'Lang Sofia Lin'],
#  ["L'immortel", 'Jean Reno'],
#  ["L'immortel", 'Richard Berry'],
#  ["L'immortel", 'Marina Foïs'],
#  ["L'immortel", 'Kad Merad'],
#  ["L'immortel", 'Gabriella Wright'],
#  ["L'immortel", 'Max Baissette de Malglaive'],
#  ["L'immortel", 'Fani Kołarova'],
#  ["L'immortel", 'Moussa Maaskri'],
#  ['The Company Men', 'Ben Affleck'],
#  ['The Company Men', 'Tommy Lee Jones'],
#  ['The Company Men', 'Kevin Costner'],
#  ['The Company Men', 'Chris Cooper'],
#  ['The Company Men', 'Maria Bello'],
#  ['The Company Men', 'Craig T. Nelson'],
#  ['The Company Men', 'Rosemarie DeWitt'],
#  ['The Company Men', 'Dana Eskelson'],
#  ['The Bang Bang Club', 'Taylor Kitsch'],
#  ['The Bang Bang Club', 'Ryan Phillippe'],
#  ['The Bang Bang Club', 'Frank Rautenbach'],
#  ['The Bang Bang Club', 'Malin Åkerman'],
#  ['The Bang Bang Club', 'Neil Tabatznik'],
#  ['The Bang Bang Club', 'Lika Berning'],
#  ['The Bang Bang Club', 'Nina Milner'],
#  ['The Bang Bang Club', 'Jessica Haines'],
#  ['The Myth of the American Sleepover', 'Marlon Morton'],
#  ['The Myth of the American Sleepover', 'Claire Sloma'],
#  ['The Myth of the American Sleepover', 'Amanda Bauer'],
#  ['The Myth of the American Sleepover', 'Brett Jacobsen'],
#  ['The Myth of the American Sleepover', 'Mary Wardell'],
#  ['The Myth of the American Sleepover', 'Jade Ramsey'],
#  ['The Myth of the American Sleepover', 'Annette DeNoyer'],
#  ['The Myth of the American Sleepover', 'Nikita Ramsey'],
#  ['All Good Things', 'Ryan Gosling'],
#  ['All Good Things', 'Kirsten Dunst'],
#  ['All Good Things', 'Frank Langella'],
#  ['All Good Things', 'Lily Rabe'],
#  ['All Good Things', 'Kristen Wiig'],
#  ['All Good Things', 'Diane Venora'],
#  ['All Good Things', 'Philip Baker Hall'],
#  ['All Good Things', 'Nick Offerman'],
#  ['A Nightmare on Elm Street', 'Robert Englund'],
#  ['A Nightmare on Elm Street', 'Heather Langenkamp'],
#  ['A Nightmare on Elm Street', 'Johnny Depp'],
#  ['A Nightmare on Elm Street', 'John Saxon'],
#  ['A Nightmare on Elm Street', 'Amanda Wyss'],
#  ['A Nightmare on Elm Street', 'Lin Shaye'],
#  ['A Nightmare on Elm Street', 'Jsu García'],
#  ['A Nightmare on Elm Street', 'Ronee Blakley'],
#  ['Black Death', 'Sean Bean'],
#  ['Black Death', 'Eddie Redmayne'],
#  ['Black Death', 'Carice van Houten'],
#  ['Black Death', 'David Warner'],
#  ['Black Death', 'Kimberley Nixon'],
#  ['Black Death', 'Andy Nyman'],
#  ['Black Death', 'Tim McInnerny'],
#  ['Black Death', 'Johnny Harris'],
#  ['Bunraku', 'Josh Hartnett'],
#  ['Bunraku', 'Woody Harrelson'],
#  ['Bunraku', 'Ron Perlman'],
#  ['Bunraku', 'Demi Moore'],
#  ['Bunraku', 'Mike Patton'],
#  ['Bunraku', 'Kevin McKidd'],
#  ['Bunraku', 'Gackt'],
#  ['Bunraku', 'Jordi Mollà'],
#  ['You Will Meet a Tall Dark Stranger', 'Anthony Hopkins'],
#  ['You Will Meet a Tall Dark Stranger', 'Josh Brolin'],
#  ['You Will Meet a Tall Dark Stranger', 'Naomi Watts'],
#  ['You Will Meet a Tall Dark Stranger', 'Antonio Banderas'],
#  ['You Will Meet a Tall Dark Stranger', 'Freida Pinto'],
#  ['You Will Meet a Tall Dark Stranger', 'Lucy Punch'],
#  ['You Will Meet a Tall Dark Stranger', 'Gemma Jones'],
#  ['You Will Meet a Tall Dark Stranger', 'Theo James'],
#  ['Mr. Nice', 'Rhys Ifans'],
#  ['Mr. Nice', 'David Thewlis'],
#  ['Mr. Nice', 'Chloë Sevigny'],
#  ['Mr. Nice', 'Christian McKay'],
#  ['Mr. Nice', 'Crispin Glover'],
#  ['Mr. Nice', 'Elsa Pataky'],
#  ['Mr. Nice', 'Jack Huston'],
#  ['Mr. Nice', 'Omid Djalili'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Rekha'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Hema Malini'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Ferena Wazeir'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Rishi Kapoor'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Javed Sheikh'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Luv Sinha'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Shabana Azmi'],
#  ['Sadiyaan: Boundaries Divide... Love Unites', 'Navni Parihar'],
#  ['Welcome to the Rileys', 'Kristen Stewart'],
#  ['Welcome to the Rileys', 'James Gandolfini'],
#  ['Welcome to the Rileys', 'Melissa Leo'],
#  ['Welcome to the Rileys', 'Tiffany Coty'],
#  ['Welcome to the Rileys', 'Kathy Lamkin'],
#  ['Welcome to the Rileys', 'Ken Hixon'],
#  ['Welcome to the Rileys', 'Sharon Landry'],
#  ['Welcome to the Rileys', 'David Jensen'],
#  ['Veer', 'Salman Khan'],
#  ['Veer', 'Zarine Khan'],
#  ['Veer', 'Mithun Chakraborty'],
#  ['Veer', 'Jackie Shroff'],
#  ['Veer', 'Lisa Lazarus'],
#  ['Veer', 'Gita Solo'],
#  ['Veer', 'Neena Gupta'],
#  ['Veer', 'Bharat Dabholkar'],
#  ['Lope', 'Leonor Watling'],
#  ['Lope', 'Pilar López de Ayala'],
#  ['Lope', 'Sônia Braga'],
#  ['Lope', 'Luis Tosar'],
#  ['Lope', 'Antonio de la Torre Martín'],
#  ['Lope', 'Alberto Ammann'],
#  ['Lope', 'Miguel Ángel Muñoz'],
#  ['Lope', 'Juan Diego'],
#  ['My Name Is Khan', 'Shahrukh Khan'],
#  ['My Name Is Khan', 'Kajol'],
#  ['My Name Is Khan', 'Adarsh Gourav'],
#  ['My Name Is Khan', 'Jimmy Shergill'],
#  ['My Name Is Khan', 'Pallavi Sharda'],
#  ['My Name Is Khan', 'Tanay Chheda'],
#  ['My Name Is Khan', 'Sonya Jehan'],
#  ['My Name Is Khan', 'Arjan Aujla'],
#  ['Right Yaaa Wrong', 'Sunny Deol'],
#  ['Right Yaaa Wrong', 'Irrfan Khan'],
#  ['Right Yaaa Wrong', 'Isha Koppikar'],
#  ['Right Yaaa Wrong', 'Konkona Sen Sharma'],
#  ['Right Yaaa Wrong', 'Aryan Vaid'],
#  ['Right Yaaa Wrong', 'Ali Haji'],
#  ['Right Yaaa Wrong', 'Deepal Shaw'],
#  ['Right Yaaa Wrong', 'Govind Namdeo'],
#  ['My Own Love Song', 'Renée Zellweger'],
#  ['My Own Love Song', 'Forest Whitaker'],
#  ['My Own Love Song', 'Nick Nolte'],
#  ['My Own Love Song', 'Madeline Zima'],
#  ['My Own Love Song', 'Elias Koteas'],
#  ['My Own Love Song', 'Chandler Frantz'],
#  ['My Own Love Song', 'Tim Parati'],
#  ['My Own Love Song', 'Bill Ladd'],
#  ['Step Up 3D', 'Adam Sevani'],
#  ['Step Up 3D', 'Rick Malambri'],
#  ['Step Up 3D', 'Sharni Vinson'],
#  ['Step Up 3D', 'Alyson Stoner'],
#  ['Step Up 3D', 'Stephen Boss'],
#  ['Step Up 3D', 'Joe Slaughter'],
#  ['Step Up 3D', 'Kendra Andrews'],
#  ['Step Up 3D', 'Martín Lombard'],
#  ['Casino Jack', 'Kevin Spacey'],
#  ['Casino Jack', 'George Hickenlooper'],
#  ['Casino Jack', 'Barry Pepper'],
#  ['Casino Jack', 'Jon Lovitz'],
#  ['Casino Jack', 'Kelly Preston'],
#  ['Casino Jack', 'Rachelle Lefevre'],
#  ['Casino Jack', 'Hannah Endicott-Douglas'],
#  ['Casino Jack', 'Xenia Siamas'],
#  ['Inhale', 'Dermot Mulroney'],
#  ['Inhale', 'Diane Kruger'],
#  ['Inhale', 'Mia Stallard'],
#  ['Inhale', 'Christian Escario'],
#  ['Inhale', 'Sam Shepard'],
#  ['Inhale', 'Rosanna Arquette'],
#  ['Inhale', 'Jordi Mollà'],
#  ['Inhale', 'Vincent Pérez'],
#  ['Diary of a Wimpy Kid', 'Zachary Gordon'],
#  ['Diary of a Wimpy Kid', 'Robert Capron'],
#  ['Diary of a Wimpy Kid', 'Devon Bostick'],
#  ['Diary of a Wimpy Kid', 'Chloë Grace Moretz'],
#  ['Diary of a Wimpy Kid', 'Steve Zahn'],
#  ['Diary of a Wimpy Kid', 'Rachael Harris'],
#  ['Diary of a Wimpy Kid', 'Laine MacNeil'],
#  ['Diary of a Wimpy Kid', 'Grayson Russell'],
#  ['Cemetery Junction', 'Ricky Gervais'],
#  ['Cemetery Junction', 'Stephen Merchant'],
#  ['Cemetery Junction', 'Jack Doolan'],
#  ['Cemetery Junction', 'Ralph Fiennes'],
#  ['Cemetery Junction', 'Christian Cooke'],
#  ['Cemetery Junction', 'Tom Hughes'],
#  ['Cemetery Junction', 'Felicity Jones'],
#  ['Cemetery Junction', 'Matthew Goode'],
#  ['Kites', 'Hrithik Roshan'],
#  ['Kites', 'Bárbara Mori'],
#  ['Kites', 'Kangana Ranaut'],
#  ['Kites', 'Kabir Bedi'],
#  ['Kites', 'Nicholas Brown'],
#  ['Kites', 'Yuri Suri'],
#  ['Kites', 'Anand Tiwari'],
#  ['Kites', 'Steven Michael Quezada'],
#  ['Person of Interest', 'Michael Emerson'],
#  ['Person of Interest', 'Kevin Chapman'],
#  ['Person of Interest', 'Jim Caviezel'],
#  ['Person of Interest', 'Amy Acker'],
#  ['Person of Interest', 'Sarah Shahi'],
#  ['Person of Interest', 'Taraji P. Henson'],
#  ['Person of Interest', 'John Nolan (British actor)'],
#  ['Person of Interest', 'Boris McGiver'],
#  ['Blood Done Sign My Name', 'Nate Parker'],
#  ['Blood Done Sign My Name', 'Rick Schroder'],
#  ['Blood Done Sign My Name', 'Michael Rooker'],
#  ['Blood Done Sign My Name', 'Nick Searcy'],
#  ['Blood Done Sign My Name', 'Omar Benson Miller'],
#  ['Blood Done Sign My Name', 'Emily Alyn Lind'],
#  ['Blood Done Sign My Name', 'Gattlin Griffith'],
#  ['Blood Done Sign My Name', 'Natalie Alyn Lind'],
#  ['Hereafter', 'Matt Damon'],
#  ['Hereafter', 'Bryce Dallas Howard'],
#  ['Hereafter', 'Cécile de France'],
#  ['Hereafter', 'Lisa Griffiths'],
#  ['Hereafter', 'Frankie McLaren'],
#  ['Hereafter', 'Steve Schirripa'],
#  ['Hereafter', 'George McLaren'],
#  ['Hereafter', 'Jay Mohr'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Eri Fukatsu'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Yūji Oda'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!',
#   'Yūsuke Santamaria'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Shun Oguri'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Atsushi Itō'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Toshirō Yanagiba'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Yūki Uchida'],
#  ['Odoru daisousasen the movie 3: Yatsura o kaihou seyo!',
#   'Sōichirō Kitamura'],
#  ['An Invisible Sign', 'Jessica Alba'],
#  ['An Invisible Sign', 'Chris Messina'],
#  ['An Invisible Sign', 'J. K. Simmons'],
#  ['An Invisible Sign', 'Bailee Madison'],
#  ['An Invisible Sign', 'John Shea'],
#  ['An Invisible Sign', 'Sônia Braga'],
#  ['An Invisible Sign', 'Ashlie Atkinson'],
#  ['An Invisible Sign', 'Sophie Nyweide'],
#  ['London Boulevard', 'Colin Farrell'],
#  ['London Boulevard', 'Keira Knightley'],
#  ['London Boulevard', 'Ray Winstone'],
#  ['London Boulevard', 'David Thewlis'],
#  ['London Boulevard', 'Anna Friel'],
#  ['London Boulevard', 'Ben Chaplin'],
#  ['London Boulevard', 'Stephen Graham'],
#  ['London Boulevard', 'Ophelia Lovibond'],
#  ['Womb', 'Eva Green'],
#  ['Womb', 'Matt Smith'],
#  ['Womb', 'Lesley Manville'],
#  ['Womb', 'Peter Wight'],
#  ['Womb', 'Ruby O. Fee'],
#  ['Womb', 'Jesse Hoffmann'],
#  ['Womb', 'Hannah Murray'],
#  ['Womb', 'István Lénárt'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Jim Sturgess'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'David Wenham'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Hugo Weaving'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Sam Neill'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Adrienne DeFaria'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Helen Mirren'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Ryan Kwanten'],
#  ["Legend of the Guardians: The Owls of Ga'Hoole", 'Emily Barclay'],
#  ["Henry's Crime", 'Keanu Reeves'],
#  ["Henry's Crime", 'James Caan'],
#  ["Henry's Crime", 'Vera Farmiga'],
#  ["Henry's Crime", 'Judy Greer'],
#  ["Henry's Crime", 'Fisher Stevens'],
#  ["Henry's Crime", 'Peter Stormare'],
#  ["Henry's Crime", 'Steve Beauchamp'],
#  ["Henry's Crime", 'Bill Duke'],
#  ['Frankie & Alice', 'Halle Berry'],
#  ['Frankie & Alice', 'Stellan Skarsgård'],
#  ['Frankie & Alice', 'Phylicia Rashād'],
#  ['Frankie & Alice', 'Chandra Wilson'],
#  ['Frankie & Alice', 'Matt Frewer'],
#  ['Frankie & Alice', 'Brian Markinson'],
#  ['Frankie & Alice', 'Vanessa Morgan'],
#  ['Frankie & Alice', 'Kira Clavell'],
#  ['Edge of Darkness', 'Mel Gibson'],
#  ['Edge of Darkness', 'Ray Winstone'],
#  ['Edge of Darkness', 'Danny Huston'],
#  ['Edge of Darkness', 'Bojana Novakovic'],
#  ['Edge of Darkness', 'Gabrielle Popa'],
#  ['Edge of Darkness', "Denis O'Hare"],
#  ['Edge of Darkness', 'Shawn Roberts'],
#  ['Edge of Darkness', 'David Aaron Baker'],
#  ['The Debt', 'Helen Mirren'],
#  ['The Debt', 'Sam Worthington'],
#  ['The Debt', 'Jessica Chastain'],
#  ['The Debt', 'Tom Wilkinson'],
#  ['The Debt', 'Ciarán Hinds'],
#  ['The Debt', 'Marton Csokas'],
#  ['The Debt', 'Romi Aboulafia'],
#  ['The Debt', 'Jesper Christensen'],
#  ['Let Me In', 'Chloë Grace Moretz'],
#  ['Let Me In', 'Kodi Smit-McPhee'],
#  ['Let Me In', 'Dylan Minnette'],
#  ['Let Me In', 'Richard Jenkins'],
#  ['Let Me In', 'Sasha Barrese'],
#  ['Let Me In', 'Cara Buono'],
#  ['Let Me In', 'Elias Koteas'],
#  ['Let Me In', 'Ritchie Coster'],
#  ['Due Date', 'Zach Galifianakis'],
#  ['Due Date', 'Robert Downey Jr.'],
#  ['Due Date', 'Todd Phillips'],
#  ['Due Date', 'Jamie Foxx'],
#  ['Due Date', 'Michelle Monaghan'],
#  ['Due Date', 'Juliette Lewis'],
#  ['Due Date', 'Danny McBride'],
#  ['Due Date', 'Nathalie Fay'],
#  ['Triple Dog', 'Britt Robertson'],
#  ['Triple Dog', 'Scout Taylor-Compton'],
#  ['Triple Dog', 'Alexia Fast'],
#  ['Triple Dog', 'Carly McKillip'],
#  ['Triple Dog', 'Emily Tennant'],
#  ['Triple Dog', 'Janel Parrish'],
#  ['Triple Dog', 'Brett Davern'],
#  ['Triple Dog', 'Valerie Tian'],
#  ['Brighton Rock', 'Sam Riley'],
#  ['Brighton Rock', 'Helen Mirren'],
#  ['Brighton Rock', 'Andrea Riseborough'],
#  ['Brighton Rock', 'John Hurt'],
#  ['Brighton Rock', 'Andy Serkis'],
#  ['Brighton Rock', 'Sean Harris'],
#  ['Brighton Rock', 'Nonso Anozie'],
#  ['Brighton Rock', 'Phil Davis'],
#  ['Chico Xavier', 'Nelson Xavier'],
#  ['Chico Xavier', 'Ângelo Antônio'],
#  ['Chico Xavier', 'Natalia Soutto'],
#  ['Chico Xavier', 'Matheus Costa'],
#  ['Chico Xavier', 'Luís Alberto Melo'],
#  ['Chico Xavier', 'Via Negromonte'],
#  ['Chico Xavier', 'Giovanna Antonelli'],
#  ['Chico Xavier', 'Tony Ramos'],
#  ["'Master Harold' ... And the Boys", 'Freddie Highmore'],
#  ["'Master Harold' ... And the Boys", 'Ving Rhames'],
#  ["'Master Harold' ... And the Boys", 'Nicky Rebello'],
#  ["'Master Harold' ... And the Boys", 'Patrick Mofokeng'],
#  ["'Master Harold' ... And the Boys", 'Mike Maxwell'],
#  ["'Master Harold' ... And the Boys", 'Jennifer Steyn'],
#  ["'Master Harold' ... And the Boys", 'Zoliswa Kawe'],
#  ["'Master Harold' ... And the Boys", 'Redd-Valentino Debray'],
#  ['Greenberg', 'Ben Stiller'],
#  ['Greenberg', 'Greta Gerwig'],
#  ['Greenberg', 'Jennifer Jason Leigh'],
#  ['Greenberg', 'Rhys Ifans'],
#  ['Greenberg', 'Brie Larson'],
#  ['Greenberg', 'Koby Rouviere'],
#  ['Greenberg', 'Mark Duplass'],
#  ['Greenberg', 'Dave Franco'],
#  ['Chico & Rita', 'Limara Meneses'],
#  ['Chico & Rita', 'Eman Xor Oña'],
#  ['Chico & Rita', 'Bebo Valdés'],
#  ['Chico & Rita', 'Mario Guerra'],
#  ['Chico & Rita', 'Estrella Morente'],
#  ['Chico & Rita', 'Yaroldi Abreu'],
#  ['Chico & Rita', 'Renny Arozarena'],
#  ['Chico & Rita', 'Rigoberto Ferrera'],
#  ['Gigola', 'Marie Kremer'],
#  ['Gigola', 'Eduardo Noriega'],
#  ['Gigola', 'Marisa Paredes'],
#  ['Gigola', 'Marisa Berenson'],
#  ['Gigola', 'Rossy de Palma'],
#  ['Gigola', 'Lou Doillon'],
#  ['Gigola', 'Thierry Lhermitte'],
#  ['Gigola', 'Ana Padrão'],
#  ['Mistérios de Lisboa', 'Maria João Bastos'],
#  ['Mistérios de Lisboa', 'Adriano Luz'],
#  ['Mistérios de Lisboa', 'Léa Seydoux'],
#  ['Mistérios de Lisboa', 'Ricardo Pereira'],
#  ['Mistérios de Lisboa', 'José Afonso Dias Pimentel'],
#  ['Mistérios de Lisboa', 'João Arrais'],
#  ['Mistérios de Lisboa', 'Clotilde Hesme'],
#  ['Mistérios de Lisboa', 'Rui Morrison'],
#  ...]

# %%
for peli in lista_pelis_actores:
    if peli[0] == "Anderson's Cross":
        print(peli)
# Out:
# ["Anderson's Cross", 'Jerome Elston Scott']
# ["Anderson's Cross", 'Nicholas Downs']
# ["Anderson's Cross", 'Heather Bergdahl']
# ["Anderson's Cross", 'Michael Warren']
# ["Anderson's Cross", 'Joyce Guy']
# ["Anderson's Cross", 'Joanna Cassidy']
# ["Anderson's Cross", 'Bill Moseley']
# ["Anderson's Cross", 'Micah Stuart']
# ["Anderson's Cross", 'Jerome Elston Scott']
# ["Anderson's Cross", 'Nicholas Downs']
# ["Anderson's Cross", 'Heather Bergdahl']
# ["Anderson's Cross", 'Michael Warren']
# ["Anderson's Cross", 'Joyce Guy']
# ["Anderson's Cross", 'Joanna Cassidy']
# ["Anderson's Cross", 'Bill Moseley']
# ["Anderson's Cross", 'Micah Stuart']

# %%
lista_definitiva = [tuple(peli) for peli in lista_pelis_actores]

# %%
lista_definitiva
# Out:
# [('In My Sleep', 'Philip Winchester'),
#  ('In My Sleep', 'Lacey Chabert'),
#  ('In My Sleep', 'Abigail Spencer'),
#  ('In My Sleep', 'Kelly Overton'),
#  ('In My Sleep', 'Tony Hale'),
#  ('In My Sleep', 'Michael Badalucco'),
#  ('In My Sleep', 'Amy Aquino'),
#  ('In My Sleep', 'Tim Draxl'),
#  ("Anderson's Cross", 'Jerome Elston Scott'),
#  ("Anderson's Cross", 'Nicholas Downs'),
#  ("Anderson's Cross", 'Heather Bergdahl'),
#  ("Anderson's Cross", 'Michael Warren'),
#  ("Anderson's Cross", 'Joyce Guy'),
#  ("Anderson's Cross", 'Joanna Cassidy'),
#  ("Anderson's Cross", 'Bill Moseley'),
#  ("Anderson's Cross", 'Micah Stuart'),
#  ('Utomlennye solntsem 2', 'Nikita Mijalkov'),
#  ('Utomlennye solntsem 2', 'Nadezhda Mijalkova'),
#  ('Utomlennye solntsem 2', 'Oleg Ménshikov'),
#  ('Utomlennye solntsem 2', 'Yevgeny Mironov'),
#  ('Utomlennye solntsem 2', 'Vladimir Adolfovich Ilyin'),
#  ('Utomlennye solntsem 2', 'Serguéi Makovetski'),
#  ('Utomlennye solntsem 2', 'Dmitri Dyuzhev'),
#  ('Utomlennye solntsem 2', 'Andrey Merzlikin'),
#  ('Tekken', 'Kelly Overton'),
#  ('Tekken', 'Candîce Hillebrand'),
#  ('Tekken', 'Cary-Hiroyuki Tagawa'),
#  ('Tekken', 'Lateef Crowder Dos Santos'),
#  ('Tekken', 'Luke Goss'),
#  ('Tekken', 'Gary Daniels'),
#  ('Tekken', 'Mircea Monroe'),
#  ('Tekken', 'Tamlyn Tomita'),
#  ('Milenge Milenge', 'Shahid Kapoor'),
#  ('Milenge Milenge', 'Kareena Kapoor'),
#  ('Milenge Milenge', 'Satish Kaushik'),
#  ('Milenge Milenge', 'Delnaaz Irani'),
#  ('Milenge Milenge', 'Satish Shah'),
#  ('Milenge Milenge', 'Aarti Chhabria'),
#  ('Milenge Milenge', 'Sarfaraz khan'),
#  ('Milenge Milenge', 'Kirron Kher'),
#  ('Les 7 jours du talion', 'Martin Dubreuil'),
#  ('Les 7 jours du talion', 'Claude Legault'),
#  ('Les 7 jours du talion', 'Rémy Girard'),
#  ('Les 7 jours du talion', 'Rose-Marie Coallier'),
#  ('Les 7 jours du talion', 'Pascale Delhaes'),
#  ('Les 7 jours du talion', 'Fanny Mallette'),
#  ('Les 7 jours du talion', 'Alexandre Goyette'),
#  ('Les 7 jours du talion', 'Dominique Quesnel'),
#  ('Vidas pequeñas', 'Ángela Molina'),
#  ('Vidas pequeñas', 'Roberto Enríquez'),
#  ('Vidas pequeñas', 'Emilio Gutiérrez Caba'),
#  ('Vidas pequeñas', 'Alicia Borrachero'),
#  ('Vidas pequeñas', 'Ana Gracia'),
#  ('Vidas pequeñas', 'Rubén Ochandiano'),
#  ('Vidas pequeñas', 'Yohana Cobo'),
#  ('Vidas pequeñas', 'Asunción Balaguer'),
#  ('Cielito lindo', 'Arturo de Córdova'),
#  ('Cielito lindo', 'Lucha Reyes'),
#  ('Cielito lindo', 'Leonor Gomez'),
#  ('Cielito lindo', 'Carlos López "Chaflán"'),
#  ('Cielito lindo', 'Max Langler'),
#  ('Cielito lindo', 'Miguel Wimer'),
#  ('Cielito lindo', 'Lupita Gallardo'),
#  ('Cielito lindo', 'Alfonso Parra'),
#  ('Barry Munday', 'Judy Greer'),
#  ('Barry Munday', 'Patrick Wilson'),
#  ('Barry Munday', 'Chloë Sevigny'),
#  ('Barry Munday', 'Jean Smart'),
#  ('Barry Munday', 'Malcolm McDowell'),
#  ('Barry Munday', 'Barry Habib'),
#  ('Barry Munday', 'Colin Hanks'),
#  ('Barry Munday', 'Cybill Shepherd'),
#  ('A Woman Is a Woman', 'Anna Karina'),
#  ('A Woman Is a Woman', 'Jean-Paul Belmondo'),
#  ('A Woman Is a Woman', 'Jean-Claude Brialy'),
#  ('A Woman Is a Woman', 'Catherine Demongeot'),
#  ('A Woman Is a Woman', 'Dorothée Blanck'),
#  ('A Woman Is a Woman', 'Gérard Hoffmann'),
#  ('A Woman Is a Woman', 'Noel Pacquin'),
#  ('A Woman Is a Woman', 'György Cserhalmi'),
#  ('Ramona and Beezus', 'Joey King'),
#  ('Ramona and Beezus', 'Selena Gomez'),
#  ('Ramona and Beezus', 'Ginnifer Goodwin'),
#  ('Ramona and Beezus', 'John Corbett'),
#  ('Ramona and Beezus', 'Josh Duhamel'),
#  ('Ramona and Beezus', 'Bridget Moynahan'),
#  ('Ramona and Beezus', 'Sandra Oh'),
#  ('Ramona and Beezus', 'Hutch Dano'),
#  ('Love & Other Drugs', 'Anne Hathaway'),
#  ('Love & Other Drugs', 'Jake Gyllenhaal'),
#  ('Love & Other Drugs', 'Oliver Platt'),
#  ('Love & Other Drugs', 'Gabriel Macht'),
#  ('Love & Other Drugs', 'Judy Greer'),
#  ('Love & Other Drugs', 'Katheryn Winnick'),
#  ('Love & Other Drugs', 'Josh Gad'),
#  ('Love & Other Drugs', 'Hank Azaria'),
#  ('Night Catches Us', 'Anthony Mackie'),
#  ('Night Catches Us', 'Kerry Washington'),
#  ('Night Catches Us', 'Jamie Hector'),
#  ('Night Catches Us', 'Jamara Griffin'),
#  ('Night Catches Us', 'Wendell Pierce'),
#  ('Night Catches Us', 'Amari Cheatom'),
#  ('Night Catches Us', 'Novella Nelson'),
#  ('Night Catches Us', 'Ron Simons'),
#  ('The Wolfman', 'Benicio del Toro'),
#  ('The Wolfman', 'Anthony Hopkins'),
#  ('The Wolfman', 'Emily Blunt'),
#  ('The Wolfman', 'Hugo Weaving'),
#  ('The Wolfman', 'Art Malik'),
#  ('The Wolfman', 'Geraldine Chaplin'),
#  ('The Wolfman', 'Rick Baker'),
#  ('The Wolfman', 'Michael Cronin'),
#  ('Ironmen', 'Robert Downey Jr.'),
#  ('Ironmen', 'Jon Favreau'),
#  ('Ironmen', 'Gwyneth Paltrow'),
#  ('Ironmen', 'Jeff Bridges'),
#  ('Ironmen', 'Terrence Howard'),
#  ('Ironmen', 'Leslie Bibb'),
#  ('Ironmen', 'Stan Lee'),
#  ('Ironmen', 'Paul Bettany'),
#  ("It's Kind of a Funny Story", 'Zach Galifianakis'),
#  ("It's Kind of a Funny Story", 'Keir Gilchrist'),
#  ("It's Kind of a Funny Story", 'Emma Roberts'),
#  ("It's Kind of a Funny Story", 'Dana DeVestern'),
#  ("It's Kind of a Funny Story", 'Viola Davis'),
#  ("It's Kind of a Funny Story", 'Lauren Graham'),
#  ("It's Kind of a Funny Story", 'Ben Folstein'),
#  ("It's Kind of a Funny Story", 'Jim Gaffigan'),
#  ('Flipped', 'Madeline Carroll'),
#  ('Flipped', 'Callan McAuliffe'),
#  ('Flipped', 'Morgan Lily'),
#  ('Flipped', 'Israel Broussard'),
#  ('Flipped', 'Stefanie Scott'),
#  ('Flipped', 'Cody Horn'),
#  ('Flipped', 'Kevin Weisman'),
#  ('Flipped', 'John Mahoney'),
#  ('Soupernatural', 'Jensen Ackles'),
#  ('Soupernatural', 'Jared Padalecki'),
#  ('Soupernatural', 'Misha Collins'),
#  ('Soupernatural', 'Mark Sheppard'),
#  ('Soupernatural', 'Jim Beaver'),
#  ('Soupernatural', 'Jeffrey Dean Morgan'),
#  ('Soupernatural', 'Alexander Calvert'),
#  ('Soupernatural', 'Genevieve Cortese'),
#  ('Waking Madison', 'Elisabeth Shue'),
#  ('Waking Madison', 'Sarah Roemer'),
#  ('Waking Madison', 'Taryn Manning'),
#  ('Waking Madison', 'Imogen Poots'),
#  ('Waking Madison', 'Erin Kelly'),
#  ('Waking Madison', 'Frances Conroy'),
#  ('Waking Madison', 'Will Patton'),
#  ('Waking Madison', 'Conner Ann Waterman'),
#  ('The Town', 'Ben Affleck'),
#  ('The Town', 'Rebecca Hall'),
#  ('The Town', 'Jeremy Renner'),
#  ('The Town', 'Blake Lively'),
#  ('The Town', 'Pete Postlethwaite'),
#  ('The Town', 'Jon Hamm'),
#  ('The Town', 'Titus Welliver'),
#  ('The Town', 'Owen Burke'),
#  ('Risen', 'Joseph Fiennes'),
#  ('Risen', 'Cliff Curtis'),
#  ('Risen', 'Tom Felton'),
#  ('Risen', 'Peter Firth'),
#  ('Risen', 'María Botto'),
#  ('Risen', 'Stephen Hagan'),
#  ('Risen', 'Richard Atwill'),
#  ('Risen', 'James Shilaimon'),
#  ('Please Give', 'Catherine Keener'),
#  ('Please Give', 'Rebecca Hall'),
#  ('Please Give', 'Amanda Peet'),
#  ('Please Give', 'Oliver Platt'),
#  ('Please Give', 'Sarah Steele'),
#  ('Please Give', 'Lois Smith'),
#  ('Please Give', 'Elizabeth Keener'),
#  ('Please Give', 'John Srednicki'),
#  ('Eat Pray Love', 'Julia Roberts'),
#  ('Eat Pray Love', 'Javier Bardem'),
#  ('Eat Pray Love', 'James Franco'),
#  ('Eat Pray Love', 'Richard Jenkins'),
#  ('Eat Pray Love', 'Billy Crudup'),
#  ('Eat Pray Love', 'Hadi Subiyanto'),
#  ('Eat Pray Love', 'Viola Davis'),
#  ('Eat Pray Love', 'I. Gusti Ayu Puspawati'),
#  ('Repo', 'Ben Gourley'),
#  ('Repo', 'Jason Mewes'),
#  ('Repo', 'Izabella Miko'),
#  ('Repo', 'Lindsey McKeon'),
#  ('Repo', 'Sunny Mabrey'),
#  ('Repo', 'Zack Ward'),
#  ('Repo', 'Patrick Muldoon'),
#  ('Repo', 'Rhett Willman'),
#  ('Letters to Juliet', 'Amanda Seyfried'),
#  ('Letters to Juliet', 'Christopher Egan'),
#  ('Letters to Juliet', 'Vanessa Redgrave'),
#  ('Letters to Juliet', 'Gael García Bernal'),
#  ('Letters to Juliet', 'Franco Nero'),
#  ('Letters to Juliet', 'Giordano Formenti'),
#  ('Letters to Juliet', 'Marcia DeBonis'),
#  ('Letters to Juliet', 'Paolo Arvedi'),
#  ('The Whistleblower', 'Rachel Weisz'),
#  ('The Whistleblower', 'Vanessa Redgrave'),
#  ('The Whistleblower', 'Nikolaj Lie Kaas'),
#  ('The Whistleblower', 'Monica Bellucci'),
#  ('The Whistleblower', 'Rosabell Laurenti Sellers'),
#  ('The Whistleblower', 'Danny John-Jules'),
#  ('The Whistleblower', 'Mihai Ghior'),
#  ('The Whistleblower', 'Cristina Cristian'),
#  ('Acts of Violence', 'Bruce Willis'),
#  ('Acts of Violence', 'Cole Hauser'),
#  ('Acts of Violence', 'Sophia Bush'),
#  ('Acts of Violence', 'Mike Epps'),
#  ('Acts of Violence', 'Shawn Ashmore'),
#  ('Acts of Violence', 'Melissa Bolona'),
#  ('Acts of Violence', 'Ashton Holmes'),
#  ('Acts of Violence', 'Sean Brosnan'),
#  ('Proie', 'Albert Dupontel'),
#  ('Proie', 'Stéphane Debac'),
#  ('Proie', 'Alice Taglioni'),
#  ('Proie', 'Caterina Murino'),
#  ('Proie', 'Sergi López'),
#  ('Proie', 'Lucien Jean-Baptiste'),
#  ('Proie', 'Zinedine Soualem'),
#  ('Proie', 'Serge Hazanavicius'),
#  ('De gelukkige huisvrouw', 'Carice van Houten'),
#  ('De gelukkige huisvrouw', 'Waldemar Torenstra'),
#  ('De gelukkige huisvrouw', 'Marcel Hensema'),
#  ('De gelukkige huisvrouw', 'Jaap Spijkers'),
#  ('De gelukkige huisvrouw', 'Maike Meijer'),
#  ('De gelukkige huisvrouw', 'Gijs de Lange'),
#  ('De gelukkige huisvrouw', 'Willem de Wolf'),
#  ('De gelukkige huisvrouw', 'Myranda Jongeling'),
#  ('Truth About Kerry', 'Stana Katić'),
#  ('Truth About Kerry', 'Jessica Dean'),
#  ('Truth About Kerry', 'Darren Reiher'),
#  ('Truth About Kerry', 'Ryan C. King'),
#  ('Truth About Kerry', 'Tommy Fitzgerald'),
#  ('Truth About Kerry', 'Rick Yudt'),
#  ('Truth About Kerry', 'Chris Fitzgerald'),
#  ('Truth About Kerry', 'Teresa Riney'),
#  ('Glenn, the Flying Robot', 'Billy Boyd'),
#  ('Glenn, the Flying Robot', 'Patrick Bauchau'),
#  ('Glenn, the Flying Robot', 'Gérard Depardieu'),
#  ('Glenn, the Flying Robot', 'Smadi Wolfman'),
#  ('Glenn, the Flying Robot', 'Dominic Gould'),
#  ('Glenn, the Flying Robot', 'Geoffrey Carey'),
#  ('Glenn, the Flying Robot', 'Cinsyla Key'),
#  ('Glenn, the Flying Robot', 'George W. Contreras'),
#  ('Rabbit Hole', 'Kiefer Sutherland'),
#  ('Rabbit Hole', 'Meta Golding'),
#  ('Rabbit Hole', 'Charles Dance'),
#  ('Rabbit Hole', 'Jason Butler Harner'),
#  ('Rabbit Hole', 'Enid Graham'),
#  ('Rabbit Hole', 'Walt Klink'),
#  ('Rabbit Hole', 'Rob Yang'),
#  ('Rabbit Hole', 'Peter Weller'),
#  ('Green Zone', 'Matt Damon'),
#  ('Green Zone', 'Greg Kinnear'),
#  ('Green Zone', 'Jason Isaacs'),
#  ('Green Zone', 'Amy Ryan'),
#  ('Green Zone', 'Brendan Gleeson'),
#  ('Green Zone', 'Yigal Naor'),
#  ('Green Zone', 'Khalid Abdalla'),
#  ('Green Zone', 'Raad Rawi'),
#  ('Black Swan', 'Natalie Portman'),
#  ('Black Swan', 'Mila Kunis'),
#  ('Black Swan', 'Vincent Cassel'),
#  ('Black Swan', 'Winona Ryder'),
#  ('Black Swan', 'Barbara Hershey'),
#  ('Black Swan', 'Benjamin Millepied'),
#  ('Black Swan', 'Sebastian Stan'),
#  ('Black Swan', 'Sarah Lane'),
#  ('The Killer Inside Me', 'Casey Affleck'),
#  ('The Killer Inside Me', 'Jessica Alba'),
#  ('The Killer Inside Me', 'Kate Hudson'),
#  ('The Killer Inside Me', 'Simon Baker'),
#  ('The Killer Inside Me', 'Bill Pullman'),
#  ('The Killer Inside Me', 'Ned Beatty'),
#  ('The Killer Inside Me', 'Donna E. Jones'),
#  ('The Killer Inside Me', 'Caitlin Turner'),
#  ('The Fighter', 'Christian Bale'),
#  ('The Fighter', 'Mark Wahlberg'),
#  ('The Fighter', 'Micky Ward'),
#  ('The Fighter', 'Melissa Leo'),
#  ('The Fighter', 'Dicky Eklund'),
#  ('The Fighter', 'Bianca Hunter'),
#  ('The Fighter', 'Jack McGee'),
#  ('The Fighter', 'Frank Renzulli'),
#  ('The Conspirator', 'James McAvoy'),
#  ('The Conspirator', 'Robin Wright'),
#  ('The Conspirator', 'Kevin Kline'),
#  ('The Conspirator', 'Evan Rachel Wood'),
#  ('The Conspirator', 'Alexis Bledel'),
#  ('The Conspirator', 'Justin Long'),
#  ('The Conspirator', 'Tom Wilkinson'),
#  ('The Conspirator', 'Toby Kebbell'),
#  ('Fair Game', 'Naomi Watts'),
#  ('Fair Game', 'Sean Penn'),
#  ('Fair Game', 'Noah Emmerich'),
#  ('Fair Game', 'Sam Shepard'),
#  ('Fair Game', 'Michael Kelly'),
#  ('Fair Game', 'Ty Burrell'),
#  ('Fair Game', 'Bruce McGill'),
#  ('Fair Game', 'Brooke Smith'),
#  ('Multiple Sarcasms', 'Timothy Hutton'),
#  ('Multiple Sarcasms', 'Mira Sorvino'),
#  ('Multiple Sarcasms', 'Mario Van Peebles'),
#  ('Multiple Sarcasms', 'Dana Delany'),
#  ('Multiple Sarcasms', 'Stockard Channing'),
#  ('Multiple Sarcasms', 'India Ennenga'),
#  ('Multiple Sarcasms', 'Aileen Quinn'),
#  ('Multiple Sarcasms', 'Brett Berg'),
#  ('Dear John', 'Channing Tatum'),
#  ('Dear John', 'Amanda Seyfried'),
#  ('Dear John', 'Richard Jenkins'),
#  ('Dear John', 'Scott Porter'),
#  ('Dear John', 'Henry Thomas'),
#  ('Dear John', 'Gavin McCulley'),
#  ('Dear John', 'Luke Benward'),
#  ('Dear John', 'Bryce Hogarth'),
#  ('The Experiment', 'Forest Whitaker'),
#  ('The Experiment', 'Adrien Brody'),
#  ('The Experiment', 'Cam Gigandet'),
#  ('The Experiment', 'Maggie Grace'),
#  ('The Experiment', 'Clifton Collins Jr.'),
#  ('The Experiment', 'Travis Fimmel'),
#  ('The Experiment', 'Fisher Stevens'),
#  ('The Experiment', 'Ethan Cohn'),
#  ('Centurion', 'Michael Fassbender'),
#  ('Centurion', 'Olga Kurylenko'),
#  ('Centurion', 'Imogen Poots'),
#  ('Centurion', 'Dominic West'),
#  ('Centurion', 'Axelle Carolyn'),
#  ('Centurion', 'JJ Feild'),
#  ('Centurion', 'David Morrissey'),
#  ('Centurion', 'Liam Cunningham'),
#  ('Copie conforme', 'Juliette Binoche'),
#  ('Copie conforme', 'William Shimell'),
#  ('Copie conforme', 'Angelo Barbagallo'),
#  ('Copie conforme', 'Filippo Trojano'),
#  ('Copie conforme', 'Andrea Laurenzi'),
#  ('Copie conforme', 'Agathe Natanson'),
#  ('Copie conforme', 'Gianna Giachetti'),
#  ('Copie conforme', 'Jean-Claude Carrière'),
#  ('The Way Back', 'Janina Gavankar'),
#  ('The Way Back', 'Justice Alan'),
#  ('The Way Back', 'Ben Affleck'),
#  ('The Way Back', 'Al Madrigal'),
#  ('The Way Back', 'Michaela Watkins'),
#  ('The Way Back', 'April Adams'),
#  ('The Way Back', 'Calvin Barber'),
#  ('The Way Back', 'Xu Razer'),
#  ('Wall Street: Money Never Sleeps', 'Michael Douglas'),
#  ('Wall Street: Money Never Sleeps', 'Shia LaBeouf'),
#  ('Wall Street: Money Never Sleeps', 'Oliver Stone'),
#  ('Wall Street: Money Never Sleeps', 'Carey Mulligan'),
#  ('Wall Street: Money Never Sleeps', 'Josh Brolin'),
#  ('Wall Street: Money Never Sleeps', 'Frank Langella'),
#  ('Wall Street: Money Never Sleeps', 'Eli Wallach'),
#  ('Wall Street: Money Never Sleeps', 'Susan Sarandon'),
#  ('Secretariat', 'Penny Chenery'),
#  ('Secretariat', 'Margo Martindale'),
#  ('Secretariat', 'John Malkovich'),
#  ('Secretariat', 'Diane Lane'),
#  ('Secretariat', 'Amanda Michalka'),
#  ('Secretariat', 'Kevin Connolly'),
#  ('Secretariat', 'Dylan Walsh'),
#  ('Secretariat', 'James Cromwell'),
#  ('The Book of Eli', 'Denzel Washington'),
#  ('The Book of Eli', 'Gary Oldman'),
#  ('The Book of Eli', 'Mila Kunis'),
#  ('The Book of Eli', 'Jennifer Beals'),
#  ('The Book of Eli', 'Ray Stevenson'),
#  ('The Book of Eli', 'Michael Gambon'),
#  ('The Book of Eli', 'Tom Waits'),
#  ('The Book of Eli', 'Evan Jones'),
#  ('El mal ajeno', 'Eduardo Noriega'),
#  ('El mal ajeno', 'Belén Rueda'),
#  ('El mal ajeno', 'Angie Cepeda'),
#  ('El mal ajeno', 'Carlos Leal'),
#  ('El mal ajeno', 'Clara Lago'),
#  ('El mal ajeno', 'José Ángel Egido'),
#  ('El mal ajeno', 'Sonia Lázaro'),
#  ('El mal ajeno', 'Dritan Biba'),
#  ('Camp Hell', 'Jesse Eisenberg'),
#  ('Camp Hell', 'Dana Delany'),
#  ('Camp Hell', 'Caroline London'),
#  ('Camp Hell', 'Andrew McCarthy'),
#  ('Camp Hell', 'Bruce Davison'),
#  ('Camp Hell', 'Connor Paolo'),
#  ('Camp Hell', 'Will Denton'),
#  ('Camp Hell', 'Spencer Treat Clark'),
#  ('Howl', 'Edward Speleers'),
#  ('Howl', 'Holly Weston'),
#  ('Howl', 'Sam Gittins'),
#  ('Howl', 'Sean Pertwee'),
#  ('Howl', 'Shauna Macdonald'),
#  ('Howl', 'Rosie Day'),
#  ('Howl', 'Elliot Cowan'),
#  ('Howl', 'Calvin Dean'),
#  ('As Melhores Coisas do Mundo', 'Francisco Miguez'),
#  ('As Melhores Coisas do Mundo', 'Denise Fraga'),
#  ('As Melhores Coisas do Mundo', 'Caio Blat'),
#  ('As Melhores Coisas do Mundo', 'Fiuk'),
#  ('As Melhores Coisas do Mundo', 'Gustavo Machado'),
#  ('As Melhores Coisas do Mundo', 'Brenda Lígia'),
#  ('As Melhores Coisas do Mundo', 'Gabriela Rocha'),
#  ('As Melhores Coisas do Mundo', 'Gabriel Illanes'),
#  ('Life as We Know It', 'Katherine Heigl'),
#  ('Life as We Know It', 'Josh Duhamel'),
#  ('Life as We Know It', 'Alexis Clagett'),
#  ('Life as We Know It', 'Josh Lucas'),
#  ('Life as We Know It', 'Brooke Clagett'),
#  ('Life as We Know It', 'Brynn Clagett'),
#  ('Life as We Know It', 'Melissa McCarthy'),
#  ('Life as We Know It', 'Christina Hendricks'),
#  ('Al Nebras', 'Bruce Dern'),
#  ('Al Nebras', 'Will Forte'),
#  ('Al Nebras', 'Bob Odenkirk'),
#  ('Al Nebras', 'June Squibb'),
#  ('Al Nebras', 'Dennis McCoig'),
#  ('Al Nebras', 'Ronald Vosta'),
#  ('Al Nebras', 'Stacy Keach'),
#  ('Al Nebras', 'Devin Ratray'),
#  ('Small Town Saturday Night', 'Chris Pine'),
#  ('Small Town Saturday Night', 'Bre Blair'),
#  ('Small Town Saturday Night', 'Shawn Christian'),
#  ('Small Town Saturday Night', 'Ryan Craig'),
#  ('Small Town Saturday Night', 'John Hawkes'),
#  ('Small Town Saturday Night', 'Lin Shaye'),
#  ('Small Town Saturday Night', 'Robert Pine'),
#  ('Small Town Saturday Night', 'Muse Watson'),
#  ("Quincas Berro d'Água", 'Marieta Severo'),
#  ("Quincas Berro d'Água", 'Paulo José'),
#  ("Quincas Berro d'Água", 'Mariana Ximenes'),
#  ("Quincas Berro d'Água", 'Milton Gonçalves'),
#  ("Quincas Berro d'Água", 'Vladimir Brichta'),
#  ("Quincas Berro d'Água", 'Walderez de Barros'),
#  ("Quincas Berro d'Água", 'Luisa Proserpio'),
#  ("Quincas Berro d'Água", 'Irandhir Santos'),
#  ('Jonah Hex', 'Josh Brolin'),
#  ('Jonah Hex', 'Megan Fox'),
#  ('Jonah Hex', 'Jimmy Hayward'),
#  ('Jonah Hex', 'John Malkovich'),
#  ('Jonah Hex', 'Michael Fassbender'),
#  ('Jonah Hex', 'Will Arnett'),
#  ('Jonah Hex', 'Michael Shannon'),
#  ('Jonah Hex', 'Wes Bentley'),
#  ('Happiness Runs', 'Hanna Hall'),
#  ('Happiness Runs', 'Adam Sherman'),
#  ('Happiness Runs', 'Andie MacDowell'),
#  ('Happiness Runs', 'Jesse Plemons'),
#  ('Happiness Runs', 'Mark L. Young'),
#  ('Happiness Runs', 'Shiloh Fernandez'),
#  ('Happiness Runs', 'Rutger Hauer'),
#  ('Happiness Runs', 'Tyler Steelman'),
#  ('Pusher', 'Nicolas Winding Refn'),
#  ('Pusher', 'Mads Mikkelsen'),
#  ('Pusher', 'Kim Bodnia'),
#  ('Pusher', 'Zlatko Burić'),
#  ('Pusher', 'Laura Drasbaek'),
#  ('Pusher', 'Slavko Labović'),
#  ('Pusher', 'Vanja Bajičić'),
#  ('Pusher', 'Lisbeth Rasmussen'),
#  ('Lights Out', 'Teresa Palmer'),
#  ('Lights Out', 'Gabriel Bateman'),
#  ('Lights Out', 'Maria Bello'),
#  ('Lights Out', 'Lotta Losten'),
#  ('Lights Out', 'Alicia Vela-Bailey'),
#  ('Lights Out', 'Alexander DiPersia'),
#  ('Lights Out', 'Billy Burke'),
#  ('Lights Out', 'Emily Alyn Lind'),
#  ('Shanghai', 'John Cusack'),
#  ('Shanghai', 'Gong Li'),
#  ('Shanghai', 'Chow Yun-Fat'),
#  ('Shanghai', 'Ken Watanabe'),
#  ('Shanghai', 'Jeffrey Dean Morgan'),
#  ('Shanghai', 'Franka Potente'),
#  ('Shanghai', 'Rinko Kikuchi'),
#  ('Shanghai', 'David Morse'),
#  ('The Quiet Ones', 'Jared Harris'),
#  ('The Quiet Ones', 'Sam Claflin'),
#  ('The Quiet Ones', 'Olivia Cooke'),
#  ('The Quiet Ones', 'Erin Richards'),
#  ('The Quiet Ones', 'Tracy Ray'),
#  ('The Quiet Ones', 'Aldo Maland'),
#  ('The Quiet Ones', 'Rory Fleck Byrne'),
#  ('The Quiet Ones', 'Harman Singh'),
#  ('Morning', 'Jennifer Aniston'),
#  ('Morning', 'Reese Witherspoon'),
#  ('Morning', 'Billy Crudup'),
#  ('Morning', 'Julianna Margulies'),
#  ('Morning', 'Steve Carell'),
#  ('Morning', 'Mark Duplass'),
#  ('Morning', 'Greta Lee'),
#  ('Morning', 'Desean K. Terry'),
#  ('Do Elephants Pray?', 'Julie Dray'),
#  ('Do Elephants Pray?', 'Jonnie Hurn'),
#  ('Do Elephants Pray?', 'Marc Warren'),
#  ('Do Elephants Pray?', 'Rosie Fellner'),
#  ('Do Elephants Pray?', 'Dougal Porteous'),
#  ('Do Elephants Pray?', 'John Last'),
#  ('Do Elephants Pray?', 'Grace Vallorani'),
#  ('Do Elephants Pray?', 'Jean-Baptiste Puech'),
#  ('Broken Sun', 'Shingo Usami'),
#  ('Broken Sun', 'Kentaro Hara'),
#  ('Broken Sun', 'Jai Koutrae'),
#  ('Broken Sun', 'James Bishop'),
#  ('Broken Sun', 'Steve Dodd'),
#  ('Broken Sun', 'Rudi Baker'),
#  ('Broken Sun', 'Kuni Hashimoto'),
#  ('Broken Sun', 'Taki Abe'),
#  ('Peep World', 'Rainn Wilson'),
#  ('Peep World', 'Michael C. Hall'),
#  ('Peep World', 'Sarah Silverman'),
#  ('Peep World', 'Ben Schwartz'),
#  ('Peep World', 'Judy Greer'),
#  ('Peep World', 'Kate Mara'),
#  ('Peep World', 'Taraji P. Henson'),
#  ('Peep World', 'Ron Rifkin'),
#  ('Dirty Girl', 'Juno Temple'),
#  ('Dirty Girl', 'Milla JOVOVICH'),
#  ('Dirty Girl', 'Jeremy Dozier'),
#  ('Dirty Girl', 'William H. Macy'),
#  ('Dirty Girl', 'Mary Steenburgen'),
#  ('Dirty Girl', 'Dwight Yoakam'),
#  ('Dirty Girl', 'Tim McGraw'),
#  ('Dirty Girl', 'Elsie Fisher'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Gabriel Batistuta'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'José Wilker'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'José Dumont'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Marcélia Cartaxo'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Zezita Matos'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Ravi Ramos Lacerda'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Fernando Teixeira'),
#  ('O Sonho de Inacim - O Aprendiz do Padre Rolim', 'Gal Cunha Lima'),
#  ('Blue Valentine', 'Michelle Williams'),
#  ('Blue Valentine', 'Ryan Gosling'),
#  ('Blue Valentine', 'Mike Vogel'),
#  ('Blue Valentine', 'Faith Wladyka'),
#  ('Blue Valentine', 'John Doman'),
#  ('Blue Valentine', 'Eileen Rosen'),
#  ('Blue Valentine', 'Ben Shenkman'),
#  ('Blue Valentine', 'Enid Graham'),
#  ('Di renjie: Tong tian di guo', 'Andy Lau'),
#  ('Di renjie: Tong tian di guo', 'Carina Lau'),
#  ('Di renjie: Tong tian di guo', 'Li Bingbing'),
#  ('Di renjie: Tong tian di guo', 'Jean-Michel Casanova'),
#  ('Di renjie: Tong tian di guo', 'Tony Leung Ka-fai'),
#  ('Di renjie: Tong tian di guo', 'Deng Chao'),
#  ('Di renjie: Tong tian di guo', 'Sos Haroyan'),
#  ('Di renjie: Tong tian di guo', 'Chi Wai Yau'),
#  ('Love Ranch', 'Helen Mirren'),
#  ('Love Ranch', 'Joe Pesci'),
#  ('Love Ranch', 'Gina Gershon'),
#  ('Love Ranch', 'Sergio Peris-Mencheta'),
#  ('Love Ranch', 'Bryan Cranston'),
#  ('Love Ranch', 'Taryn Manning'),
#  ('Love Ranch', 'Bai Ling'),
#  ('Love Ranch', 'Scout Taylor-Compton'),
#  ('Burlesque', 'Christina Aguilera'),
#  ('Burlesque', 'Cher'),
#  ('Burlesque', 'Cam Gigandet'),
#  ('Burlesque', 'Stanley Tucci'),
#  ('Burlesque', 'Kristen Bell'),
#  ('Burlesque', 'Julianne Hough'),
#  ('Burlesque', 'Eric Dane'),
#  ('Burlesque', 'Alan Cumming'),
#  ('Morning Glory', 'Harrison Ford'),
#  ('Morning Glory', 'Rachel McAdams'),
#  ('Morning Glory', 'Diane Keaton'),
#  ('Morning Glory', 'Roger Michell'),
#  ('Morning Glory', 'Patrick Wilson'),
#  ('Morning Glory', 'Jeff Goldblum'),
#  ('Morning Glory', 'Alwin H. Küchler'),
#  ('Morning Glory', 'Joseph J. Vargas'),
#  ('Another Harvest Moon', 'Ernest Borgnine'),
#  ('Another Harvest Moon', 'Doris Roberts'),
#  ('Another Harvest Moon', 'Piper Laurie'),
#  ('Another Harvest Moon', 'Sunkrish Bala'),
#  ('Another Harvest Moon', 'Anne Meara'),
#  ('Another Harvest Moon', 'Richard Schiff'),
#  ('Another Harvest Moon', 'Cybill Shepherd'),
#  ('Another Harvest Moon', 'Cameron Monaghan'),
#  ('Sisanje', 'Bojana Novakovic'),
#  ('Sisanje', 'Nikola Rakočević'),
#  ('Sisanje', 'Viktor Savić'),
#  ('Sisanje', 'Nataša Tapušković'),
#  ('Sisanje', 'Nikola Kojo'),
#  ('Sisanje', 'Dragan Mićanović'),
#  ('Sisanje', 'Predrag Ejdus'),
#  ('Sisanje', 'Srђan Miletić'),
#  ('The 5th Quarter', 'Andie MacDowell'),
#  ('The 5th Quarter', 'Aidan Quinn'),
#  ('The 5th Quarter', 'Ryan Merriman'),
#  ('The 5th Quarter', 'Stefan Guy'),
#  ('The 5th Quarter', 'Michael Harding'),
#  ('The 5th Quarter', 'Anessa Ramsey'),
#  ('The 5th Quarter', 'Mandy Manis'),
#  ('The 5th Quarter', 'Jillian Batherson'),
#  ('The Ghost Writer', 'Ewan McGregor'),
#  ('The Ghost Writer', 'Pierce Brosnan'),
#  ('The Ghost Writer', 'Olivia Williams'),
#  ('The Ghost Writer', 'Kim Cattrall'),
#  ('The Ghost Writer', 'Tom Wilkinson'),
#  ('The Ghost Writer', 'Eli Wallach'),
#  ('The Ghost Writer', 'Jim Belushi'),
#  ('The Ghost Writer', 'Jon Bernthal'),
#  ('Holy Rollers', 'Jesse Eisenberg'),
#  ('Holy Rollers', 'Justin Bartha'),
#  ('Holy Rollers', 'Danny A. Abeckaser'),
#  ('Holy Rollers', 'Ari Graynor'),
#  ('Holy Rollers', 'Hallie Kate Eisenberg'),
#  ('Holy Rollers', 'Jason Fuchs'),
#  ('Holy Rollers', 'Elizabeth Marvel'),
#  ('Holy Rollers', 'David Vadim'),
#  ('NY Export: Opus Jazz', 'Tiler Peck'),
#  ('NY Export: Opus Jazz', 'Robert Fairchild'),
#  ('NY Export: Opus Jazz', 'Amar Ramasar'),
#  ('NY Export: Opus Jazz', 'Georgina Pazcoguin'),
#  ('NY Export: Opus Jazz', 'Andrew Veyette'),
#  ('NY Export: Opus Jazz', 'Ashley Laracey'),
#  ('NY Export: Opus Jazz', 'Ellen Bar'),
#  ('NY Export: Opus Jazz', 'Brittany Pollack'),
#  ('The Karate Kid', 'Ralph Macchio'),
#  ('The Karate Kid', 'Pat Morita'),
#  ('The Karate Kid', 'William Zabka'),
#  ('The Karate Kid', 'Jaden Smith'),
#  ('The Karate Kid', 'Elisabeth Shue'),
#  ('The Karate Kid', 'John G. Avildsen'),
#  ('The Karate Kid', 'Martin Kove'),
#  ('The Karate Kid', 'Randee Heller'),
#  ('Biutiful', 'Javier Bardem'),
#  ('Biutiful', 'Alejandro González Iñárritu'),
#  ('Biutiful', 'Diaryatou Daff'),
#  ('Biutiful', 'Maricel Álvarez'),
#  ('Biutiful', 'Hanaa Bouchaib'),
#  ('Biutiful', 'Eduard Fernández'),
#  ('Biutiful', 'Germán Almendros'),
#  ('Biutiful', 'Lang Sofia Lin'),
#  ("L'immortel", 'Jean Reno'),
#  ("L'immortel", 'Richard Berry'),
#  ("L'immortel", 'Marina Foïs'),
#  ("L'immortel", 'Kad Merad'),
#  ("L'immortel", 'Gabriella Wright'),
#  ("L'immortel", 'Max Baissette de Malglaive'),
#  ("L'immortel", 'Fani Kołarova'),
#  ("L'immortel", 'Moussa Maaskri'),
#  ('The Company Men', 'Ben Affleck'),
#  ('The Company Men', 'Tommy Lee Jones'),
#  ('The Company Men', 'Kevin Costner'),
#  ('The Company Men', 'Chris Cooper'),
#  ('The Company Men', 'Maria Bello'),
#  ('The Company Men', 'Craig T. Nelson'),
#  ('The Company Men', 'Rosemarie DeWitt'),
#  ('The Company Men', 'Dana Eskelson'),
#  ('The Bang Bang Club', 'Taylor Kitsch'),
#  ('The Bang Bang Club', 'Ryan Phillippe'),
#  ('The Bang Bang Club', 'Frank Rautenbach'),
#  ('The Bang Bang Club', 'Malin Åkerman'),
#  ('The Bang Bang Club', 'Neil Tabatznik'),
#  ('The Bang Bang Club', 'Lika Berning'),
#  ('The Bang Bang Club', 'Nina Milner'),
#  ('The Bang Bang Club', 'Jessica Haines'),
#  ('The Myth of the American Sleepover', 'Marlon Morton'),
#  ('The Myth of the American Sleepover', 'Claire Sloma'),
#  ('The Myth of the American Sleepover', 'Amanda Bauer'),
#  ('The Myth of the American Sleepover', 'Brett Jacobsen'),
#  ('The Myth of the American Sleepover', 'Mary Wardell'),
#  ('The Myth of the American Sleepover', 'Jade Ramsey'),
#  ('The Myth of the American Sleepover', 'Annette DeNoyer'),
#  ('The Myth of the American Sleepover', 'Nikita Ramsey'),
#  ('All Good Things', 'Ryan Gosling'),
#  ('All Good Things', 'Kirsten Dunst'),
#  ('All Good Things', 'Frank Langella'),
#  ('All Good Things', 'Lily Rabe'),
#  ('All Good Things', 'Kristen Wiig'),
#  ('All Good Things', 'Diane Venora'),
#  ('All Good Things', 'Philip Baker Hall'),
#  ('All Good Things', 'Nick Offerman'),
#  ('A Nightmare on Elm Street', 'Robert Englund'),
#  ('A Nightmare on Elm Street', 'Heather Langenkamp'),
#  ('A Nightmare on Elm Street', 'Johnny Depp'),
#  ('A Nightmare on Elm Street', 'John Saxon'),
#  ('A Nightmare on Elm Street', 'Amanda Wyss'),
#  ('A Nightmare on Elm Street', 'Lin Shaye'),
#  ('A Nightmare on Elm Street', 'Jsu García'),
#  ('A Nightmare on Elm Street', 'Ronee Blakley'),
#  ('Black Death', 'Sean Bean'),
#  ('Black Death', 'Eddie Redmayne'),
#  ('Black Death', 'Carice van Houten'),
#  ('Black Death', 'David Warner'),
#  ('Black Death', 'Kimberley Nixon'),
#  ('Black Death', 'Andy Nyman'),
#  ('Black Death', 'Tim McInnerny'),
#  ('Black Death', 'Johnny Harris'),
#  ('Bunraku', 'Josh Hartnett'),
#  ('Bunraku', 'Woody Harrelson'),
#  ('Bunraku', 'Ron Perlman'),
#  ('Bunraku', 'Demi Moore'),
#  ('Bunraku', 'Mike Patton'),
#  ('Bunraku', 'Kevin McKidd'),
#  ('Bunraku', 'Gackt'),
#  ('Bunraku', 'Jordi Mollà'),
#  ('You Will Meet a Tall Dark Stranger', 'Anthony Hopkins'),
#  ('You Will Meet a Tall Dark Stranger', 'Josh Brolin'),
#  ('You Will Meet a Tall Dark Stranger', 'Naomi Watts'),
#  ('You Will Meet a Tall Dark Stranger', 'Antonio Banderas'),
#  ('You Will Meet a Tall Dark Stranger', 'Freida Pinto'),
#  ('You Will Meet a Tall Dark Stranger', 'Lucy Punch'),
#  ('You Will Meet a Tall Dark Stranger', 'Gemma Jones'),
#  ('You Will Meet a Tall Dark Stranger', 'Theo James'),
#  ('Mr. Nice', 'Rhys Ifans'),
#  ('Mr. Nice', 'David Thewlis'),
#  ('Mr. Nice', 'Chloë Sevigny'),
#  ('Mr. Nice', 'Christian McKay'),
#  ('Mr. Nice', 'Crispin Glover'),
#  ('Mr. Nice', 'Elsa Pataky'),
#  ('Mr. Nice', 'Jack Huston'),
#  ('Mr. Nice', 'Omid Djalili'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Rekha'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Hema Malini'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Ferena Wazeir'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Rishi Kapoor'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Javed Sheikh'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Luv Sinha'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Shabana Azmi'),
#  ('Sadiyaan: Boundaries Divide... Love Unites', 'Navni Parihar'),
#  ('Welcome to the Rileys', 'Kristen Stewart'),
#  ('Welcome to the Rileys', 'James Gandolfini'),
#  ('Welcome to the Rileys', 'Melissa Leo'),
#  ('Welcome to the Rileys', 'Tiffany Coty'),
#  ('Welcome to the Rileys', 'Kathy Lamkin'),
#  ('Welcome to the Rileys', 'Ken Hixon'),
#  ('Welcome to the Rileys', 'Sharon Landry'),
#  ('Welcome to the Rileys', 'David Jensen'),
#  ('Veer', 'Salman Khan'),
#  ('Veer', 'Zarine Khan'),
#  ('Veer', 'Mithun Chakraborty'),
#  ('Veer', 'Jackie Shroff'),
#  ('Veer', 'Lisa Lazarus'),
#  ('Veer', 'Gita Solo'),
#  ('Veer', 'Neena Gupta'),
#  ('Veer', 'Bharat Dabholkar'),
#  ('Lope', 'Leonor Watling'),
#  ('Lope', 'Pilar López de Ayala'),
#  ('Lope', 'Sônia Braga'),
#  ('Lope', 'Luis Tosar'),
#  ('Lope', 'Antonio de la Torre Martín'),
#  ('Lope', 'Alberto Ammann'),
#  ('Lope', 'Miguel Ángel Muñoz'),
#  ('Lope', 'Juan Diego'),
#  ('My Name Is Khan', 'Shahrukh Khan'),
#  ('My Name Is Khan', 'Kajol'),
#  ('My Name Is Khan', 'Adarsh Gourav'),
#  ('My Name Is Khan', 'Jimmy Shergill'),
#  ('My Name Is Khan', 'Pallavi Sharda'),
#  ('My Name Is Khan', 'Tanay Chheda'),
#  ('My Name Is Khan', 'Sonya Jehan'),
#  ('My Name Is Khan', 'Arjan Aujla'),
#  ('Right Yaaa Wrong', 'Sunny Deol'),
#  ('Right Yaaa Wrong', 'Irrfan Khan'),
#  ('Right Yaaa Wrong', 'Isha Koppikar'),
#  ('Right Yaaa Wrong', 'Konkona Sen Sharma'),
#  ('Right Yaaa Wrong', 'Aryan Vaid'),
#  ('Right Yaaa Wrong', 'Ali Haji'),
#  ('Right Yaaa Wrong', 'Deepal Shaw'),
#  ('Right Yaaa Wrong', 'Govind Namdeo'),
#  ('My Own Love Song', 'Renée Zellweger'),
#  ('My Own Love Song', 'Forest Whitaker'),
#  ('My Own Love Song', 'Nick Nolte'),
#  ('My Own Love Song', 'Madeline Zima'),
#  ('My Own Love Song', 'Elias Koteas'),
#  ('My Own Love Song', 'Chandler Frantz'),
#  ('My Own Love Song', 'Tim Parati'),
#  ('My Own Love Song', 'Bill Ladd'),
#  ('Step Up 3D', 'Adam Sevani'),
#  ('Step Up 3D', 'Rick Malambri'),
#  ('Step Up 3D', 'Sharni Vinson'),
#  ('Step Up 3D', 'Alyson Stoner'),
#  ('Step Up 3D', 'Stephen Boss'),
#  ('Step Up 3D', 'Joe Slaughter'),
#  ('Step Up 3D', 'Kendra Andrews'),
#  ('Step Up 3D', 'Martín Lombard'),
#  ('Casino Jack', 'Kevin Spacey'),
#  ('Casino Jack', 'George Hickenlooper'),
#  ('Casino Jack', 'Barry Pepper'),
#  ('Casino Jack', 'Jon Lovitz'),
#  ('Casino Jack', 'Kelly Preston'),
#  ('Casino Jack', 'Rachelle Lefevre'),
#  ('Casino Jack', 'Hannah Endicott-Douglas'),
#  ('Casino Jack', 'Xenia Siamas'),
#  ('Inhale', 'Dermot Mulroney'),
#  ('Inhale', 'Diane Kruger'),
#  ('Inhale', 'Mia Stallard'),
#  ('Inhale', 'Christian Escario'),
#  ('Inhale', 'Sam Shepard'),
#  ('Inhale', 'Rosanna Arquette'),
#  ('Inhale', 'Jordi Mollà'),
#  ('Inhale', 'Vincent Pérez'),
#  ('Diary of a Wimpy Kid', 'Zachary Gordon'),
#  ('Diary of a Wimpy Kid', 'Robert Capron'),
#  ('Diary of a Wimpy Kid', 'Devon Bostick'),
#  ('Diary of a Wimpy Kid', 'Chloë Grace Moretz'),
#  ('Diary of a Wimpy Kid', 'Steve Zahn'),
#  ('Diary of a Wimpy Kid', 'Rachael Harris'),
#  ('Diary of a Wimpy Kid', 'Laine MacNeil'),
#  ('Diary of a Wimpy Kid', 'Grayson Russell'),
#  ('Cemetery Junction', 'Ricky Gervais'),
#  ('Cemetery Junction', 'Stephen Merchant'),
#  ('Cemetery Junction', 'Jack Doolan'),
#  ('Cemetery Junction', 'Ralph Fiennes'),
#  ('Cemetery Junction', 'Christian Cooke'),
#  ('Cemetery Junction', 'Tom Hughes'),
#  ('Cemetery Junction', 'Felicity Jones'),
#  ('Cemetery Junction', 'Matthew Goode'),
#  ('Kites', 'Hrithik Roshan'),
#  ('Kites', 'Bárbara Mori'),
#  ('Kites', 'Kangana Ranaut'),
#  ('Kites', 'Kabir Bedi'),
#  ('Kites', 'Nicholas Brown'),
#  ('Kites', 'Yuri Suri'),
#  ('Kites', 'Anand Tiwari'),
#  ('Kites', 'Steven Michael Quezada'),
#  ('Person of Interest', 'Michael Emerson'),
#  ('Person of Interest', 'Kevin Chapman'),
#  ('Person of Interest', 'Jim Caviezel'),
#  ('Person of Interest', 'Amy Acker'),
#  ('Person of Interest', 'Sarah Shahi'),
#  ('Person of Interest', 'Taraji P. Henson'),
#  ('Person of Interest', 'John Nolan (British actor)'),
#  ('Person of Interest', 'Boris McGiver'),
#  ('Blood Done Sign My Name', 'Nate Parker'),
#  ('Blood Done Sign My Name', 'Rick Schroder'),
#  ('Blood Done Sign My Name', 'Michael Rooker'),
#  ('Blood Done Sign My Name', 'Nick Searcy'),
#  ('Blood Done Sign My Name', 'Omar Benson Miller'),
#  ('Blood Done Sign My Name', 'Emily Alyn Lind'),
#  ('Blood Done Sign My Name', 'Gattlin Griffith'),
#  ('Blood Done Sign My Name', 'Natalie Alyn Lind'),
#  ('Hereafter', 'Matt Damon'),
#  ('Hereafter', 'Bryce Dallas Howard'),
#  ('Hereafter', 'Cécile de France'),
#  ('Hereafter', 'Lisa Griffiths'),
#  ('Hereafter', 'Frankie McLaren'),
#  ('Hereafter', 'Steve Schirripa'),
#  ('Hereafter', 'George McLaren'),
#  ('Hereafter', 'Jay Mohr'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Eri Fukatsu'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Yūji Oda'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!',
#   'Yūsuke Santamaria'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Shun Oguri'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Atsushi Itō'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Toshirō Yanagiba'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!', 'Yūki Uchida'),
#  ('Odoru daisousasen the movie 3: Yatsura o kaihou seyo!',
#   'Sōichirō Kitamura'),
#  ('An Invisible Sign', 'Jessica Alba'),
#  ('An Invisible Sign', 'Chris Messina'),
#  ('An Invisible Sign', 'J. K. Simmons'),
#  ('An Invisible Sign', 'Bailee Madison'),
#  ('An Invisible Sign', 'John Shea'),
#  ('An Invisible Sign', 'Sônia Braga'),
#  ('An Invisible Sign', 'Ashlie Atkinson'),
#  ('An Invisible Sign', 'Sophie Nyweide'),
#  ('London Boulevard', 'Colin Farrell'),
#  ('London Boulevard', 'Keira Knightley'),
#  ('London Boulevard', 'Ray Winstone'),
#  ('London Boulevard', 'David Thewlis'),
#  ('London Boulevard', 'Anna Friel'),
#  ('London Boulevard', 'Ben Chaplin'),
#  ('London Boulevard', 'Stephen Graham'),
#  ('London Boulevard', 'Ophelia Lovibond'),
#  ('Womb', 'Eva Green'),
#  ('Womb', 'Matt Smith'),
#  ('Womb', 'Lesley Manville'),
#  ('Womb', 'Peter Wight'),
#  ('Womb', 'Ruby O. Fee'),
#  ('Womb', 'Jesse Hoffmann'),
#  ('Womb', 'Hannah Murray'),
#  ('Womb', 'István Lénárt'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Jim Sturgess'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'David Wenham'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Hugo Weaving'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Sam Neill'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Adrienne DeFaria'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Helen Mirren'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Ryan Kwanten'),
#  ("Legend of the Guardians: The Owls of Ga'Hoole", 'Emily Barclay'),
#  ("Henry's Crime", 'Keanu Reeves'),
#  ("Henry's Crime", 'James Caan'),
#  ("Henry's Crime", 'Vera Farmiga'),
#  ("Henry's Crime", 'Judy Greer'),
#  ("Henry's Crime", 'Fisher Stevens'),
#  ("Henry's Crime", 'Peter Stormare'),
#  ("Henry's Crime", 'Steve Beauchamp'),
#  ("Henry's Crime", 'Bill Duke'),
#  ('Frankie & Alice', 'Halle Berry'),
#  ('Frankie & Alice', 'Stellan Skarsgård'),
#  ('Frankie & Alice', 'Phylicia Rashād'),
#  ('Frankie & Alice', 'Chandra Wilson'),
#  ('Frankie & Alice', 'Matt Frewer'),
#  ('Frankie & Alice', 'Brian Markinson'),
#  ('Frankie & Alice', 'Vanessa Morgan'),
#  ('Frankie & Alice', 'Kira Clavell'),
#  ('Edge of Darkness', 'Mel Gibson'),
#  ('Edge of Darkness', 'Ray Winstone'),
#  ('Edge of Darkness', 'Danny Huston'),
#  ('Edge of Darkness', 'Bojana Novakovic'),
#  ('Edge of Darkness', 'Gabrielle Popa'),
#  ('Edge of Darkness', "Denis O'Hare"),
#  ('Edge of Darkness', 'Shawn Roberts'),
#  ('Edge of Darkness', 'David Aaron Baker'),
#  ('The Debt', 'Helen Mirren'),
#  ('The Debt', 'Sam Worthington'),
#  ('The Debt', 'Jessica Chastain'),
#  ('The Debt', 'Tom Wilkinson'),
#  ('The Debt', 'Ciarán Hinds'),
#  ('The Debt', 'Marton Csokas'),
#  ('The Debt', 'Romi Aboulafia'),
#  ('The Debt', 'Jesper Christensen'),
#  ('Let Me In', 'Chloë Grace Moretz'),
#  ('Let Me In', 'Kodi Smit-McPhee'),
#  ('Let Me In', 'Dylan Minnette'),
#  ('Let Me In', 'Richard Jenkins'),
#  ('Let Me In', 'Sasha Barrese'),
#  ('Let Me In', 'Cara Buono'),
#  ('Let Me In', 'Elias Koteas'),
#  ('Let Me In', 'Ritchie Coster'),
#  ('Due Date', 'Zach Galifianakis'),
#  ('Due Date', 'Robert Downey Jr.'),
#  ('Due Date', 'Todd Phillips'),
#  ('Due Date', 'Jamie Foxx'),
#  ('Due Date', 'Michelle Monaghan'),
#  ('Due Date', 'Juliette Lewis'),
#  ('Due Date', 'Danny McBride'),
#  ('Due Date', 'Nathalie Fay'),
#  ('Triple Dog', 'Britt Robertson'),
#  ('Triple Dog', 'Scout Taylor-Compton'),
#  ('Triple Dog', 'Alexia Fast'),
#  ('Triple Dog', 'Carly McKillip'),
#  ('Triple Dog', 'Emily Tennant'),
#  ('Triple Dog', 'Janel Parrish'),
#  ('Triple Dog', 'Brett Davern'),
#  ('Triple Dog', 'Valerie Tian'),
#  ('Brighton Rock', 'Sam Riley'),
#  ('Brighton Rock', 'Helen Mirren'),
#  ('Brighton Rock', 'Andrea Riseborough'),
#  ('Brighton Rock', 'John Hurt'),
#  ('Brighton Rock', 'Andy Serkis'),
#  ('Brighton Rock', 'Sean Harris'),
#  ('Brighton Rock', 'Nonso Anozie'),
#  ('Brighton Rock', 'Phil Davis'),
#  ('Chico Xavier', 'Nelson Xavier'),
#  ('Chico Xavier', 'Ângelo Antônio'),
#  ('Chico Xavier', 'Natalia Soutto'),
#  ('Chico Xavier', 'Matheus Costa'),
#  ('Chico Xavier', 'Luís Alberto Melo'),
#  ('Chico Xavier', 'Via Negromonte'),
#  ('Chico Xavier', 'Giovanna Antonelli'),
#  ('Chico Xavier', 'Tony Ramos'),
#  ("'Master Harold' ... And the Boys", 'Freddie Highmore'),
#  ("'Master Harold' ... And the Boys", 'Ving Rhames'),
#  ("'Master Harold' ... And the Boys", 'Nicky Rebello'),
#  ("'Master Harold' ... And the Boys", 'Patrick Mofokeng'),
#  ("'Master Harold' ... And the Boys", 'Mike Maxwell'),
#  ("'Master Harold' ... And the Boys", 'Jennifer Steyn'),
#  ("'Master Harold' ... And the Boys", 'Zoliswa Kawe'),
#  ("'Master Harold' ... And the Boys", 'Redd-Valentino Debray'),
#  ('Greenberg', 'Ben Stiller'),
#  ('Greenberg', 'Greta Gerwig'),
#  ('Greenberg', 'Jennifer Jason Leigh'),
#  ('Greenberg', 'Rhys Ifans'),
#  ('Greenberg', 'Brie Larson'),
#  ('Greenberg', 'Koby Rouviere'),
#  ('Greenberg', 'Mark Duplass'),
#  ('Greenberg', 'Dave Franco'),
#  ('Chico & Rita', 'Limara Meneses'),
#  ('Chico & Rita', 'Eman Xor Oña'),
#  ('Chico & Rita', 'Bebo Valdés'),
#  ('Chico & Rita', 'Mario Guerra'),
#  ('Chico & Rita', 'Estrella Morente'),
#  ('Chico & Rita', 'Yaroldi Abreu'),
#  ('Chico & Rita', 'Renny Arozarena'),
#  ('Chico & Rita', 'Rigoberto Ferrera'),
#  ('Gigola', 'Marie Kremer'),
#  ('Gigola', 'Eduardo Noriega'),
#  ('Gigola', 'Marisa Paredes'),
#  ('Gigola', 'Marisa Berenson'),
#  ('Gigola', 'Rossy de Palma'),
#  ('Gigola', 'Lou Doillon'),
#  ('Gigola', 'Thierry Lhermitte'),
#  ('Gigola', 'Ana Padrão'),
#  ('Mistérios de Lisboa', 'Maria João Bastos'),
#  ('Mistérios de Lisboa', 'Adriano Luz'),
#  ('Mistérios de Lisboa', 'Léa Seydoux'),
#  ('Mistérios de Lisboa', 'Ricardo Pereira'),
#  ('Mistérios de Lisboa', 'José Afonso Dias Pimentel'),
#  ('Mistérios de Lisboa', 'João Arrais'),
#  ('Mistérios de Lisboa', 'Clotilde Hesme'),
#  ('Mistérios de Lisboa', 'Rui Morrison'),
#  ...]

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='bho')


mycursor = cnx.cursor()
query = "INSERT INTO peli_act(pelicula, actor) VALUES(%s, %s)"
val = lista_definitiva

try: 
    mycursor.executemany(query, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 4072 registro/s insertado/s.

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='bho')

cnx.close()
