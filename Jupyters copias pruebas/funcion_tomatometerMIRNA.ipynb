# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
# from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import numpy as np

import re
import random

# %%
df_action = pd.read_csv("action.csv", index_col = 0)
df_comedy = pd.read_csv("comedy.csv", index_col = 0)
df_drama = pd.read_csv("drama_no_duplicado.csv", index_col = 0)

# %%
# df = pd.read_csv("action_1000_pelis.csv", index_col = 0)
df = pd.read_csv("action_1000_pelis.csv", index_col = 0)

# %%
# primeras_action_1000_imdb= df.values.tolist()
primeras_action_1000_imdb= df.values.tolist()

# %%
# len(primeras_action_1000_imdb)
len(primeras_action_1000_imdb)
# Out:
# 1001

# %%
# primeras_action_1000_api= df_action.values.tolist()[:1001]
primeras_action_1000_api= df_action.values.tolist()[:1001]

# %%
# len(primeras_action_1000_api)
len(primeras_action_1000_api)
# Out:
# 1001

# %%
# primeras_action_1000_imdb[0]
primeras_action_1000_imdb[0]
# Out:
# ['6.6',
#  'Jonathan Mostow',
#  'Jonathan Mostow, Sam Montgomery, David Ayer',
#  'Un submarino alemán es abordado por submarinistas americanos disfrazados que intentan capturar su máquina de cifrado Enigma.',
#  '116',
#  'U-571']

# %%
# primeras_action_1000_api[0]
primeras_action_1000_api[0]
# Out:
# [0, 'Movie', 'U-571', 2000.0, 9.0, 'tt0141926']

# %%
# terceras_action_6000_api= df_action.values.tolist()[2001:6001]
# len 4000

# %%
# #NO USAR!! ES PARA CONPROBAR SI HEMOS HECHO BIEN LAS EXTRACCIONES

# for i, pelicula in enumerate(lista_drama_api):
#     for ind, peli in enumerate(primeras_drama_8000_imdb):
        
#         if lista_drama_api[i][1] == primeras_drama_8000_imdb[i][5]:
#             print("----",lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
#         else:
#             print(lista_drama_api[i][1], primeras_drama_8000_imdb[i][5])
#         break

# %%
# Inicializar navegador
def datos_tomatoes (lista_imdb, lista_API):

    driver = webdriver.Chrome() 

    # URL Google para extraer la información solicitada. 

    url = "https://www.google.com/" 

    # Hacer una solicitud GET a la URL especificada.

    driver.get(url)  

    # Maximizar la ventana

    driver.maximize_window()
    


    sleep(5)

    # Aceptar cookies

    driver.find_element("css selector", "#L2AGLb > div").click()

    # Creamos lista vacía para introducir el resultado de las puntuaciones (tomatometer) de cada pelicula.

    #total_puntuacion_tomatoes = []

    # Iniciamos bucle for por cada pelicula de los csv que tenemos accediendo por su indice.

    for i, pelicula in enumerate(lista_imdb): 
        for peli in lista_API:
        

            sleep(random.randint(3,10))
            #creamos un string para pasarle a Google el nombre y el año de la pelicula extraidos de IMDB
            peticion = f"'Tomatometer de {lista_imdb[i][5]} del año {lista_API[i][2]}'"
            print(i, peticion)
            #incluimos el string en la barra de busqueda de Google
            driver.find_element("css selector","#APjFqb").send_keys(peticion, Keys.ENTER)  

            #puntuación (tomatometer)
            
            try:

                #creamos una variable con el nombre de la primera pelicula que aparece en Google
                nombre_peli_google = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text
                print(nombre_peli_google)
                # print()

                #si el nombre es igual al nombre de la pelicula que pedimos la añadimos a la lista
                if nombre_peli_google == lista_imdb[i][5]:
                    
                    puntuacion = driver.find_element("css selector","#rso > div:nth-child(1) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                    total_puntuacion_tomatoes.append(puntuacion)
                    print(puntuacion)
                #si el nombre no coincide lo intentamos con la segunda opcion que aparece en google
                else:
                    try:
                        nombre_peli_google2 = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div.kb0PBd.cvP2Ce.jGGQ5e > div > div > span > a > h3").text

                        if nombre_peli_google2 == lista_imdb[i][5]:
                    
                            puntuacion = driver.find_element("css selector","#rso > div:nth-child(2) > div > div > div:nth-child(3) > div > span:nth-child(2)").text.replace("%","").replace("Valoración: ", "")
                            total_puntuacion_tomatoes.append(puntuacion)
                            print(puntuacion)
                        else:
                            total_puntuacion_tomatoes.append("No tiene datos")
                            print("No tiene datos")
                    except:
                        total_puntuacion_tomatoes.append("No tiene datos")
                        print("No tiene datos")
            except: 

                total_puntuacion_tomatoes.append("No tiene datos")
                print("No tiene datos")
            
        
            # Salimos a la pag.principal del navegador
            
            driver.back()
            break

    return total_puntuacion_tomatoes    # Impresion lista total

# %%
total_puntuacion_tomatoes = []

# %%
len(total_puntuacion_tomatoes)
# Out:
# 0

# %%
#llamamos a la funcion
primeras_1001_action_tomatoes = datos_tomatoes(primeras_action_1000_imdb, primeras_action_1000_api)
# Out:
# 0 'Tomatometer de U-571 del año U-571'
# U-571
# 68
# 1 'Tomatometer de K.O. Fuera de combate del año Knockout'
# No tiene datos
# 2 'Tomatometer de Los inmortales: Juego final del año Highlander: Endgame'
# Highlander: Endgame
# No tiene datos
# 3 'Tomatometer de Simbad del año Sinbad: Beyond the Veil of Mists'
# Sinbad: Beyond the Veil of Mists
# No tiene datos
# 4 'Tomatometer de Shafted! del año Shafted!'
# Shafted!
# 50
# 5 'Tomatometer de Josh del año Josh'
# No tiene datos
# 6 'Tomatometer de Yup Yup Man del año Yup Yup Man'
# Dark Justice
# No tiene datos
# 7 'Tomatometer de El arte de la guerra del año The Art of War'
# The Art of War
# No tiene datos
# 8 'Tomatometer de Los ángeles de Charlie del año Charlie's Angels'
# Charlie's Angels
# No tiene datos
# 9 'Tomatometer de Shaft: The Return del año Shaft'
# Shaft
# No tiene datos
# 10 'Tomatometer de El hombre sin sombra del año Hollow Man'
# Hollow Man
# No tiene datos
# 11 'Tomatometer de Black Sea 213 del año Black Sea 213'
# Black Sea 213
# No tiene datos
# 12 'Tomatometer de Nautilus del año Nautilus'
# Nautilus
# 38
# 13 'Tomatometer de Romeo debe morir del año Romeo Must Die'
# Romeo Must Die
# No tiene datos
# 14 'Tomatometer de Red Team del año Red Team'
# About
# No tiene datos
# 15 'Tomatometer de Dream Witch del año Dream Witch'
# No tiene datos
# 16 'Tomatometer de Entre dos fuegos (A Better Way to Die) del año A Better Way to Die'
# A Better Way to Die
# No tiene datos
# 17 'Tomatometer de El príncipe de Central Park del año Prince of Central Park'
# Prince of Central Park
# No tiene datos
# 18 'Tomatometer de Gladiator (El gladiador) del año Gladiator'
# No tiene datos
# 19 'Tomatometer de The Thundering 8th del año The Thundering 8th'
# The Thundering 8th (2000)
# No tiene datos
# 20 'Tomatometer de Alex l'ariete del año Alex l'ariete'
# Alex l'ariete (2000)
# No tiene datos
# 21 'Tomatometer de Cazadores de fortuna del año The Million Dollar Kid'
# Million Dollar Kid
# No tiene datos
# 22 'Tomatometer de Delta Force One: The Lost Patrol del año Delta Force One: The Lost Patrol'
# Delta Force One: The Lost Patrol
# 20
# 23 'Tomatometer de Bullfighter del año Bullfighter'
# Bullfighter
# 0
# 24 'Tomatometer de La tormenta perfecta del año The Perfect Storm'
# The Perfect Storm
# No tiene datos
# 25 'Tomatometer de Fortaleza infernal 2 del año Fortress 2'
# Fortress 2: Re-Entry
# No tiene datos
# 26 'Tomatometer de Mondialito del año Mondialito'
# No tiene datos
# 27 'Tomatometer de Icebreaker del año Icebreaker'
# The Icebreaker
# 20
# 28 'Tomatometer de The Grizzly Six del año The Grizzly Six'
# The Bear (1988 film)
# No tiene datos
# 29 'Tomatometer de La aventura del Intrépido del año Intrepid'
# No tiene datos
# 30 'Tomatometer de The Specials del año The Specials'
# The Specials
# 82
# 31 'Tomatometer de Taxi 2 del año Taxi 2'
# Taxi 2
# 70
# 32 'Tomatometer de Operación reno del año Reindeer Games'
# Reindeer Games: Official Clip - Bad Santas
# No tiene datos
# 33 'Tomatometer de Shanghai Kid: Del Este al Oeste del año Shanghai Noon'
# Shanghai Noon
# No tiene datos
# 34 'Tomatometer de Adios, amor mio del año Farewell, My Love'
# Adiós, mi amor (1951)
# No tiene datos
# 35 'Tomatometer de Space Cowboys del año Space Cowboys'
# Space Cowboys
# 78
# 36 'Tomatometer de El patriota del año The Patriot'
# The Patriot
# No tiene datos
# 37 'Tomatometer de El infiltrado del año Primary Suspect'
# No tiene datos
# 38 'Tomatometer de Campo de batalla: La Tierra del año Battlefield Earth'
# Battlefield Earth
# No tiene datos
# 39 'Tomatometer de Brooklyn Sonnet del año Brooklyn Sonnet'
# No tiene datos
# 40 'Tomatometer de 60 segundos del año Gone in Sixty Seconds'
# Gone in Sixty Seconds
# No tiene datos
# 41 'Tomatometer de Punto sin retorno del año Point Doom'
# No tiene datos
# 42 'Tomatometer de Dungeons & Dragons (Dragones y mazmorras) del año Dungeons & Dragons'
# No tiene datos
# 43 'Tomatometer de Desaparecidos del año Left Behind'
# Left Behind
# No tiene datos
# 44 'Tomatometer de Tigre y dragón del año Wo hu cang long'
# Crouching Tiger, Hidden Dragon
# No tiene datos
# 45 'Tomatometer de The Skulls: Sociedad secreta del año The Skulls'
# The Skulls
# No tiene datos
# 46 'Tomatometer de Límite vertical del año Vertical Limit'
# Vertical Limit
# No tiene datos
# 47 'Tomatometer de Lek del año Lek'
# Lek Mazi Navasachi
# No tiene datos
# 48 'Tomatometer de Accelerator del año Accelerator'
# Accelerator
# No tiene datos
# 49 'Tomatometer de Newsbreak del año Newsbreak'
# Newsbreak
# No tiene datos
# 50 'Tomatometer de Starforce del año Starforce'
# Starforce
# No tiene datos
# 51 'Tomatometer de Hjärta av sten del año Hjärta av sten'
# No tiene datos
# 52 'Tomatometer de The Wrecking Crew del año The Wrecking Crew'
# The Wrecking Crew
# 95
# 53 'Tomatometer de Huida bajo presión del año Under Pressure'
# Under Pressure
# No tiene datos
# 54 'Tomatometer de Tiger Claws 3: El espiritu de tigre negro del año Tiger Claws III'
# El espíritu del tigre negro (Las garras del tigre III) (2000)
# No tiene datos
# 55 'Tomatometer de Misión en el mar negro del año Black Sea Raid'
# Goldfinger (película) - Wikipedia, la enciclopedia libre
# No tiene datos
# 56 'Tomatometer de Wings of the Crow del año Wings of the Crow'
# The Crow
# No tiene datos
# 57 'Tomatometer de Recipe for Disaster del año Recipe for Disaster'
# Recipe for Disaster: Season 1
# 61
# 58 'Tomatometer de Planeta rojo del año Red Planet'
# Red Planet
# No tiene datos
# 59 'Tomatometer de Manhattan Chase del año Manhattan Chase'
# Manhattan Chase
# No tiene datos
# 60 'Tomatometer de The Cheapest Movie Ever Made del año The Cheapest Movie Ever Made'
# 24 Most Profitable Low-Budget Movies Ever
# No tiene datos
# 61 'Tomatometer de Peligro en las profundidades del año Deep Core'
# Deep Core
# No tiene datos
# 62 'Tomatometer de Conspiración en la Casa Blanca del año The Alternate'
# The Alternate
# No tiene datos
# 63 'Tomatometer de Pilgrim del año Pilgrim'
# The Pilgrim
# No tiene datos
# 64 'Tomatometer de Secuestro infernal del año The Way of the Gun'
# The Way of the Gun
# No tiene datos
# 65 'Tomatometer de Ninja Mission 2000 del año Ninja Mission 2000'
# Ninja Mission 2000
# 4,8/10
# 66 'Tomatometer de Airboss III: The Payback del año Airboss III: The Payback'
# Airboss III: The Payback
# No tiene datos
# 67 'Tomatometer de Hassel/Förgörarna del año Hassel/Förgörarna'
# No tiene datos
# 68 'Tomatometer de Airboss IV: The X Factor del año Airboss IV: The X Factor'
# Airboss IV: The X Factor (2000)
# No tiene datos
# 69 'Tomatometer de Al servicio del presidente del año Chain of Command'
# Chain of Command - Wikipedia, la enciclopedia libre
# No tiene datos
# 70 'Tomatometer de Get Carter (Asesino implacable) del año Get Carter'
# Get Carter
# No tiene datos
# 71 'Tomatometer de Nostradamus del año Nostradamus'
# Nostradamus
# 47
# 72 'Tomatometer de Factor caos del año The Chaos Factor'
# No tiene datos
# 73 'Tomatometer de El guardián del año The Guardian'
# The Guardian
# No tiene datos
# 74 'Tomatometer de Esta abuela es un peligro del año Big Momma's House'
# Big Momma's House
# No tiene datos
# 75 'Tomatometer de Aquarius del año Aquarius'
# No tiene datos
# 76 'Tomatometer de Obstacles del año Obstacles'
# Obstacles
# No tiene datos
# 77 'Tomatometer de Miss Agente Especial del año Miss Congeniality'
# Miss Congeniality
# No tiene datos
# 78 'Tomatometer de Bait del año Bait'
# Bait
# 100
# 79 'Tomatometer de El vengador tóxico 4 del año Citizen Toxie: The Toxic Avenger IV'
# Citizen Toxie: The Toxic Avenger IV
# No tiene datos
# 80 'Tomatometer de Punto cero del año Ground Zero'
# Punto cero - Wikipedia, la enciclopedia libre
# No tiene datos
# 81 'Tomatometer de Última resistencia del año Last Stand'
# The Last Stand
# No tiene datos
# 82 'Tomatometer de Doomsdayer del año Doomsdayer'
# Doomsdayer
# No tiene datos
# 83 'Tomatometer de Gong yuan 2000 AD del año Gong yuan 2000 AD'
# Gong yuan 2000 AD
# 5,9/10
# 84 'Tomatometer de Faith and the Water Dog del año Faith and the Water Dog'
# No tiene datos
# 85 'Tomatometer de La última patrulla del año The Last Patrol'
# The Last Patrol
# No tiene datos
# 86 'Tomatometer de O Dia da Caça del año O Dia da Caça'
# https://www.rottentomatoes.com/search?search=O+Dia...
# No tiene datos
# 87 'Tomatometer de El 6º día del año The 6th Day'
# The 6th Day
# No tiene datos
# 88 'Tomatometer de No tiene datos del año Total western'
# No tiene datos
# 89 'Tomatometer de Vampire hunter D: Bloodlust del año Vampire Hunter D: Bloodlust'
# Vampire Hunter D
# No tiene datos
# 90 'Tomatometer de Turn It Up del año Turn It Up'
# Turn It Up
# 10
# 91 'Tomatometer de El camino de la traición del año Militia'
# El Camino: A Breaking Bad Movie
# No tiene datos
# 92 'Tomatometer de Mrs. Death 2: Hells Fury del año Mrs. Death 2: Hells Fury'
# No tiene datos
# 93 'Tomatometer de Agente rojo del año Agent Red'
# Agent Red
# No tiene datos
# 94 'Tomatometer de Drácula 2001 del año Dracula 2000'
# Wes Craven Presents: Dracula 2000
# No tiene datos
# 95 'Tomatometer de Rescate desesperado del año Submerged'
# Rescate desesperado (2000)
# No tiene datos
# 96 'Tomatometer de La máscara de Zorro del año La máscara de Zorro'
# The Mask of Zorro
# No tiene datos
# 97 'Tomatometer de Pukar del año Pukar'
# Pilar del Pino
# No tiene datos
# 98 'Tomatometer de Blue Shirts del año Blue Shirts'
# No tiene datos
# 99 'Tomatometer de Daybreak del año Daybreak'
# Daybreak
# 70
# 100 'Tomatometer de G-Men from Hell del año G-Men from Hell'
# G Men From Hell
# No tiene datos
# 101 'Tomatometer de Khauff del año Khauff'
# Khauff
# 38
# 102 'Tomatometer de Pánico en el Concorde del año Mach 2'
# No tiene datos
# 103 'Tomatometer de Fuerza delta V del año Operation Delta Force 5: Random Fire'
# Operation Delta Force 5: Random Fire
# No tiene datos
# 104 'Tomatometer de Ojos que no ven del año Ojos que no ven'
# Ojos que no ven
# No tiene datos
# 105 'Tomatometer de Prueba de vida del año Proof of Life'
# No tiene datos
# 106 'Tomatometer de Ultraman Tiga: The Final Odyssey del año Ultraman Tiga: The Final Odyssey'
# Ultraman Tiga: The Final Odyssey
# No tiene datos
# 107 'Tomatometer de Tha Eastsidaz del año Tha Eastsidaz'
# Tha Eastsidaz
# 59
# 108 'Tomatometer de Blue Belgium del año Blue Belgium'
# No tiene datos
# 109 'Tomatometer de No tiene datos del año Bulandi'
# No tiene datos
# 110 'Tomatometer de The Last Man del año The Last Man'
# The Last Man
# 0
# 111 'Tomatometer de Mela del año Mela'
# Mela
# No tiene datos
# 112 'Tomatometer de Future Murder del año Future Murder'
# Future Murder (2000)
# No tiene datos
# 113 'Tomatometer de Epicentro del año Epicenter'
# Epicenter
# 90
# 114 'Tomatometer de Command Approved del año Command Approved'
# Command Approved (2000)
# No tiene datos
# 115 'Tomatometer de Reencuentro con el destino del año Kaho Naa... Pyaar Hai'
# Kaho Naa Pyaar Hai
# No tiene datos
# 116 'Tomatometer de Inte bara mördare del año Inte bara mördare'
# No tiene datos
# 117 'Tomatometer de Pokémon 3: El hechizo de los Unown del año Gekijô-ban poketto monsutâ: Kesshô-tô no teiô'
# No tiene datos
# 118 'Tomatometer de Isola (Múltiples personalidades) del año Isola: Tajuu jinkaku shôjo'
# No tiene datos
# 119 'Tomatometer de Luces parpadeantes del año Blinkende lygter'
# No tiene datos
# 120 'Tomatometer de Tokyo Raiders del año Dong jing gong lüe'
# No tiene datos
# 121 'Tomatometer de Dora-heita del año Dora-heita'
# Dora-Heita (Alley Cat) (Playboy)
# No tiene datos
# 122 'Tomatometer de Brat 2 del año Brat 2'
# Brother 2
# No tiene datos
# 123 'Tomatometer de Monday del año Monday'
# Monday
# 49
# 124 'Tomatometer de Castle Rock del año Castle Rock'
# Castle Rock
# 88
# 125 'Tomatometer de Hera Pheri del año Hera Pheri'
# Hera Pheri
# 92
# 126 'Tomatometer de Never Look Back del año Never Look Back'
# Never Look Back
# No tiene datos
# 127 'Tomatometer de La calle del perdón del año Mercy Streets'
# Mercy Streets
# No tiene datos
# 128 'Tomatometer de Crackerjack 3 del año Crackerjack 3'
# Crackerjack 3
# No tiene datos
# 129 'Tomatometer de Supêsutoraberâzu del año Supêsutoraberâzu'
# No tiene datos
# 130 'Tomatometer de Ides of March del año Ides of March'
# The Ides of March
# No tiene datos
# 131 'Tomatometer de Kuet chin chi gam ji din del año Kuet chin chi gam ji din'
# 2024 Nyad 400 density {tdvabgh} Unbearable ... - SensAbility
# No tiene datos
# 132 'Tomatometer de Solid Cover del año Solid Cover'
# Guy Ritchie's The Covenant
# No tiene datos
# 133 'Tomatometer de Pierwszy milion del año Pierwszy milion'
# Season 1 – The Good Doctor
# No tiene datos
# 134 'Tomatometer de Warpath del año Warpath'
# Warpath
# No tiene datos
# 135 'Tomatometer de Cómplices del año Wilder'
# No tiene datos
# 136 'Tomatometer de Yau ching sui yuet: San Gai goo si del año Yau ching sui yuet: San Gai goo si'
# Yau ching sui yuet: San Gai goo si (2000)
# No tiene datos
# 137 'Tomatometer de Bad Guys del año Bad Guys'
# The Bad Guys
# No tiene datos
# 138 'Tomatometer de Misión en Cachemira del año Mission Kashmir'
# Mission Kashmir
# No tiene datos
# 139 'Tomatometer de Mehanizam del año Mehanizam'
# No tiene datos
# 140 'Tomatometer de Split Intent del año Split Intent'
# Split
# No tiene datos
# 141 'Tomatometer de Badal del año Badal'
# Badal
# 30
# 142 'Tomatometer de Je li jasno prijatelju? del año Je li jasno prijatelju?'
# No tiene datos
# 143 'Tomatometer de Hum To Mohabbat Karega del año Hum To Mohabbat Karega'
# Hum To Mohabbat Karega
# No tiene datos
# 144 'Tomatometer de Take It to the Limit del año Take It to the Limit'
# Take It to the Limit
# No tiene datos
# 145 'Tomatometer de El tiempo no espera del año Shun liu ni liu'
# No tiene datos
# 146 'Tomatometer de Bichhoo del año Bichhoo'
# Bichoo
# No tiene datos
# 147 'Tomatometer de Experimento letal del año Dak ging san yan lui 2'
# No tiene datos
# 148 'Tomatometer de Jungle del año Jungle'
# Jungle
# 61
# 149 'Tomatometer de Kouravudu del año Kouravudu'
# No tiene datos
# 150 'Tomatometer de Kumite del año Kumite'
# The Last Kumite
# No tiene datos
# 151 'Tomatometer de Game Day del año Game Day'
# No tiene datos
# 152 'Tomatometer de Kurukshetra del año Kurukshetra'
# Kurukshetra
# 71
# 153 'Tomatometer de Gojira tai Megagirasu: Jî shômetsu sakusen del año Gojira tai Megagirasu: Jî shômetsu sakusen'
# Gojira tai Megagirasu: Jî shômetsu sakusen (2000)
# No tiene datos
# 154 'Tomatometer de Burisuta del año Burisuta'
# No tiene datos
# 155 'Tomatometer de Hamara Dil Aapke Paas Hai del año Hamara Dil Aapke Paas Hai'
# Hamara Dil Aap Ke Paas Hain
# No tiene datos
# 156 'Tomatometer de El viaje de Arián del año El viaje de Arián'
# Viaje de Arian
# No tiene datos
# 157 'Tomatometer de Khiladi 420 del año Khiladi 420'
# Khiladi 420
# 47
# 158 'Tomatometer de Aaghaaz del año Aaghaaz'
# Aaghaaz
# No tiene datos
# 159 'Tomatometer de Deewane del año Deewane'
# Deewane
# 29
# 160 'Tomatometer de Sensitive New Age Killer del año Sensitive New Age Killer'
# Sensitive New-Age Killer
# No tiene datos
# 161 'Tomatometer de Manoharam del año Manoharam'
# Manoharam
# No tiene datos
# 162 'Tomatometer de Gung Fu: The New Dragon del año Gung Fu: The New Dragon'
# Gung Fu: The New Dragon
# No tiene datos
# 163 'Tomatometer de Cheung wong del año Cheung wong'
# Tino Wong Cheung
# No tiene datos
# 164 'Tomatometer de Enduro Bojz del año Enduro Bojz'
# No tiene datos
# 165 'Tomatometer de Contacto ruso del año The Operative'
# The Operative
# No tiene datos
# 166 'Tomatometer de Chong gwai nei: Huet gwong ji joi del año Jong gwai lei: Huet gwong ji zoi'
# No tiene datos
# 167 'Tomatometer de Digimon: La película del año Digimon: The Movie'
# Digimon: The Movie
# No tiene datos
# 168 'Tomatometer de Gojô reisenki: Gojoe del año Gojô reisenki: Gojoe'
# No tiene datos
# 169 'Tomatometer de The Price of Air del año The Price of Air'
# The Price of Air
# 0
# 170 'Tomatometer de Joint Security Area (JSA) del año Gongdong gyeongbi guyeok JSA'
# Joint Security Area
# No tiene datos
# 171 'Tomatometer de Oi yue shing del año Oi yue shing'
# No tiene datos
# 172 'Tomatometer de Jinji pojiang del año Jinji pojiang'
# No tiene datos
# 173 'Tomatometer de Chek del año Chek'
# No tiene datos
# 174 'Tomatometer de Objetivo a ciegas del año Blind Target'
# Blind Target
# No tiene datos
# 175 'Tomatometer de Bangkok Dangerous del año Bangkok Dangerous'
# Bangkok Dangerous
# 9
# 176 'Tomatometer de The Black Rose del año The Black Rose'
# The Black Rose
# 45
# 177 'Tomatometer de Deep Six del año Deep Six'
# The Deep Six
# No tiene datos
# 178 'Tomatometer de Lagarista del año Lagarista'
# No tiene datos
# 179 'Tomatometer de Battle Royale del año Batoru rowaiaru'
# Battle Royale
# 90
# 180 'Tomatometer de Whiteout del año Howaitoauto'
# Whiteout
# 7
# 181 'Tomatometer de China Strike Force del año Lei ting zhan jing'
# No tiene datos
# 182 'Tomatometer de No Deposit, No Return del año No Deposit, No Return'
# No Deposit, No Return
# 66
# 183 'Tomatometer de Jukgeona hokeun nabbeugeona del año Jukgeona hokeun nabbeugeona'
# No tiene datos
# 184 'Tomatometer de Oro diablo del año Oro diablo'
# Oro diablo
# No tiene datos
# 185 'Tomatometer de El camino del año El camino'
# No tiene datos
# 186 'Tomatometer de Las lágrimas del tigre negro del año Fah talai jone'
# Las lágrimas del tigre negro
# No tiene datos
# 187 'Tomatometer de Escaflowne del año Escaflowne'
# Escaflowne
# 43
# 188 'Tomatometer de No tiene datos del año Champion'
# Champions
# No tiene datos
# 189 'Tomatometer de Mong min ji to del año Mong min ji to'
# No tiene datos
# 190 'Tomatometer de Papá es un ídolo del año Papá es un ídolo'
# Papá es un ídolo
# No tiene datos
# 191 'Tomatometer de Xiang si chen xianzai del año Xiang si chen xianzai'
# No tiene datos
# 192 'Tomatometer de Ikíngut del año Ikíngut'
# No tiene datos
# 193 'Tomatometer de Highway 395 del año Highway 395'
# Highway 395
# No tiene datos
# 194 'Tomatometer de Bhai Thakur del año Bhai Thakur'
# Bhai Thakur
# No tiene datos
# 195 'Tomatometer de Raju Chacha del año Raju Chacha'
# Raju Chacha
# 18
# 196 'Tomatometer de San tau chi sai doi del año San tau chi sai doi'
# No tiene datos
# 197 'Tomatometer de Blinker en het Bagbag-juweel del año Blinker en het Bagbag-juweel'
# Blinker en het Bagbag-juweel (2000)
# No tiene datos
# 198 'Tomatometer de Cyberon del año Cyberon'
# No tiene datos
# 199 'Tomatometer de Dada Sahib del año Dada Sahib'
# Dada Sahib
# No tiene datos
# 200 'Tomatometer de Hakkyousuru kuchibiru del año Hakkyousuru kuchibiru'
# Hakkyousuru kuchibiru (2000)
# No tiene datos
# 201 'Tomatometer de Narasimham del año Narasimham'
# Narasimha
# No tiene datos
# 202 'Tomatometer de Valliettan del año Valliettan'
# Al Valletta
# No tiene datos
# 203 'Tomatometer de Blood: El último vampiro del año Blood: The Last Vampire'
# Blood: The Last Vampire
# No tiene datos
# 204 'Tomatometer de Bau lik ying ging del año Bao li xing jing'
# No tiene datos
# 205 'Tomatometer de Blood and Honor del año Blood and Honor'
# Blood and Honor
# No tiene datos
# 206 'Tomatometer de Hysteric del año Hysteric'
# Hysterical
# No tiene datos
# 207 'Tomatometer de Gau geung ying ging del año Gau geung ying ging'
# No tiene datos
# 208 'Tomatometer de Azaad del año Azaad'
# Azaad
# No tiene datos
# 209 'Tomatometer de Khoroshie i plokhie del año Khoroshie i plokhie'
# No tiene datos
# 210 'Tomatometer de Oi ngo bit jow del año Oi ngo bit jow'
# No tiene datos
# 211 'Tomatometer de Versus del año Versus'
# No tiene datos
# 212 'Tomatometer de Sang sei kuen chuk del año Sang sei kuen chuk'
# No tiene datos
# 213 'Tomatometer de Bichunmoo del año Bichunmoo'
# No tiene datos
# 214 'Tomatometer de Conflicto fatal del año Fatal Conflict'
# Fatal Conflict
# No tiene datos
# 215 'Tomatometer de Ostatnia misja del año Ostatnia misja'
# No tiene datos
# 216 'Tomatometer de The Anarchists del año Anakiseuteu Anarchists'
# The Anarchists: Season 1
# 57
# 217 'Tomatometer de Epoch of Lotus del año Epoch of Lotus'
# Epoch of Lotus (2000)
# No tiene datos
# 218 'Tomatometer de Mark Antony del año Mark Antony'
# Marc Anthony
# No tiene datos
# 219 'Tomatometer de Hong qiang dao ying del año Hong qiang dao ying'
# No tiene datos
# 220 'Tomatometer de The Gang del año The Gang'
# The Gang
# No tiene datos
# 221 'Tomatometer de Pilots del año Pilots'
# Twenty One Pilots Cinema Experience
# No tiene datos
# 222 'Tomatometer de Adavi Chukka del año Adavi Chukka'
# Adavi Chukka
# No tiene datos
# 223 'Tomatometer de Cons del año Cons'
# Anexo:Películas con un 100% de aprobación en Rotten ...
# No tiene datos
# 224 'Tomatometer de Bad boy dak gung del año Bad boy dak gung'
# Bad Boys for Life
# No tiene datos
# 225 'Tomatometer de Bangrajan del año Bangrajan'
# Legend of the Village Warriors
# No tiene datos
# 226 'Tomatometer de Dead or Alive 2: Sangre yakuza del año Dead or Alive 2: Tôbôsha'
# Dead or Alive II: Sangre Yakuza (2000)
# No tiene datos
# 227 'Tomatometer de Pandavas: The Five Warriors del año Pandavas: The Five Warriors'
# No tiene datos
# 228 'Tomatometer de A Matter of Time del año A Matter of Time'
# A Matter of Time
# 50
# 229 'Tomatometer de Plastic Boy and the Jokers del año Plastic Boy and the Jokers'
# No tiene datos
# 230 'Tomatometer de Libera me del año Libera me'
# Libera me
# No tiene datos
# 231 'Tomatometer de Jung del año Jung'
# Jung_E
# No tiene datos
# 232 'Tomatometer de Biyaheng langit del año Biyaheng langit'
# No tiene datos
# 233 'Tomatometer de 01412 pasasingeum del año 01412 pasasingeum'
# No tiene datos
# 234 'Tomatometer de Deathrow del año Deathrow'
# Death Row
# No tiene datos
# 235 'Tomatometer de Narcosys del año Narcosys'
# Narcosis
# No tiene datos
# 236 'Tomatometer de Kilimanjaro del año Kilimanjaro'
# The Snows of Kilimanjaro
# 55
# 237 'Tomatometer de Danjeogbiyeonsu del año Danjeogbiyeonsu'
# No tiene datos
# 238 'Tomatometer de Ramayana: The Legend of Prince Rama del año The Prince of Light'
# The Prince of Light: The Legend of Ramayana
# 100
# 239 'Tomatometer de La dama de rojo del año La dama de rojo'
# No tiene datos
# 240 'Tomatometer de Jonni Nitro del año Jonni Nitro'
# No tiene datos
# 241 'Tomatometer de Eto na naman ako del año Eto na naman ako'
# No tiene datos
# 242 'Tomatometer de Krodh del año Krodh'
# Krodh
# No tiene datos
# 243 'Tomatometer de Night All Day del año Night All Day'
# No tiene datos
# 244 'Tomatometer de Heukwoo del año Heukwoo'
# No tiene datos
# 245 'Tomatometer de Baller Blockin' del año Baller Blockin''
# Baller Blockin
# No tiene datos
# 246 'Tomatometer de Gone in 60 Seconds: The Ride del año Gone in 60 Seconds: The Ride'
# Gone in Sixty Seconds
# No tiene datos
# 247 'Tomatometer de Baaghi del año Baaghi'
# Baaghi: A Rebel for Love
# 14
# 248 'Tomatometer de Chung wah dou hap del año Chung wah dou hap'
# No tiene datos
# 249 'Tomatometer de Reinkarnasi del año Reinkarnasi'
# No tiene datos
# 250 'Tomatometer de Cuenta saldada del año Cuenta saldada'
# No tiene datos
# 251 'Tomatometer de Semilla de odio del año Semilla de odio'
# Semilla de odio
# No tiene datos
# 252 'Tomatometer de 36K del año 36K'
# No tiene datos
# 253 'Tomatometer de Recompensa del año Recompensa'
# No tiene datos
# 254 'Tomatometer de Ex-Con del año Ex-Con'
# Ex-Con
# No tiene datos
# 255 'Tomatometer de Baliktaran del año Baliktaran'
# No tiene datos
# 256 'Tomatometer de Juan & Ted: Wanted del año Juan & Ted: Wanted'
# Juan & Ted: Wanted
# No tiene datos
# 257 'Tomatometer de Sagot kita... mula ulo hanggang paa del año Sagot kita: Mula ulo hanggang paa'
# Sagot kita... mula ulo hanggang paa (2000)
# No tiene datos
# 258 'Tomatometer de La texana maldita del año La texana maldita'
# La Texana Maldita
# No tiene datos
# 259 'Tomatometer de Ayos na... ang kasunod del año Ayos na... ang kasunod'
# No tiene datos
# 260 'Tomatometer de Pau lui: Duet min ji lui del año Pau lui: Duet min ji lui'
# Lee Min-ji
# No tiene datos
# 261 'Tomatometer de Ang dalubhasa del año Ang dalubhasa'
# No tiene datos
# 262 'Tomatometer de Fidel Jimenez: Magkakasubukan tayo del año Fidel Jimenez: Magkasubukan tayo'
# Fidel Jimenez: Magkasubukan tayo
# No tiene datos
# 263 'Tomatometer de Col. Elmer Jamias: Barako ng Maynila del año Col. Elmer Jamias: Barako ng Maynila'
# Col. Elmer Jamias: Barako ng Maynila
# No tiene datos
# 264 'Tomatometer de Garapal del año Garapal'
# Garapal
# No tiene datos
# 265 'Tomatometer de Anghel dela guardia del año Anghel dela guardia'
# Anghel Dela Guardia
# No tiene datos
# 266 'Tomatometer de Antonio Cuervo - Police: Walang pinipili ang batas del año Antonio Cuervo - Police: Walang pinipili ang batas'
# Antonio Cuervo - Police: Walang pinipili ang batas (2000)
# No tiene datos
# 267 'Tomatometer de Eskort del año Eskort'
# The Escort
# No tiene datos
# 268 'Tomatometer de Katayan del año Katayan'
# No tiene datos
# 269 'Tomatometer de Makamandag na bala del año Makamandag na bala'
# No tiene datos
# 270 'Tomatometer de Tunay na tunay: Gets mo? Gets ko! del año Tunay na tunay: Gets mo? Gets ko!'
# Tunay Na Tunay: Gets Mo? Gets Ko!
# No tiene datos
# 271 'Tomatometer de Sugo ng Tondo del año Sugo ng Tondo'
# No tiene datos
# 272 'Tomatometer de Most Wanted del año Most Wanted'
# Most Wanted
# 70
# 273 'Tomatometer de Matalino man ang matsing naiisahan din! del año Matalino man ang matsing naiisahan din!'
# No tiene datos
# 274 'Tomatometer de Minsan ko lang sasabihin del año Minsan ko lang sasabihin'
# No tiene datos
# 275 'Tomatometer de Pag oras mo, oras mo na del año Pag oras mo, oras mo na'
# Pag Oras Mo, Oras Mo Na
# No tiene datos
# 276 'Tomatometer de Entre las patas de los caballos del año Entre las patas de los caballos'
# No tiene datos
# 277 'Tomatometer de Ipinanganak na ang taong papatay sa iyo del año Ipinanganak na ang taong papatay sa iyo'
# No tiene datos
# 278 'Tomatometer de Ping Lacson: Super Cop del año Ping Lacson: Super Cop'
# Ping Lacson: Super Cop
# No tiene datos
# 279 'Tomatometer de Spirit Warriors del año Spirit Warriors'
# Spirit Warriors
# No tiene datos
# 280 'Tomatometer de No tiene datos del año Testigo'
# No tiene datos
# 281 'Tomatometer de Tumbador del año Tumbador'
# No tiene datos
# 282 'Tomatometer de Palaban del año Palaban'
# No tiene datos
# 283 'Tomatometer de Pasasabugin ko ang mundo mo del año Pasasabugin ko ang mundo mo'
# Pasasabugin Ko Ang Mundo Mo
# No tiene datos
# 284 'Tomatometer de Pedro Penduko, Episode II: The Return of the Comeback del año Pedro Penduko, Episode II: The Return of the Comeback'
# Pedro Penduko, Episode II: The Return of the Comeback
# No tiene datos
# 285 'Tomatometer de Sheng shi chuan shuo del año Sheng shi chuan shuo'
# No tiene datos
# 286 'Tomatometer de Waray del año Waray'
# Waray-Waray
# No tiene datos
# 287 'Tomatometer de Ang babaeng putik del año Ang babaeng putik'
# No tiene datos
# 288 'Tomatometer de Tequila y mezcal del año Tequila y mezcal'
# No tiene datos
# 289 'Tomatometer de Jallad No. 1 del año Jallad No. 1'
# No tiene datos
# 290 'Tomatometer de Fils de personne del año Fils de personne'
# Children of Men
# No tiene datos
# 291 'Tomatometer de ¡Alerta!... La justicia de Rojo del año ¡Alerta!... La justicia de Rojo'
# No tiene datos
# 292 'Tomatometer de Paris boum boum del año Paris boum boum'
# No tiene datos
# 293 'Tomatometer de The Drop del año The Drop'
# The Drop
# 89
# 294 'Tomatometer de Bandolero del año Bandolero'
# Bandolero!
# No tiene datos
# 295 'Tomatometer de 23 Hours del año 23 Hours'
# Jerry Seinfeld: 23 Hours to Kill
# No tiene datos
# 296 'Tomatometer de Maten a la hiena del año Maten a la hiena'
# No tiene datos
# 297 'Tomatometer de La perra anda suelta del año La perra anda suelta'
# No tiene datos
# 298 'Tomatometer de The Dominant Eye del año The Dominant Eye'
# Eye of the Tiger
# No tiene datos
# 299 'Tomatometer de Tres reos del año Tres reos'
# Tres reos
# No tiene datos
# 300 'Tomatometer de Moment's Notice del año Moment's Notice'
# Top Gun: Maverick
# No tiene datos
# 301 'Tomatometer de Orpheus & Eurydice del año Orpheus & Eurydice'
# Orpheus
# No tiene datos
# 302 'Tomatometer de Patigasan del año Patigasan'
# No tiene datos
# 303 'Tomatometer de Kahit pito ang buhay mo del año Kahit pito ang buhay mo'
# No tiene datos
# 304 'Tomatometer de Mitades del año Mitades'
# No tiene datos
# 305 'Tomatometer de Barrio sin ley del año Barrio sin ley'
# Barrio sin ley (Serie de TV) (2022)
# No tiene datos
# 306 'Tomatometer de Horas contadas del año Horas contadas'
# The Finest Hours
# No tiene datos
# 307 'Tomatometer de Cazador de serpientes del año Cazador de serpientes'
# No tiene datos
# 308 'Tomatometer de Barrio 13 al desnudo del año Barrio 13 al desnudo'
# No tiene datos
# 309 'Tomatometer de Maten al cazador del año Maten al cazador'
# Maten al cazador
# No tiene datos
# 310 'Tomatometer de El gallo de guerrero del año El gallo de guerrero'
# The Golden Cockerel - Movie Reviews
# No tiene datos
# 311 'Tomatometer de Xiao Li fei dao zi Fei dao wai chuan del año Xiao Li fei dao zi Fei dao wai chuan'
# Xiao Li fei dao zi Fei dao wai chuan (2000)
# No tiene datos
# 312 'Tomatometer de Infierno en la sierra del año Infierno en la sierra'
# No tiene datos
# 313 'Tomatometer de La ley de guerrero del año La ley de guerrero'
# Sergio Guerrero
# No tiene datos
# 314 'Tomatometer de Ley fuga del año Ley fuga'
# http://www.rottentomatoes.com/search/full_search.p...
# No tiene datos
# 315 'Tomatometer de Cholos empericados del año Cholos empericados'
# Cholos empericados
# No tiene datos
# 316 'Tomatometer de El regreso de Camelia la Chicana del año El regreso de Camelia la Chicana'
# El regreso de Camelia la Chicana
# No tiene datos
# 317 'Tomatometer de Catarino y los rurales del año Catarino y los rurales'
# Catarino y los Rurales
# No tiene datos
# 318 'Tomatometer de El carretonero del año El carretonero'
# El carretonero
# No tiene datos
# 319 'Tomatometer de Caceria del chivo del año Caceria del chivo'
# Eleazar García Jr.
# No tiene datos
# 320 'Tomatometer de 80 kilos suicidas del año 80 kilos suicidas'
# No tiene datos
# 321 'Tomatometer de Sagot ko ang buhay mo del año Sagot ko ang buhay mo'
# No tiene datos
# 322 'Tomatometer de Huwag mo akong subukan del año Huwag mo akong subukan'
# Huwag mo akong subukan (2000)
# No tiene datos
# 323 'Tomatometer de Shinsengumi del año Shinsengumi'
# No tiene datos
# 324 'Tomatometer de Biu che ji che san chuen suet del año Biu che ji che san chuen suet'
# No tiene datos
# 325 'Tomatometer de Emilio Aguinaldo del año Emilio Aguinaldo'
# General Emilio Aguinaldo and the First Philippine Republic
# No tiene datos
# 326 'Tomatometer de Aaj Ka Ravan del año Aaj Ka Ravan'
# No tiene datos
# 327 'Tomatometer de Kahit demonyo itutumba ko del año Kahit demonyo itutumba ko'
# No tiene datos
# 328 'Tomatometer de El jueves no matamos del año El jueves no matamos'
# El jueves no matamos | AI-powered Movie Search
# No tiene datos
# 329 'Tomatometer de Tierra de escorpiones del año Tierra de escorpiones'
# Tierra de Escorpiones
# No tiene datos
# 330 'Tomatometer de Thrill Kill Jack in Hale Manor del año Thrill Kill Jack in Hale Manor'
# Thrill Kill Jack in Hale Manor
# No tiene datos
# 331 'Tomatometer de Sultaan del año Sultaan'
# Three Thousand Years of Longing
# No tiene datos
# 332 'Tomatometer de La ley del gris del año La ley del gris'
# De la ley a la ley
# No tiene datos
# 333 'Tomatometer de Doubles del año Doubles'
# Doubles
# No tiene datos
# 334 'Tomatometer de Senza paura del año Senza paura'
# No tiene datos
# 335 'Tomatometer de Shirley Pimple in the John Wayne Temple of Doom del año Shirley Pimple in the John Wayne Temple of Doom'
# Shirley Pimple in the John Wayne Temple of Doom (2000)
# No tiene datos
# 336 'Tomatometer de Meri Jung Ka Elaan del año Meri Jung Ka Elaan'
# Meri Jung Ka Elaan
# No tiene datos
# 337 'Tomatometer de Vamsee del año Vamsee'
# Vamsee
# No tiene datos
# 338 'Tomatometer de Shabdavedi del año Shabdavedi'
# No tiene datos
# 339 'Tomatometer de Billa No. 786 del año Billa No. 786'
# No tiene datos
# 340 'Tomatometer de Shikaar del año Shikaar'
# Shikaar
# No tiene datos
# 341 'Tomatometer de 13 Días antes de vivir del año 13 Días antes de vivir'
# No tiene datos
# 342 'Tomatometer de Los muertos no hablan del año Los muertos no hablan'
# The Dead Don't Die
# No tiene datos
# 343 'Tomatometer de The Revenge: Geeta Mera Naam del año The Revenge: Geeta Mera Naam'
# The Revenge: Geeta Mera Naam
# No tiene datos
# 344 'Tomatometer de Patrón de patrones del año Patrón de patrones'
# No tiene datos
# 345 'Tomatometer de Kaze wo mita shônen del año Kaze wo mita shônen'
# The Boy Who Saw the Wind
# No tiene datos
# 346 'Tomatometer de Las plebes de Sinaloa del año Las plebes de Sinaloa'
# Las Plebes de Sinaloa
# No tiene datos
# 347 'Tomatometer de Gomer and Ed Lost in Space del año Gomer and Ed Lost in Space'
# Lost in Space
# No tiene datos
# 348 'Tomatometer de One Piece: La película del año Kaisokuou ni ore wa naru'
# One Piece: Season 1
# No tiene datos
# 349 'Tomatometer de Nan guo feng yun del año Nan guo feng yun'
# Operation Red Sea - Wikipedia, la enciclopedia libre
# No tiene datos
# 350 'Tomatometer de Ölüm Pesimizde del año Ölüm Pesimizde'
# No tiene datos
# 351 'Tomatometer de Ngo joi gam yuk dik yat ji del año Ngo joi gam yuk dik yat ji'
# No tiene datos
# 352 'Tomatometer de Ying: Saat ji fat del año Ying: Saat ji fat'
# No tiene datos
# 353 'Tomatometer de Pravo na vybor del año Pravo na vybor'
# Pravo na vybor (TV Movie 1984)
# No tiene datos
# 354 'Tomatometer de Ying Xiong Wu Yu del año Ying Xiong Wu Yu'
# Ying xiong you lei
# No tiene datos
# 355 'Tomatometer de Soorappa del año Soorappa'
# No tiene datos
# 356 'Tomatometer de Umi no ourora del año Umi no ourora'
# No tiene datos
# 357 'Tomatometer de Kugel ins Genick del año Kugel ins Genick'
# No tiene datos
# 358 'Tomatometer de Gai zheng gui xie del año Gai zheng gui xie'
# No tiene datos
# 359 'Tomatometer de Kaali Ki Saugandh del año Kaali Ki Saugandh'
# No tiene datos
# 360 'Tomatometer de I epohi ton asevon del año I epohi ton asevon'
# No tiene datos
# 361 'Tomatometer de Kosto del año Kosto'
# No tiene datos
# 362 'Tomatometer de Rayalaseema Ramanna Chowdary del año Rayalaseema Ramanna Chowdary'
# Rayalaseema Ramanna Chowdary
# 100
# 363 'Tomatometer de Aaj Ka Nanha Farishta del año Aaj Ka Nanha Farishta'
# Aaj Ka Nanha Farishta
# No tiene datos
# 364 'Tomatometer de Kaali Topi Lal Rumaal del año Kaali Topi Lal Rumaal'
# Kaali Topi Laal Rumaal
# No tiene datos
# 365 'Tomatometer de Dujon Dujonar del año Dujon Dujonar'
# No tiene datos
# 366 'Tomatometer de Bayer 04 Leverkusen vs Eintracht Frankfurt del año Bayer 04 Leverkusen vs Eintracht Frankfurt'
# Eintracht Frankfurt vs Bayer 04 Leverkusen Estadísticas ...
# No tiene datos
# 367 'Tomatometer de Dalaal No.1 del año Dalaal No.1'
# Dalaal
# No tiene datos
# 368 'Tomatometer de Foh lung lui del año Foh lung lui'
# Flash Point (2007)
# No tiene datos
# 369 'Tomatometer de Aakhir Kaun Thi Woh? del año Aakhir Kaun Thi Woh?'
# No tiene datos
# 370 'Tomatometer de Babu Parsuram del año Babu Parsuram'
# No tiene datos
# 371 'Tomatometer de Sudhandhiram del año Sudhandhiram'
# No tiene datos
# 372 'Tomatometer de Ayudha Pooja del año Ayudha Pooja'
# Ayudha Poojai
# No tiene datos
# 373 'Tomatometer de Dard Pardesaan De del año Dard Pardesaan De'
# Dard Pardesaan Dey
# No tiene datos
# 374 'Tomatometer de Prema Kosam del año Prema Kosam'
# No tiene datos
# 375 'Tomatometer de Sivaji del año Sivaji'
# Sivaji
# 82
# 376 'Tomatometer de Jayam Manadera del año Jayam Manadera'
# Jayam Manadera
# No tiene datos
# 377 'Tomatometer de Baachi del año Baachi'
# Las 25 mejores películas adolescentes de Netflix, según ...
# No tiene datos
# 378 'Tomatometer de Nu nan jue del año Nu nan jue'
# No tiene datos
# 379 'Tomatometer de Yi bu yi di xue del año Yi bu yi di xue'
# No tiene datos
# 380 'Tomatometer de Goo yung bing del año Goo yung bing'
# No tiene datos
# 381 'Tomatometer de 12 O'clock del año 12 O'clock'
# Twelve O'Clock High
# No tiene datos
# 382 'Tomatometer de Akin ang labang ito del año Akin ang labang ito'
# Akin Ang Labang Ito
# No tiene datos
# 383 'Tomatometer de Bhai No 1 del año Bhai No 1'
# Bhai Bhai
# No tiene datos
# 384 'Tomatometer de Aakhri Dacait del año Aakhri Dacait'
# Aakhri Dacait
# No tiene datos
# 385 'Tomatometer de Saugandh del año Saugandh'
# Saugandh
# No tiene datos
# 386 'Tomatometer de Patthar Aur Payal del año Patthar Aur Payal'
# Patthar aur payal
# No tiene datos
# 387 'Tomatometer de Agniputra del año Agniputra'
# No tiene datos
# 388 'Tomatometer de Justice Chowdhary del año Justice Chowdhary'
# Justice Chowdhary
# No tiene datos
# 389 'Tomatometer de Babu Badshah del año Babu Badshah'
# No tiene datos
# 390 'Tomatometer de Jwalamukhi del año Jwalamukhi'
# Jwalamukhi
# No tiene datos
# 391 'Tomatometer de Qurbaniyaan del año Qurbaniyaan'
# No tiene datos
# 392 'Tomatometer de Sabse Bada Be-Imaan del año Sabse Bada Be-Imaan'
# No tiene datos
# 393 'Tomatometer de Qian long duo bao del año Qian long duo bao'
# No tiene datos
# 394 'Tomatometer de Nante yononakada. del año Nante yononakada.'
# No tiene datos
# 395 'Tomatometer de Maguna del año Maguna'
# No tiene datos
# 396 'Tomatometer de Liu mang te jing del año Liu mang te jing'
# No tiene datos
# 397 'Tomatometer de The Twitching Dead del año The Twitching Dead'
# No tiene datos
# 398 'Tomatometer de Shin Chan: Perdidos en la jungla del año Kureyon Shinchan: Arashi o Yobu Janguru!'
# Crayon Shin-chan: Honeymoon Hurricane - The Lost Hiroshi
# No tiene datos
# 399 'Tomatometer de Tit nam boon sik del año Tie nan ben se'
# No tiene datos
# 400 'Tomatometer de Tian xia wu di zhang men ren del año Tian xia wu di zhang men ren'
# No tiene datos
# 401 'Tomatometer de Daku Sultana del año Daku Sultana'
# Daku Sultana
# No tiene datos
# 402 'Tomatometer de Daku Kali Bhawani del año Daku Kali Bhawani'
# No tiene datos
# 403 'Tomatometer de Dacait del año Dacait'
# Dacait
# No tiene datos
# 404 'Tomatometer de Ganga Dacait del año Ganga Dacait'
# No tiene datos
# 405 'Tomatometer de Heerabai del año Heerabai'
# No tiene datos
# 406 'Tomatometer de Daku Ganga Jamuna del año Daku Ganga Jamuna'
# No tiene datos
# 407 'Tomatometer de Jwala Daku del año Jwala Daku'
# No tiene datos
# 408 'Tomatometer de Johra Bai del año Johra Bai'
# No tiene datos
# 409 'Tomatometer de Lady Dacoit del año Lady Dacoit'
# No tiene datos
# 410 'Tomatometer de Champakali del año Champakali'
# No tiene datos
# 411 'Tomatometer de Jai Bhavani del año Jai Bhavani'
# No tiene datos
# 412 'Tomatometer de Basanti del año Basanti'
# Rang de Basanti
# No tiene datos
# 413 'Tomatometer de Rani Mera Naam del año Rani Mera Naam'
# No tiene datos
# 414 'Tomatometer de Badla Aurat Ka del año Badla Aurat Ka'
# No tiene datos
# 415 'Tomatometer de Sultana Mera Naam del año Sultana Mera Naam'
# No tiene datos
# 416 'Tomatometer de Jigar Baaz del año Jigar Baaz'
# Las mejores series en Star Plus (marzo 2024)
# No tiene datos
# 417 'Tomatometer de Kukkhato Khuni del año Kukkhato Khuni'
# No tiene datos
# 418 'Tomatometer de Gunda Number One del año Gunda Number One'
# Gunda
# No tiene datos
# 419 'Tomatometer de Ai sha 2000 del año Ai sha 2000'
# Aisha
# No tiene datos
# 420 'Tomatometer de Weyback del año Weyback'
# The Way Back
# No tiene datos
# 421 'Tomatometer de Daku Rani Champa Bai del año Daku Rani Champa Bai'
# No tiene datos
# 422 'Tomatometer de Bharat India Hindustan del año Bharat India Hindustan'
# No tiene datos
# 423 'Tomatometer de Chehrey Ke Peechhey del año Chehrey Ke Peechhey'
# No tiene datos
# 424 'Tomatometer de Bijlee del año Bijlee'
# Bijlee
# No tiene datos
# 425 'Tomatometer de Daku Rani del año Daku Rani'
# No tiene datos
# 426 'Tomatometer de Daaku Dilruba del año Daaku Dilruba'
# No tiene datos
# 427 'Tomatometer de Maila Aanchal del año Maila Aanchal'
# No tiene datos
# 428 'Tomatometer de Rahasya del año Rahasya'
# Rahasya
# 78
# 429 'Tomatometer de Daku Maharani del año Daku Maharani'
# No tiene datos
# 430 'Tomatometer de Aaghaat del año Aaghaat'
# No tiene datos
# 431 'Tomatometer de Geeta Mera Naam del año Geeta Mera Naam'
# Geeta Mera Naam
# No tiene datos
# 432 'Tomatometer de Rana the Don del año Rana the Don'
# No tiene datos
# 433 'Tomatometer de Kanoon Ki Lalkaar del año Kanoon Ki Lalkaar'
# No tiene datos
# 434 'Tomatometer de Main Khunkar Yodha del año Main Khunkar Yodha'
# No tiene datos
# 435 'Tomatometer de Sastra del año Sastra'
# No tiene datos
# 436 'Tomatometer de Mita De Bindiya Utha De Bandook del año Mita De Bindiya Utha De Bandook'
# Mita De Bindiya Utha De Bandook (2000)
# No tiene datos
# 437 'Tomatometer de Goo wak lui 2 del año Goo wak lui 2'
# No tiene datos
# 438 'Tomatometer de Lui fei foo del año Lui fei foo'
# No tiene datos
# 439 'Tomatometer de Mrityu: The Truth del año Mrityu: The Truth'
# No tiene datos
# 440 'Tomatometer de Noble Blade del año Noble Blade'
# No tiene datos
# 441 'Tomatometer de Duplicity del año Duplicity'
# Duplicity
# 65
# 442 'Tomatometer de Kanoon Ki Jung del año Kanoon Ki Jung'
# No tiene datos
# 443 'Tomatometer de No tiene datos del año Vallarasu'
# Vallarasu
# No tiene datos
# 444 'Tomatometer de Robin and the Dreamweavers del año Robin and the Dreamweavers'
# No tiene datos
# 445 'Tomatometer de Anbudan del año Anbudan'
# No tiene datos
# 446 'Tomatometer de Naxalite del año Naxalite'
# No tiene datos
# 447 'Tomatometer de Main Hoon Hero Khiladi del año Main Hoon Hero Khiladi'
# No tiene datos
# 448 'Tomatometer de Yeh Kaisi Hukumat del año Yeh Kaisi Hukumat'
# No tiene datos
# 449 'Tomatometer de Dum: Man Of Power del año Dum: Man Of Power'
# No tiene datos
# 450 'Tomatometer de Gori Khol Darwaza del año Gori Khol Darwaza'
# No tiene datos
# 451 'Tomatometer de Ek Anari Duja Khiladi del año Ek Anari Duja Khiladi'
# No tiene datos
# 452 'Tomatometer de Fist to Fist del año Fist to Fist'
# F.I.S.T.
# No tiene datos
# 453 'Tomatometer de Mera Inteqaam del año Mera Inteqaam'
# No tiene datos
# 454 'Tomatometer de Stingray del año Stingray'
# No tiene datos
# 455 'Tomatometer de Blood on Bullet del año Blood on Bullet'
# No tiene datos
# 456 'Tomatometer de Bidroho Charidike del año Bidroho Charidike'
# No tiene datos
# 457 'Tomatometer de Laang zin del año Laang zin'
# No tiene datos
# 458 'Tomatometer de Apocalipsis Nuclear del año Apocalipsis Nuclear'
# 2024: Apocalipsis nuclear (1975)
# No tiene datos
# 459 'Tomatometer de Xi you ji xuji del año Journey to the West 2000'
# Journey to the West 2000 (TV Series 2000
# No tiene datos
# 460 'Tomatometer de Joddha del año Joddha'
# No tiene datos
# 461 'Tomatometer de Wong Gok dik tin hung 3: Jung gik bin yuen del año Wong Gok dik tin hung 3: Jung gik bin yuen'
# No tiene datos
# 462 'Tomatometer de Vijayaramaraju del año Vijayaramaraju'
# No tiene datos
# 463 'Tomatometer de Appu del año Appu'
# Appu
# No tiene datos
# 464 'Tomatometer de Dabee del año Dabee'
# No tiene datos
# 465 'Tomatometer de Operation: Overthrow del año Operation: Overthrow'
# Operation Overthrow
# No tiene datos
# 466 'Tomatometer de Cinema Enthusiast del año Cinema Enthusiast'
# No tiene datos
# 467 'Tomatometer de Contratiempo Mortal del año Contratiempo Mortal'
# The Invisible Guest
# No tiene datos
# 468 'Tomatometer de Supercop.com del año Supercop.com'
# Supercop
# No tiene datos
# 469 'Tomatometer de Hira Chuni Panna del año Hira Chuni Panna'
# No tiene datos
# 470 'Tomatometer de Tumi Mur Mathu Mur del año Tumi Mur Mathu Mur'
# No tiene datos
# 471 'Tomatometer de Ravanna del año Ravanna'
# No tiene datos
# 472 'Tomatometer de Contrabando En El Chile del año Contrabando En El Chile'
# Contrabando en el Chile
# No tiene datos
# 473 'Tomatometer de Aag Ka Darya del año Aag Ka Darya'
# No tiene datos
# 474 'Tomatometer de Golam del año Golam'
# Golan the Insatiable: Season 1
# No tiene datos
# 475 'Tomatometer de Pursuit of a Killer del año Xiong ba si hai'
# No tiene datos
# 476 'Tomatometer de Bhad No Dikaro del año Bhad No Dikaro'
# No tiene datos
# 477 'Tomatometer de Kaigaikenkaretuden del año Kaigaikenkaretuden'
# No tiene datos
# 478 'Tomatometer de Asene Kunuba Hiyat del año Asene Kunuba Hiyat'
# No tiene datos
# 479 'Tomatometer de Russkie detki 2 del año Russkie detki 2'
# No tiene datos
# 480 'Tomatometer de Ajker Dapot del año Ajker Dapot'
# No tiene datos
# 481 'Tomatometer de Beyond Pardon del año Beyond Pardon'
# Everything Everywhere All at Once
# No tiene datos
# 482 'Tomatometer de Janer Jaan del año Janer Jaan'
# Jane
# No tiene datos
# 483 'Tomatometer de Oshantir Agun del año Oshantir Agun'
# No tiene datos
# 484 'Tomatometer de Palta Hamla: The Counter Attack del año Palta Hamla: The Counter Attack'
# Counter Attack
# No tiene datos
# 485 'Tomatometer de Kasam Banglar Mati del año Kasam Banglar Mati'
# No tiene datos
# 486 'Tomatometer de Final Solution del año Final Solution'
# The Final Solution
# No tiene datos
# 487 'Tomatometer de Jurassic Park III (Parque Jurásico III) del año Jurassic Park III'
# No tiene datos
# 488 'Tomatometer de Prueba de valor del año Net Worth'
# 2024 Timba Vk s Profile Net Worth Age Height Relationships ...
# No tiene datos
# 489 'Tomatometer de Vidocq: El mito del año Vidocq'
# Vidocq
# No tiene datos
# 490 'Tomatometer de Final fantasy: La fuerza interior del año Final Fantasy: The Spirits Within'
# Final Fantasy: The Spirits Within
# No tiene datos
# 491 'Tomatometer de 15 minutos del año 15 Minutes'
# 15 Minutes
# No tiene datos
# 492 'Tomatometer de Osmosis Jones del año Osmosis Jones'
# Osmosis Jones
# 56
# 493 'Tomatometer de Destino de caballero del año A Knight's Tale'
# No tiene datos
# 494 'Tomatometer de Dragon and the Hawk del año Dragon and the Hawk'
# No tiene datos
# 495 'Tomatometer de The Order del año The Order'
# The Order
# 100
# 496 'Tomatometer de Texas Rangers del año Texas Rangers'
# Texas Rangers
# 2
# 497 'Tomatometer de Tiempo límite del año Ticker'
# No tiene datos
# 498 'Tomatometer de Vital Parts del año Vital Parts'
# No tiene datos
# 499 'Tomatometer de Birds of Passage del año Birds of Passage'
# Birds of Passage
# 96
# 500 'Tomatometer de Lo Foo Ji del año Lo Foo Ji'
# 140 Essential Action Movies To Watch Now
# No tiene datos
# 501 'Tomatometer de Longshot del año Longshot'
# Long Shot
# No tiene datos
# 502 'Tomatometer de Nunca juegues con extraños del año Joy Ride'
# Joy Ride
# No tiene datos
# 503 'Tomatometer de Qué hacer en caso de incendio del año Was tun, wenn's brennt?'
# ¿Qué hacer en caso de incendio? (2001)
# No tiene datos
# 504 'Tomatometer de The Mummy Returns (El regreso de la momia) del año The Mummy Returns'
# The Mummy Returns
# No tiene datos
# 505 'Tomatometer de Jason X del año Jason X'
# Jason X
# 19
# 506 'Tomatometer de El poder del destino del año The Rage Within'
# The Rage Within
# No tiene datos
# 507 'Tomatometer de Fall del año Fall'
# Fall
# 79
# 508 'Tomatometer de Pearl Harbor del año Pearl Harbor'
# No tiene datos
# 509 'Tomatometer de El alma del diablo del año Soulkeeper'
# No tiene datos
# 510 'Tomatometer de Ruta 666 del año Route 666'
# Route 666
# No tiene datos
# 511 'Tomatometer de Enemigo a las puertas del año Enemy at the Gates'
# Enemy at the Gates
# No tiene datos
# 512 'Tomatometer de Die grüne Wolke del año Die grüne Wolke'
# Die grüne Wolke (2001)
# No tiene datos
# 513 'Tomatometer de Tormenta de fuego del año Ablaze'
# No tiene datos
# 514 'Tomatometer de Situación crítica del año Critical Mass'
# Critical Mass
# No tiene datos
# 515 'Tomatometer de Conspiración en la red (Antitrust) del año Antitrust'
# Antitrust
# No tiene datos
# 516 'Tomatometer de Black Friday del año Black Friday'
# Black Friday
# 65
# 517 'Tomatometer de Mint Condition del año Mint Condition'
# Mint Condition; Chris Farley Pictures
# No tiene datos
# 518 'Tomatometer de Inocencia secuestrada del año On the Borderline'
# No tiene datos
# 519 'Tomatometer de Livvakterna del año Livvakterna'
# No tiene datos
# 520 'Tomatometer de Justicia final del año Final Payback'
# Final Payback
# No tiene datos
# 521 'Tomatometer de G.O.D. del año G.O.D.'
# No tiene datos
# 522 'Tomatometer de One 2 Ka 4 del año One 2 Ka 4'
# One Two Ka Four
# No tiene datos
# 523 'Tomatometer de The Score (Un golpe maestro) del año The Score'
# The Score
# No tiene datos
# 524 'Tomatometer de Posljednja volja del año Posljednja volja'
# No tiene datos
# 525 'Tomatometer de Negocios sucios del año The 51st State'
# The 51st State
# No tiene datos
# 526 'Tomatometer de Fantasmas de Marte de John Carpenter del año Ghosts of Mars'
# John Carpenter's Ghosts of Mars
# No tiene datos
# 527 'Tomatometer de Two Coyotes del año Two Coyotes'
# No tiene datos
# 528 'Tomatometer de Spy Kids del año Spy Kids'
# Spy Kids
# 93
# 529 'Tomatometer de Jarrett del año Jarrett'
# Jarrett
# No tiene datos
# 530 'Tomatometer de Atlantis: El imperio perdido del año Atlantis: The Lost Empire'
# Atlantis: The Lost Empire
# No tiene datos
# 531 'Tomatometer de High Explosive del año High Explosive'
# High Explosive
# No tiene datos
# 532 'Tomatometer de BattleQueen 2020 del año BattleQueen 2020'
# Battle Queen 2020
# No tiene datos
# 533 'Tomatometer de Cocodrilo Dundee en Los Angeles del año Crocodile Dundee in Los Angeles'
# Crocodile Dundee in Los Angeles
# No tiene datos
# 534 'Tomatometer de The Fast and the Furious (A todo gas) del año The Fast and the Furious'
# The Fast and the Furious - Franchise
# No tiene datos
# 535 'Tomatometer de Los reyes del crimen del año 3000 Miles to Graceland'
# 3000 Miles to Graceland
# No tiene datos
# 536 'Tomatometer de Sakura Wars: The Movie del año Sakura taisen: Katsudou shashin'
# Sakura Wars: The Movie
# 70
# 537 'Tomatometer de El pacto de los lobos del año Le pacte des loups'
# Brotherhood of the Wolf
# No tiene datos
# 538 'Tomatometer de Devi Putrudu del año Devi Putrudu'
# No tiene datos
# 539 'Tomatometer de Menudo bocazas del año Double Take'
# Menudo bocazas - Wikipedia, la enciclopedia libre
# No tiene datos
# 540 'Tomatometer de Replicant del año Replicant'
# Replicant
# 27
# 541 'Tomatometer de Como perros y gatos del año Cats & Dogs'
# Cats & Dogs
# No tiene datos
# 542 'Tomatometer de Fuera de lugar del año Out of Line'
# Out of Line - Movie Reviews
# No tiene datos
# 543 'Tomatometer de Herida abierta del año Exit Wounds'
# Exit Wounds
# No tiene datos
# 544 'Tomatometer de Vuelta al infierno del año Going Back'
# Going Back
# No tiene datos
# 545 'Tomatometer de American Outlaws del año American Outlaws'
# American Outlaws
# 13
# 546 'Tomatometer de Más allá del deber del año To End All Wars'
# To End All Wars
# No tiene datos
# ...
# Uubusin ko ang bala sa katawan mo (2001)
# No tiene datos
# 821 'Tomatometer de Panabla del año Panabla'
# No tiene datos
# 822 'Tomatometer de Aagos ang dugo del año Aagos ang dugo'
# Aagos Ang Dugo
# No tiene datos
# 823 'Tomatometer de Goal Club del año Goal Club'
# Next Goal Wins
# No tiene datos
# 824 'Tomatometer de Amasona.... kumakasa, pumuputok del año Amasona.... kumakasa, pumuputok'
# No tiene datos
# 825 'Tomatometer de Sgt. Maderazo: Bayad na pati kaluluwa mo del año Sgt. Maderazo: Bayad na pati kaluluwa mo'
# No tiene datos
# 826 'Tomatometer de Mahal kita... Kahit sino ka pa! del año Mahal kita... Kahit sino ka pa!'
# Mahal Kita Kahit Sino Ka Pa
# No tiene datos
# 827 'Tomatometer de Booking Sonata del año Booking Sonata'
# Booking Sonata
# No tiene datos
# 828 'Tomatometer de Mano mano 2: Ubusan ng lakas del año Mano mano 2: Ubusan ng lakas'
# Mano mano 2: Ubusan ng lakas (2001)
# No tiene datos
# 829 'Tomatometer de Oras na para lumaban del año Oras na para lumaban'
# No tiene datos
# 830 'Tomatometer de The Ying Yang master del año Onmyôji'
# Onmyoji
# No tiene datos
# 831 'Tomatometer de Neighborhood Watch del año Neighborhood Watch'
# The Neighborhood Watch
# 31
# 832 'Tomatometer de Siu nin cheong dong del año Siu nin cheong dong'
# No tiene datos
# 833 'Tomatometer de Recoil del año Recoil'
# Recoil
# 27
# 834 'Tomatometer de No tiene datos del año Fallen Dreams'
# 100 Best Computer-Animated Movies, Ranked by ...
# No tiene datos
# 835 'Tomatometer de Reluctant Hitman del año Reluctant Hitman'
# Reluctant Hitman
# No tiene datos
# 836 'Tomatometer de Sharp and Sudden del año Sharp and Sudden'
# Nocebo
# No tiene datos
# 837 'Tomatometer de Lvinaya dolya del año Lvinaya dolya'
# No tiene datos
# 838 'Tomatometer de The Ultimate Game del año The Ultimate Game'
# The Ultimate Game
# 40
# 839 'Tomatometer de Udar Lotosa del año Udar Lotosa'
# No tiene datos
# 840 'Tomatometer de Barbaarit menneisyydestä del año Barbaarit menneisyydestä'
# Barbaarit menneisyydestä (2001)
# No tiene datos
# 841 'Tomatometer de Yingxiong Zheng Chengong del año Yingxiong Zheng Chengong'
# No tiene datos
# 842 'Tomatometer de The Good, the Bad & the Innocent del año The Good, the Bad & the Innocent'
# The Innocent
# No tiene datos
# 843 'Tomatometer de Desired Effect del año Desired Effect'
# Awards Leaderboard: Top Movies of 2023
# No tiene datos
# 844 'Tomatometer de Dhill del año Dhill'
# Dill Scallion
# No tiene datos
# 845 'Tomatometer de Nandha del año Nandha'
# No tiene datos
# 846 'Tomatometer de Master del año Master'
# Master
# 75
# 847 'Tomatometer de El soplo de la muerte del año El soplo de la muerte'
# El soplo de la muerte
# No tiene datos
# 848 'Tomatometer de El cholo del año El cholo'
# No tiene datos
# 849 'Tomatometer de Zana del año Zana'
# No tiene datos
# 850 'Tomatometer de La dama de la Texana 1000x del año La dama de la Texana 1000x'
# La dama de la Texana 1000x (2001)
# No tiene datos
# 851 'Tomatometer de Orquidea sangrienta del año Orquidea sangrienta'
# Anacondas: The Hunt for the Blood Orchid
# No tiene datos
# 852 'Tomatometer de Initial D: Third Stage del año Initial D: Third Stage'
# No tiene datos
# 853 'Tomatometer de Troy & Julie del año Troy & Julie'
# Troy & Julie
# No tiene datos
# 854 'Tomatometer de Desafiando a la mafia del año Desafiando a la mafia'
# Desafiando a la Mafia
# No tiene datos
# 855 'Tomatometer de Las dos caras del señor del año Las dos caras del señor'
# Dos caras tiene el destino
# No tiene datos
# 856 'Tomatometer de Tres fronteras del año Tres fronteras'
# Triple Frontier
# No tiene datos
# 857 'Tomatometer de Ya la barranca pario del año Ya la barranca pario'
# Ocio 883 by Ocio Guadalajara
# No tiene datos
# 858 'Tomatometer de El árbol de la horca del año El árbol de la horca'
# El Árbol de la Horca
# No tiene datos
# 859 'Tomatometer de El agricultor del año El agricultor'
# El Agricultor
# No tiene datos
# 860 'Tomatometer de 3 metros bajo tierra del año 3 metros bajo tierra'
# No tiene datos
# 861 'Tomatometer de Me gusta pegarle al polvo del año Me gusta pegarle al polvo'
# Me gusta pegarle al polvo
# No tiene datos
# 862 'Tomatometer de Galleros de tierra caliente del año Galleros de tierra caliente'
# Galleros de tierra caliente (2001)
# No tiene datos
# 863 'Tomatometer de Revolver cachas de oro del año Revolver cachas de oro'
# No tiene datos
# 864 'Tomatometer de Perros de pelea del año Perros de pelea'
# Pelea de perros Pictures
# No tiene datos
# 865 'Tomatometer de El patrón del año El patrón'
# No tiene datos
# 866 'Tomatometer de Hadh: Life on the Edge of Death del año Hadh: Life on the Edge of Death'
# Hadh: Life on the Edge of Death
# No tiene datos
# 867 'Tomatometer de El rey de los coleaderos del año El rey de los coleaderos'
# Rey de los Coleaderos
# No tiene datos
# 868 'Tomatometer de Cactus del año Cactus'
# No tiene datos
# 869 'Tomatometer de El ángel de mi guarda del año El ángel de mi guarda'
# No tiene datos
# 870 'Tomatometer de Songshan xiao yao gu del año Songshan xiao yao gu'
# No tiene datos
# 871 'Tomatometer de Ashab wala business del año Ashab wala business'
# No tiene datos
# 872 'Tomatometer de Samurai gâru 21 del año Samurai gâru 21'
# No tiene datos
# 873 'Tomatometer de Chavos de la calle del año Chavos de la calle'
# De la calle: Season 1
# No tiene datos
# 874 'Tomatometer de La caspa del diablo del año La caspa del diablo'
# La Caspa del Diablo
# No tiene datos
# 875 'Tomatometer de Chilinui saebyeok del año Chilinui saebyeok'
# No tiene datos
# 876 'Tomatometer de Kapag buhay ang inutang... buhay din ang kabayaran... del año Buhay mo ang kabayaran'
# Kapag Buhay Ang Inutang
# No tiene datos
# 877 'Tomatometer de No tiene datos del año Mitti'
# No tiene datos
# 878 'Tomatometer de Little John del año Little John'
# Little John
# 44
# 879 'Tomatometer de Kaidômaru del año Kai Doh Maru'
# No tiene datos
# 880 'Tomatometer de Casi el infierno del año Casi el infierno'
# No tiene datos
# 881 'Tomatometer de Bana Sans Dile del año Bana sans dile'
# No tiene datos
# 882 'Tomatometer de Bhairav del año Bhairav'
# Bhairav
# No tiene datos
# 883 'Tomatometer de Black & Blue del año Black & Blue'
# Black and Blue
# No tiene datos
# 884 'Tomatometer de Murudeka 17805 del año Murudeka 17805'
# No tiene datos
# 885 'Tomatometer de Bengal Tiger del año Bengal Tiger'
# The Bengal Tiger
# No tiene datos
# 886 'Tomatometer de Husn Ke Lootere del año Husn Ke Lootere'
# No tiene datos
# 887 'Tomatometer de Kon dib lhek nam pee del año Kon dib lhek nam pee'
# No tiene datos
# 888 'Tomatometer de Nuk leng klong yao del año Nuk leng klong yao'
# Nuk leng klong yao
# No tiene datos
# 889 'Tomatometer de Echo del año Echo'
# Echo: Season 1
# 71
# 890 'Tomatometer de Sotana roja del año Sotana roja'
# No tiene datos
# 891 'Tomatometer de Emisario del odio del año Emisario del odio'
# Rotten Tomatoes
# No tiene datos
# 892 'Tomatometer de Carreras de muerte del año Carreras de muerte'
# Death Race 2000
# No tiene datos
# 893 'Tomatometer de Kunoichi nimpoden: Mamono no yakata del año Kunoichi nimpoden: Mamono no yakata'
# Kunoichi nimpoden: Mamono no yakata (2001)
# No tiene datos
# 894 'Tomatometer de Dheena del año Dheena'
# Sheena
# No tiene datos
# 895 'Tomatometer de El rey de la mota del año El rey de la mota'
# El Rey de la Mota
# No tiene datos
# 896 'Tomatometer de Gomer and Ed Turn Gay del año Gomer and Ed Turn Gay'
# No tiene datos
# 897 'Tomatometer de Dejimon Teimâzu: Bôkensha tachi no tatakai del año Dejimon Teimâzu: Bôkensha tachi no tatakai'
# No tiene datos
# 898 'Tomatometer de Shinchan ¡Los adultos contraatacan! La película del año Kureyon Shin-chan: Arashi wo yobu - Mouretsu! Otona teikoku no gyakushuu'
# Shin-chan: Los adultos contraatacan
# No tiene datos
# 899 'Tomatometer de Malditos violadores del año Malditos violadores'
# No tiene datos
# 900 'Tomatometer de Arjun Devaa del año Arjun Devaa'
# Arjun Devaa
# No tiene datos
# 901 'Tomatometer de Dal: The Gang del año Dal: The Gang'
# No tiene datos
# 902 'Tomatometer de Meri Adaalat del año Meri Adaalat'
# Meri Adalat
# No tiene datos
# 903 'Tomatometer de Ying xiong shen hua del año Ying xiong shen hua'
# No tiene datos
# 904 'Tomatometer de Shenmue: The Movie del año Shenmue: The Movie'
# Shenmue: Season 1
# No tiene datos
# 905 'Tomatometer de Lady Plastic del año Lady Plastic'
# No tiene datos
# 906 'Tomatometer de Narasimha del año Narasimha'
# No tiene datos
# 907 'Tomatometer de Ren she tou du del año Ren she tou du'
# No tiene datos
# 908 'Tomatometer de Aaj Ka Gunda del año Aaj Ka Gunda'
# No tiene datos
# 909 'Tomatometer de Galiyon Ka Badshah del año Galiyon Ka Badshah'
# No tiene datos
# 910 'Tomatometer de Jagira del año Jagira'
# No tiene datos
# 911 'Tomatometer de Citizen del año Citizen'
# The Distinguished Citizen
# No tiene datos
# 912 'Tomatometer de The Devil's Dance del año The Devil's Dance'
# Devil's Dance Pictures
# No tiene datos
# 913 'Tomatometer de Meitantei Conan: Tengoku no countdown del año Meitantei Conan: Tengoku no countdown'
# Detective Conan: Countdown to Heaven
# No tiene datos
# 914 'Tomatometer de Terror am Strand del año Terror am Strand'
# No tiene datos
# 915 'Tomatometer de Git suk geung see del año Git suk geung see'
# No tiene datos
# 916 'Tomatometer de No tiene datos del año Zahreela'
# No tiene datos
# 917 'Tomatometer de Adhipathi del año Adhipathi'
# No tiene datos
# 918 'Tomatometer de Turicon - The Legend of Sollthar del año Turicon - The Legend of Sollthar'
# No tiene datos
# 919 'Tomatometer de Lei ting han fei del año Lei ting han fei'
# No tiene datos
# 920 'Tomatometer de Borsha Badol del año Borsha Badol'
# No tiene datos
# 921 'Tomatometer de Boond del año Boond'
# James Bond 007 - Franchise
# No tiene datos
# 922 'Tomatometer de Mahaarani del año Maharaani'
# Maharani
# No tiene datos
# 923 'Tomatometer de Bager Baccha del año Bager Baccha'
# No tiene datos
# 924 'Tomatometer de Student No. 1 del año Student No. 1'
# Student No. 1
# No tiene datos
# 925 'Tomatometer de Memoir Hokuriku Yakuza War del año Memoir Hokuriku Yakuza War'
# No tiene datos
# 926 'Tomatometer de Bhooka Sher del año Bhooka Sher'
# No tiene datos
# 927 'Tomatometer de Mein Hoon Pyassi Suhagan del año Mein Hoon Pyassi Suhagan'
# No tiene datos
# 928 'Tomatometer de No tiene datos del año Raiva'
# No tiene datos
# 929 'Tomatometer de Guerrero del año Guerrero'
# Sergio Guerrero
# No tiene datos
# 930 'Tomatometer de Baazi del año Baazi'
# Baazi
# No tiene datos
# 931 'Tomatometer de Gare Sindura Dhare Luha del año Gare Sindura Dhare Luha'
# Gare Sindura Dhare Luha (2001)
# No tiene datos
# 932 'Tomatometer de No tiene datos del año Dharma Debata'
# Dharma Debata
# No tiene datos
# 933 'Tomatometer de Rishi del año Rishi'
# Rishi
# No tiene datos
# 934 'Tomatometer de Vaanchinathan del año Vaanchinathan'
# No tiene datos
# 935 'Tomatometer de Narasimha Naidu del año Narasimha Naidu'
# Narasimha Naidu
# No tiene datos
# 936 'Tomatometer de Sri Raja Rajeswari del año Sri Raja Rajeswari'
# Sri Raja Rajeswari
# No tiene datos
# 937 'Tomatometer de Bhadrachalam del año Badrachalam'
# Bhadrachalam
# No tiene datos
# 938 'Tomatometer de Dadagiri del año Dadagiri'
# Dadagiri
# No tiene datos
# 939 'Tomatometer de No tiene datos del año Short6'
# No tiene datos
# 940 'Tomatometer de Thavasi del año Thavasi'
# Thavasi
# No tiene datos
# 941 'Tomatometer de Zhan long del año Zhan long'
# Shang-Chi and the Legend of the Ten Rings
# No tiene datos
# 942 'Tomatometer de Bureizu obu za san del año Bureizu obu za san'
# No tiene datos
# 943 'Tomatometer de Gekijôban kamen raidâ Agito: Purojekutô jî fô del año Gekijôban kamen raidâ Agito: Purojekutô jî fô'
# Kamen Rider Agito: Project G4 (2001)
# No tiene datos
# 944 'Tomatometer de Zakhmi Sherni del año Zakhmi Sherni'
# No tiene datos
# 945 'Tomatometer de Saugandh Geeta Ki del año Saugandh Geeta Ki'
# No tiene datos
# 946 'Tomatometer de Bhagawat Ek Jung del año Bhagawat Ek Jung'
# No tiene datos
# 947 'Tomatometer de Blade Warrior del año Blade Warrior'
# Blade Warrior
# No tiene datos
# 948 'Tomatometer de Smesitel del año Smesitel'
# No tiene datos
# 949 'Tomatometer de Eri Naam Dosti del año Eri Naam Dosti'
# No tiene datos
# 950 'Tomatometer de Badr del año Badr'
# Sawsan Badr
# No tiene datos
# 951 'Tomatometer de Bulgarski Poscikk del año Bulgarski Poscikk'
# No tiene datos
# 952 'Tomatometer de Mayer Samman del año Mayer Samman'
# No tiene datos
# 953 'Tomatometer de Eksperto: Ako ang sasagupa! del año Eksperto: Ako ang sasagupa!'
# No tiene datos
# 954 'Tomatometer de Sikandera del año Sikandera'
# Sikandera
# No tiene datos
# 955 'Tomatometer de Bindiya Mange Bandook del año Bindiya Mange Bandook'
# Bindiya Mange Bandook (2001)
# No tiene datos
# 956 'Tomatometer de Khatron Ke Khiladi del año Khatron Ke Khiladi'
# No tiene datos
# 957 'Tomatometer de Alfred Hitchcock's Gun del año Alfred Hitchcock's Gun'
# No tiene datos
# 958 'Tomatometer de Ek Aur Jung del año Ek Aur Jung'
# Jung_E
# No tiene datos
# 959 'Tomatometer de Daku Bhairav Singh del año Daku Bhairav Singh'
# Daku Bhairav Singh
# No tiene datos
# 960 'Tomatometer de Ek Lootera del año Ek Lootera'
# Lootera
# No tiene datos
# 961 'Tomatometer de Jaydev del año Jaydev'
# Jaydev
# No tiene datos
# 962 'Tomatometer de Rongbaz Badsha del año Rongbaz Badsha'
# No tiene datos
# 963 'Tomatometer de Kothin Bastob del año Kothin Bastob'
# No tiene datos
# 964 'Tomatometer de Chairman del año Chairman'
# Chairman of the Board
# No tiene datos
# 965 'Tomatometer de Cartier del año Cartier'
# No tiene datos
# 966 'Tomatometer de Shola Aur Barood del año Shola Aur Barood'
# No tiene datos
# 967 'Tomatometer de Pratighaath del año Pratighaath'
# No tiene datos
# 968 'Tomatometer de Main Jyoti Tu Jwala del año Main Jyoti Tu Jwala'
# No tiene datos
# 969 'Tomatometer de 5 Rifles del año 5 Rifles'
# No tiene datos
# 970 'Tomatometer de Sindoor Mange Khoon del año Sindoor Mange Khoon'
# Sindoor Mange Khoon (2001)
# No tiene datos
# 971 'Tomatometer de Jungle Ki Sherni del año Jungle Ki Sherni'
# No tiene datos
# 972 'Tomatometer de Junglee Tarzan del año Junglee Tarzan'
# No tiene datos
# 973 'Tomatometer de Rupa Rani Ramkali del año Rupa Rani Ramkali'
# No tiene datos
# 974 'Tomatometer de Badri del año Badri'
# Badri
# No tiene datos
# 975 'Tomatometer de Huccha del año Huccha'
# No tiene datos
# 976 'Tomatometer de Balas en el desierto del año Desert Saints'
# Desert Saints
# No tiene datos
# 977 'Tomatometer de Pluto Nash del año The Adventures of Pluto Nash'
# The Adventures of Pluto Nash
# No tiene datos
# 978 'Tomatometer de Minority Report del año Minority Report'
# Minority Report
# 89
# 979 'Tomatometer de Blade II del año Blade II'
# Blade II
# 57
# 980 'Tomatometer de The gang (Golpe perfecto) del año $windle'
# No tiene datos
# 981 'Tomatometer de The Water Game del año The Water Game'
# No tiene datos
# 982 'Tomatometer de Legend of the Phantom Rider del año Legend of the Phantom Rider'
# Legend of the Phantom Rider
# 50
# 983 'Tomatometer de The Third Society del año The Third Society'
# The Third Society
# No tiene datos
# 984 'Tomatometer de Superbob del año Superbob'
# SuperBob
# No tiene datos
# 985 'Tomatometer de Ángeles enmascarados del año Glory Glory'
# Glory
# No tiene datos
# 986 'Tomatometer de Jóvenes salvajes del año Deuces Wild'
# Deuces Wild
# No tiene datos
# 987 'Tomatometer de Devious Beings del año Devious Beings'
# Devious Beings
# No tiene datos
# 988 'Tomatometer de Daño colateral del año Collateral Damage'
# Collateral Damage
# No tiene datos
# 989 'Tomatometer de Cheerleader Ninjas del año Cheerleader Ninjas'
# Ninja Cheerleaders
# 30
# 990 'Tomatometer de De profesión asesino del año Love and a Bullet'
# Love and a Bullet
# No tiene datos
# 991 'Tomatometer de Equilibrium del año Equilibrium'
# Equilibrium
# 40
# 992 'Tomatometer de Kung Pow: A puñetazo limpio del año Kung Pow: Enter the Fist'
# Kung Pow: Enter the Fist
# No tiene datos
# 993 'Tomatometer de Las cuatro plumas del año The Four Feathers'
# The Four Feathers
# No tiene datos
# 994 'Tomatometer de Windtalkers del año Windtalkers'
# Windtalkers
# 33
# 995 'Tomatometer de La venganza del conde de Montecristo del año The Count of Monte Cristo'
# The Count of Monte Cristo
# No tiene datos
# 996 'Tomatometer de Muere otro día del año Die Another Day'
# Die Another Day
# No tiene datos
# 997 'Tomatometer de The Code Conspiracy del año The Code Conspiracy'
# The Code Conspiracy
# 21
# 998 'Tomatometer de Rollerball del año Rollerball'
# Rollerball
# 67
# 999 'Tomatometer de Gamle mænd i nye biler del año Gamle mænd i nye biler'
# Old Men in New Cars
# No tiene datos
# 1000 'Tomatometer de Aap Mujhe Achche Lagne Lage del año Aap Mujhe Achche Lagne Lage'
# Aap Mujhe Acheche Lagne Lage
# No tiene datos

# %%
#convertimos la lista a dataframe
# df_action_1001_tomatoes = pd.DataFrame(primeras_1001_action_tomatoes)
df_action_1001_tomatoes = pd.DataFrame(primeras_1001_action_tomatoes)


df_action_1001_tomatoes
# Out:
#                    0
# 0                 68
# 1     No tiene datos
# 2     No tiene datos
# 3     No tiene datos
# 4                 50
# ...              ...
# 996   No tiene datos
# 997               21
# 998               67
# 999   No tiene datos
# 1000  No tiene datos
#
# [1001 rows x 1 columns]

# %%
len(total_puntuacion_tomatoes)
# Out:
# 1001

# %%
# df_action_1001_listatomatoes = pd.DataFrame(total_puntuacion_tomatoes)
df_action_1001_listatomatoes = pd.DataFrame(total_puntuacion_tomatoes)

# %%
#convertimos el dataframe a csv
# df_action_1001_tomatoes.to_csv("action_1001_tomatoes.csv")
df_action_1001_tomatoes.to_csv("action_1001_tomatoes.csv")

# %%
# df_action_1001_listatomatoes.to_csv("action_1001_lista_tomatoes.csv")
df_action_1001_listatomatoes.to_csv("action_1001_lista_tomatoes.csv")
